# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
from lxml import html
from lxml.html import fromstring
import urllib.request
from urllib.request import urlopen
import random
import re
import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code

html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-a3b8a10d4a9e37a78f033ef4a4f525f5.css" integrity="sha512-pWLt6abkYhNeAHaDrPVG0yXCtIGRuCkwSUqQpsyN6smAIpIt+Iuq2IZKmoH9l3Cy/9ZnjvVrFZnvFFjGiqE3EA==" media="all" rel="stylesheet">
#    <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-6aa34635057b47b21a5f5ae68b399802.css" integrity="sha512-ECAanBjudv0WlHYfCowVr4moYjiVc/W4YKbONdyiUGUfOpqQbHE44OWSIqV69VKzenfq8zPQtewxS72Pq1Awdg==" media="all" rel="stylesheet">
#     <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-bdd55e67f0ed3e8974c7c941589e8c6a.css" integrity="sha512-N5cRdPCXHO5wgAMNwip0pdEIY0qHrTsCnrGLSLxLiQ8TVr0Mi2xZjL6/CzD3LakUjPrFHc06OU5i0jEQ8hCwJA==" media="all" rel="stylesheet">
#      <meta content="width=device-width" name="viewport"/>
#      <title>
#       Trending  developers on GitHub today · GitHub
#      </title>
#      <meta content="GitHub is where people build software. More than 28 million people use GitHub to discover, fork, and contribute to over 85 million projects." name="description"/>
#      <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
#      <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
#      <meta content="1401488693436528" property="fb:app_id"/>
#      <meta content="https://github.com" property="og:url"/>
#      <meta content="GitHub" property="og:site_name"/>
#      <meta content="Build software better, together" property="og:title"/>
#      <meta content="GitHub is where people build software. More than 28 million people use GitHub to discover, fork, and contribute to over 85 million projects." property="og:description"/>
#      <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
#      <meta content="image/png" property="og:image:type"/>
#      <meta content="1200" property="og:image:width"/>
#      <meta content="1200" property="og:image:height"/>
#      <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
#      <meta content="image/png" property="og:image:type"/>
#      <meta content="1200" property="og:image:width"/>
#      <meta content="620" property="og:image:height"/>
#      <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
#      <meta content="image/png" property="og:image:type"/>
#      <meta content="1200" property="og:image:width"/>
#      <meta content="620" property="og:image:height"/>
#      <link href="https://github.githubassets.com/" rel="assets"/>
#      <meta content="1000" name="pjax-timeout"/>
#      <meta content="D37B:5C6D:A48CEC:1471470:5C4D5298" data-pjax-transient="" name="request-id"/>
#      <meta data-pjax-transient="" name="selected-link" value="trending_developers"/>
#      <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
#      <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
#      <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
#      <meta content="collector.githubapp.com" name="octolytics-host">
#       <meta content="github" name="octolytics-app-id">
#        <meta content="https://collector.githubapp.com/github-external/browser_event" name="octolytics-event-url">
#         <meta content="D37B:5C6D:A48CEC:1471470:5C4D5298" name="octolytics-dimension-request_id">
#          <meta content="iad" name="octolytics-dimension-region_edge">
#           <meta content="iad" name="octolytics-dimension-region_render">
#            <meta content="UA-3769691-2" name="google-analytics"/>
#            <meta class="js-ga-set" content="Logged Out" name="dimension1"/>
#            <meta content="github.com" name="hostname"/>
#            <meta content="" name="user-login"/>
#            <meta content="github.com" name="expected-hostname"/>
#            <meta content="N2RiODM5YTNiNWI1ZjkwOWIwNmQwYTc5YWFkYTliN2I0OWM5ODdiNzI1YWUwOTcyZDJiY2E5YTAyMzk5ODNhNHx7InJlbW90ZV9hZGRyZXNzIjoiOTkuNzMuMTMxLjE0NyIsInJlcXVlc3RfaWQiOiJEMzdCOjVDNkQ6QTQ4Q0VDOjE0NzE0NzA6NUM0RDUyOTgiLCJ0aW1lc3RhbXAiOjE1NDg1NzEyODksImhvc3QiOiJnaXRodWIuY29tIn0=" name="js-proxy-site-detection-payload"/>
#            <meta content="UNIVERSE_BANNER,MARKETPLACE_PLAN_RESTRICTION_EDITOR" name="enabled-features"/>
#            <meta content="2a38cce81a73b7340a234575193527b25474b185" name="html-safe-nonce"/>
#            <meta content="bf820d79d0eaa09635947066da0f6259" http-equiv="x-pjax-version"/>
#            <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-bdd55e67f0ed3e8974c7c941589e8c6a.css" integrity="sha512-N5cRdPCXHO5wgAMNwip0pdEIY0qHrTsCnrGLSLxLiQ8TVr0Mi2xZjL6/CzD3LakUjPrFHc06OU5i0jEQ8hCwJA==" media="all" rel="stylesheet">
#             <link data-pjax-transient="" href="https://github.com/trending/developers" rel="canonical"/>
#             <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
#             <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
#             <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
#             <link class="js-site-favicon" href="https://github.githubassets.com/favicon.ico" rel="icon" type="image/x-icon"/>
#             <meta content="#1e2327" name="theme-color"/>
#             <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
#            </link>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="logged-out env-production page-responsive min-width-0">
#   <div class="position-relative js-header-wrapper">
#    <a class="px-2 py-4 bg-blue text-white show-on-focus js-skip-to-content" href="#start-of-content" tabindex="1">
#     Skip to content
#    </a>
#    <div class="pjax-loader-bar" id="js-pjax-loader-bar">
#     <div class="progress">
#     </div>
#    </div>
#    <header class="Header header-logged-out js-details-container Details position-relative f4 py-3" role="banner">
#     <div class="container-lg d-lg-flex flex-items-center p-responsive">
#      <div class="d-flex flex-justify-between flex-items-center">
#       <a aria-label="Homepage" class="mr-4" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
#        <svg aria-hidden="true" class="octicon octicon-mark-github text-white" height="32" version="1.1" viewbox="0 0 16 16" width="32">
#         <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </a>
#       <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
#       </div>
#       <div class="d-flex flex-items-center">
#        <a class="d-inline-block d-lg-none f5 text-white no-underline border border-gray-dark rounded-2 px-2 py-1 mr-3 mr-sm-5" data-ga-click="(Logged out) Header, clicked Sign up, text:sign-up" href="/join?source=header">
#         Sign up
#        </a>
#        <button aria-expanded="false" aria-label="Toggle navigation" class="btn-link d-lg-none mt-1 js-details-target" type="button">
#         <svg aria-hidden="true" class="octicon octicon-three-bars text-white" height="24" version="1.1" viewbox="0 0 12 16" width="18">
#          <path d="M11.41 9H.59C0 9 0 8.59 0 8c0-.59 0-1 .59-1H11.4c.59 0 .59.41.59 1 0 .59 0 1-.59 1h.01zm0-4H.59C0 5 0 4.59 0 4c0-.59 0-1 .59-1H11.4c.59 0 .59.41.59 1 0 .59 0 1-.59 1h.01zM.59 11H11.4c.59 0 .59.41.59 1 0 .59 0 1-.59 1H.59C0 13 0 12.59 0 12c0-.59 0-1 .59-1z" fill-rule="evenodd">
#          </path>
#         </svg>
#        </button>
#       </div>
#      </div>
#      <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
#       <div class="d-flex d-lg-none flex-justify-end border-bottom bg-gray-light p-3">
#        <button aria-expanded="false" aria-label="Toggle navigation" class="btn-link js-details-target" type="button">
#         <svg aria-hidden="true" class="octicon octicon-x text-gray" height="24" version="1.1" viewbox="0 0 12 16" width="18">
#          <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#          </path>
#         </svg>
#        </button>
#       </div>
#       <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
#        <ul class="d-lg-flex list-style-none">
#         <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
#          <details class="HeaderMenu-details details-overlay details-reset width-full">
#           <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#            Why GitHub?
#            <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
#             <path d="M1,1l6.2,6L13,1">
#             </path>
#            </svg>
#           </summary>
#           <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
#            <a class="py-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Features" href="/features">
#             Features
#             <span class="Bump-link-symbol float-right text-normal text-gray-light">
#              →
#             </span>
#            </a>
#            <ul class="list-style-none f5 pb-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Code review" href="/features/code-review/">
#               Code review
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Project management" href="/features/project-management/">
#               Project management
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Integrations" href="/features/integrations">
#               Integrations
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray" data-ga-click="(Logged out) Header, go to Actions" href="/features/actions">
#               Actions
#              </a>
#              <li class="edge-item-fix">
#               <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Team management" href="/features#team-management">
#                Team management
#               </a>
#              </li>
#              <li class="edge-item-fix">
#               <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Social coding" href="/features#social-coding">
#                Social coding
#               </a>
#              </li>
#              <li class="edge-item-fix">
#               <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Documentation" href="/features#documentation">
#                Documentation
#               </a>
#              </li>
#              <li class="edge-item-fix">
#               <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Code hosting" href="/features#code-hosting">
#                Code hosting
#               </a>
#              </li>
#             </li>
#            </ul>
#            <ul class="list-style-none mb-0 border-lg-top pt-lg-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Case studies" href="/case-studies">
#               Case Studies
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Security" href="/security">
#               Security
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </details>
#         </li>
#         <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">
#          <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, click, go to Enterprise" href="/enterprise">
#           Enterprise
#          </a>
#         </li>
#         <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
#          <details class="HeaderMenu-details details-overlay details-reset width-full">
#           <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#            Explore
#            <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
#             <path d="M1,1l6.2,6L13,1">
#             </path>
#            </svg>
#           </summary>
#           <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 pt-2 pb-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
#            <ul class="list-style-none mb-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Features" href="/explore">
#               Explore GitHub
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#            </ul>
#            <h4 class="text-gray-light text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">
#             Learn &amp; contribute
#            </h4>
#            <ul class="list-style-none mb-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Topics" href="/topics">
#               Topics
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Collections" href="/collections">
#               Collections
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Trending" href="/trending">
#               Trending
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Learning lab" href="https://lab.github.com/">
#               Learning Lab
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Open source guides" href="https://opensource.guide">
#               Open source guides
#              </a>
#             </li>
#            </ul>
#            <h4 class="text-gray-light text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">
#             Connect with others
#            </h4>
#            <ul class="list-style-none mb-0">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Events" href="/events">
#               Events
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Community forum" href="https://github.community">
#               Community forum
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 pb-0 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to GitHub Education" href="https://education.github.com">
#               GitHub Education
#              </a>
#             </li>
#            </ul>
#           </div>
#          </details>
#         </li>
#         <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">
#          <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Marketplace" href="/marketplace">
#           Marketplace
#          </a>
#         </li>
#         <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
#          <details class="HeaderMenu-details details-overlay details-reset width-full">
#           <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#            Pricing
#            <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
#             <path d="M1,1l6.2,6L13,1">
#             </path>
#            </svg>
#           </summary>
#           <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 pt-2 pb-4 mt-0 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
#            <a class="pb-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Pricing" href="/pricing">
#             Plans
#             <span class="Bump-link-symbol float-right text-normal text-gray-light">
#              →
#             </span>
#            </a>
#            <ul class="list-style-none mb-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Compare features" href="/pricing#feature-comparison">
#               Compare plans
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Compare features" href="https://enterprise.github.com/contact">
#               Contact Sales
#              </a>
#             </li>
#            </ul>
#            <ul class="list-style-none mb-0 border-lg-top pt-lg-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Nonprofits" href="/nonprofit">
#               Nonprofit
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 pb-0 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Education" href="https://education.github.com">
#               Education
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </details>
#         </li>
#        </ul>
#       </nav>
#       <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
#        <div class="d-lg-flex mr-lg-3 mb-3 mb-lg-0">
#         <div aria-expanded="false" aria-haspopup="listbox" aria-label="Search or jump to" aria-owns="jump-to-results" class="header-search js-site-search position-relative js-jump-to" role="combobox">
#          <div class="position-relative">
#           <!-- '"` -->
#           <!-- </textarea></xmp> -->
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#   </div>
#  </body>
# </html>
# <form accept-charset="UTF-8" action="/search" class="js-site-search-form" data-unscoped-search-url="/search" method="get">
#  <input name="utf8" type="hidden" value="✓"/>
#  <label class="form-control header-search-wrapper header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center js-chromeless-input-container">
#   <input aria-autocomplete="list" aria-controls="jump-to-results" aria-label="Search GitHub" autocapitalize="off" autocomplete="off" class="form-control header-search-input jump-to-field js-jump-to-field js-site-search-focus" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations#csrf-token=DzKqKFxDYNQyXl77UgIU/0eDPSHvdacBxCx8tCLPe/COGPa206bjDAEpIrrYCeHuLYHUwvZ6S6hqrUfIAkqt0g==" data-scoped-placeholder="Search" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search GitHub" spellcheck="false" type="text" value=""/>
#   <input class="js-site-search-type-field" name="type" type="hidden"/>
#   <img alt="" class="mr-2 header-search-key-slash" src="https://github.githubassets.com/images/search-key-slash.svg"/>
#   <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
#    <ul class="d-none js-jump-to-suggestions-template-container">
#     <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
#      <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
#       <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#        <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16">
#         <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16">
#         <path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#         <path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </div>
#       <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#       <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#       </div>
#       <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#        </span>
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#        </span>
#        <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#       <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#      </a>
#     </li>
#    </ul>
#    <ul class="d-none js-jump-to-no-results-template-container">
#     <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
#      <span class="text-gray">
#       No suggested jump to results
#      </span>
#     </li>
#    </ul>
#    <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
#     <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
#      <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
#       <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#        <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16">
#         <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16">
#         <path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#         <path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </div>
#       <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#       <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#       </div>
#       <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#        </span>
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#        </span>
#        <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#       <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#      </a>
#     </li>
#     <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
#      <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
#       <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#        <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16">
#         <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16">
#         <path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#         <path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </div>
#       <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#       <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#       </div>
#       <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#        </span>
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#        </span>
#        <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#       <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#      </a>
#     </li>
#    </ul>
#   </div>
#  </label>
# </form>
# <a class="HeaderMenu-link no-underline mr-3" data-ga-click="(Logged out) Header, clicked Sign in, text:sign-in" href="/login?return_to=%2Ftrending%2Fdevelopers">
#  Sign in
# </a>
# <a class="HeaderMenu-link d-inline-block no-underline border border-gray-dark rounded-1 px-2 py-1" data-ga-click="(Logged out) Header, clicked Sign up, text:sign-up" href="/join?source=header">
#  Sign up
# </a>
# <div class="show-on-focus" id="start-of-content">
# </div>
# <div id="js-flash-container">
# </div>
# <div class="application-main" data-commit-hovercards-enabled="" role="main">
#  <div data-pjax-container="" id="container">
#   <div class="bg-gray-light border-bottom">
#    <div class="container-lg p-responsive text-center py-6">
#     <h1 class="f0-light">
#      Trending
#     </h1>
#     <p class="f4 text-gray col-md-8 mx-auto">
#      These are the organizations and developers building the hot tools today.
#     </p>
#    </div>
#   </div>
#   <div class="explore-pjax-container container-lg p-responsive clearfix">
#    <div class="gutter-md pt-6">
#     <div class="col-md-9 float-md-left">
#      <div class="tabnav">
#       <div class="float-sm-right mb-2 mb-sm-0">
#        <div class="select-menu js-menu-container js-select-menu select-menu-modal-right">
#         <button aria-expanded="false" aria-haspopup="true" class="btn btn-sm select-menu-button js-menu-target" type="button">
#          <i>
#           Trending:
#          </i>
#          <span class="js-select-button">
#           today
#          </span>
#         </button>
#         <div class="select-menu-modal-holder js-menu-content js-navigation-container">
#          <div class="select-menu-modal">
#           <div class="select-menu-header">
#            <svg aria-label="Close" class="octicon octicon-x js-menu-close" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="select-menu-title">
#             Adjust time span
#            </span>
#           </div>
#           <div class="select-menu-list" role="menu">
#            <div>
#             <a class="select-menu-item js-navigation-item selected" data-pjax="" href="/trending/developers?since=daily">
#              <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#               <path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="select-menu-item-text js-select-button-text">
#               today
#              </span>
#             </a>
#             <a class="select-menu-item js-navigation-item" data-pjax="" href="/trending/developers?since=weekly">
#              <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#               <path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="select-menu-item-text js-select-button-text">
#               this week
#              </span>
#             </a>
#             <a class="select-menu-item js-navigation-item" data-pjax="" href="/trending/developers?since=monthly">
#              <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#               <path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="select-menu-item-text js-select-button-text">
#               this month
#              </span>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <nav class="tabnav-tabs" data-pjax="">
#        <a class="js-selected-navigation-item tabnav-tab" data-selected-links="trending_repositories /trending" href="/trending">
#         Repositories
#        </a>
#        <a aria-current="page" class="js-selected-navigation-item selected tabnav-tab" data-selected-links="trending_developers /trending/developers" href="/trending/developers">
#         Developers
#        </a>
#       </nav>
#      </div>
#      <div class="explore-content">
#       <ol class="list-style-none">
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-joewalnes">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-joewalnes" style="width: 16px;">
#           1
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=48950" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/joewalnes">
#            <img alt="@joewalnes" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/48950?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/joewalnes">
#             joewalnes
#             <span class="text-gray text-bold">
#              (Joe Walnes)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/joewalnes/websocketd">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="websocketd">
#              websocketd
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             Turn any program that uses STDIN/STDOUT into a WebSocket server. Like inetd, but for WebSockets.
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-trimstray">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-trimstray" style="width: 16px;">
#           2
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=31127917" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/trimstray">
#            <img alt="@trimstray" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/31127917?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/trimstray">
#             trimstray
#             <span class="text-gray text-bold">
#              (@trimstray)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/trimstray/the-book-of-secret-knowledge">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="the-book-of-secret-knowledge">
#              the-book-of-secret-knowledge
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             <g-emoji alias="zap" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/26a1.png">
#              ⚡️
#             </g-emoji>
#             A collection of awesome lists, manuals, blogs, hacks, one-liners, cli/web tools and more. Especially for System and Network Administrators, DevOps, Pentesters or Security Researchers.
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-ForrestKnight">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-ForrestKnight" style="width: 16px;">
#           3
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=15620553" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/ForrestKnight">
#            <img alt="@ForrestKnight" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/15620553?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/ForrestKnight">
#             ForrestKnight
#             <span class="text-gray text-bold">
#              (Forrest Knight)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/ForrestKnight/open-source-cs">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="open-source-cs">
#              open-source-cs
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             Video discussing this curriculum:
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-charlax">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-charlax" style="width: 16px;">
#           4
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=120501" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/charlax">
#            <img alt="@charlax" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/120501?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/charlax">
#             charlax
#             <span class="text-gray text-bold">
#              (Charles-Axel Dein)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/charlax/professional-programming">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="professional-programming">
#              professional-programming
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             A collection of full-stack resources for programmers.
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-boazsegev">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-boazsegev" style="width: 16px;">
#           5
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=870622" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/boazsegev">
#            <img alt="@boazsegev" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/870622?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/boazsegev">
#             boazsegev
#             <span class="text-gray text-bold">
#              (Bo)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/boazsegev/facil.io">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="facil.io">
#              facil.io
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             Your high performance web application C framework
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-alibaba">
#         <div class="d-flex">
# ...
#           </path>
#          </svg>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="protip protip-callout">
#       <strong class="protip">
#        ProTip!
#       </strong>
#       Looking for most starred  repositories?
#       <a href="/search?q=stars%3A%3E1&amp;s=stars&amp;type=Repositories">
#        Try this search
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="modal-backdrop js-touch-events">
#  </div>
# </div>
# <div class="footer mt-6" role="contentinfo">
#  <div class="container-lg p-responsive">
#   <div class="d-flex flex-wrap py-5 mb-5">
#    <div class="col-12 col-lg-4 mb-5">
#     <a aria-label="Go to GitHub homepage" class="text-gray-dark" data-ga-click="Footer, go to home, text:home" href="/">
#      <svg aria-hidden="true" class="octicon octicon-logo-github" height="30" version="1.1" viewbox="0 0 45 16" width="84">
#       <path d="M18.53 12.03h-.02c.009 0 .015.01.024.011h.006l-.01-.01zm.004.011c-.093.001-.327.05-.574.05-.78 0-1.05-.36-1.05-.83V8.13h1.59c.09 0 .16-.08.16-.19v-1.7c0-.09-.08-.17-.16-.17h-1.59V3.96c0-.08-.05-.13-.14-.13h-2.16c-.09 0-.14.05-.14.13v2.17s-1.09.27-1.16.28c-.08.02-.13.09-.13.17v1.36c0 .11.08.19.17.19h1.11v3.28c0 2.44 1.7 2.69 2.86 2.69.53 0 1.17-.17 1.27-.22.06-.02.09-.09.09-.16v-1.5a.177.177 0 0 0-.146-.18zM42.23 9.84c0-1.81-.73-2.05-1.5-1.97-.6.04-1.08.34-1.08.34v3.52s.49.34 1.22.36c1.03.03 1.36-.34 1.36-2.25zm2.43-.16c0 3.43-1.11 4.41-3.05 4.41-1.64 0-2.52-.83-2.52-.83s-.04.46-.09.52c-.03.06-.08.08-.14.08h-1.48c-.1 0-.19-.08-.19-.17l.02-11.11c0-.09.08-.17.17-.17h2.13c.09 0 .17.08.17.17v3.77s.82-.53 2.02-.53l-.01-.02c1.2 0 2.97.45 2.97 3.88zm-8.72-3.61h-2.1c-.11 0-.17.08-.17.19v5.44s-.55.39-1.3.39-.97-.34-.97-1.09V6.25c0-.09-.08-.17-.17-.17h-2.14c-.09 0-.17.08-.17.17v5.11c0 2.2 1.23 2.75 2.92 2.75 1.39 0 2.52-.77 2.52-.77s.05.39.08.45c.02.05.09.09.16.09h1.34c.11 0 .17-.08.17-.17l.02-7.47c0-.09-.08-.17-.19-.17zm-23.7-.01h-2.13c-.09 0-.17.09-.17.2v7.34c0 .2.13.27.3.27h1.92c.2 0 .25-.09.25-.27V6.23c0-.09-.08-.17-.17-.17zm-1.05-3.38c-.77 0-1.38.61-1.38 1.38 0 .77.61 1.38 1.38 1.38.75 0 1.36-.61 1.36-1.38 0-.77-.61-1.38-1.36-1.38zm16.49-.25h-2.11c-.09 0-.17.08-.17.17v4.09h-3.31V2.6c0-.09-.08-.17-.17-.17h-2.13c-.09 0-.17.08-.17.17v11.11c0 .09.09.17.17.17h2.13c.09 0 .17-.08.17-.17V8.96h3.31l-.02 4.75c0 .09.08.17.17.17h2.13c.09 0 .17-.08.17-.17V2.6c0-.09-.08-.17-.17-.17zM8.81 7.35v5.74c0 .04-.01.11-.06.13 0 0-1.25.89-3.31.89-2.49 0-5.44-.78-5.44-5.92S2.58 1.99 5.1 2c2.18 0 3.06.49 3.2.58.04.05.06.09.06.14L7.94 4.5c0 .09-.09.2-.2.17-.36-.11-.9-.33-2.17-.33-1.47 0-3.05.42-3.05 3.73s1.5 3.7 2.58 3.7c.92 0 1.25-.11 1.25-.11v-2.3H4.88c-.11 0-.19-.08-.19-.17V7.35c0-.09.08-.17.19-.17h3.74c.11 0 .19.08.19.17z" fill-rule="evenodd">
#       </path>
#      </svg>
#     </a>
#    </div>
#    <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-lg-0 pl-lg-4">
#     <h4 class="mb-3 text-mono text-gray-light text-normal">
#      Product
#     </h4>
#     <ul class="list-style-none text-gray f5">
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to features, text:features" href="/features">
#        Features
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to security, text:security" href="/security">
#        Security
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to enterprise, text:enterprise" href="/enterprise">
#        Enterprise
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to case studies, text:case studies" href="/case-studies?type=customers">
#        Case studies
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to pricing, text:pricing" href="/pricing">
#        Pricing
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to resources, text:resources" href="https://resources.github.com">
#        Resources
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-md-0 pl-md-4">
#     <h4 class="mb-3 text-mono text-gray-light text-normal">
#      Platform
#     </h4>
#     <ul class="list-style-none f5">
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to api, text:api" href="https://developer.github.com">
#        Developer API
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to partner, text:partner" href="http://partner.github.com/">
#        Partners
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to atom, text:atom" href="https://atom.io">
#        Atom
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to electron, text:electron" href="http://electron.atom.io/">
#        Electron
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to desktop, text:desktop" href="https://desktop.github.com/">
#        GitHub Desktop
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-md-0 pl-md-4">
#     <h4 class="mb-3 text-mono text-gray-light text-normal">
#      Support
#     </h4>
#     <ul class="list-style-none f5">
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to help, text:help" href="https://help.github.com">
#        Help
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to community, text:community" href="https://github.community">
#        Community Forum
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to training, text:training" href="https://services.github.com/">
#        Training
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to status, text:status" href="https://githubstatus.com/">
#        Status
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to contact, text:contact" href="https://github.com/contact">
#        Contact GitHub
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-md-0 pl-md-4">
#     <h4 class="mb-3 text-mono text-gray-light text-normal">
#      Company
#     </h4>
#     <ul class="list-style-none f5">
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to about, text:about" href="https://github.com/about">
#        About
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to blog, text:blog" href="https://github.blog">
#        Blog
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to careers, text:careers" href="/about/careers">
#        Careers
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to press, text:press" href="/about/press">
#        Press
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to shop, text:shop" href="https://shop.github.com">
#        Shop
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </div>
#  <div class="bg-gray-light">
#   <div class="container-lg p-responsive f6 py-4 d-sm-flex flex-justify-between flex-row-reverse flex-items-center">
#    <ul class="list-style-none d-flex flex-items-center mb-3 mb-sm-0 lh-condensed-ultra">
#     <li class="mr-3">
#      <a data-ga-click="Footer, go to Twitter, text:twitter" href="https://twitter.com/github" style="color: #959da5;" title="GitHub on Twitter">
#       <svg class="d-block" height="18" viewbox="0 0 273.5 222.3" xmlns="http://www.w3.org/2000/svg">
#        <path d="M273.5 26.3a109.77 109.77 0 0 1-32.2 8.8 56.07 56.07 0 0 0 24.7-31 113.39 113.39 0 0 1-35.7 13.6 56.1 56.1 0 0 0-97 38.4 54 54 0 0 0 1.5 12.8A159.68 159.68 0 0 1 19.1 10.3a56.12 56.12 0 0 0 17.4 74.9 56.06 56.06 0 0 1-25.4-7v.7a56.11 56.11 0 0 0 45 55 55.65 55.65 0 0 1-14.8 2 62.39 62.39 0 0 1-10.6-1 56.24 56.24 0 0 0 52.4 39 112.87 112.87 0 0 1-69.7 24 119 119 0 0 1-13.4-.8 158.83 158.83 0 0 0 86 25.2c103.2 0 159.6-85.5 159.6-159.6 0-2.4-.1-4.9-.2-7.3a114.25 114.25 0 0 0 28.1-29.1" fill="currentColor">
#        </path>
#       </svg>
#      </a>
#     </li>
#     <li class="mr-3">
#      <a data-ga-click="Footer, go to Facebook, text:facebook" href="https://www.facebook.com/GitHub" style="color: #959da5;" title="GitHub on Facebook">
#       <svg class="d-block" height="18" viewbox="0 0 15.3 15.4" xmlns="http://www.w3.org/2000/svg">
#        <path d="M14.5 0H.8a.88.88 0 0 0-.8.9v13.6a.88.88 0 0 0 .8.9h7.3v-6h-2V7.1h2V5.4a2.87 2.87 0 0 1 2.5-3.1h.5a10.87 10.87 0 0 1 1.8.1v2.1h-1.3c-1 0-1.1.5-1.1 1.1v1.5h2.3l-.3 2.3h-2v5.9h3.9a.88.88 0 0 0 .9-.8V.8a.86.86 0 0 0-.8-.8z" fill="currentColor">
#        </path>
#       </svg>
#      </a>
#     </li>
#     <li class="mr-3">
#      <a data-ga-click="Footer, go to YouTube, text:youtube" href="https://www.youtube.com/github" style="color: #959da5;" title="GitHub on YouTube">
#       <svg class="d-block" height="16" viewbox="0 0 19.17 13.6" xmlns="http://www.w3.org/2000/svg">
#        <path d="M18.77 2.13A2.4 2.4 0 0 0 17.09.42C15.59 0 9.58 0 9.58 0a57.55 57.55 0 0 0-7.5.4A2.49 2.49 0 0 0 .39 2.13 26.27 26.27 0 0 0 0 6.8a26.15 26.15 0 0 0 .39 4.67 2.43 2.43 0 0 0 1.69 1.71c1.52.42 7.5.42 7.5.42a57.69 57.69 0 0 0 7.51-.4 2.4 2.4 0 0 0 1.68-1.71 25.63 25.63 0 0 0 .4-4.67 24 24 0 0 0-.4-4.69zM7.67 9.71V3.89l5 2.91z" fill="currentColor">
#        </path>
#       </svg>
#      </a>
#     </li>
#     <li class="mr-3 flex-self-start">
#      <a data-ga-click="Footer, go to Linkedin, text:linkedin" href="https://www.linkedin.com/company/github" style="color: #959da5;" title="GitHub on Linkedin">
#       <svg class="d-block" height="18" viewbox="0 0 19 18" xmlns="http://www.w3.org/2000/svg">
#        <path d="M3.94 2A2 2 0 1 1 2 0a2 2 0 0 1 1.94 2zM4 5.48H0V18h4zm6.32 0H6.34V18h3.94v-6.57c0-3.66 4.77-4 4.77 0V18H19v-7.93c0-6.17-7.06-5.94-8.72-2.91z" fill="currentColor">
#        </path>
#       </svg>
#      </a>
#     </li>
#     <li>
#      <a data-ga-click="Footer, go to github's org, text:github" href="https://github.com/github" style="color: #959da5;" title="GitHub's organization">
#       <svg alt="GitHub" aria-hidden="true" class="octicon octicon-mark-github d-block" height="20" version="1.1" viewbox="0 0 16 16" width="20">
#        <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd">
#        </path>
#       </svg>
#      </a>
#     </li>
#    </ul>
#    <ul class="list-style-none d-flex text-gray">
#     <li class="mr-3">
#      © 2019 GitHub, Inc.
#     </li>
#     <li class="mr-3">
#      <a class="link-gray" data-ga-click="Footer, go to terms, text:terms" href="/site/terms">
#       Terms
#      </a>
#     </li>
#     <li>
#      <a class="link-gray" data-ga-click="Footer, go to privacy, text:privacy" href="/site/privacy">
#       Privacy
#      </a>
#     </li>
#    </ul>
#   </div>
#  </div>
# </div>
# <div class="ajax-error-message flash flash-error" id="ajax-error-message">
#  <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#   <path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 0 0 0 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 0 0 .01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd">
#   </path>
#  </svg>
#  <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
#   <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#    <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#    </path>
#   </svg>
#  </button>
#  You can’t perform that action at this time.
# </div>
# <script crossorigin="anonymous" integrity="sha512-Mp0nAOFvmE8PVQP49TPVMbQBLb+lpf3gu9GF1CPqybGGzl/8KEKDTKzuJpxxd5xF8HUi85xKPkssLtVVdLKtlw==" src="https://github.githubassets.com/assets/compat-6e5ed2648dae3be3f9358af5732a780f.js" type="application/javascript">
# </script>
# <script crossorigin="anonymous" integrity="sha512-munE9dNLI0m3pEuNvjoQ8yUQPQuAU2ERx7YI54vEL0SqY7xa6rwJfB7m+mt7N9uXSShm+/8OjEDMWNeNXYA6aQ==" src="https://github.githubassets.com/assets/frameworks-6b1e5c0082cc318bd85fc3f598b31949.js" type="application/javascript">
# </script>
# <script async="async" crossorigin="anonymous" integrity="sha512-/1Dm7YaiDDQ5qvDIy2RTdEsKik/YA0zyw2SUZSYVlARXSEaCjmev/C2icBVlVAWt1LYGXZsrpf7TeT1+t/wTNQ==" src="https://github.githubassets.com/assets/github-d22fd39d1493a998022914a62e071a04.js" type="application/javascript">
# </script>
# <div class="js-stale-session-flash stale-session-flash flash flash-warn flash-banner d-none">
#  <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#   <path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 0 0 0 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 0 0 .01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd">
#   </path>
#  </svg>
#  <span class="signed-in-tab-flash">
#   You signed in with another tab or window.
#   <a href="">
#    Reload
#   </a>
#   to refresh your session.
#  </span>
#  <span class="signed-out-tab-flash">
#   You signed out in another tab or window.
#   <a href="">
#    Reload
#   </a>
#   to refresh your session.
#  </span>
# </div>
# <template id="site-details-dialog">
#  <details class="details-reset details-overlay details-overlay-dark lh-default text-gray-dark" open="">
#   <summary aria-haspopup="dialog" aria-label="Close dialog">
#   </summary>
#   <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast">
#    <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
#     <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#      <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#      </path>
#     </svg>
#    </button>
#    <div class="octocat-spinner my-6 js-details-dialog-spinner">
#    </div>
#   </details-dialog>
#  </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
#  <div class="Popover-message Popover-message--bottom-left Popover-message--large Box box-shadow-large" style="width:360px;">
#  </div>
# </div>
# <div class="sr-only" id="hovercard-aria-description">
#  Press h to open a hovercard with more details.
# </div>
# <div aria-live="polite" class="js-global-screen-reader-notice sr-only">
# </div>

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code
names = soup.find_all('h2',{'class':'f3 text-normal'})

results = [name.text.strip().replace(' ','').replace('\n\n', ' ') for name in names]

results
# Out:
# ['joewalnes (JoeWalnes)',
#  'trimstray (@trimstray)',
#  'ForrestKnight (ForrestKnight)',
#  'charlax (Charles-AxelDein)',
#  'boazsegev (Bo)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'revery-ui (revery-ui)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'google (Google)',
#  'DevonCrawford (DevonCrawford)',
#  'apache (TheApacheSoftwareFoundation)',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'cloudfetch',
#  'fastai (fast.ai)',
#  'myshov (AlexanderMyshov)',
#  'vuejs (vuejs)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'script-8',
#  'torvalds (LinusTorvalds)',
#  'tranbathanhtung (TrầnBáThanhTùng)',
#  'komeiji-satori (神楽坂覚々)',
#  'SebLague (SebastianLague)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-a3b8a10d4a9e37a78f033ef4a4f525f5.css" integrity="sha512-pWLt6abkYhNeAHaDrPVG0yXCtIGRuCkwSUqQpsyN6smAIpIt+Iuq2IZKmoH9l3Cy/9ZnjvVrFZnvFFjGiqE3EA==" media="all" rel="stylesheet">
#    <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-6aa34635057b47b21a5f5ae68b399802.css" integrity="sha512-ECAanBjudv0WlHYfCowVr4moYjiVc/W4YKbONdyiUGUfOpqQbHE44OWSIqV69VKzenfq8zPQtewxS72Pq1Awdg==" media="all" rel="stylesheet">
#     <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-bdd55e67f0ed3e8974c7c941589e8c6a.css" integrity="sha512-N5cRdPCXHO5wgAMNwip0pdEIY0qHrTsCnrGLSLxLiQ8TVr0Mi2xZjL6/CzD3LakUjPrFHc06OU5i0jEQ8hCwJA==" media="all" rel="stylesheet">
#      <meta content="width=device-width" name="viewport"/>
#      <title>
#       Trending  developers on GitHub today · GitHub
#      </title>
#      <meta content="GitHub is where people build software. More than 28 million people use GitHub to discover, fork, and contribute to over 85 million projects." name="description"/>
#      <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
#      <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
#      <meta content="1401488693436528" property="fb:app_id"/>
#      <meta content="https://github.com" property="og:url"/>
#      <meta content="GitHub" property="og:site_name"/>
#      <meta content="Build software better, together" property="og:title"/>
#      <meta content="GitHub is where people build software. More than 28 million people use GitHub to discover, fork, and contribute to over 85 million projects." property="og:description"/>
#      <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
#      <meta content="image/png" property="og:image:type"/>
#      <meta content="1200" property="og:image:width"/>
#      <meta content="1200" property="og:image:height"/>
#      <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
#      <meta content="image/png" property="og:image:type"/>
#      <meta content="1200" property="og:image:width"/>
#      <meta content="620" property="og:image:height"/>
#      <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
#      <meta content="image/png" property="og:image:type"/>
#      <meta content="1200" property="og:image:width"/>
#      <meta content="620" property="og:image:height"/>
#      <link href="https://github.githubassets.com/" rel="assets"/>
#      <meta content="1000" name="pjax-timeout"/>
#      <meta content="D3A4:5C6B:39ECFA:7B4002:5C4D538D" data-pjax-transient="" name="request-id"/>
#      <meta data-pjax-transient="" name="selected-link" value="trending_developers"/>
#      <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
#      <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
#      <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
#      <meta content="collector.githubapp.com" name="octolytics-host">
#       <meta content="github" name="octolytics-app-id">
#        <meta content="https://collector.githubapp.com/github-external/browser_event" name="octolytics-event-url">
#         <meta content="D3A4:5C6B:39ECFA:7B4002:5C4D538D" name="octolytics-dimension-request_id">
#          <meta content="iad" name="octolytics-dimension-region_edge">
#           <meta content="iad" name="octolytics-dimension-region_render">
#            <meta content="UA-3769691-2" name="google-analytics"/>
#            <meta class="js-ga-set" content="Logged Out" name="dimension1"/>
#            <meta content="github.com" name="hostname"/>
#            <meta content="" name="user-login"/>
#            <meta content="github.com" name="expected-hostname"/>
#            <meta content="ODg3YzhhZTgzNjQ0OGU5MWM3MjBlMDMzMGY5ODNiYzliMzYzMjNmZTY3MTViNzk0N2Y2MWVmODNmZWVjZDc4N3x7InJlbW90ZV9hZGRyZXNzIjoiOTkuNzMuMTMxLjE0NyIsInJlcXVlc3RfaWQiOiJEM0E0OjVDNkI6MzlFQ0ZBOjdCNDAwMjo1QzRENTM4RCIsInRpbWVzdGFtcCI6MTU0ODU3MTUzMywiaG9zdCI6ImdpdGh1Yi5jb20ifQ==" name="js-proxy-site-detection-payload"/>
#            <meta content="UNIVERSE_BANNER,MARKETPLACE_PLAN_RESTRICTION_EDITOR" name="enabled-features"/>
#            <meta content="dd4df614f709c8bf46acd1f6cffb86c6fefb42d3" name="html-safe-nonce"/>
#            <meta content="bf820d79d0eaa09635947066da0f6259" http-equiv="x-pjax-version"/>
#            <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-bdd55e67f0ed3e8974c7c941589e8c6a.css" integrity="sha512-N5cRdPCXHO5wgAMNwip0pdEIY0qHrTsCnrGLSLxLiQ8TVr0Mi2xZjL6/CzD3LakUjPrFHc06OU5i0jEQ8hCwJA==" media="all" rel="stylesheet">
#             <link data-pjax-transient="" href="https://github.com/trending/developers" rel="canonical"/>
#             <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
#             <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
#             <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
#             <link class="js-site-favicon" href="https://github.githubassets.com/favicon.ico" rel="icon" type="image/x-icon"/>
#             <meta content="#1e2327" name="theme-color"/>
#             <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
#            </link>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body class="logged-out env-production page-responsive min-width-0">
#   <div class="position-relative js-header-wrapper">
#    <a class="px-2 py-4 bg-blue text-white show-on-focus js-skip-to-content" href="#start-of-content" tabindex="1">
#     Skip to content
#    </a>
#    <div class="pjax-loader-bar" id="js-pjax-loader-bar">
#     <div class="progress">
#     </div>
#    </div>
#    <header class="Header header-logged-out js-details-container Details position-relative f4 py-3" role="banner">
#     <div class="container-lg d-lg-flex flex-items-center p-responsive">
#      <div class="d-flex flex-justify-between flex-items-center">
#       <a aria-label="Homepage" class="mr-4" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
#        <svg aria-hidden="true" class="octicon octicon-mark-github text-white" height="32" version="1.1" viewbox="0 0 16 16" width="32">
#         <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </a>
#       <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
#       </div>
#       <div class="d-flex flex-items-center">
#        <a class="d-inline-block d-lg-none f5 text-white no-underline border border-gray-dark rounded-2 px-2 py-1 mr-3 mr-sm-5" data-ga-click="(Logged out) Header, clicked Sign up, text:sign-up" href="/join?source=header">
#         Sign up
#        </a>
#        <button aria-expanded="false" aria-label="Toggle navigation" class="btn-link d-lg-none mt-1 js-details-target" type="button">
#         <svg aria-hidden="true" class="octicon octicon-three-bars text-white" height="24" version="1.1" viewbox="0 0 12 16" width="18">
#          <path d="M11.41 9H.59C0 9 0 8.59 0 8c0-.59 0-1 .59-1H11.4c.59 0 .59.41.59 1 0 .59 0 1-.59 1h.01zm0-4H.59C0 5 0 4.59 0 4c0-.59 0-1 .59-1H11.4c.59 0 .59.41.59 1 0 .59 0 1-.59 1h.01zM.59 11H11.4c.59 0 .59.41.59 1 0 .59 0 1-.59 1H.59C0 13 0 12.59 0 12c0-.59 0-1 .59-1z" fill-rule="evenodd">
#          </path>
#         </svg>
#        </button>
#       </div>
#      </div>
#      <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
#       <div class="d-flex d-lg-none flex-justify-end border-bottom bg-gray-light p-3">
#        <button aria-expanded="false" aria-label="Toggle navigation" class="btn-link js-details-target" type="button">
#         <svg aria-hidden="true" class="octicon octicon-x text-gray" height="24" version="1.1" viewbox="0 0 12 16" width="18">
#          <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#          </path>
#         </svg>
#        </button>
#       </div>
#       <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
#        <ul class="d-lg-flex list-style-none">
#         <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
#          <details class="HeaderMenu-details details-overlay details-reset width-full">
#           <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#            Why GitHub?
#            <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
#             <path d="M1,1l6.2,6L13,1">
#             </path>
#            </svg>
#           </summary>
#           <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
#            <a class="py-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Features" href="/features">
#             Features
#             <span class="Bump-link-symbol float-right text-normal text-gray-light">
#              →
#             </span>
#            </a>
#            <ul class="list-style-none f5 pb-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Code review" href="/features/code-review/">
#               Code review
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Project management" href="/features/project-management/">
#               Project management
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Integrations" href="/features/integrations">
#               Integrations
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray" data-ga-click="(Logged out) Header, go to Actions" href="/features/actions">
#               Actions
#              </a>
#              <li class="edge-item-fix">
#               <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Team management" href="/features#team-management">
#                Team management
#               </a>
#              </li>
#              <li class="edge-item-fix">
#               <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Social coding" href="/features#social-coding">
#                Social coding
#               </a>
#              </li>
#              <li class="edge-item-fix">
#               <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Documentation" href="/features#documentation">
#                Documentation
#               </a>
#              </li>
#              <li class="edge-item-fix">
#               <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Code hosting" href="/features#code-hosting">
#                Code hosting
#               </a>
#              </li>
#             </li>
#            </ul>
#            <ul class="list-style-none mb-0 border-lg-top pt-lg-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Case studies" href="/case-studies">
#               Case Studies
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Security" href="/security">
#               Security
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </details>
#         </li>
#         <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">
#          <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, click, go to Enterprise" href="/enterprise">
#           Enterprise
#          </a>
#         </li>
#         <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
#          <details class="HeaderMenu-details details-overlay details-reset width-full">
#           <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#            Explore
#            <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
#             <path d="M1,1l6.2,6L13,1">
#             </path>
#            </svg>
#           </summary>
#           <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 pt-2 pb-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
#            <ul class="list-style-none mb-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Features" href="/explore">
#               Explore GitHub
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#            </ul>
#            <h4 class="text-gray-light text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">
#             Learn &amp; contribute
#            </h4>
#            <ul class="list-style-none mb-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Topics" href="/topics">
#               Topics
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Collections" href="/collections">
#               Collections
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Trending" href="/trending">
#               Trending
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Learning lab" href="https://lab.github.com/">
#               Learning Lab
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Open source guides" href="https://opensource.guide">
#               Open source guides
#              </a>
#             </li>
#            </ul>
#            <h4 class="text-gray-light text-normal text-mono f5 mb-2 border-lg-top pt-lg-3">
#             Connect with others
#            </h4>
#            <ul class="list-style-none mb-0">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Events" href="/events">
#               Events
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Community forum" href="https://github.community">
#               Community forum
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 pb-0 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to GitHub Education" href="https://education.github.com">
#               GitHub Education
#              </a>
#             </li>
#            </ul>
#           </div>
#          </details>
#         </li>
#         <li class="border-bottom border-lg-bottom-0 mr-0 mr-lg-3">
#          <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-ga-click="(Logged out) Header, go to Marketplace" href="/marketplace">
#           Marketplace
#          </a>
#         </li>
#         <li class="d-block d-lg-flex flex-lg-nowrap flex-lg-items-center border-bottom border-lg-bottom-0 mr-0 mr-lg-3 edge-item-fix position-relative flex-wrap flex-justify-between d-flex flex-items-center">
#          <details class="HeaderMenu-details details-overlay details-reset width-full">
#           <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#            Pricing
#            <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0px" xml:space="preserve" y="0px">
#             <path d="M1,1l6.2,6L13,1">
#             </path>
#            </svg>
#           </summary>
#           <div class="dropdown-menu flex-auto rounded-1 bg-white px-0 pt-2 pb-4 mt-0 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
#            <a class="pb-2 lh-condensed-ultra d-block link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Pricing" href="/pricing">
#             Plans
#             <span class="Bump-link-symbol float-right text-normal text-gray-light">
#              →
#             </span>
#            </a>
#            <ul class="list-style-none mb-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Compare features" href="/pricing#feature-comparison">
#               Compare plans
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block link-gray no-underline f5" data-ga-click="(Logged out) Header, go to Compare features" href="https://enterprise.github.com/contact">
#               Contact Sales
#              </a>
#             </li>
#            </ul>
#            <ul class="list-style-none mb-0 border-lg-top pt-lg-3">
#             <li class="edge-item-fix">
#              <a class="py-2 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Nonprofits" href="/nonprofit">
#               Nonprofit
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#             <li class="edge-item-fix">
#              <a class="py-2 pb-0 lh-condensed-ultra d-block no-underline link-gray-dark no-underline h5 Bump-link--hover" data-ga-click="(Logged out) Header, go to Education" href="https://education.github.com">
#               Education
#               <span class="Bump-link-symbol float-right text-normal text-gray-light">
#                →
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </details>
#         </li>
#        </ul>
#       </nav>
#       <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
#        <div class="d-lg-flex mr-lg-3 mb-3 mb-lg-0">
#         <div aria-expanded="false" aria-haspopup="listbox" aria-label="Search or jump to" aria-owns="jump-to-results" class="header-search js-site-search position-relative js-jump-to" role="combobox">
#          <div class="position-relative">
#           <!-- '"` -->
#           <!-- </textarea></xmp> -->
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#   </div>
#  </body>
# </html>
# <form accept-charset="UTF-8" action="/search" class="js-site-search-form" data-unscoped-search-url="/search" method="get">
#  <input name="utf8" type="hidden" value="✓"/>
#  <label class="form-control header-search-wrapper header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center js-chromeless-input-container">
#   <input aria-autocomplete="list" aria-controls="jump-to-results" aria-label="Search GitHub" autocapitalize="off" autocomplete="off" class="form-control header-search-input jump-to-field js-jump-to-field js-site-search-focus" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations#csrf-token=EOrJq5+ArhHx2Zs4HrYPuNOMkrR3LThW+BT7Awizd9Z+sDQzH2DRxRvAcnpqiPDe68IWVSvRMlQKj9BtcAEjVQ==" data-scoped-placeholder="Search" data-unscoped-placeholder="Search GitHub" name="q" placeholder="Search GitHub" spellcheck="false" type="text" value=""/>
#   <input class="js-site-search-type-field" name="type" type="hidden"/>
#   <img alt="" class="mr-2 header-search-key-slash" src="https://github.githubassets.com/images/search-key-slash.svg"/>
#   <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
#    <ul class="d-none js-jump-to-suggestions-template-container">
#     <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
#      <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
#       <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#        <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16">
#         <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16">
#         <path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#         <path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </div>
#       <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#       <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#       </div>
#       <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#        </span>
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#        </span>
#        <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#       <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#      </a>
#     </li>
#    </ul>
#    <ul class="d-none js-jump-to-no-results-template-container">
#     <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
#      <span class="text-gray">
#       No suggested jump to results
#      </span>
#     </li>
#    </ul>
#    <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
#     <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
#      <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
#       <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#        <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16">
#         <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16">
#         <path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#         <path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </div>
#       <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#       <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#       </div>
#       <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#        </span>
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#        </span>
#        <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#       <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#      </a>
#     </li>
#     <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
#      <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
#       <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
#        <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 12 16" width="16">
#         <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 15 16" width="16">
#         <path d="M10 12h3V2h-3v10zm-4-2h3V2H6v8zm-4 4h3V2H2v12zm-1 1h13V1H1v14zM14 0H1a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h13a1 1 0 0 0 1-1V1a1 1 0 0 0-1-1z" fill-rule="evenodd">
#         </path>
#        </svg>
#        <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16">
#         <path d="M15.7 13.3l-3.81-3.83A5.93 5.93 0 0 0 13 6c0-3.31-2.69-6-6-6S1 2.69 1 6s2.69 6 6 6c1.3 0 2.48-.41 3.47-1.11l3.83 3.81c.19.2.45.3.7.3.25 0 .52-.09.7-.3a.996.996 0 0 0 0-1.41v.01zM7 10.7c-2.59 0-4.7-2.11-4.7-4.7 0-2.59 2.11-4.7 4.7-4.7 2.59 0 4.7 2.11 4.7 4.7 0 2.59-2.11 4.7-4.7 4.7z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </div>
#       <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
#       <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
#       </div>
#       <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#        </span>
#        <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#        </span>
#        <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#       <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#        Jump to
#        <span class="d-inline-block ml-1 v-align-middle">
#         ↵
#        </span>
#       </div>
#      </a>
#     </li>
#    </ul>
#   </div>
#  </label>
# </form>
# <a class="HeaderMenu-link no-underline mr-3" data-ga-click="(Logged out) Header, clicked Sign in, text:sign-in" href="/login?return_to=%2Ftrending%2Fdevelopers">
#  Sign in
# </a>
# <a class="HeaderMenu-link d-inline-block no-underline border border-gray-dark rounded-1 px-2 py-1" data-ga-click="(Logged out) Header, clicked Sign up, text:sign-up" href="/join?source=header">
#  Sign up
# </a>
# <div class="show-on-focus" id="start-of-content">
# </div>
# <div id="js-flash-container">
# </div>
# <div class="application-main" data-commit-hovercards-enabled="" role="main">
#  <div data-pjax-container="" id="container">
#   <div class="bg-gray-light border-bottom">
#    <div class="container-lg p-responsive text-center py-6">
#     <h1 class="f0-light">
#      Trending
#     </h1>
#     <p class="f4 text-gray col-md-8 mx-auto">
#      These are the organizations and developers building the hot tools today.
#     </p>
#    </div>
#   </div>
#   <div class="explore-pjax-container container-lg p-responsive clearfix">
#    <div class="gutter-md pt-6">
#     <div class="col-md-9 float-md-left">
#      <div class="tabnav">
#       <div class="float-sm-right mb-2 mb-sm-0">
#        <div class="select-menu js-menu-container js-select-menu select-menu-modal-right">
#         <button aria-expanded="false" aria-haspopup="true" class="btn btn-sm select-menu-button js-menu-target" type="button">
#          <i>
#           Trending:
#          </i>
#          <span class="js-select-button">
#           today
#          </span>
#         </button>
#         <div class="select-menu-modal-holder js-menu-content js-navigation-container">
#          <div class="select-menu-modal">
#           <div class="select-menu-header">
#            <svg aria-label="Close" class="octicon octicon-x js-menu-close" height="16" role="img" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="select-menu-title">
#             Adjust time span
#            </span>
#           </div>
#           <div class="select-menu-list" role="menu">
#            <div>
#             <a class="select-menu-item js-navigation-item selected" data-pjax="" href="/trending/developers?since=daily">
#              <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#               <path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="select-menu-item-text js-select-button-text">
#               today
#              </span>
#             </a>
#             <a class="select-menu-item js-navigation-item" data-pjax="" href="/trending/developers?since=weekly">
#              <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#               <path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="select-menu-item-text js-select-button-text">
#               this week
#              </span>
#             </a>
#             <a class="select-menu-item js-navigation-item" data-pjax="" href="/trending/developers?since=monthly">
#              <svg aria-hidden="true" class="octicon octicon-check select-menu-item-icon" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#               <path d="M12 5l-8 8-4-4 1.5-1.5L4 10l6.5-6.5L12 5z" fill-rule="evenodd">
#               </path>
#              </svg>
#              <span class="select-menu-item-text js-select-button-text">
#               this month
#              </span>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <nav class="tabnav-tabs" data-pjax="">
#        <a class="js-selected-navigation-item tabnav-tab" data-selected-links="trending_repositories /trending" href="/trending">
#         Repositories
#        </a>
#        <a aria-current="page" class="js-selected-navigation-item selected tabnav-tab" data-selected-links="trending_developers /trending/developers" href="/trending/developers">
#         Developers
#        </a>
#       </nav>
#      </div>
#      <div class="explore-content">
#       <ol class="list-style-none">
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-joewalnes">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-joewalnes" style="width: 16px;">
#           1
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=48950" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/joewalnes">
#            <img alt="@joewalnes" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/48950?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/joewalnes">
#             joewalnes
#             <span class="text-gray text-bold">
#              (Joe Walnes)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/joewalnes/websocketd">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="websocketd">
#              websocketd
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             Turn any program that uses STDIN/STDOUT into a WebSocket server. Like inetd, but for WebSockets.
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-trimstray">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-trimstray" style="width: 16px;">
#           2
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=31127917" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/trimstray">
#            <img alt="@trimstray" class="rounded-1" height="48" src="https://avatars3.githubusercontent.com/u/31127917?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/trimstray">
#             trimstray
#             <span class="text-gray text-bold">
#              (@trimstray)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/trimstray/the-book-of-secret-knowledge">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="the-book-of-secret-knowledge">
#              the-book-of-secret-knowledge
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             <g-emoji alias="zap" class="g-emoji" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/26a1.png">
#              ⚡️
#             </g-emoji>
#             A collection of awesome lists, manuals, blogs, hacks, one-liners, cli/web tools and more. Especially for System and Network Administrators, DevOps, Pentesters or Security Researchers.
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-ForrestKnight">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-ForrestKnight" style="width: 16px;">
#           3
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=15620553" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/ForrestKnight">
#            <img alt="@ForrestKnight" class="rounded-1" height="48" src="https://avatars0.githubusercontent.com/u/15620553?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/ForrestKnight">
#             ForrestKnight
#             <span class="text-gray text-bold">
#              (Forrest Knight)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/ForrestKnight/open-source-cs">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="open-source-cs">
#              open-source-cs
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             Video discussing this curriculum:
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-charlax">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-charlax" style="width: 16px;">
#           4
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=120501" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/charlax">
#            <img alt="@charlax" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/120501?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/charlax">
#             charlax
#             <span class="text-gray text-bold">
#              (Charles-Axel Dein)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/charlax/professional-programming">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="professional-programming">
#              professional-programming
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             A collection of full-stack resources for programmers.
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-boazsegev">
#         <div class="d-flex">
#          <a class="text-center text-small text-gray mx-2" href="#pa-boazsegev" style="width: 16px;">
#           5
#          </a>
#          <div class="mx-2">
#           <a class="d-inline-block" data-hovercard-type="user" data-hovercard-url="/hovercards?user_id=870622" data-octo-click="hovercard-link-click" data-octo-dimensions="link_type:self" href="/boazsegev">
#            <img alt="@boazsegev" class="rounded-1" height="48" src="https://avatars2.githubusercontent.com/u/870622?s=96&amp;v=4" width="48"/>
#           </a>
#          </div>
#          <div class="mx-2">
#           <h2 class="f3 text-normal">
#            <a href="/boazsegev">
#             boazsegev
#             <span class="text-gray text-bold">
#              (Bo)
#             </span>
#            </a>
#           </h2>
#           <a class="repo-snipit css-truncate" data-ga-click="Explore, go to repository, location:trending" href="/boazsegev/facil.io">
#            <svg aria-hidden="true" class="octicon octicon-repo text-gray" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#             <path d="M4 9H3V8h1v1zm0-3H3v1h1V6zm0-2H3v1h1V4zm0-2H3v1h1V2zm8-1v12c0 .55-.45 1-1 1H6v2l-1.5-1.5L3 16v-2H1c-.55 0-1-.45-1-1V1c0-.55.45-1 1-1h10c.55 0 1 .45 1 1zm-1 10H1v2h2v-1h3v1h5v-2zm0-10H2v9h9V1z" fill-rule="evenodd">
#             </path>
#            </svg>
#            <span class="repo-snipit-name css-truncate-target">
#             <span class="repo" title="facil.io">
#              facil.io
#             </span>
#            </span>
#            <span class="repo-snipit-description css-truncate-target">
#             Your high performance web application C framework
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="mx-2 ml-6 ml-sm-2">
#          <span class="user-following-container">
#           <span class="follow">
#            <a class="btn btn-sm" href="/login?return_to=%2Ftrending%2Fdevelopers">
#             Follow
#            </a>
#           </span>
#          </span>
#         </div>
#        </li>
#        <li class="d-sm-flex flex-justify-between border-bottom border-gray-light py-3" id="pa-alibaba">
#         <div class="d-flex">
# ...
#           </path>
#          </svg>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="protip protip-callout">
#       <strong class="protip">
#        ProTip!
#       </strong>
#       Looking for recently updated  repositories?
#       <a href="/search?q=stars%3A%3E1&amp;s=updated&amp;type=Repositories">
#        Try this search
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div class="modal-backdrop js-touch-events">
#  </div>
# </div>
# <div class="footer mt-6" role="contentinfo">
#  <div class="container-lg p-responsive">
#   <div class="d-flex flex-wrap py-5 mb-5">
#    <div class="col-12 col-lg-4 mb-5">
#     <a aria-label="Go to GitHub homepage" class="text-gray-dark" data-ga-click="Footer, go to home, text:home" href="/">
#      <svg aria-hidden="true" class="octicon octicon-logo-github" height="30" version="1.1" viewbox="0 0 45 16" width="84">
#       <path d="M18.53 12.03h-.02c.009 0 .015.01.024.011h.006l-.01-.01zm.004.011c-.093.001-.327.05-.574.05-.78 0-1.05-.36-1.05-.83V8.13h1.59c.09 0 .16-.08.16-.19v-1.7c0-.09-.08-.17-.16-.17h-1.59V3.96c0-.08-.05-.13-.14-.13h-2.16c-.09 0-.14.05-.14.13v2.17s-1.09.27-1.16.28c-.08.02-.13.09-.13.17v1.36c0 .11.08.19.17.19h1.11v3.28c0 2.44 1.7 2.69 2.86 2.69.53 0 1.17-.17 1.27-.22.06-.02.09-.09.09-.16v-1.5a.177.177 0 0 0-.146-.18zM42.23 9.84c0-1.81-.73-2.05-1.5-1.97-.6.04-1.08.34-1.08.34v3.52s.49.34 1.22.36c1.03.03 1.36-.34 1.36-2.25zm2.43-.16c0 3.43-1.11 4.41-3.05 4.41-1.64 0-2.52-.83-2.52-.83s-.04.46-.09.52c-.03.06-.08.08-.14.08h-1.48c-.1 0-.19-.08-.19-.17l.02-11.11c0-.09.08-.17.17-.17h2.13c.09 0 .17.08.17.17v3.77s.82-.53 2.02-.53l-.01-.02c1.2 0 2.97.45 2.97 3.88zm-8.72-3.61h-2.1c-.11 0-.17.08-.17.19v5.44s-.55.39-1.3.39-.97-.34-.97-1.09V6.25c0-.09-.08-.17-.17-.17h-2.14c-.09 0-.17.08-.17.17v5.11c0 2.2 1.23 2.75 2.92 2.75 1.39 0 2.52-.77 2.52-.77s.05.39.08.45c.02.05.09.09.16.09h1.34c.11 0 .17-.08.17-.17l.02-7.47c0-.09-.08-.17-.19-.17zm-23.7-.01h-2.13c-.09 0-.17.09-.17.2v7.34c0 .2.13.27.3.27h1.92c.2 0 .25-.09.25-.27V6.23c0-.09-.08-.17-.17-.17zm-1.05-3.38c-.77 0-1.38.61-1.38 1.38 0 .77.61 1.38 1.38 1.38.75 0 1.36-.61 1.36-1.38 0-.77-.61-1.38-1.36-1.38zm16.49-.25h-2.11c-.09 0-.17.08-.17.17v4.09h-3.31V2.6c0-.09-.08-.17-.17-.17h-2.13c-.09 0-.17.08-.17.17v11.11c0 .09.09.17.17.17h2.13c.09 0 .17-.08.17-.17V8.96h3.31l-.02 4.75c0 .09.08.17.17.17h2.13c.09 0 .17-.08.17-.17V2.6c0-.09-.08-.17-.17-.17zM8.81 7.35v5.74c0 .04-.01.11-.06.13 0 0-1.25.89-3.31.89-2.49 0-5.44-.78-5.44-5.92S2.58 1.99 5.1 2c2.18 0 3.06.49 3.2.58.04.05.06.09.06.14L7.94 4.5c0 .09-.09.2-.2.17-.36-.11-.9-.33-2.17-.33-1.47 0-3.05.42-3.05 3.73s1.5 3.7 2.58 3.7c.92 0 1.25-.11 1.25-.11v-2.3H4.88c-.11 0-.19-.08-.19-.17V7.35c0-.09.08-.17.19-.17h3.74c.11 0 .19.08.19.17z" fill-rule="evenodd">
#       </path>
#      </svg>
#     </a>
#    </div>
#    <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-lg-0 pl-lg-4">
#     <h4 class="mb-3 text-mono text-gray-light text-normal">
#      Product
#     </h4>
#     <ul class="list-style-none text-gray f5">
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to features, text:features" href="/features">
#        Features
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to security, text:security" href="/security">
#        Security
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to enterprise, text:enterprise" href="/enterprise">
#        Enterprise
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to case studies, text:case studies" href="/case-studies?type=customers">
#        Case studies
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to pricing, text:pricing" href="/pricing">
#        Pricing
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to resources, text:resources" href="https://resources.github.com">
#        Resources
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-md-0 pl-md-4">
#     <h4 class="mb-3 text-mono text-gray-light text-normal">
#      Platform
#     </h4>
#     <ul class="list-style-none f5">
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to api, text:api" href="https://developer.github.com">
#        Developer API
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to partner, text:partner" href="http://partner.github.com/">
#        Partners
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to atom, text:atom" href="https://atom.io">
#        Atom
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to electron, text:electron" href="http://electron.atom.io/">
#        Electron
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to desktop, text:desktop" href="https://desktop.github.com/">
#        GitHub Desktop
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-md-0 pl-md-4">
#     <h4 class="mb-3 text-mono text-gray-light text-normal">
#      Support
#     </h4>
#     <ul class="list-style-none f5">
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to help, text:help" href="https://help.github.com">
#        Help
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to community, text:community" href="https://github.community">
#        Community Forum
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to training, text:training" href="https://services.github.com/">
#        Training
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to status, text:status" href="https://githubstatus.com/">
#        Status
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to contact, text:contact" href="https://github.com/contact">
#        Contact GitHub
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="col-6 col-sm-3 col-lg-2 mb-6 mb-md-2 pr-3 pr-md-0 pl-md-4">
#     <h4 class="mb-3 text-mono text-gray-light text-normal">
#      Company
#     </h4>
#     <ul class="list-style-none f5">
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to about, text:about" href="https://github.com/about">
#        About
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to blog, text:blog" href="https://github.blog">
#        Blog
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to careers, text:careers" href="/about/careers">
#        Careers
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to press, text:press" href="/about/press">
#        Press
#       </a>
#      </li>
#      <li class="lh-condensed mb-3">
#       <a class="link-gray" data-ga-click="Footer, go to shop, text:shop" href="https://shop.github.com">
#        Shop
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#  </div>
#  <div class="bg-gray-light">
#   <div class="container-lg p-responsive f6 py-4 d-sm-flex flex-justify-between flex-row-reverse flex-items-center">
#    <ul class="list-style-none d-flex flex-items-center mb-3 mb-sm-0 lh-condensed-ultra">
#     <li class="mr-3">
#      <a data-ga-click="Footer, go to Twitter, text:twitter" href="https://twitter.com/github" style="color: #959da5;" title="GitHub on Twitter">
#       <svg class="d-block" height="18" viewbox="0 0 273.5 222.3" xmlns="http://www.w3.org/2000/svg">
#        <path d="M273.5 26.3a109.77 109.77 0 0 1-32.2 8.8 56.07 56.07 0 0 0 24.7-31 113.39 113.39 0 0 1-35.7 13.6 56.1 56.1 0 0 0-97 38.4 54 54 0 0 0 1.5 12.8A159.68 159.68 0 0 1 19.1 10.3a56.12 56.12 0 0 0 17.4 74.9 56.06 56.06 0 0 1-25.4-7v.7a56.11 56.11 0 0 0 45 55 55.65 55.65 0 0 1-14.8 2 62.39 62.39 0 0 1-10.6-1 56.24 56.24 0 0 0 52.4 39 112.87 112.87 0 0 1-69.7 24 119 119 0 0 1-13.4-.8 158.83 158.83 0 0 0 86 25.2c103.2 0 159.6-85.5 159.6-159.6 0-2.4-.1-4.9-.2-7.3a114.25 114.25 0 0 0 28.1-29.1" fill="currentColor">
#        </path>
#       </svg>
#      </a>
#     </li>
#     <li class="mr-3">
#      <a data-ga-click="Footer, go to Facebook, text:facebook" href="https://www.facebook.com/GitHub" style="color: #959da5;" title="GitHub on Facebook">
#       <svg class="d-block" height="18" viewbox="0 0 15.3 15.4" xmlns="http://www.w3.org/2000/svg">
#        <path d="M14.5 0H.8a.88.88 0 0 0-.8.9v13.6a.88.88 0 0 0 .8.9h7.3v-6h-2V7.1h2V5.4a2.87 2.87 0 0 1 2.5-3.1h.5a10.87 10.87 0 0 1 1.8.1v2.1h-1.3c-1 0-1.1.5-1.1 1.1v1.5h2.3l-.3 2.3h-2v5.9h3.9a.88.88 0 0 0 .9-.8V.8a.86.86 0 0 0-.8-.8z" fill="currentColor">
#        </path>
#       </svg>
#      </a>
#     </li>
#     <li class="mr-3">
#      <a data-ga-click="Footer, go to YouTube, text:youtube" href="https://www.youtube.com/github" style="color: #959da5;" title="GitHub on YouTube">
#       <svg class="d-block" height="16" viewbox="0 0 19.17 13.6" xmlns="http://www.w3.org/2000/svg">
#        <path d="M18.77 2.13A2.4 2.4 0 0 0 17.09.42C15.59 0 9.58 0 9.58 0a57.55 57.55 0 0 0-7.5.4A2.49 2.49 0 0 0 .39 2.13 26.27 26.27 0 0 0 0 6.8a26.15 26.15 0 0 0 .39 4.67 2.43 2.43 0 0 0 1.69 1.71c1.52.42 7.5.42 7.5.42a57.69 57.69 0 0 0 7.51-.4 2.4 2.4 0 0 0 1.68-1.71 25.63 25.63 0 0 0 .4-4.67 24 24 0 0 0-.4-4.69zM7.67 9.71V3.89l5 2.91z" fill="currentColor">
#        </path>
#       </svg>
#      </a>
#     </li>
#     <li class="mr-3 flex-self-start">
#      <a data-ga-click="Footer, go to Linkedin, text:linkedin" href="https://www.linkedin.com/company/github" style="color: #959da5;" title="GitHub on Linkedin">
#       <svg class="d-block" height="18" viewbox="0 0 19 18" xmlns="http://www.w3.org/2000/svg">
#        <path d="M3.94 2A2 2 0 1 1 2 0a2 2 0 0 1 1.94 2zM4 5.48H0V18h4zm6.32 0H6.34V18h3.94v-6.57c0-3.66 4.77-4 4.77 0V18H19v-7.93c0-6.17-7.06-5.94-8.72-2.91z" fill="currentColor">
#        </path>
#       </svg>
#      </a>
#     </li>
#     <li>
#      <a data-ga-click="Footer, go to github's org, text:github" href="https://github.com/github" style="color: #959da5;" title="GitHub's organization">
#       <svg alt="GitHub" aria-hidden="true" class="octicon octicon-mark-github d-block" height="20" version="1.1" viewbox="0 0 16 16" width="20">
#        <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0 0 16 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd">
#        </path>
#       </svg>
#      </a>
#     </li>
#    </ul>
#    <ul class="list-style-none d-flex text-gray">
#     <li class="mr-3">
#      © 2019 GitHub, Inc.
#     </li>
#     <li class="mr-3">
#      <a class="link-gray" data-ga-click="Footer, go to terms, text:terms" href="/site/terms">
#       Terms
#      </a>
#     </li>
#     <li>
#      <a class="link-gray" data-ga-click="Footer, go to privacy, text:privacy" href="/site/privacy">
#       Privacy
#      </a>
#     </li>
#    </ul>
#   </div>
#  </div>
# </div>
# <div class="ajax-error-message flash flash-error" id="ajax-error-message">
#  <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#   <path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 0 0 0 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 0 0 .01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd">
#   </path>
#  </svg>
#  <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
#   <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#    <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#    </path>
#   </svg>
#  </button>
#  You can’t perform that action at this time.
# </div>
# <script crossorigin="anonymous" integrity="sha512-Mp0nAOFvmE8PVQP49TPVMbQBLb+lpf3gu9GF1CPqybGGzl/8KEKDTKzuJpxxd5xF8HUi85xKPkssLtVVdLKtlw==" src="https://github.githubassets.com/assets/compat-6e5ed2648dae3be3f9358af5732a780f.js" type="application/javascript">
# </script>
# <script crossorigin="anonymous" integrity="sha512-munE9dNLI0m3pEuNvjoQ8yUQPQuAU2ERx7YI54vEL0SqY7xa6rwJfB7m+mt7N9uXSShm+/8OjEDMWNeNXYA6aQ==" src="https://github.githubassets.com/assets/frameworks-6b1e5c0082cc318bd85fc3f598b31949.js" type="application/javascript">
# </script>
# <script async="async" crossorigin="anonymous" integrity="sha512-/1Dm7YaiDDQ5qvDIy2RTdEsKik/YA0zyw2SUZSYVlARXSEaCjmev/C2icBVlVAWt1LYGXZsrpf7TeT1+t/wTNQ==" src="https://github.githubassets.com/assets/github-d22fd39d1493a998022914a62e071a04.js" type="application/javascript">
# </script>
# <div class="js-stale-session-flash stale-session-flash flash flash-warn flash-banner d-none">
#  <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16">
#   <path d="M8.893 1.5c-.183-.31-.52-.5-.887-.5s-.703.19-.886.5L.138 13.499a.98.98 0 0 0 0 1.001c.193.31.53.501.886.501h13.964c.367 0 .704-.19.877-.5a1.03 1.03 0 0 0 .01-1.002L8.893 1.5zm.133 11.497H6.987v-2.003h2.039v2.003zm0-3.004H6.987V5.987h2.039v4.006z" fill-rule="evenodd">
#   </path>
#  </svg>
#  <span class="signed-in-tab-flash">
#   You signed in with another tab or window.
#   <a href="">
#    Reload
#   </a>
#   to refresh your session.
#  </span>
#  <span class="signed-out-tab-flash">
#   You signed out in another tab or window.
#   <a href="">
#    Reload
#   </a>
#   to refresh your session.
#  </span>
# </div>
# <template id="site-details-dialog">
#  <details class="details-reset details-overlay details-overlay-dark lh-default text-gray-dark" open="">
#   <summary aria-haspopup="dialog" aria-label="Close dialog">
#   </summary>
#   <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast">
#    <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
#     <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 12 16" width="12">
#      <path d="M7.48 8l3.75 3.75-1.48 1.48L6 9.48l-3.75 3.75-1.48-1.48L4.52 8 .77 4.25l1.48-1.48L6 6.52l3.75-3.75 1.48 1.48L7.48 8z" fill-rule="evenodd">
#      </path>
#     </svg>
#    </button>
#    <div class="octocat-spinner my-6 js-details-dialog-spinner">
#    </div>
#   </details-dialog>
#  </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
#  <div class="Popover-message Popover-message--bottom-left Popover-message--large Box box-shadow-large" style="width:360px;">
#  </div>
# </div>
# <div class="sr-only" id="hovercard-aria-description">
#  Press h to open a hovercard with more details.
# </div>
# <div aria-live="polite" class="js-global-screen-reader-notice sr-only">
# </div>

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
#your code
html = urlopen(url)
bsObj = BeautifulSoup(html)
for link in bsObj.findAll("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #start-of-content
# https://github.com/
# /join?source=header
# /features
# /features/code-review/
# /features/project-management/
# /features/integrations
# /features/actions
# /features#team-management
# /features#social-coding
# /features#documentation
# /features#code-hosting
# /case-studies
# /security
# /enterprise
# /explore
# /topics
# /collections
# /trending
# https://lab.github.com/
# https://opensource.guide
# /events
# https://github.community
# https://education.github.com
# /marketplace
# /pricing
# /pricing#feature-comparison
# https://enterprise.github.com/contact
# /nonprofit
# https://education.github.com
#
#
#
# /login?return_to=%2Ftrending%2Fdevelopers
# /join?source=header
# /trending/developers?since=daily
# /trending/developers?since=weekly
# /trending/developers?since=monthly
# /trending
# /trending/developers
# #pa-joewalnes
# /joewalnes
# /joewalnes
# /joewalnes/websocketd
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-trimstray
# /trimstray
# /trimstray
# /trimstray/the-book-of-secret-knowledge
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-ForrestKnight
# /ForrestKnight
# /ForrestKnight
# /ForrestKnight/open-source-cs
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-charlax
# /charlax
# /charlax
# /charlax/professional-programming
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-boazsegev
# /boazsegev
# /boazsegev
# /boazsegev/facil.io
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-alibaba
# /alibaba
# /alibaba
# /alibaba/weex
# #pa-Microsoft
# /Microsoft
# /Microsoft
# /Microsoft/vscode
# #pa-revery-ui
# /revery-ui
# /revery-ui
# /revery-ui/revery
# #pa-github
# /github
# /github
# /github/gitignore
# #pa-facebook
# /facebook
# /facebook
# /facebook/react
# #pa-google
# /google
# /google
# /google/material-design-icons
# #pa-DevonCrawford
# /DevonCrawford
# /DevonCrawford
# /DevonCrawford/Timelapse-Auto-Ramp-Photoshop-Plugin
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-apache
# /apache
# /apache
# /apache/incubator-echarts
# #pa-sindresorhus
# /sindresorhus
# /sindresorhus
# /sindresorhus/awesome
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-tensorflow
# /tensorflow
# /tensorflow
# /tensorflow/tensorflow
# #pa-cloudfetch
# /cloudfetch
# /cloudfetch
# /cloudfetch/cloudquery
# #pa-fastai
# /fastai
# /fastai
# /fastai/fastai
# #pa-myshov
# /myshov
# /myshov
# /myshov/history-of-javascript
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-vuejs
# /vuejs
# /vuejs
# /vuejs/vue
# #pa-joelparkerhenderson
# /joelparkerhenderson
# /joelparkerhenderson
# /joelparkerhenderson/architecture_decision_record
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-script-8
# /script-8
# /script-8
# /script-8/script-8.github.io
# #pa-torvalds
# /torvalds
# /torvalds
# /torvalds/linux
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-tranbathanhtung
# /tranbathanhtung
# /tranbathanhtung
# /tranbathanhtung/react-fiber-implement
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-komeiji-satori
# /komeiji-satori
# /komeiji-satori
# /komeiji-satori/Dress
# /login?return_to=%2Ftrending%2Fdevelopers
# #pa-SebLague
# /SebLague
# /SebLague
# /SebLague/Procedural-Landmass-Generation
# /login?return_to=%2Ftrending%2Fdevelopers
# /trending/developers?since=daily
# /trending/developers/unknown?since=daily
# /trending/developers/c++?since=daily
# /trending/developers/html?since=daily
# /trending/developers/java?since=daily
# /trending/developers/javascript?since=daily
# /trending/developers/php?since=daily
# /trending/developers/python?since=daily
# /trending/developers/ruby?since=daily
# /trending/developers/1c-enterprise?since=daily
# /trending/developers/abap?since=daily
# /trending/developers/abnf?since=daily
# /trending/developers/actionscript?since=daily
# /trending/developers/ada?since=daily
# /trending/developers/adobe-font-metrics?since=daily
# /trending/developers/agda?since=daily
# /trending/developers/ags-script?since=daily
# /trending/developers/alloy?since=daily
# /trending/developers/alpine-abuild?since=daily
# /trending/developers/ampl?since=daily
# /trending/developers/angelscript?since=daily
# /trending/developers/ant-build-system?since=daily
# /trending/developers/antlr?since=daily
# /trending/developers/apacheconf?since=daily
# /trending/developers/apex?since=daily
# /trending/developers/api-blueprint?since=daily
# /trending/developers/apl?since=daily
# /trending/developers/apollo-guidance-computer?since=daily
# /trending/developers/applescript?since=daily
# /trending/developers/arc?since=daily
# /trending/developers/asciidoc?since=daily
# /trending/developers/asn.1?since=daily
# /trending/developers/asp?since=daily
# /trending/developers/aspectj?since=daily
# /trending/developers/assembly?since=daily
# /trending/developers/ats?since=daily
# /trending/developers/augeas?since=daily
# /trending/developers/autohotkey?since=daily
# /trending/developers/autoit?since=daily
# /trending/developers/awk?since=daily
# /trending/developers/ballerina?since=daily
# /trending/developers/batchfile?since=daily
# /trending/developers/befunge?since=daily
# /trending/developers/bison?since=daily
# /trending/developers/bitbake?since=daily
# /trending/developers/blade?since=daily
# /trending/developers/blitzbasic?since=daily
# /trending/developers/blitzmax?since=daily
# /trending/developers/bluespec?since=daily
# /trending/developers/boo?since=daily
# /trending/developers/brainfuck?since=daily
# /trending/developers/brightscript?since=daily
# /trending/developers/bro?since=daily
# /trending/developers/c?since=daily
# /trending/developers/c%23?since=daily
# /trending/developers/c++?since=daily
# /trending/developers/c-objdump?since=daily
# /trending/developers/c2hs-haskell?since=daily
# /trending/developers/cap'n-proto?since=daily
# /trending/developers/cartocss?since=daily
# /trending/developers/ceylon?since=daily
# /trending/developers/chapel?since=daily
# /trending/developers/charity?since=daily
# /trending/developers/chuck?since=daily
# /trending/developers/cirru?since=daily
# /trending/developers/clarion?since=daily
# /trending/developers/clean?since=daily
# /trending/developers/click?since=daily
# /trending/developers/clips?since=daily
# /trending/developers/clojure?since=daily
# /trending/developers/closure-templates?since=daily
# /trending/developers/cloud-firestore-security-rules?since=daily
# /trending/developers/cmake?since=daily
# /trending/developers/cobol?since=daily
# /trending/developers/coffeescript?since=daily
# /trending/developers/coldfusion?since=daily
# /trending/developers/coldfusion-cfc?since=daily
# /trending/developers/collada?since=daily
# /trending/developers/common-lisp?since=daily
# /trending/developers/common-workflow-language?since=daily
# /trending/developers/component-pascal?since=daily
# /trending/developers/conll-u?since=daily
# /trending/developers/cool?since=daily
# /trending/developers/coq?since=daily
# /trending/developers/cpp-objdump?since=daily
# /trending/developers/creole?since=daily
# /trending/developers/crystal?since=daily
# /trending/developers/cson?since=daily
# /trending/developers/csound?since=daily
# /trending/developers/csound-document?since=daily
# /trending/developers/csound-score?since=daily
# /trending/developers/css?since=daily
# /trending/developers/csv?since=daily
# /trending/developers/cuda?since=daily
# /trending/developers/cweb?since=daily
# /trending/developers/cycript?since=daily
# /trending/developers/cython?since=daily
# /trending/developers/d?since=daily
# /trending/developers/d-objdump?since=daily
# /trending/developers/darcs-patch?since=daily
# /trending/developers/dart?since=daily
# /trending/developers/dataweave?since=daily
# /trending/developers/desktop?since=daily
# /trending/developers/diff?since=daily
# /trending/developers/digital-command-language?since=daily
# /trending/developers/dm?since=daily
# /trending/developers/dns-zone?since=daily
# /trending/developers/dockerfile?since=daily
# /trending/developers/dogescript?since=daily
# /trending/developers/dtrace?since=daily
# /trending/developers/dylan?since=daily
# /trending/developers/e?since=daily
# /trending/developers/eagle?since=daily
# /trending/developers/easybuild?since=daily
# /trending/developers/ebnf?since=daily
# /trending/developers/ec?since=daily
# /trending/developers/ecere-projects?since=daily
# /trending/developers/ecl?since=daily
# /trending/developers/eclipse?since=daily
# /trending/developers/edje-data-collection?since=daily
# /trending/developers/edn?since=daily
# /trending/developers/eiffel?since=daily
# /trending/developers/ejs?since=daily
# /trending/developers/elixir?since=daily
# /trending/developers/elm?since=daily
# /trending/developers/emacs-lisp?since=daily
# /trending/developers/emberscript?since=daily
# /trending/developers/eml?since=daily
# /trending/developers/eq?since=daily
# /trending/developers/erlang?since=daily
# /trending/developers/f%23?since=daily
# /trending/developers/f*?since=daily
# /trending/developers/factor?since=daily
# /trending/developers/fancy?since=daily
# /trending/developers/fantom?since=daily
# /trending/developers/figlet-font?since=daily
# /trending/developers/filebench-wml?since=daily
# /trending/developers/filterscript?since=daily
# /trending/developers/fish?since=daily
# /trending/developers/flux?since=daily
# /trending/developers/formatted?since=daily
# /trending/developers/forth?since=daily
# /trending/developers/fortran?since=daily
# /trending/developers/freemarker?since=daily
# /trending/developers/frege?since=daily
# /trending/developers/g-code?since=daily
# /trending/developers/game-maker-language?since=daily
# /trending/developers/gams?since=daily
# /trending/developers/gap?since=daily
# /trending/developers/gcc-machine-description?since=daily
# /trending/developers/gdb?since=daily
# /trending/developers/gdscript?since=daily
# /trending/developers/genie?since=daily
# /trending/developers/genshi?since=daily
# /trending/developers/gentoo-ebuild?since=daily
# /trending/developers/gentoo-eclass?since=daily
# /trending/developers/gerber-image?since=daily
# /trending/developers/gettext-catalog?since=daily
# /trending/developers/gherkin?since=daily
# /trending/developers/glsl?since=daily
# /trending/developers/glyph?since=daily
# /trending/developers/glyph-bitmap-distribution-format?since=daily
# /trending/developers/gn?since=daily
# /trending/developers/gnuplot?since=daily
# /trending/developers/go?since=daily
# /trending/developers/golo?since=daily
# /trending/developers/gosu?since=daily
# /trending/developers/grace?since=daily
# /trending/developers/gradle?since=daily
# /trending/developers/grammatical-framework?since=daily
# /trending/developers/graph-modeling-language?since=daily
# /trending/developers/graphql?since=daily
# /trending/developers/graphviz-(dot)?since=daily
# /trending/developers/groovy?since=daily
# /trending/developers/groovy-server-pages?since=daily
# /trending/developers/hack?since=daily
# /trending/developers/haml?since=daily
# /trending/developers/handlebars?since=daily
# /trending/developers/haproxy?since=daily
# /trending/developers/harbour?since=daily
# /trending/developers/haskell?since=daily
# /trending/developers/haxe?since=daily
# /trending/developers/hcl?since=daily
# /trending/developers/hiveql?since=daily
# /trending/developers/hlsl?since=daily
# /trending/developers/html?since=daily
# /trending/developers/html+django?since=daily
# /trending/developers/html+ecr?since=daily
# /trending/developers/html+eex?since=daily
# /trending/developers/html+erb?since=daily
# /trending/developers/html+php?since=daily
# /trending/developers/html+razor?since=daily
# /trending/developers/http?since=daily
# /trending/developers/hxml?since=daily
# /trending/developers/hy?since=daily
# /trending/developers/hyphy?since=daily
# /trending/developers/idl?since=daily
# /trending/developers/idris?since=daily
# /trending/developers/igor-pro?since=daily
# /trending/developers/inform-7?since=daily
# /trending/developers/ini?since=daily
# /trending/developers/inno-setup?since=daily
# /trending/developers/io?since=daily
# /trending/developers/ioke?since=daily
# /trending/developers/irc-log?since=daily
# /trending/developers/isabelle?since=daily
# /trending/developers/isabelle-root?since=daily
# /trending/developers/j?since=daily
# /trending/developers/jasmin?since=daily
# /trending/developers/java?since=daily
# /trending/developers/java-properties?since=daily
# /trending/developers/java-server-pages?since=daily
# /trending/developers/javascript?since=daily
# /trending/developers/jflex?since=daily
# /trending/developers/jison?since=daily
# /trending/developers/jison-lex?since=daily
# /trending/developers/jolie?since=daily
# /trending/developers/json?since=daily
# /trending/developers/json-with-comments?since=daily
# /trending/developers/json5?since=daily
# /trending/developers/jsoniq?since=daily
# /trending/developers/jsonld?since=daily
# /trending/developers/jsx?since=daily
# /trending/developers/julia?since=daily
# /trending/developers/jupyter-notebook?since=daily
# /trending/developers/kicad-layout?since=daily
# /trending/developers/kicad-legacy-layout?since=daily
# /trending/developers/kicad-schematic?since=daily
# /trending/developers/kit?since=daily
# /trending/developers/kotlin?since=daily
# /trending/developers/krl?since=daily
# /trending/developers/labview?since=daily
# /trending/developers/lasso?since=daily
# /trending/developers/latte?since=daily
# /trending/developers/lean?since=daily
# /trending/developers/less?since=daily
# /trending/developers/lex?since=daily
# /trending/developers/lfe?since=daily
# /trending/developers/lilypond?since=daily
# /trending/developers/limbo?since=daily
# /trending/developers/linker-script?since=daily
# /trending/developers/linux-kernel-module?since=daily
# /trending/developers/liquid?since=daily
# /trending/developers/literate-agda?since=daily
# /trending/developers/literate-coffeescript?since=daily
# /trending/developers/literate-haskell?since=daily
# /trending/developers/livescript?since=daily
# /trending/developers/llvm?since=daily
# /trending/developers/logos?since=daily
# /trending/developers/logtalk?since=daily
# /trending/developers/lolcode?since=daily
# /trending/developers/lookml?since=daily
# /trending/developers/loomscript?since=daily
# /trending/developers/lsl?since=daily
# /trending/developers/lua?since=daily
# /trending/developers/m?since=daily
# /trending/developers/m4?since=daily
# /trending/developers/m4sugar?since=daily
# /trending/developers/makefile?since=daily
# /trending/developers/mako?since=daily
# /trending/developers/markdown?since=daily
# /trending/developers/marko?since=daily
# /trending/developers/mask?since=daily
# /trending/developers/mathematica?since=daily
# /trending/developers/matlab?since=daily
# /trending/developers/maven-pom?since=daily
# /trending/developers/max?since=daily
# /trending/developers/maxscript?since=daily
# /trending/developers/mediawiki?since=daily
# /trending/developers/mercury?since=daily
# /trending/developers/meson?since=daily
# /trending/developers/metal?since=daily
# /trending/developers/minid?since=daily
# /trending/developers/mirah?since=daily
# /trending/developers/modelica?since=daily
# /trending/developers/modula-2?since=daily
# /trending/developers/modula-3?since=daily
# /trending/developers/module-management-system?since=daily
# /trending/developers/monkey?since=daily
# /trending/developers/moocode?since=daily
# /trending/developers/moonscript?since=daily
# /trending/developers/mql4?since=daily
# /trending/developers/mql5?since=daily
# /trending/developers/mtml?since=daily
# /trending/developers/muf?since=daily
# /trending/developers/mupad?since=daily
# /trending/developers/myghty?since=daily
# /trending/developers/ncl?since=daily
# /trending/developers/nearley?since=daily
# /trending/developers/nemerle?since=daily
# /trending/developers/nesc?since=daily
# /trending/developers/netlinx?since=daily
# /trending/developers/netlinx+erb?since=daily
# /trending/developers/netlogo?since=daily
# /trending/developers/newlisp?since=daily
# /trending/developers/nextflow?since=daily
# /trending/developers/nginx?since=daily
# /trending/developers/nim?since=daily
# /trending/developers/ninja?since=daily
# /trending/developers/nit?since=daily
# /trending/developers/nix?since=daily
# /trending/developers/nl?since=daily
# /trending/developers/nsis?since=daily
# /trending/developers/nu?since=daily
# /trending/developers/numpy?since=daily
# /trending/developers/objdump?since=daily
# /trending/developers/objective-c?since=daily
# /trending/developers/objective-c++?since=daily
# /trending/developers/objective-j?since=daily
# /trending/developers/ocaml?since=daily
# /trending/developers/omgrofl?since=daily
# /trending/developers/ooc?since=daily
# /trending/developers/opa?since=daily
# /trending/developers/opal?since=daily
# /trending/developers/opencl?since=daily
# /trending/developers/openedge-abl?since=daily
# /trending/developers/openrc-runscript?since=daily
# /trending/developers/openscad?since=daily
# /trending/developers/opentype-feature-file?since=daily
# /trending/developers/org?since=daily
# /trending/developers/ox?since=daily
# /trending/developers/oxygene?since=daily
# /trending/developers/oz?since=daily
# /trending/developers/p4?since=daily
# /trending/developers/pan?since=daily
# /trending/developers/papyrus?since=daily
# /trending/developers/parrot?since=daily
# /trending/developers/parrot-assembly?since=daily
# /trending/developers/parrot-internal-representation?since=daily
# /trending/developers/pascal?since=daily
# /trending/developers/pawn?since=daily
# /trending/developers/pep8?since=daily
# /trending/developers/perl?since=daily
# /trending/developers/perl-6?since=daily
# /trending/developers/php?since=daily
# /trending/developers/pic?since=daily
# /trending/developers/pickle?since=daily
# /trending/developers/picolisp?since=daily
# /trending/developers/piglatin?since=daily
# /trending/developers/pike?since=daily
# /trending/developers/plpgsql?since=daily
# /trending/developers/plsql?since=daily
# /trending/developers/pod?since=daily
# /trending/developers/pod-6?since=daily
# /trending/developers/pogoscript?since=daily
# /trending/developers/pony?since=daily
# /trending/developers/postcss?since=daily
# /trending/developers/postscript?since=daily
# /trending/developers/pov-ray-sdl?since=daily
# /trending/developers/powerbuilder?since=daily
# /trending/developers/powershell?since=daily
# /trending/developers/processing?since=daily
# /trending/developers/prolog?since=daily
# /trending/developers/propeller-spin?since=daily
# /trending/developers/protocol-buffer?since=daily
# /trending/developers/public-key?since=daily
# /trending/developers/pug?since=daily
# /trending/developers/puppet?since=daily
# /trending/developers/pure-data?since=daily
# /trending/developers/purebasic?since=daily
# /trending/developers/purescript?since=daily
# /trending/developers/python?since=daily
# /trending/developers/python-console?since=daily
# /trending/developers/python-traceback?since=daily
# /trending/developers/q?since=daily
# /trending/developers/qmake?since=daily
# /trending/developers/qml?since=daily
# /trending/developers/quake?since=daily
# /trending/developers/r?since=daily
# /trending/developers/racket?since=daily
# /trending/developers/ragel?since=daily
# /trending/developers/raml?since=daily
# /trending/developers/rascal?since=daily
# /trending/developers/raw-token-data?since=daily
# /trending/developers/rdoc?since=daily
# /trending/developers/realbasic?since=daily
# /trending/developers/reason?since=daily
# /trending/developers/rebol?since=daily
# /trending/developers/red?since=daily
# /trending/developers/redcode?since=daily
# /trending/developers/regular-expression?since=daily
# /trending/developers/ren'py?since=daily
# /trending/developers/renderscript?since=daily
# /trending/developers/restructuredtext?since=daily
# /trending/developers/rexx?since=daily
# /trending/developers/rhtml?since=daily
# /trending/developers/ring?since=daily
# /trending/developers/rmarkdown?since=daily
# /trending/developers/robotframework?since=daily
# /trending/developers/roff?since=daily
# /trending/developers/rouge?since=daily
# /trending/developers/rpc?since=daily
# /trending/developers/rpm-spec?since=daily
# /trending/developers/ruby?since=daily
# /trending/developers/runoff?since=daily
# /trending/developers/rust?since=daily
# /trending/developers/sage?since=daily
# /trending/developers/saltstack?since=daily
# /trending/developers/sas?since=daily
# /trending/developers/sass?since=daily
# /trending/developers/scala?since=daily
# /trending/developers/scaml?since=daily
# /trending/developers/scheme?since=daily
# /trending/developers/scilab?since=daily
# /trending/developers/scss?since=daily
# /trending/developers/sed?since=daily
# /trending/developers/self?since=daily
# /trending/developers/shaderlab?since=daily
# /trending/developers/shell?since=daily
# /trending/developers/shellsession?since=daily
# /trending/developers/shen?since=daily
# /trending/developers/slash?since=daily
# /trending/developers/slice?since=daily
# /trending/developers/slim?since=daily
# /trending/developers/smali?since=daily
# /trending/developers/smalltalk?since=daily
# /trending/developers/smarty?since=daily
# /trending/developers/smt?since=daily
# /trending/developers/solidity?since=daily
# /trending/developers/sourcepawn?since=daily
# /trending/developers/sparql?since=daily
# /trending/developers/spline-font-database?since=daily
# /trending/developers/sqf?since=daily
# /trending/developers/sql?since=daily
# /trending/developers/sqlpl?since=daily
# /trending/developers/squirrel?since=daily
# /trending/developers/srecode-template?since=daily
# /trending/developers/stan?since=daily
# /trending/developers/standard-ml?since=daily
# /trending/developers/stata?since=daily
# /trending/developers/ston?since=daily
# /trending/developers/stylus?since=daily
# /trending/developers/subrip-text?since=daily
# /trending/developers/sugarss?since=daily
# /trending/developers/supercollider?since=daily
# /trending/developers/svg?since=daily
# /trending/developers/swift?since=daily
# /trending/developers/systemverilog?since=daily
# /trending/developers/tcl?since=daily
# /trending/developers/tcsh?since=daily
# /trending/developers/tea?since=daily
# /trending/developers/terra?since=daily
# /trending/developers/tex?since=daily
# /trending/developers/text?since=daily
# /trending/developers/textile?since=daily
# /trending/developers/thrift?since=daily
# /trending/developers/ti-program?since=daily
# /trending/developers/tla?since=daily
# /trending/developers/toml?since=daily
# /trending/developers/turing?since=daily
# /trending/developers/turtle?since=daily
# /trending/developers/twig?since=daily
# /trending/developers/txl?since=daily
# /trending/developers/type-language?since=daily
# /trending/developers/typescript?since=daily
# /trending/developers/unified-parallel-c?since=daily
# /trending/developers/unity3d-asset?since=daily
# /trending/developers/unix-assembly?since=daily
# /trending/developers/uno?since=daily
# /trending/developers/unrealscript?since=daily
# /trending/developers/urweb?since=daily
# /trending/developers/vala?since=daily
# /trending/developers/vcl?since=daily
# /trending/developers/verilog?since=daily
# /trending/developers/vhdl?since=daily
# /trending/developers/vim-script?since=daily
# /trending/developers/visual-basic?since=daily
# /trending/developers/volt?since=daily
# /trending/developers/vue?since=daily
# /trending/developers/wavefront-material?since=daily
# /trending/developers/wavefront-object?since=daily
# /trending/developers/wdl?since=daily
# /trending/developers/web-ontology-language?since=daily
# /trending/developers/webassembly?since=daily
# /trending/developers/webidl?since=daily
# /trending/developers/windows-registry-entries?since=daily
# /trending/developers/wisp?since=daily
# /trending/developers/world-of-warcraft-addon-data?since=daily
# /trending/developers/x-bitmap?since=daily
# /trending/developers/x-font-directory-index?since=daily
# /trending/developers/x-pixmap?since=daily
# /trending/developers/x10?since=daily
# /trending/developers/xbase?since=daily
# /trending/developers/xc?since=daily
# /trending/developers/xcompose?since=daily
# /trending/developers/xml?since=daily
# /trending/developers/xojo?since=daily
# /trending/developers/xpages?since=daily
# /trending/developers/xproc?since=daily
# /trending/developers/xquery?since=daily
# /trending/developers/xs?since=daily
# /trending/developers/xslt?since=daily
# /trending/developers/xtend?since=daily
# /trending/developers/yacc?since=daily
# /trending/developers/yaml?since=daily
# /trending/developers/yang?since=daily
# /trending/developers/yara?since=daily
# /trending/developers/yasnippet?since=daily
# /trending/developers/zephir?since=daily
# /trending/developers/zimpl?since=daily
# /search?q=stars%3A%3E1&s=forks&type=Repositories
# /
# /features
# /security
# /enterprise
# /case-studies?type=customers
# /pricing
# https://resources.github.com
# https://developer.github.com
# http://partner.github.com/
# https://atom.io
# http://electron.atom.io/
# https://desktop.github.com/
# https://help.github.com
# https://github.community
# https://services.github.com/
# https://githubstatus.com/
# https://github.com/contact
# https://github.com/about
# https://github.blog
# /about/careers
# /about/press
# https://shop.github.com
# https://twitter.com/github
# https://www.facebook.com/GitHub
# https://www.youtube.com/github
# https://www.linkedin.com/company/github
# https://github.com/github
# /site/terms
# /site/privacy

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
txt = requests.get(url).text
print(txt.count('class="usctitlechanged" id'))
# Out:
# 0

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 
response = requests.get(url).content
soup = BeautifulSoup(response, 'html.parser')
h3titles = soup.find_all('h3', {'class':'title'})
names = [item.text.strip() for item in h3titles]

print(names)
# Out:
# ['LAMONT STEPHENSON', 'RAFAEL CARO-QUINTERO', 'ALEXIS FLORES', 'SANTIAGO VILLALBA MEDEROS', 'ROBERT WILLIAM FISHER', 'ALEJANDRO ROSALES CASTILLO', 'GREG ALYN CARLSON', 'YASER ABDEL SAID', 'BHADRESHKUMAR CHETANBHAI PATEL', 'JASON DEREK BROWN']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code
res = requests.get(url)
bs = BeautifulSoup(res.text, 'lxml')
hacks_data = bs.find_all('div',{'class':'hackathon '})
for i,f in enumerate(hacks_data,1):
    hacks_month = f.find('div',{'class':'date'}).find('div',{'class':'date-month'}).text.strip()
    hacks_date = f.find('div',{'class':'date'}).find('div',{'class':'date-day-number'}).text.strip()
    hacks_days = f.find('div',{'class':'date'}).find('div',{'class':'date-week-days'}).text.strip()
    hacks_final_date = "{} {}, {} ".format(hacks_date, hacks_month, hacks_days )
    hacks_name = f.find('div',{'class':'info'}).find('h2').text.strip()
    hacks_city = f.find('div',{'class':'info'}).find('p').find('span',{'class':'city'}).text.strip()
    hacks_country = f.find('div',{'class':'info'}).find('p').find('span',{'class':'country'}).text.strip()
    print("{:<5}{:<15}: {:<90}: {}, {}\n ".format(str(i)+')',hacks_final_date, hacks_name.title(), hacks_city, hacks_country))

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

handle = input('Input your account name on Twitter: ')
temp = requests.get('https://twitter.com/'+handle)
bs = BeautifulSoup(temp.text,'lxml')

try:
    tweet_box = bs.find('li',{'class':'ProfileNav-item ProfileNav-item--tweets is-active'})
    tweets= tweet_box.find('a').find('span',{'class':'ProfileNav-value'})
    print("{} has {} number of tweets.".format(handle,tweets.get('data-count')))

except:
    print('Account name not found...')
# Out:
# Input your account name on Twitter: @BelenLinacero
# @BelenLinacero has 3876 number of tweets.

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code
handle = input('Input your account name on Twitter: ') 
temp = requests.get('https://twitter.com/'+handle)
bs = BeautifulSoup(temp.text,'lxml')
try:
    follow_box = bs.find('li',{'class':'ProfileNav-item ProfileNav-item--followers'})
    followers = follow_box.find('a').find('span',{'class':'ProfileNav-value'})
    print("Number of followers: {} ".format(followers.get('data-count')))
except:
    print('Account name not found...')
# Out:
# Input your account name on Twitter: @BelenLinacero
# Number of followers: 14

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
html = requests.get(url).content
bs = BeautifulSoup(html, "html.parser")
nameList = bs.findAll('a', {'class' : 'link-box'})
for name in nameList:
    print(name.get_text())

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code 
html = requests.get(url).content
soup = BeautifulSoup(html,"html.parser")
nameList= soup.findAll('h2')
for name in nameList:
    print(name.get_text())
# Out:
# Most Wanted
#
#
# News
#
#
# What We Investigate
#
#
# Services
#
#
# Resources
#
#
# About
#
#
# Contact Us
#
#
# More

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code
handle = input('Input your account name on Twitter: ')
ctr = int(input('Input number of tweets to scrape: '))
res=requests.get('https://twitter.com/'+ handle)
bs=BeautifulSoup(res.content,'lxml')
all_tweets = bs.find_all('div',{'class':'tweet'})
if all_tweets:
    for tweet in all_tweets[:ctr]:
        context = tweet.find('div',{'class':'context'}).text.replace("\n"," ").strip()
        content = tweet.find('div',{'class':'content'})
        header = content.find('div',{'class':'stream-item-header'})
        user = header.find('a',{'class':'account-group js-account-group js-action-profile js-user-profile-link js-nav'}).text.replace("\n"," ").strip()
        time = header.find('a',{'class':'tweet-timestamp js-permalink js-nav js-tooltip'}).find('span').text.replace("\n"," ").strip()
        message = content.find('div',{'class':'js-tweet-text-container'}).text.replace("\n"," ").strip()
        footer = content.find('div',{'class':'stream-item-footer'})
        stat = footer.find('div',{'class':'ProfileTweet-actionCountList u-hiddenVisually'}).text.replace("\n"," ").strip()
        if context:
            print(context)
        print(user,time)
        print(message)
        print(stat)
        print()
else:
    print("List is empty/account name not found.")
# Out:
# Input your account name on Twitter: @BelenLinacero
# Input number of tweets to scrape: 3
# Belen Linacero‏ @BelenLinacero 3 Jul 2018
# https://aprendemosjuntos.elpais.com/especial/por-que-es-tan-importante-como-miras-a-tu-hijo-alex-rovira/ …https://aprendemosjuntos.elpais.com/especial/por-que-es-tan-importante-como-miras-a-tu-hijo-alex-rovira/ …
# 0 replies     0 retweets     0 likes
#
# Belen Linacero‏ @BelenLinacero 3 Jul 2018
# Como la vida misma...  El cambio es,  a veces,  imperceptible pero esta siempre ahí. Vivimos en permanente cambio seamos conscientes o no. https://www.facebook.com/100000221625055/posts/2272279312789434/ …
# 0 replies     0 retweets     0 likes
#
# Belen Linacero‏ @BelenLinacero 3 Jul 2018
# Hacia la mejor versión de uno mismo,  sin miedos ni dilaciones porque podemos conseguir lo que nos propongamos. Si hay gente que consigue lo que yo quiero en mi interior,  que me lo impide a mi?  Te lo has preguntado alguna vez? Interesante y útil...https://www.youtube.com/attribution_link?a=cYtqcczBhJY&u=%2Fwatch%3Fv%3DQT8D8vNkVkk%26feature%3Dshare …
# 0 replies     0 retweets     0 likes

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
#your code
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, len(movies)):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

top_250_data = [print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:',\
  item['star_cast']) for item in imdb]
print(top_250_data)
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino
# 3 - The Godfather: Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro
# 4 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman
# 9 - The Good, the Bad and the Ugly (1966) - Starring: Sergio Leone (dir.), Clint Eastwood, Eli Wallach
# 1 -  Fight Club (1999) - Starring: David Fincher (dir.), Brad Pitt, Edward Norton
# 11 - The Lord of the Rings: The Fellowship of the Ring (2001) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen
# 12 - Forrest Gump (1994) - Starring: Robert Zemeckis (dir.), Tom Hanks, Robin Wright
# 13 - Star Wars: Episode V - The Empire Strikes Back (1980) - Starring: Irvin Kershner (dir.), Mark Hamill, Harrison Ford
# 14 - Inception (2010) - Starring: Christopher Nolan (dir.), Leonardo DiCaprio, Joseph Gordon-Levitt
# 15 - The Lord of the Rings: The Two Towers (2002) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen
# 16 - One Flew Over the Cuckoo's Nest (1975) - Starring: Milos Forman (dir.), Jack Nicholson, Louise Fletcher
# 17 - Goodfellas (1990) - Starring: Martin Scorsese (dir.), Robert De Niro, Ray Liotta
# 18 - The Matrix (1999) - Starring: Lana Wachowski (dir.), Keanu Reeves, Laurence Fishburne
# 19 - Seven Samurai (1954) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Takashi Shimura
# 20 - Se7en (1995) - Starring: David Fincher (dir.), Morgan Freeman, Brad Pitt
# 21 - City of God (2002) - Starring: Fernando Meirelles (dir.), Alexandre Rodrigues, Leandro Firmino
# 22 - Star Wars: Episode IV - A New Hope (1977) - Starring: George Lucas (dir.), Mark Hamill, Harrison Ford
# 23 - The Silence of the Lambs (1991) - Starring: Jonathan Demme (dir.), Jodie Foster, Anthony Hopkins
# 24 - It's a Wonderful Life (1946) - Starring: Frank Capra (dir.), James Stewart, Donna Reed
# 25 - Life Is Beautiful (1997) - Starring: Roberto Benigni (dir.), Roberto Benigni, Nicoletta Braschi
# 26 - Spider-Man: Into the Spider-Verse (2018) - Starring: Bob Persichetti (dir.), Shameik Moore, Jake Johnson
# 27 - The Usual Suspects (1995) - Starring: Bryan Singer (dir.), Kevin Spacey, Gabriel Byrne
# 28 - Spirited Away (2001) - Starring: Hayao Miyazaki (dir.), Daveigh Chase, Suzanne Pleshette
# 29 - Saving Private Ryan (1998) - Starring: Steven Spielberg (dir.), Tom Hanks, Matt Damon
# 30 - Léon: The Professional (1994) - Starring: Luc Besson (dir.), Jean Reno, Gary Oldman
# 31 - The Green Mile (1999) - Starring: Frank Darabont (dir.), Tom Hanks, Michael Clarke Duncan
# 32 - Interstellar (2014) - Starring: Christopher Nolan (dir.), Matthew McConaughey, Anne Hathaway
# 33 - Psycho (1960) - Starring: Alfred Hitchcock (dir.), Anthony Perkins, Janet Leigh
# 34 - American History X (1998) - Starring: Tony Kaye (dir.), Edward Norton, Edward Furlong
# 35 - City Lights (1931) - Starring: Charles Chaplin (dir.), Charles Chaplin, Virginia Cherrill
# 36 - Once Upon a Time in the West (1968) - Starring: Sergio Leone (dir.), Henry Fonda, Charles Bronson
# 37 - Casablanca (1942) - Starring: Michael Curtiz (dir.), Humphrey Bogart, Ingrid Bergman
# 38 - Modern Times (1936) - Starring: Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard
# 39 - The Pianist (2002) - Starring: Roman Polanski (dir.), Adrien Brody, Thomas Kretschmann
# 40 - The Intouchables (2011) - Starring: Olivier Nakache (dir.), François Cluzet, Omar Sy
# 41 - The Departed (2006) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Matt Damon
# 42 - Back to the Future (1985) - Starring: Robert Zemeckis (dir.), Michael J. Fox, Christopher Lloyd
# 43 - Terminator 2: Judgment Day (1991) - Starring: James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton
# 44 - Whiplash (2014) - Starring: Damien Chazelle (dir.), Miles Teller, J.K. Simmons
# 45 - Rear Window (1954) - Starring: Alfred Hitchcock (dir.), James Stewart, Grace Kelly
# 46 - Raiders of the Lost Ark (1981) - Starring: Steven Spielberg (dir.), Harrison Ford, Karen Allen
# 47 - The Lion King (1994) - Starring: Roger Allers (dir.), Matthew Broderick, Jeremy Irons
# 48 - Gladiator (2000) - Starring: Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix
# 49 - The Prestige (2006) - Starring: Christopher Nolan (dir.), Christian Bale, Hugh Jackman
# 50 - Apocalypse Now (1979) - Starring: Francis Ford Coppola (dir.), Martin Sheen, Marlon Brando
# 51 - Memento (2000) - Starring: Christopher Nolan (dir.), Guy Pearce, Carrie-Anne Moss
# 52 - Alien (1979) - Starring: Ridley Scott (dir.), Sigourney Weaver, Tom Skerritt
# 53 - Cinema Paradiso (1988) - Starring: Giuseppe Tornatore (dir.), Philippe Noiret, Enzo Cannavale
# 54 - The Great Dictator (1940) - Starring: Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard
# 55 - Grave of the Fireflies (1988) - Starring: Isao Takahata (dir.), Tsutomu Tatsumi, Ayano Shiraishi
# 56 - Sunset Blvd (1950) - Starring: Billy Wilder (dir.), William Holden, Gloria Swanson
# 57 - The Lives of Others (2006) - Starring: Florian Henckel von Donnersmarck (dir.), Ulrich Mühe, Martina Gedeck
# 58 - Dr Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964) - Starring: Stanley Kubrick (dir.), Peter Sellers, George C. Scott
# 59 - Avengers: Infinity War (2018) - Starring: Anthony Russo (dir.), Robert Downey Jr., Chris Hemsworth
# 60 - Paths of Glory (1957) - Starring: Stanley Kubrick (dir.), Kirk Douglas, Ralph Meeker
# 61 - The Shining (1980) - Starring: Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall
# 62 - Django Unchained (2012) - Starring: Quentin Tarantino (dir.), Jamie Foxx, Christoph Waltz
# 63 - WALL·E (2008) - Starring: Andrew Stanton (dir.), Ben Burtt, Elissa Knight
# 64 - Princess Mononoke (1997) - Starring: Hayao Miyazaki (dir.), Yôji Matsuda, Yuriko Ishida
# 65 - Witness for the Prosecution (1957) - Starring: Billy Wilder (dir.), Tyrone Power, Marlene Dietrich
# 66 - Oldeuboi (2003) - Starring: Chan-wook Park (dir.), Min-sik Choi, Ji-tae Yu
# 67 - The Dark Knight Rises (2012) - Starring: Christopher Nolan (dir.), Christian Bale, Tom Hardy
# 68 - American Beauty (1999) - Starring: Sam Mendes (dir.), Kevin Spacey, Annette Bening
# 69 - Aliens (1986) - Starring: James Cameron (dir.), Sigourney Weaver, Michael Biehn
# 70 - Once Upon a Time in America (1984) - Starring: Sergio Leone (dir.), Robert De Niro, James Woods
# 71 - Coco (2017) - Starring: Lee Unkrich (dir.), Anthony Gonzalez, Gael García Bernal
# 72 - Das Boot (1981) - Starring: Wolfgang Petersen (dir.), Jürgen Prochnow, Herbert Grönemeyer
# 73 - Citizen Kane (1941) - Starring: Orson Welles (dir.), Orson Welles, Joseph Cotten
# 74 - Braveheart (1995) - Starring: Mel Gibson (dir.), Mel Gibson, Sophie Marceau
# 75 - Vertigo (1958) - Starring: Alfred Hitchcock (dir.), James Stewart, Kim Novak
# 76 - North by Northwest (1959) - Starring: Alfred Hitchcock (dir.), Cary Grant, Eva Marie Saint
# 77 - Reservoir Dogs (1992) - Starring: Quentin Tarantino (dir.), Harvey Keitel, Tim Roth
# 78 - Star Wars: Episode VI - Return of the Jedi (1983) - Starring: Richard Marquand (dir.), Mark Hamill, Harrison Ford
# 79 - Your Name (2016) - Starring: Makoto Shinkai (dir.), Ryûnosuke Kamiki, Mone Kamishiraishi
# 80 - M (1931) - Starring: Fritz Lang (dir.), Peter Lorre, Ellen Widmann
# 81 - Amadeus (1984) - Starring: Milos Forman (dir.), F. Murray Abraham, Tom Hulce
# 82 - Dangal (2016) - Starring: Nitesh Tiwari (dir.), Aamir Khan, Sakshi Tanwar
# 83 - Requiem for a Dream (2000) - Starring: Darren Aronofsky (dir.), Ellen Burstyn, Jared Leto
# 84 - Taare Zameen Par (2007) - Starring: Aamir Khan (dir.), Darsheel Safary, Aamir Khan
# 85 - Lawrence of Arabia (1962) - Starring: David Lean (dir.), Peter O'Toole, Alec Guinness
# 86 - 3 Idiots (2009) - Starring: Rajkumar Hirani (dir.), Aamir Khan, Madhavan
# 87 - Eternal Sunshine of the Spotless Mind (2004) - Starring: Michel Gondry (dir.), Jim Carrey, Kate Winslet
# 88 - 2001: A Space Odyssey (1968) - Starring: Stanley Kubrick (dir.), Keir Dullea, Gary Lockwood
# 89 - A Clockwork Orange (1971) - Starring: Stanley Kubrick (dir.), Malcolm McDowell, Patrick Magee
# 90 - Toy Story (1995) - Starring: John Lasseter (dir.), Tom Hanks, Tim Allen
# 91 - Amélie (2001) - Starring: Jean-Pierre Jeunet (dir.), Audrey Tautou, Mathieu Kassovitz
# 92 - Double Indemnity (1944) - Starring: Billy Wilder (dir.), Fred MacMurray, Barbara Stanwyck
# 93 - Singin' in the Rain (1952) - Starring: Stanley Donen (dir.), Gene Kelly, Donald O'Connor
# 94 - Taxi Driver (1976) - Starring: Martin Scorsese (dir.), Robert De Niro, Jodie Foster
# 95 - Inglourious Basterds (2009) - Starring: Quentin Tarantino (dir.), Brad Pitt, Diane Kruger
# 96 - Full Metal Jacket (1987) - Starring: Stanley Kubrick (dir.), Matthew Modine, R. Lee Ermey
# 97 - Bicycle Thieves (1948) - Starring: Vittorio De Sica (dir.), Lamberto Maggiorani, Enzo Staiola
# 98 - To Kill a Mockingbird (1962) - Starring: Robert Mulligan (dir.), Gregory Peck, John Megna
# 99 - The Kid (1921) - Starring: Charles Chaplin (dir.), Charles Chaplin, Edna Purviance
# 10 -  The Sting (1973) - Starring: George Roy Hill (dir.), Paul Newman, Robert Redford
# 101 - Good Will Hunting (1997) - Starring: Gus Van Sant (dir.), Robin Williams, Matt Damon
# 102 - Toy Story 3 (2010) - Starring: Lee Unkrich (dir.), Tom Hanks, Tim Allen
# 103 - Jagten (2012) - Starring: Thomas Vinterberg (dir.), Mads Mikkelsen, Thomas Bo Larsen
# 104 - Snatch (2000) - Starring: Guy Ritchie (dir.), Jason Statham, Brad Pitt
# 105 - Scarface (1983) - Starring: Brian De Palma (dir.), Al Pacino, Michelle Pfeiffer
# 106 - Monty Python and the Holy Grail (1975) - Starring: Terry Gilliam (dir.), Graham Chapman, John Cleese
# 107 - For a Few Dollars More (1965) - Starring: Sergio Leone (dir.), Clint Eastwood, Lee Van Cleef
# 108 - The Apartment (1960) - Starring: Billy Wilder (dir.), Jack Lemmon, Shirley MacLaine
# 109 - Metropolis (1927) - Starring: Fritz Lang (dir.), Brigitte Helm, Alfred Abel
# 110 - LA Confidential (1997) - Starring: Curtis Hanson (dir.), Kevin Spacey, Russell Crowe
# 111 - A Separation (2011) - Starring: Asghar Farhadi (dir.), Payman Maadi, Leila Hatami
# 112 - Indiana Jones and the Last Crusade (1989) - Starring: Steven Spielberg (dir.), Harrison Ford, Sean Connery
# 113 - Rashômon (1950) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Machiko Kyô
# 114 - Up (2009) - Starring: Pete Docter (dir.), Edward Asner, Jordan Nagai
# 115 - All About Eve (1950) - Starring: Joseph L. Mankiewicz (dir.), Bette Davis, Anne Baxter
# 116 - Batman Begins (2005) - Starring: Christopher Nolan (dir.), Christian Bale, Michael Caine
# 117 - Yojimbo (1961) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Eijirô Tôno
# 118 - Some Like It Hot (1959) - Starring: Billy Wilder (dir.), Marilyn Monroe, Tony Curtis
# 119 - Unforgiven (1992) - Starring: Clint Eastwood (dir.), Clint Eastwood, Gene Hackman
# 120 - Downfall (2004) - Starring: Oliver Hirschbiegel (dir.), Bruno Ganz, Alexandra Maria Lara
# 121 - Die Hard (1988) - Starring: John McTiernan (dir.), Bruce Willis, Alan Rickman
# 122 - The Treasure of the Sierra Madre (1948) - Starring: John Huston (dir.), Humphrey Bogart, Walter Huston
# 123 - Heat (1995) - Starring: Michael Mann (dir.), Al Pacino, Robert De Niro
# 124 - Ikiru (1952) - Starring: Akira Kurosawa (dir.), Takashi Shimura, Nobuo Kaneko
# 125 - Incendies (2010) - Starring: Denis Villeneuve (dir.), Lubna Azabal, Mélissa Désormeaux-Poulin
# 126 - Andhadhun (2018) - Starring: Sriram Raghavan (dir.), Ayushmann Khurrana, Tabu
# 127 - Raging Bull (1980) - Starring: Martin Scorsese (dir.), Robert De Niro, Cathy Moriarty
# 128 - The Great Escape (1963) - Starring: John Sturges (dir.), Steve McQueen, James Garner
# 129 - Children of Heaven (1997) - Starring: Majid Majidi (dir.), Mohammad Amir Naji, Amir Farrokh Hashemian
# 130 - Pan's Labyrinth (2006) - Starring: Guillermo del Toro (dir.), Ivana Baquero, Ariadna Gil
# 131 - Babam ve Oglum (2005) - Starring: Çagan Irmak (dir.), Çetin Tekindor, Fikret Kuskan
# 132 - Chinatown (1974) - Starring: Roman Polanski (dir.), Jack Nicholson, Faye Dunaway
# 133 - The Third Man (1949) - Starring: Carol Reed (dir.), Orson Welles, Joseph Cotten
# 134 - My Neighbor Totoro (1988) - Starring: Hayao Miyazaki (dir.), Hitoshi Takagi, Noriko Hidaka
# 135 - Howl's Moving Castle (2004) - Starring: Hayao Miyazaki (dir.), Chieko Baishô, Takuya Kimura
# 136 - Ran (1985) - Starring: Akira Kurosawa (dir.), Tatsuya Nakadai, Akira Terao
# 137 - Judgment at Nuremberg (1961) - Starring: Stanley Kramer (dir.), Spencer Tracy, Burt Lancaster
# 138 - The Secret in Their Eyes (2009) - Starring: Juan José Campanella (dir.), Ricardo Darín, Soledad Villamil
# 139 - The Gold Rush (1925) - Starring: Charles Chaplin (dir.), Charles Chaplin, Mack Swain
# 140 - The Bridge on the River Kwai (1957) - Starring: David Lean (dir.), William Holden, Alec Guinness
# 141 - A Beautiful Mind (2001) - Starring: Ron Howard (dir.), Russell Crowe, Ed Harris
# 142 - Lock, Stock and Two Smoking Barrels (1998) - Starring: Guy Ritchie (dir.), Jason Flemyng, Dexter Fletcher
# 143 - Casino (1995) - Starring: Martin Scorsese (dir.), Robert De Niro, Sharon Stone
# 144 - Three Billboards Outside Ebbing, Missouri (2017) - Starring: Martin McDonagh (dir.), Frances McDormand, Woody Harrelson
# 145 - On the Waterfront (1954) - Starring: Elia Kazan (dir.), Marlon Brando, Karl Malden
# 146 - The Seventh Seal (1957) - Starring: Ingmar Bergman (dir.), Max von Sydow, Gunnar Björnstrand
# 147 - Inside Out (2015) - Starring: Pete Docter (dir.), Amy Poehler, Bill Hader
# 148 - The Elephant Man (1980) - Starring: David Lynch (dir.), Anthony Hopkins, John Hurt
# 149 - The Wolf of Wall Street (2013) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Jonah Hill
# 150 - Room (2015) - Starring: Lenny Abrahamson (dir.), Brie Larson, Jacob Tremblay
# 151 - V for Vendetta (2005) - Starring: James McTeigue (dir.), Hugo Weaving, Natalie Portman
# 152 - Mr Smith Goes to Washington (1939) - Starring: Frank Capra (dir.), James Stewart, Jean Arthur
# 153 - Warrior (2011) - Starring: Gavin O'Connor (dir.), Tom Hardy, Nick Nolte
# 154 - Blade Runner (1982) - Starring: Ridley Scott (dir.), Harrison Ford, Rutger Hauer
# 155 - Dial M for Murder (1954) - Starring: Alfred Hitchcock (dir.), Ray Milland, Grace Kelly
# 156 - Wild Strawberries (1957) - Starring: Ingmar Bergman (dir.), Victor Sjöström, Bibi Andersson
# 157 - The General (1926) - Starring: Clyde Bruckman (dir.), Buster Keaton, Marion Mack
# 158 - No Country for Old Men (2007) - Starring: Ethan Coen (dir.), Tommy Lee Jones, Javier Bardem
# 159 - Trainspotting (1996) - Starring: Danny Boyle (dir.), Ewan McGregor, Ewen Bremner
# 160 - There Will Be Blood (2007) - Starring: Paul Thomas Anderson (dir.), Daniel Day-Lewis, Paul Dano
# 161 - The Sixth Sense (1999) - Starring: M. Night Shyamalan (dir.), Bruce Willis, Haley Joel Osment
# 162 - Gone with the Wind (1939) - Starring: Victor Fleming (dir.), Clark Gable, Vivien Leigh
# 163 - The Thing (1982) - Starring: John Carpenter (dir.), Kurt Russell, Wilford Brimley
# 164 - Fargo (1996) - Starring: Joel Coen (dir.), William H. Macy, Frances McDormand
# 165 - Gran Torino (2008) - Starring: Clint Eastwood (dir.), Clint Eastwood, Bee Vang
# 166 - Bohemian Rhapsody (2018) - Starring: Bryan Singer (dir.), Rami Malek, Lucy Boynton
# 167 - Come and See (1985) - Starring: Elem Klimov (dir.), Aleksey Kravchenko, Olga Mironova
# 168 - Finding Nemo (2003) - Starring: Andrew Stanton (dir.), Albert Brooks, Ellen DeGeneres
# 169 - The Deer Hunter (1978) - Starring: Michael Cimino (dir.), Robert De Niro, Christopher Walken
# 170 - Green Book (2018) - Starring: Peter Farrelly (dir.), Viggo Mortensen, Mahershala Ali
# 171 - Sherlock Jr (1924) - Starring: Buster Keaton (dir.), Buster Keaton, Kathryn McGuire
# 172 - The Big Lebowski (1998) - Starring: Joel Coen (dir.), Jeff Bridges, John Goodman
# 173 - Shutter Island (2010) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Emily Mortimer
# 174 - Kill Bill: Vol 1 (2003) - Starring: Quentin Tarantino (dir.), Uma Thurman, David Carradine
# 175 - Cool Hand Luke (1967) - Starring: Stuart Rosenberg (dir.), Paul Newman, George Kennedy
# 176 - Rebecca (1940) - Starring: Alfred Hitchcock (dir.), Laurence Olivier, Joan Fontaine
# 177 - Tokyo Story (1953) - Starring: Yasujirô Ozu (dir.), Chishû Ryû, Chieko Higashiyama
# 178 - Mary and Max (2009) - Starring: Adam Elliot (dir.), Toni Collette, Philip Seymour Hoffman
# 179 - Hacksaw Ridge (2016) - Starring: Mel Gibson (dir.), Andrew Garfield, Sam Worthington
# 180 - Gone Girl (2014) - Starring: David Fincher (dir.), Ben Affleck, Rosamund Pike
# 181 - How to Train Your Dragon (2010) - Starring: Dean DeBlois (dir.), Jay Baruchel, Gerard Butler
# 182 - Sunrise (1927) - Starring: F.W. Murnau (dir.), George O'Brien, Janet Gaynor
# 183 - Jurassic Park (1993) - Starring: Steven Spielberg (dir.), Sam Neill, Laura Dern
# 184 - Relatos salvajes (2014) - Starring: Damián Szifron (dir.), Darío Grandinetti, María Marull
# 185 - Into the Wild (2007) - Starring: Sean Penn (dir.), Emile Hirsch, Vince Vaughn
# 186 - The Truman Show (1998) - Starring: Peter Weir (dir.), Jim Carrey, Ed Harris
# 187 - In the Name of the Father (1993) - Starring: Jim Sheridan (dir.), Daniel Day-Lewis, Pete Postlethwaite
# 188 - The Grand Budapest Hotel (2014) - Starring: Wes Anderson (dir.), Ralph Fiennes, F. Murray Abraham
# 189 - It Happened One Night (1934) - Starring: Frank Capra (dir.), Clark Gable, Claudette Colbert
# 190 - Stand by Me (1986) - Starring: Rob Reiner (dir.), Wil Wheaton, River Phoenix
# 191 - Life of Brian (1979) - Starring: Terry Jones (dir.), Graham Chapman, John Cleese
# 192 - Stalker (1979) - Starring: Andrei Tarkovsky (dir.), Alisa Freyndlikh, Aleksandr Kaydanovskiy
# 193 - Platoon (1986) - Starring: Oliver Stone (dir.), Charlie Sheen, Tom Berenger
# 194 - The Bandit (1996) - Starring: Yavuz Turgul (dir.), Sener Sen, Ugur Yücel
# 195 - Network (1976) - Starring: Sidney Lumet (dir.), Faye Dunaway, William Holden
# 196 - Memories of Murder (2003) - Starring: Joon-ho Bong (dir.), Kang-ho Song, Sang-kyung Kim
# 197 - Persona (1966) - Starring: Ingmar Bergman (dir.), Bibi Andersson, Liv Ullmann
# 198 - Ben-Hur (1959) - Starring: William Wyler (dir.), Charlton Heston, Jack Hawkins
# 199 - Hotel Rwanda (2004) - Starring: Terry George (dir.), Don Cheadle, Sophie Okonedo
# 200 - 12 Years a Slave (2013) - Starring: Steve McQueen (dir.), Chiwetel Ejiofor, Michael Kenneth Williams
# 201 - Million Dollar Baby (2004) - Starring: Clint Eastwood (dir.), Hilary Swank, Clint Eastwood
# 202 - Andrei Rublev (1966) - Starring: Andrei Tarkovsky (dir.), Anatoliy Solonitsyn, Ivan Lapikov
# 203 - The Passion of Joan of Arc (1928) - Starring: Carl Theodor Dreyer (dir.), Maria Falconetti, Eugene Silvain
# 204 - Before Sunrise (1995) - Starring: Richard Linklater (dir.), Ethan Hawke, Julie Delpy
# 205 - The Wages of Fear (1953) - Starring: Henri-Georges Clouzot (dir.), Yves Montand, Charles Vanel
# 206 - Rush (2013) - Starring: Ron Howard (dir.), Daniel Brühl, Chris Hemsworth
# 207 - Mad Max: Fury Road (2015) - Starring: George Miller (dir.), Tom Hardy, Charlize Theron
# 208 - The 400 Blows (1959) - Starring: François Truffaut (dir.), Jean-Pierre Léaud, Albert Rémy
# 209 - Prisoners (2013) - Starring: Denis Villeneuve (dir.), Hugh Jackman, Jake Gyllenhaal
# 210 - Hachi: A Dog's Tale (2009) - Starring: Lasse Hallström (dir.), Richard Gere, Joan Allen
# 211 - Spotlight (2015) - Starring: Tom McCarthy (dir.), Mark Ruffalo, Michael Keaton
# 212 - Logan (2017) - Starring: James Mangold (dir.), Hugh Jackman, Patrick Stewart
# 213 - Amores Perros (2000) - Starring: Alejandro G. Iñárritu (dir.), Emilio Echevarría, Gael García Bernal
# 214 - Rang De Basanti (2006) - Starring: Rakeysh Omprakash Mehra (dir.), Aamir Khan, Soha Ali Khan
# 215 - Catch Me If You Can (2002) - Starring: Steven Spielberg (dir.), Leonardo DiCaprio, Tom Hanks
# 216 - The Princess Bride (1987) - Starring: Rob Reiner (dir.), Cary Elwes, Mandy Patinkin
# 217 - Nausicaä of the Valley of the Wind (1984) - Starring: Hayao Miyazaki (dir.), Sumi Shimamoto, Mahito Tsujimura
# 218 - Harry Potter and the Deathly Hallows: Part 2 (2011) - Starring: David Yates (dir.), Daniel Radcliffe, Emma Watson
# 219 - Butch Cassidy and the Sundance Kid (1969) - Starring: George Roy Hill (dir.), Paul Newman, Robert Redford
# 220 - Rocky (1976) - Starring: John G. Avildsen (dir.), Sylvester Stallone, Talia Shire
# 221 - Barry Lyndon (1975) - Starring: Stanley Kubrick (dir.), Ryan O'Neal, Marisa Berenson
# 222 - Monsters, Inc (2001) - Starring: Pete Docter (dir.), Billy Crystal, John Goodman
# 223 - The Grapes of Wrath (1940) - Starring: John Ford (dir.), Henry Fonda, Jane Darwell
# 224 - The Maltese Falcon (1941) - Starring: John Huston (dir.), Humphrey Bogart, Mary Astor
# 225 - Dead Poets Society (1989) - Starring: Peter Weir (dir.), Robin Williams, Robert Sean Leonard
# 226 - The Terminator (1984) - Starring: James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton
# 227 - Donnie Darko (2001) - Starring: Richard Kelly (dir.), Jake Gyllenhaal, Jena Malone
# 228 - Gandhi (1982) - Starring: Richard Attenborough (dir.), Ben Kingsley, John Gielgud
# 229 - Diabolique (1955) - Starring: Henri-Georges Clouzot (dir.), Simone Signoret, Véra Clouzot
# 230 - La Haine (1995) - Starring: Mathieu Kassovitz (dir.), Vincent Cassel, Hubert Koundé
# 231 - Groundhog Day (1993) - Starring: Harold Ramis (dir.), Bill Murray, Andie MacDowell
# 232 - In the Mood for Love (2000) - Starring: Kar-Wai Wong (dir.), Tony Chiu-Wai Leung, Maggie Cheung
# 233 - The Nights of Cabiria (1957) - Starring: Federico Fellini (dir.), Giulietta Masina, François Périer
# 234 - The Wizard of Oz (1939) - Starring: Victor Fleming (dir.), Judy Garland, Frank Morgan
# 235 - The Help (2011) - Starring: Tate Taylor (dir.), Emma Stone, Viola Davis
# 236 - Jaws (1975) - Starring: Steven Spielberg (dir.), Roy Scheider, Robert Shaw
# 237 - Ah-ga-ssi (2016) - Starring: Chan-wook Park (dir.), Min-hee Kim, Jung-woo Ha
# 238 - Before Sunset (2004) - Starring: Richard Linklater (dir.), Ethan Hawke, Julie Delpy
# 239 - Tangerines (2013) - Starring: Zaza Urushadze (dir.), Lembit Ulfsak, Elmo Nüganen
# 240 - Drishyam (2015) - Starring: Nishikant Kamat (dir.), Ajay Devgn, Shriya Saran
# 241 - Gangs of Wasseypur (2012) - Starring: Anurag Kashyap (dir.), Manoj Bajpayee, Richa Chadha
# 242 - Paris, Texas (1984) - Starring: Wim Wenders (dir.), Harry Dean Stanton, Nastassja Kinski
# 243 - Castle in the Sky (1986) - Starring: Hayao Miyazaki (dir.), Anna Paquin, James Van Der Beek
# 244 - Paper Moon (1973) - Starring: Peter Bogdanovich (dir.), Ryan O'Neal, Tatum O'Neal
# 245 - Sanjuro (1962) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Tatsuya Nakadai
# 246 - The Best Years of Our Lives (1946) - Starring: William Wyler (dir.), Myrna Loy, Dana Andrews
# 247 - Fanny and Alexander (1982) - Starring: Ingmar Bergman (dir.), Bertil Guve, Pernilla Allwin
# 248 - 8½ (1963) - Starring: Federico Fellini (dir.), Marcello Mastroianni, Anouk Aimée
# 249 - PK (2014) - Starring: Rajkumar Hirani (dir.), Aamir Khan, Anushka Sharma
# 250 - Guardians of the Galaxy (2014) - Starring: James Gunn (dir.), Chris Pratt, Vin Diesel
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
def get_imd_movies(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')
    movies = soup.find_all("td", class_="titleColumn")
    random.shuffle(movies)
    return movies
def get_imd_summary(url):
    movie_page = requests.get(url)
    soup = BeautifulSoup(movie_page.text, 'html.parser')
    return soup.find("div", class_="summary_text").contents[0].strip()

def get_imd_movie_info(movie):
    movie_title = movie.a.contents[0]
    movie_year = movie.span.contents[0]
    movie_url = 'http://www.imdb.com' + movie.a['href']
    return movie_title, movie_year, movie_url

def imd_movie_picker():
    ctr=0
    print("--------------------------------------------")
    for movie in get_imd_movies('http://www.imdb.com/chart/top'):
        movie_title, movie_year, movie_url = get_imd_movie_info(movie)
        movie_summary = get_imd_summary(movie_url)
        print(movie_title, movie_year)
        print(movie_summary)
        print("--------------------------------------------")
        ctr=ctr+1
        if (ctr==10):
          break;   
if __name__ == '__main__':
    imd_movie_picker()
# Out:
# --------------------------------------------
# Amadeus (1984)
# The life, success and troubles of Wolfgang Amadeus Mozart, as told by Antonio Salieri, the contemporary composer who was insanely jealous of Mozart's talent and claimed to have murdered him.
# --------------------------------------------
# Life Is Beautiful (1997)
# When an open-minded Jewish librarian and his son become victims of the Holocaust, he uses a perfect mixture of will, humor, and imagination to protect his son from the dangers around their camp.
# --------------------------------------------
# Butch Cassidy and the Sundance Kid (1969)
# Wyoming, early 1900s. Butch Cassidy and The Sundance Kid are the leaders of a band of outlaws. After a train robbery goes wrong they find themselves on the run with a posse hard on their heels. Their solution - escape to Bolivia.
# --------------------------------------------
# Donnie Darko (2001)
# A troubled teenager is plagued by visions of a man in a large rabbit suit who manipulates him to commit a series of crimes, after he narrowly escapes a bizarre accident.
# --------------------------------------------
# The Princess Bride (1987)
# While home sick in bed, a young boy's grandfather reads him the story of a farmboy-turned-pirate who encounters numerous obstacles, enemies and allies in his quest to be reunited with his true love.
# --------------------------------------------
# 8½ (1963)
# A harried movie director retreats into his memories and fantasies.
# --------------------------------------------
# Dead Poets Society (1989)
# English teacher John Keating inspires his students to look at poetry with a different perspective of authentic knowledge and feelings.
# --------------------------------------------
# Raiders of the Lost Ark (1981)
# In 1936, archaeologist and adventurer Indiana Jones is hired by the U.S. government to find the Ark of the Covenant before
# --------------------------------------------
# Seven Samurai (1954)
# A poor village under attack by bandits recruits seven unemployed samurai to help them defend themselves.
# --------------------------------------------
# Star Wars: Episode VI - Return of the Jedi (1983)
# After a daring mission to rescue Han Solo from Jabba the Hutt, the rebels dispatch to Endor to destroy a more powerful Death Star. Meanwhile, Luke struggles to help Darth Vader back from the dark side without falling into the Emperor's trap.
# --------------------------------------------

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'
# Out:
# Enter the city:Madrid

# %%
# your code
#https://github.com/stanfordjournalism/search-script-scrape
def weather_data(query):
    res=requests.get('http://api.openweathermap.org/data/2.5/weather?'+query+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric');
    return res.json();
def print_weather(result,city):
    print("{}'s temperature: {}°C ".format(city,result['main']['temp']))
    print("Wind speed: {} m/s".format(result['wind']['speed']))
    print("Description: {}".format(result['weather'][0]['description']))
    print("Weather: {}".format(result['weather'][0]['main']))
def main():
    city=input('Enter the city:')
    print()
    try:
        query='q='+city;
        w_data=weather_data(query);
        print_weather(w_data, city)
        print()
    except:
        print('City name not found...')
if __name__=='__main__':
    main()
# Out:
# Enter the city:Madrid
#
# Madrid's temperature: 2.44°C
# Wind speed: 5.7 m/s
# Description: clear sky
# Weather: Clear

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
