# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# import reduce from functools, numpy and pandas
from functools import reduce
import itertools
import numpy as np
import pandas as pd
import re

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up a words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:
location = '../58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')
    print(prophet)
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'The', 'Prophet,', 'by', 'Kahlil', 'Gibran\n\nThis', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and\nmost', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions\nwhatsoever.', '', 'You', 'may', 'copy', 'it,', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms\nof', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at\nwww.gutenberg.org.', '', 'If', 'you', 'are', 'not', 'located', 'in', 'the', 'United', 'States,', "you'll\nhave", 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using\nthis', 'ebook.\n\n\n\nTitle:', 'The', 'Prophet\n\nAuthor:', 'Kahlil', 'Gibran\n\nRelease', 'Date:', 'January', '1,', '2019', '[EBook', '#58585]\nLast', 'Updated:', 'January', '3,', '2018\n\n\nLanguage:', 'English\n\nCharacter', 'set', 'encoding:', 'UTF-8\n\n***', 'START', 'OF', 'THIS', 'PROJECT', 'GUTENBERG', 'EBOOK', 'THE', 'PROPHET', '***\n\n\n\n\nProduced', 'by', 'David', 'Widger', 'from', 'page', 'images', 'generously\nprovided', 'by', 'the', 'Internet', "Archive\n\n\nTranscriber's", 'Note:', 'Page', 'numbers,', 'ie:', '{20},', 'are', 'included', 'in', 'this\nutf-8', 'text', 'file.', 'For', 'those', 'wishing', 'to', 'use', 'a', 'text', 'file', 'unencumbered\nwith', 'page', 'numbers', 'open', 'or', 'download', 'the', 'Latin-1', 'file', '58585-8.txt.\n\n\n\n\n\n\n\nTHE', 'PROPHET\n\nBy', 'Kahlil', 'Gibran\n\nNew', 'York:', 'Alfred', 'A.', 'Knopf\n\n1923\n\n_The', 'Twelve', 'Illustrations', 'In', 'This', 'Volume\nAre', 'Reproduced', 'From', 'Original', 'Drawings', 'By\nThe', 'Author_\n\n\n“His', 'power', 'came', 'from', 'some', 'great', 'reservoir\nof', 'spiritual', 'life', 'else', 'it', 'could', 'not', 'have\nbeen', 'so', 'universal', 'and', 'so', 'potent,', 'but', 'the\nmajesty', 'and', 'beauty', 'of', 'the', 'language', 'with\nwhich', 'he', 'clothed', 'it', 'were', 'all', 'his', 'own?”\n\n--Claude', 'Bragdon\n\n\nTHE', 'BOOKS', 'OF', 'KAHLIL', 'GIBRAN\n\nThe', 'Madman.', '1918', 'Twenty', 'Drawings.', '1919\nThe', 'Forerunner.', '1920', 'The', 'Prophet.', '1923\nSand', 'and', 'Foam.', '1926', 'Jesus', 'the', 'Son', 'of\nMan.', '1928', 'The', 'Forth', 'Gods.', '1931', 'The\nWanderer.', '1932', 'The', 'Garden', 'of', 'the', 'Prophet\n1933', 'Prose', 'Poems.', '1934', 'Nymphs', 'of', 'the\nValley.', '1948\n\n\n\n\nCONTENTS\n\n', '', '', '', '', '', '', '', '', '', 'The', 'Coming', 'of', 'the', 'Ship.......7\n', '', '', '', '', '', '', '', '', '', 'On', 'Love.....................15\n', '', '', '', '', '', '', '', '', '', 'On', 'Marriage.................19\n', '', '', '', '', '', '', '', '', '', 'On', 'Children.................21\n', '', '', '', '', '', '', '', '', '', 'On', 'Giving...................23\n', '', '', '', '', '', '', '', '', '', 'On', 'Eating', 'and', 'Drinking......27\n', '', '', '', '', '', '', '', '', '', 'On', 'Work.....................31\n', '', '', '', '', '', '', '', '', '', 'On', 'Joy', 'and', 'Sorrow...........33\n', '', '', '', '', '', '', '', '', '', 'On', 'Houses...................37\n', '', '', '', '', '', '', '', '', '', 'On', 'Clothes..................41\n', '', '', '', '', '', '', '', '', '', 'On', 'Buying', 'and', 'Selling.......43\n', '', '', '', '', '', '', '', '', '', 'On', 'Crime', 'and', 'Punishment.....45\n', '', '', '', '', '', '', '', '', '', 'On', 'Laws.....................51\n', '', '', '', '', '', '', '', '', '', 'On', 'Freedom..................55\n', '', '', '', '', '', '', '', '', '', 'On', 'Reason', 'and', 'Passion.......57\n', '', '', '', '', '', '', '', '', '', 'On', 'Pain.....................60\n', '', '', '', '', '', '', '', '', '', 'On', 'Self-Knowledge...........62\n', '', '', '', '', '', '', '', '', '', 'On', 'Teaching.................64\n', '', '', '', '', '', '', '', '', '', 'On', 'Friendship...............66\n', '', '', '', '', ...

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# Your code here:
index=568

new_pro=[el for el in prophet if prophet.index(el) >= 568]
print(new_pro)
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'the\nbeloved,', 'who', 'was', 'dawn', 'unto', 'own\nday,', 'had', 'waited', 'twelve', 'years', 'city\nof', 'Orphalese', 'ship', 'that', 'was', 'to\nreturn', 'bear', 'him', 'back', 'isle', 'of\nhis', 'birth.\n\nAnd', 'twelfth', 'year,', 'on', 'seventh\nday', 'Ielool,', 'month', 'reaping,', 'he\nclimbed', 'hill', 'without', 'city', 'walls\nand', 'looked', 'seaward;', 'beheld', 'his\nship', 'coming', 'mist.\n\nThen', 'gates', 'heart', 'flung\nopen,', 'joy', 'flew', 'far', 'over', 'sea.\nAnd', 'closed', 'eyes', 'prayed', 'the\nsilences', 'soul.\n\n*****\n\nBut', 'as', 'descended', 'hill,', 'sadness\ncame', 'upon', 'him,', 'thought', 'his\nheart:\n\nHow', 'shall', 'I', 'go', 'peace', 'without\nsorrow?', 'Nay,', 'without', 'wound', 'the\nspirit', 'shall', 'I', 'leave', 'city.', '{8}Long\nwere', 'days', 'pain', 'I', 'have', 'spent\nwithin', 'its', 'walls,', 'long', 'the\nnights', 'aloneness;', 'who', 'can', 'depart\nfrom', 'pain', 'aloneness', 'without\nregret?\n\nToo', 'many', 'fragments', 'spirit', 'have', 'I\nscattered', 'these', 'streets,', 'too', 'many\nare', 'children', 'my', 'longing', 'that', 'walk\nnaked', 'among', 'these', 'hills,', 'I', 'cannot\nwithdraw', 'them', 'without', 'burden', 'and\nan', 'ache.\n\nIt', 'garment', 'I', 'cast', 'off', 'this\nday,', 'skin', 'that', 'I', 'tear', 'my', 'own\nhands.\n\nNor', 'thought', 'I', 'leave', 'behind', 'me,\nbut', 'heart', 'made', 'sweet', 'hunger', 'and\nwith', 'thirst.\n\n*****\n\nYet', 'I', 'cannot', 'tarry', 'longer.\n\nThe', 'sea', 'that', 'calls', 'things', 'unto', 'her\ncalls', 'me,', 'I', 'must', 'embark.\n\nFor', 'stay,', 'though', 'hours', 'burn', 'in\nthe', 'night,', 'freeze', 'crystallize\nand', 'be', 'bound', 'mould.\n\nFain', 'would', 'I', 'take', 'me', 'that', 'is\nhere.', 'But', 'how', 'shall', 'I?\n\nA', 'voice', 'cannot', 'carry', 'tongue', 'and\n{9}the', 'lips', 'that', 'gave', 'wings.', 'Alone\nmust', 'seek', 'ether.\n\nAnd', 'alone', 'without', 'nest', 'shall', 'the\neagle', 'fly', 'across', 'sun.\n\n*****\n\nNow', 'when', 'reached', 'foot', 'the\nhill,', 'turned', 'again', 'towards', 'sea,\nand', 'saw', 'ship', 'approaching', 'the\nharbour,', 'upon', 'her', 'prow', 'mariners,\nthe', 'men', 'own', 'land.\n\nAnd', 'soul', 'cried', 'out', 'them,', 'he\nsaid:\n\nSons', 'my', 'ancient', 'mother,', 'riders', 'of\nthe', 'tides,\n\nHow', 'often', 'have', 'sailed', 'my', 'dreams.\nAnd', 'now', 'come', 'my', 'awakening,', 'which\nis', 'my', 'deeper', 'dream.\n\nReady', 'am', 'I', 'go,', 'my', 'eagerness', 'with\nsails', 'full', 'awaits', 'wind.\n\nOnly', 'another', 'breath', 'will', 'I', 'breathe', 'in\nthis', 'still', 'air,', 'only', 'another', 'loving', 'look\ncast', 'backward,\n\nAnd', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'a\nseafarer', 'among', 'seafarers.', '{10}And', 'you,\nvast', 'sea,', 'sleepless', 'mother,\n\nWho', 'alone', 'peace', 'freedom', 'the\nriver', 'stream,\n\nOnly', 'another', 'winding', 'will', 'stream\nmake,', 'only', 'another', 'murmur', 'glade,\n\nAnd', 'then', 'shall', 'I', 'come', 'you,', 'a\nboundless', 'drop', 'boundless', 'ocean.\n\n*****\n\nAnd', 'as', 'walked', 'saw', 'afar', 'men\nand', 'women', 'leaving', 'their', 'fields', 'their\nvineyards', 'hastening', 'towards', 'city\ngates.\n\nAnd', 'heard', 'their', 'voices', 'calling', 'his\nname,', 'shouting', 'field', 'field\ntelling', 'one', 'another', 'coming', 'his\nship.\n\nAnd', 'said', 'himself:\n\nShall', 'day', 'parting', 'be', 'day', 'of\ngathering?\n\nAnd', 'shall', 'be', 'said', 'that', 'my', 'eve', 'was', 'in\ntruth', 'my', 'dawn?\n\nAnd', 'what', 'shall', 'I', 'unto', 'him', 'who', 'has\nleft', 'plough', 'midfurrow,', 'to\nhim', 'who', 'has', 'stopped', 'wheel', 'his\nwinepress?', '{11}Shall', 'my', 'heart', 'become', 'a\ntree', 'heavy-laden', 'fruit', 'that', 'I', 'may\ngather', 'unto', 'them?\n\nAnd', 'shall', 'my', 'desires', 'flow', 'like', 'a\nfountain', 'that', 'I', 'fill', 'their', 'cups?\n\nAm', 'I', 'harp', 'that ...

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# Your code here:
one_to_one=new_pro[:10]
print(one_to_one)
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'the\nbeloved,', 'who', 'was', 'dawn', 'unto', 'own\nday,', 'had']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    
    # Your code here:
    return re.sub(r'{\d+}','',x)

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`

# %%
# Your code here:
prophet_reference=(list(map(reference,new_pro)))
print(prophet_reference)
# Out:
# ['PROPHET\n\n|Almustafa,', 'the', 'chosen', 'the\nbeloved,', 'who', 'was', 'dawn', 'unto', 'own\nday,', 'had', 'waited', 'twelve', 'years', 'city\nof', 'Orphalese', 'ship', 'that', 'was', 'to\nreturn', 'bear', 'him', 'back', 'isle', 'of\nhis', 'birth.\n\nAnd', 'twelfth', 'year,', 'on', 'seventh\nday', 'Ielool,', 'month', 'reaping,', 'he\nclimbed', 'hill', 'without', 'city', 'walls\nand', 'looked', 'seaward;', 'beheld', 'his\nship', 'coming', 'mist.\n\nThen', 'gates', 'heart', 'flung\nopen,', 'joy', 'flew', 'far', 'over', 'sea.\nAnd', 'closed', 'eyes', 'prayed', 'the\nsilences', 'soul.\n\n*****\n\nBut', 'as', 'descended', 'hill,', 'sadness\ncame', 'upon', 'him,', 'thought', 'his\nheart:\n\nHow', 'shall', 'I', 'go', 'peace', 'without\nsorrow?', 'Nay,', 'without', 'wound', 'the\nspirit', 'shall', 'I', 'leave', 'city.', 'Long\nwere', 'days', 'pain', 'I', 'have', 'spent\nwithin', 'its', 'walls,', 'long', 'the\nnights', 'aloneness;', 'who', 'can', 'depart\nfrom', 'pain', 'aloneness', 'without\nregret?\n\nToo', 'many', 'fragments', 'spirit', 'have', 'I\nscattered', 'these', 'streets,', 'too', 'many\nare', 'children', 'my', 'longing', 'that', 'walk\nnaked', 'among', 'these', 'hills,', 'I', 'cannot\nwithdraw', 'them', 'without', 'burden', 'and\nan', 'ache.\n\nIt', 'garment', 'I', 'cast', 'off', 'this\nday,', 'skin', 'that', 'I', 'tear', 'my', 'own\nhands.\n\nNor', 'thought', 'I', 'leave', 'behind', 'me,\nbut', 'heart', 'made', 'sweet', 'hunger', 'and\nwith', 'thirst.\n\n*****\n\nYet', 'I', 'cannot', 'tarry', 'longer.\n\nThe', 'sea', 'that', 'calls', 'things', 'unto', 'her\ncalls', 'me,', 'I', 'must', 'embark.\n\nFor', 'stay,', 'though', 'hours', 'burn', 'in\nthe', 'night,', 'freeze', 'crystallize\nand', 'be', 'bound', 'mould.\n\nFain', 'would', 'I', 'take', 'me', 'that', 'is\nhere.', 'But', 'how', 'shall', 'I?\n\nA', 'voice', 'cannot', 'carry', 'tongue', 'and\nthe', 'lips', 'that', 'gave', 'wings.', 'Alone\nmust', 'seek', 'ether.\n\nAnd', 'alone', 'without', 'nest', 'shall', 'the\neagle', 'fly', 'across', 'sun.\n\n*****\n\nNow', 'when', 'reached', 'foot', 'the\nhill,', 'turned', 'again', 'towards', 'sea,\nand', 'saw', 'ship', 'approaching', 'the\nharbour,', 'upon', 'her', 'prow', 'mariners,\nthe', 'men', 'own', 'land.\n\nAnd', 'soul', 'cried', 'out', 'them,', 'he\nsaid:\n\nSons', 'my', 'ancient', 'mother,', 'riders', 'of\nthe', 'tides,\n\nHow', 'often', 'have', 'sailed', 'my', 'dreams.\nAnd', 'now', 'come', 'my', 'awakening,', 'which\nis', 'my', 'deeper', 'dream.\n\nReady', 'am', 'I', 'go,', 'my', 'eagerness', 'with\nsails', 'full', 'awaits', 'wind.\n\nOnly', 'another', 'breath', 'will', 'I', 'breathe', 'in\nthis', 'still', 'air,', 'only', 'another', 'loving', 'look\ncast', 'backward,\n\nAnd', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'a\nseafarer', 'among', 'seafarers.', 'And', 'you,\nvast', 'sea,', 'sleepless', 'mother,\n\nWho', 'alone', 'peace', 'freedom', 'the\nriver', 'stream,\n\nOnly', 'another', 'winding', 'will', 'stream\nmake,', 'only', 'another', 'murmur', 'glade,\n\nAnd', 'then', 'shall', 'I', 'come', 'you,', 'a\nboundless', 'drop', 'boundless', 'ocean.\n\n*****\n\nAnd', 'as', 'walked', 'saw', 'afar', 'men\nand', 'women', 'leaving', 'their', 'fields', 'their\nvineyards', 'hastening', 'towards', 'city\ngates.\n\nAnd', 'heard', 'their', 'voices', 'calling', 'his\nname,', 'shouting', 'field', 'field\ntelling', 'one', 'another', 'coming', 'his\nship.\n\nAnd', 'said', 'himself:\n\nShall', 'day', 'parting', 'be', 'day', 'of\ngathering?\n\nAnd', 'shall', 'be', 'said', 'that', 'my', 'eve', 'was', 'in\ntruth', 'my', 'dawn?\n\nAnd', 'what', 'shall', 'I', 'unto', 'him', 'who', 'has\nleft', 'plough', 'midfurrow,', 'to\nhim', 'who', 'has', 'stopped', 'wheel', 'his\nwinepress?', 'Shall', 'my', 'heart', 'become', 'a\ntree', 'heavy-laden', 'fruit', 'that', 'I', 'may\ngather', 'unto', 'them?\n\nAnd', 'shall', 'my', 'desires', 'flow', 'like', 'a\nfountain', 'that', 'I', 'fill', 'their', 'cups?\n\nAm', 'I', 'harp', 'that', 'hand', 'might ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # Your code here:
    s= [x.split('\n') for x in prophet_reference]
    return s

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# Your code here:
prophet_line=(line_break(prophet_reference))
print(prophet_line)
# Out:
# [['PROPHET', '', '|Almustafa,'], ['the'], ['chosen'], ['the', 'beloved,'], ['who'], ['was'], ['dawn'], ['unto'], ['own', 'day,'], ['had'], ['waited'], ['twelve'], ['years'], ['city', 'of'], ['Orphalese'], ['ship'], ['that'], ['was'], ['to', 'return'], ['bear'], ['him'], ['back'], ['isle'], ['of', 'his'], ['birth.', '', 'And'], ['twelfth'], ['year,'], ['on'], ['seventh', 'day'], ['Ielool,'], ['month'], ['reaping,'], ['he', 'climbed'], ['hill'], ['without'], ['city'], ['walls', 'and'], ['looked'], ['seaward;'], ['beheld'], ['his', 'ship'], ['coming'], ['mist.', '', 'Then'], ['gates'], ['heart'], ['flung', 'open,'], ['joy'], ['flew'], ['far'], ['over'], ['sea.', 'And'], ['closed'], ['eyes'], ['prayed'], ['the', 'silences'], ['soul.', '', '*****', '', 'But'], ['as'], ['descended'], ['hill,'], ['sadness', 'came'], ['upon'], ['him,'], ['thought'], ['his', 'heart:', '', 'How'], ['shall'], ['I'], ['go'], ['peace'], ['without', 'sorrow?'], ['Nay,'], ['without'], ['wound'], ['the', 'spirit'], ['shall'], ['I'], ['leave'], ['city.'], ['Long', 'were'], ['days'], ['pain'], ['I'], ['have'], ['spent', 'within'], ['its'], ['walls,'], ['long'], ['the', 'nights'], ['aloneness;'], ['who'], ['can'], ['depart', 'from'], ['pain'], ['aloneness'], ['without', 'regret?', '', 'Too'], ['many'], ['fragments'], ['spirit'], ['have'], ['I', 'scattered'], ['these'], ['streets,'], ['too'], ['many', 'are'], ['children'], ['my'], ['longing'], ['that'], ['walk', 'naked'], ['among'], ['these'], ['hills,'], ['I'], ['cannot', 'withdraw'], ['them'], ['without'], ['burden'], ['and', 'an'], ['ache.', '', 'It'], ['garment'], ['I'], ['cast'], ['off'], ['this', 'day,'], ['skin'], ['that'], ['I'], ['tear'], ['my'], ['own', 'hands.', '', 'Nor'], ['thought'], ['I'], ['leave'], ['behind'], ['me,', 'but'], ['heart'], ['made'], ['sweet'], ['hunger'], ['and', 'with'], ['thirst.', '', '*****', '', 'Yet'], ['I'], ['cannot'], ['tarry'], ['longer.', '', 'The'], ['sea'], ['that'], ['calls'], ['things'], ['unto'], ['her', 'calls'], ['me,'], ['I'], ['must'], ['embark.', '', 'For'], ['stay,'], ['though'], ['hours'], ['burn'], ['in', 'the'], ['night,'], ['freeze'], ['crystallize', 'and'], ['be'], ['bound'], ['mould.', '', 'Fain'], ['would'], ['I'], ['take'], ['me'], ['that'], ['is', 'here.'], ['But'], ['how'], ['shall'], ['I?', '', 'A'], ['voice'], ['cannot'], ['carry'], ['tongue'], ['and', 'the'], ['lips'], ['that'], ['gave'], ['wings.'], ['Alone', 'must'], ['seek'], ['ether.', '', 'And'], ['alone'], ['without'], ['nest'], ['shall'], ['the', 'eagle'], ['fly'], ['across'], ['sun.', '', '*****', '', 'Now'], ['when'], ['reached'], ['foot'], ['the', 'hill,'], ['turned'], ['again'], ['towards'], ['sea,', 'and'], ['saw'], ['ship'], ['approaching'], ['the', 'harbour,'], ['upon'], ['her'], ['prow'], ['mariners,', 'the'], ['men'], ['own'], ['land.', '', 'And'], ['soul'], ['cried'], ['out'], ['them,'], ['he', 'said:', '', 'Sons'], ['my'], ['ancient'], ['mother,'], ['riders'], ['of', 'the'], ['tides,', '', 'How'], ['often'], ['have'], ['sailed'], ['my'], ['dreams.', 'And'], ['now'], ['come'], ['my'], ['awakening,'], ['which', 'is'], ['my'], ['deeper'], ['dream.', '', 'Ready'], ['am'], ['I'], ['go,'], ['my'], ['eagerness'], ['with', 'sails'], ['full'], ['awaits'], ['wind.', '', 'Only'], ['another'], ['breath'], ['will'], ['I'], ['breathe'], ['in', 'this'], ['still'], ['air,'], ['only'], ['another'], ['loving'], ['look', 'cast'], ['backward,', '', 'And'], ['then'], ['I'], ['shall'], ['stand'], ['among'], ['you,'], ['a', 'seafarer'], ['among'], ['seafarers.'], ['And'], ['you,', 'vast'], ['sea,'], ['sleepless'], ['mother,', '', 'Who'], ['alone'], ['peace'], ['freedom'], ['the', 'river'], ['stream,', '', 'Only'], ['another'], ['winding'], ['will'], ['stream', 'make,'], ['only'], ['another'], ['murmur'], ['glade,', '', 'And'], ['then'], ['shall'], ['I'], ['come'], ['you,'], ['a', 'boundless'], ['drop'], ['boundless'], ['ocean.', '', '*****', '', 'And'], ['as'], ['walked'], ['saw'], ['afar'], ['men', 'an ...

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# Your code here:
prophet_flat=[item for sublist in prophet_line for item in sublist]
print(prophet_flat)
# Out:
# ['PROPHET', '', '|Almustafa,', 'the', 'chosen', 'the', 'beloved,', 'who', 'was', 'dawn', 'unto', 'own', 'day,', 'had', 'waited', 'twelve', 'years', 'city', 'of', 'Orphalese', 'ship', 'that', 'was', 'to', 'return', 'bear', 'him', 'back', 'isle', 'of', 'his', 'birth.', '', 'And', 'twelfth', 'year,', 'on', 'seventh', 'day', 'Ielool,', 'month', 'reaping,', 'he', 'climbed', 'hill', 'without', 'city', 'walls', 'and', 'looked', 'seaward;', 'beheld', 'his', 'ship', 'coming', 'mist.', '', 'Then', 'gates', 'heart', 'flung', 'open,', 'joy', 'flew', 'far', 'over', 'sea.', 'And', 'closed', 'eyes', 'prayed', 'the', 'silences', 'soul.', '', '*****', '', 'But', 'as', 'descended', 'hill,', 'sadness', 'came', 'upon', 'him,', 'thought', 'his', 'heart:', '', 'How', 'shall', 'I', 'go', 'peace', 'without', 'sorrow?', 'Nay,', 'without', 'wound', 'the', 'spirit', 'shall', 'I', 'leave', 'city.', 'Long', 'were', 'days', 'pain', 'I', 'have', 'spent', 'within', 'its', 'walls,', 'long', 'the', 'nights', 'aloneness;', 'who', 'can', 'depart', 'from', 'pain', 'aloneness', 'without', 'regret?', '', 'Too', 'many', 'fragments', 'spirit', 'have', 'I', 'scattered', 'these', 'streets,', 'too', 'many', 'are', 'children', 'my', 'longing', 'that', 'walk', 'naked', 'among', 'these', 'hills,', 'I', 'cannot', 'withdraw', 'them', 'without', 'burden', 'and', 'an', 'ache.', '', 'It', 'garment', 'I', 'cast', 'off', 'this', 'day,', 'skin', 'that', 'I', 'tear', 'my', 'own', 'hands.', '', 'Nor', 'thought', 'I', 'leave', 'behind', 'me,', 'but', 'heart', 'made', 'sweet', 'hunger', 'and', 'with', 'thirst.', '', '*****', '', 'Yet', 'I', 'cannot', 'tarry', 'longer.', '', 'The', 'sea', 'that', 'calls', 'things', 'unto', 'her', 'calls', 'me,', 'I', 'must', 'embark.', '', 'For', 'stay,', 'though', 'hours', 'burn', 'in', 'the', 'night,', 'freeze', 'crystallize', 'and', 'be', 'bound', 'mould.', '', 'Fain', 'would', 'I', 'take', 'me', 'that', 'is', 'here.', 'But', 'how', 'shall', 'I?', '', 'A', 'voice', 'cannot', 'carry', 'tongue', 'and', 'the', 'lips', 'that', 'gave', 'wings.', 'Alone', 'must', 'seek', 'ether.', '', 'And', 'alone', 'without', 'nest', 'shall', 'the', 'eagle', 'fly', 'across', 'sun.', '', '*****', '', 'Now', 'when', 'reached', 'foot', 'the', 'hill,', 'turned', 'again', 'towards', 'sea,', 'and', 'saw', 'ship', 'approaching', 'the', 'harbour,', 'upon', 'her', 'prow', 'mariners,', 'the', 'men', 'own', 'land.', '', 'And', 'soul', 'cried', 'out', 'them,', 'he', 'said:', '', 'Sons', 'my', 'ancient', 'mother,', 'riders', 'of', 'the', 'tides,', '', 'How', 'often', 'have', 'sailed', 'my', 'dreams.', 'And', 'now', 'come', 'my', 'awakening,', 'which', 'is', 'my', 'deeper', 'dream.', '', 'Ready', 'am', 'I', 'go,', 'my', 'eagerness', 'with', 'sails', 'full', 'awaits', 'wind.', '', 'Only', 'another', 'breath', 'will', 'I', 'breathe', 'in', 'this', 'still', 'air,', 'only', 'another', 'loving', 'look', 'cast', 'backward,', '', 'And', 'then', 'I', 'shall', 'stand', 'among', 'you,', 'a', 'seafarer', 'among', 'seafarers.', 'And', 'you,', 'vast', 'sea,', 'sleepless', 'mother,', '', 'Who', 'alone', 'peace', 'freedom', 'the', 'river', 'stream,', '', 'Only', 'another', 'winding', 'will', 'stream', 'make,', 'only', 'another', 'murmur', 'glade,', '', 'And', 'then', 'shall', 'I', 'come', 'you,', 'a', 'boundless', 'drop', 'boundless', 'ocean.', '', '*****', '', 'And', 'as', 'walked', 'saw', 'afar', 'men', 'and', 'women', 'leaving', 'their', 'fields', 'their', 'vineyards', 'hastening', 'towards', 'city', 'gates.', '', 'And', 'heard', 'their', 'voices', 'calling', 'his', 'name,', 'shouting', 'field', 'field', 'telling', 'one', 'another', 'coming', 'his', 'ship.', '', 'And', 'said', 'himself:', '', 'Shall', 'day', 'parting', 'be', 'day', 'of', 'gathering?', '', 'And', 'shall', 'be', 'said', 'that', 'my', 'eve', 'was', 'in', 'truth', 'my', 'dawn?', '', 'And', 'what', 'shall', 'I', 'unto', 'him', 'who', 'has', 'left', 'plough', 'midfurrow,', 'to', 'him', 'who', 'has', 'stopped', 'wheel', 'his', 'winepre ...

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: true if the word is not in the specified list and false if the word is in the list
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:
    word_filter=list(filter(lambda x: x not in word_list, prophet_flat))
    return word_filter
prophet_filter= word_filter(prophet_flat)
# Out:
# ['PROPHET',
#  '',
#  '|Almustafa,',
#  'chosen',
#  'beloved,',
#  'who',
#  'was',
#  'dawn',
#  'unto',
#  'own',
#  'day,',
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'city',
#  'of',
#  'Orphalese',
#  'ship',
#  'that',
#  'was',
#  'to',
#  'return',
#  'bear',
#  'him',
#  'back',
#  'isle',
#  'of',
#  'his',
#  'birth.',
#  '',
#  'And',
#  'twelfth',
#  'year,',
#  'on',
#  'seventh',
#  'day',
#  'Ielool,',
#  'month',
#  'reaping,',
#  'he',
#  'climbed',
#  'hill',
#  'without',
#  'city',
#  'walls',
#  'looked',
#  'seaward;',
#  'beheld',
#  'his',
#  'ship',
#  'coming',
#  'mist.',
#  '',
#  'Then',
#  'gates',
#  'heart',
#  'flung',
#  'open,',
#  'joy',
#  'flew',
#  'far',
#  'over',
#  'sea.',
#  'And',
#  'closed',
#  'eyes',
#  'prayed',
#  'silences',
#  'soul.',
#  '',
#  '*****',
#  '',
#  'But',
#  'as',
#  'descended',
#  'hill,',
#  'sadness',
#  'came',
#  'upon',
#  'him,',
#  'thought',
#  'his',
#  'heart:',
#  '',
#  'How',
#  'shall',
#  'I',
#  'go',
#  'peace',
#  'without',
#  'sorrow?',
#  'Nay,',
#  'without',
#  'wound',
#  'spirit',
#  'shall',
#  'I',
#  'leave',
#  'city.',
#  'Long',
#  'were',
#  'days',
#  'pain',
#  'I',
#  'have',
#  'spent',
#  'within',
#  'its',
#  'walls,',
#  'long',
#  'nights',
#  'aloneness;',
#  'who',
#  'can',
#  'depart',
#  'from',
#  'pain',
#  'aloneness',
#  'without',
#  'regret?',
#  '',
#  'Too',
#  'many',
#  'fragments',
#  'spirit',
#  'have',
#  'I',
#  'scattered',
#  'these',
#  'streets,',
#  'too',
#  'many',
#  'are',
#  'children',
#  'my',
#  'longing',
#  'that',
#  'walk',
#  'naked',
#  'among',
#  'these',
#  'hills,',
#  'I',
#  'cannot',
#  'withdraw',
#  'them',
#  'without',
#  'burden',
#  'ache.',
#  '',
#  'It',
#  'garment',
#  'I',
#  'cast',
#  'off',
#  'this',
#  'day,',
#  'skin',
#  'that',
#  'I',
#  'tear',
#  'my',
#  'own',
#  'hands.',
#  '',
#  'Nor',
#  'thought',
#  'I',
#  'leave',
#  'behind',
#  'me,',
#  'but',
#  'heart',
#  'made',
#  'sweet',
#  'hunger',
#  'with',
#  'thirst.',
#  '',
#  '*****',
#  '',
#  'Yet',
#  'I',
#  'cannot',
#  'tarry',
#  'longer.',
#  '',
#  'The',
#  'sea',
#  'that',
#  'calls',
#  'things',
#  'unto',
#  'her',
#  'calls',
#  'me,',
#  'I',
#  'must',
#  'embark.',
#  '',
#  'For',
#  'stay,',
#  'though',
#  'hours',
#  'burn',
#  'in',
#  'night,',
#  'freeze',
#  'crystallize',
#  'be',
#  'bound',
#  'mould.',
#  '',
#  'Fain',
#  'would',
#  'I',
#  'take',
#  'me',
#  'that',
#  'is',
#  'here.',
#  'But',
#  'how',
#  'shall',
#  'I?',
#  '',
#  'A',
#  'voice',
#  'cannot',
#  'carry',
#  'tongue',
#  'lips',
#  'that',
#  'gave',
#  'wings.',
#  'Alone',
#  'must',
#  'seek',
#  'ether.',
#  '',
#  'And',
#  'alone',
#  'without',
#  'nest',
#  'shall',
#  'eagle',
#  'fly',
#  'across',
#  'sun.',
#  '',
#  '*****',
#  '',
#  'Now',
#  'when',
#  'reached',
#  'foot',
#  'hill,',
#  'turned',
#  'again',
#  'towards',
#  'sea,',
#  'saw',
#  'ship',
#  'approaching',
#  'harbour,',
#  'upon',
#  'her',
#  'prow',
#  'mariners,',
#  'men',
#  'own',
#  'land.',
#  '',
#  'And',
#  'soul',
#  'cried',
#  'out',
#  'them,',
#  'he',
#  'said:',
#  '',
#  'Sons',
#  'my',
#  'ancient',
#  'mother,',
#  'riders',
#  'of',
#  'tides,',
#  '',
#  'How',
#  'often',
#  'have',
#  'sailed',
#  'my',
#  'dreams.',
#  'And',
#  'now',
#  'come',
#  'my',
#  'awakening,',
#  'which',
#  'is',
#  'my',
#  'deeper',
#  'dream.',
#  '',
#  'Ready',
#  'am',
#  'I',
#  'go,',
#  'my',
#  'eagerness',
#  'with',
#  'sails',
#  'full',
#  'awaits',
#  'wind.',
#  '',
#  'Only',
#  'another',
#  'breath',
#  'will',
#  'I',
#  'breathe',
#  'in',
#  'this',
#  'still',
#  'air,',
#  'only',
#  'another',
#  'loving',
#  'look',
#  'cast',
#  'backward,',
#  '',
#  'And',
#  'then',
#  'I',
#  'shall',
#  'stand',
#  'among',
#  'you,',
#  'seafarer',
#  'among',
#  'seafarers.',
#  'And',
#  'you,',
#  'vast',
#  'sea,',
#  'sleepless',
#  'mother,',
#  '',
#  'Who',
#  'alone',
#  'peace',
#  'freedom',
#  'river',
#  'stream,',
#  '',
#  'Only',
#  'another',
#  'winding',
#  'will',
#  'stream',
#  'make,',
#  'only',
#  'another',
#  'murmur',
#  'glade,',
#  '',
#  'And',
#  'then',
#  'shall',
#  'I',
#  'come',
#  'you,',
#  'boundless',
#  'drop',
#  'boundless',
#  'ocean.',
#  '',
#  '*****',
#  '',
#  'And',
#  'as',
#  'walked',
#  'saw',
#  'afar',
#  'men',
#  'women',
#  'leaving',
#  'their',
#  'fields',
#  'their',
#  'vineyards',
#  'hastening',
#  'towards',
#  'city',
#  'gates.',
#  '',
#  'And',
#  'heard',
#  'their',
#  'voices',
#  'calling',
#  'his',
#  'name,',
#  'shouting',
#  'field',
#  'field',
#  'telling',
#  'one',
#  'another',
#  'coming',
#  'his',
#  'ship.',
#  '',
#  'And',
#  'said',
#  'himself:',
#  '',
#  'Shall',
#  'day',
#  'parting',
#  'be',
#  'day',
#  'of',
#  'gathering?',
#  '',
#  'And',
#  'shall',
#  'be',
#  'said',
#  'that',
#  'my',
#  'eve',
#  'was',
#  'in',
#  'truth',
#  'my',
#  'dawn?',
#  '',
#  'And',
#  'what',
#  'shall',
#  'I',
#  'unto',
#  'him',
#  'who',
#  'has',
#  'left',
#  'plough',
#  'midfurrow,',
#  'to',
#  'him',
#  'who',
#  'has',
#  'stopped',
#  'wheel',
#  'his',
#  'winepress?',
#  'Shall',
#  'my',
#  'heart',
#  'become',
#  'tree',
#  'heavy-laden',
#  'fruit',
#  'that',
#  'I',
#  'may',
#  'gather',
#  'unto',
#  'them?',
#  '',
#  'And',
#  'shall',
#  'my',
#  'desires',
#  'flow',
#  'like',
#  'fountain',
#  'that',
#  'I',
#  'fill',
#  'their',
#  'cups?',
#  '',
#  'Am',
#  'I',
#  'harp',
#  'that',
#  'hand',
#  'mighty',
#  'may',
#  'touch',
#  'me,',
#  'flute',
#  'that',
#  'breath',
#  'may',
#  'pass',
#  'through',
#  'me?',
#  '',
#  'A',
#  'seeker',
#  'silences',
#  'am',
#  'I,',
#  'what',
#  'treasure',
#  'have',
#  'I',
#  'found',
#  'silences',
#  'that',
#  'I',
#  'may',
#  'dispense',
#  'confidence?',
#  '',
#  'If',
#  'my',
#  'day',
#  'harvest,',
#  'what',
#  'fields',
#  'have',
#  'I',
#  'sowed',
#  'seed,',
#  'in',
#  'what',
#  'unremembered',
#  'seasons?',
#  '',
#  'If',
#  'indeed',
#  'be',
#  'hour',
#  'which',
#  'I',
#  'lift',
#  'up',
#  'my',
#  'lantern,',
#  'my',
#  'flame',
#  'that',
#  'shall',
#  'burn',
#  'therein.',
#  '',
#  'Empty',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  'lantern,',
#  '',
#  'And',
#  'guardian',
#  'night',
#  'shall',
#  'fill',
#  'it',
#  'oil',
#  'shall',
#  'light',
#  'also.',
#  '',
#  '*****',
#  '',
#  'These',
#  'things',
#  'said',
#  'words.',
#  'But',
#  'much',
#  'in',
#  'heart',
#  'remained',
#  'unsaid.',
#  'he',
#  'himself',
#  'speak',
#  'deeper',
#  'secret.',
#  '',
#  '*****',
#  '',
#  '[Illustration:',
#  '0020]',
#  '',
#  'And',
#  'when',
#  'entered',
#  'into',
#  'city',
#  'all',
#  'people',
#  'meet',
#  'him,',
#  'they',
#  'were',
#  'crying',
#  'out',
#  'him',
#  'as',
#  'one',
#  'voice.',
#  '',
#  'And',
#  'elders',
#  'city',
#  'stood',
#  'forth',
#  'said:',
#  '',
#  'Go',
#  'yet',
#  'us.',
#  '',
#  'A',
#  'noontide',
#  'have',
#  'been',
#  'our',
#  'twilight,',
#  'your',
#  'youth',
#  'has',
#  'given',
#  'us',
#  'dreams',
#  'dream.',
#  '',
#  'No',
#  'stranger',
#  'among',
#  'us,',
#  'nor',
#  'guest,',
#  'our',
#  'son',
#  'our',
#  'dearly',
#  'beloved.',
#  '',
#  'Suffer',
#  'yet',
#  'our',
#  'eyes',
#  'hunger',
#  'for',
#  'your',
#  'face.',
#  '',
#  '*****',
#  '',
#  'And',
#  'priests',
#  'priestesses',
#  'said',
#  'unto',
#  'him:',
#  '',
#  'Let',
#  'waves',
#  'sea',
#  'separate',
#  'us',
#  'now,',
#  'years',
#  'have',
#  'spent',
#  'our',
#  'midst',
#  'become',
#  'memory.',
#  '',
#  'You',
#  'have',
#  'walked',
#  'among',
#  'us',
#  'spirit,',
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'light',
#  'upon',
#  'our',
#  'faces.',
#  '',
#  'Much',
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  'speechless',
#  'was',
#  'our',
#  'love,',
#  'veils',
#  'has',
#  'been',
#  'veiled.',
#  '',
#  'Yet',
#  'now',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  'would',
#  'stand',
#  'revealed',
#  'you.',
#  '',
#  'And',
#  'ever',
#  'has',
#  'been',
#  'that',
#  'love',
#  'knows',
#  'not',
#  'its',
#  'own',
#  'depth',
#  'until',
#  'hour',
#  'of',
#  'separation.',
#  '',
#  '*****',
#  '',
#  'And',
#  'others',
#  'also',
#  'entreated',
#  'him.',
#  'But',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  'bent',
#  'his',
#  'head;',
#  'who',
#  'stood',
#  'near',
#  'saw',
#  'his',
#  'tears',
#  'falling',
#  'upon',
#  'breast.',
#  '',
#  'And',
#  'people',
#  'proceeded',
#  'towards',
#  'square',
#  'temple.',
#  '',
#  'And',
#  'there',
#  'out',
#  'sanctuary',
#  'woman',
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  'she',
#  'was',
#  'seeress.',
#  '',
#  'And',
#  'looked',
#  'upon',
#  'her',
#  'exceeding',
#  'tenderness,',
#  'was',
#  'she',
#  'who',
#  'had',
#  'first',
#  'sought',
#  'believed',
#  'him',
#  'when',
#  'had',
#  'been',
#  'day',
#  'their',
#  'city.',
#  'And',
#  'she',
#  'hailed',
#  'him,',
#  'saying:',
#  '',
#  'Prophet',
#  'God,',
#  'quest',
#  'uttermost,',
#  'long',
#  'have',
#  'searched',
#  'distances',
#  'your',
#  'ship.',
#  '',
#  'And',
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'must',
#  'needs',
#  'go.',
#  '',
#  'Deep',
#  'your',
#  'longing',
#  'land',
#  'of',
#  'your',
#  'memories',
#  'dwelling',
#  'place',
#  'of',
#  'your',
#  'greater',
#  'desires;',
#  'our',
#  'love',
#  'would',
#  'bind',
#  'nor',
#  'our',
#  'needs',
#  'hold',
#  'you.',
#  '',
#  'Yet',
#  'we',
#  'ask',
#  'ere',
#  'leave',
#  'us,',
#  'that',
#  'you',
#  'speak',
#  'us',
#  'us',
#  'your',
#  'truth.',
#  '',
#  'And',
#  'we',
#  'will',
#  'unto',
#  'our',
#  'children,',
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'it',
#  'shall',
#  'perish.',
#  '',
#  'In',
#  'your',
#  'aloneness',
#  'have',
#  'watched',
#  'with',
#  'our',
#  'days,',
#  'your',
#  'wakefulness',
#  'you',
#  'have',
#  'listened',
#  'weeping',
#  'laughter',
#  'our',
#  'sleep.',
#  '',
#  'Now',
#  'therefore',
#  'disclose',
#  'us',
#  'ourselves,',
#  'tell',
#  'us',
#  'that',
#  'has',
#  'been',
#  'shown',
#  'you',
#  'that',
#  'which',
#  'between',
#  'birth',
#  'death.',
#  '',
#  '*****',
#  '',
#  'And',
#  'answered,',
#  '',
#  'People',
#  'Orphalese,',
#  'what',
#  'can',
#  'I',
#  'speak',
#  'save',
#  'that',
#  'which',
#  'even',
#  'now',
#  'moving',
#  'within',
#  'your',
#  'souls?',
#  '',
#  '*****',
#  '*****',
#  '',
#  'Then',
#  'said',
#  'Almitra,',
#  'Speak',
#  'us',
#  'of',
#  '_Love_.',
#  '',
#  'And',
#  'raised',
#  'head',
#  'looked',
#  'upon',
#  'people,',
#  'there',
#  'fell',
#  'stillness',
#  'upon',
#  'them.',
#  'And',
#  'voice',
#  'he',
#  'said:',
#  '',
#  'When',
#  'love',
#  'beckons',
#  'you,',
#  'follow',
#  'him,',
#  '',
#  'Though',
#  'ways',
#  'hard',
#  'steep.',
#  '',
#  'And',
#  'when',
#  'wings',
#  'enfold',
#  'yield',
#  'to',
#  'him,',
#  '',
#  'Though',
#  'sword',
#  'hidden',
#  'among',
#  'his',
#  'pinions',
#  'wound',
#  'you.',
#  '',
#  'And',
#  ...]

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %% [markdown]
# # Bonus Challenge - Part 1
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # Your code here:
    i = [i.lower() for i in prophet_flat]
    word_filter=list(filter(lambda x: x not in word_list, i))
    return word_filter

prophet_filter=word_filter_case(prophet_flat)
print(prophet_filter)
# Out:
# ['prophet', '', '|almustafa,', 'chosen', 'beloved,', 'who', 'was', 'dawn', 'unto', 'own', 'day,', 'had', 'waited', 'twelve', 'years', 'city', 'of', 'orphalese', 'ship', 'that', 'was', 'to', 'return', 'bear', 'him', 'back', 'isle', 'of', 'his', 'birth.', '', 'twelfth', 'year,', 'on', 'seventh', 'day', 'ielool,', 'month', 'reaping,', 'he', 'climbed', 'hill', 'without', 'city', 'walls', 'looked', 'seaward;', 'beheld', 'his', 'ship', 'coming', 'mist.', '', 'then', 'gates', 'heart', 'flung', 'open,', 'joy', 'flew', 'far', 'over', 'sea.', 'closed', 'eyes', 'prayed', 'silences', 'soul.', '', '*****', '', 'but', 'as', 'descended', 'hill,', 'sadness', 'came', 'upon', 'him,', 'thought', 'his', 'heart:', '', 'how', 'shall', 'i', 'go', 'peace', 'without', 'sorrow?', 'nay,', 'without', 'wound', 'spirit', 'shall', 'i', 'leave', 'city.', 'long', 'were', 'days', 'pain', 'i', 'have', 'spent', 'within', 'its', 'walls,', 'long', 'nights', 'aloneness;', 'who', 'can', 'depart', 'from', 'pain', 'aloneness', 'without', 'regret?', '', 'too', 'many', 'fragments', 'spirit', 'have', 'i', 'scattered', 'these', 'streets,', 'too', 'many', 'are', 'children', 'my', 'longing', 'that', 'walk', 'naked', 'among', 'these', 'hills,', 'i', 'cannot', 'withdraw', 'them', 'without', 'burden', 'ache.', '', 'it', 'garment', 'i', 'cast', 'off', 'this', 'day,', 'skin', 'that', 'i', 'tear', 'my', 'own', 'hands.', '', 'nor', 'thought', 'i', 'leave', 'behind', 'me,', 'but', 'heart', 'made', 'sweet', 'hunger', 'with', 'thirst.', '', '*****', '', 'yet', 'i', 'cannot', 'tarry', 'longer.', '', 'sea', 'that', 'calls', 'things', 'unto', 'her', 'calls', 'me,', 'i', 'must', 'embark.', '', 'for', 'stay,', 'though', 'hours', 'burn', 'in', 'night,', 'freeze', 'crystallize', 'be', 'bound', 'mould.', '', 'fain', 'would', 'i', 'take', 'me', 'that', 'is', 'here.', 'but', 'how', 'shall', 'i?', '', 'voice', 'cannot', 'carry', 'tongue', 'lips', 'that', 'gave', 'wings.', 'alone', 'must', 'seek', 'ether.', '', 'alone', 'without', 'nest', 'shall', 'eagle', 'fly', 'across', 'sun.', '', '*****', '', 'now', 'when', 'reached', 'foot', 'hill,', 'turned', 'again', 'towards', 'sea,', 'saw', 'ship', 'approaching', 'harbour,', 'upon', 'her', 'prow', 'mariners,', 'men', 'own', 'land.', '', 'soul', 'cried', 'out', 'them,', 'he', 'said:', '', 'sons', 'my', 'ancient', 'mother,', 'riders', 'of', 'tides,', '', 'how', 'often', 'have', 'sailed', 'my', 'dreams.', 'now', 'come', 'my', 'awakening,', 'which', 'is', 'my', 'deeper', 'dream.', '', 'ready', 'am', 'i', 'go,', 'my', 'eagerness', 'with', 'sails', 'full', 'awaits', 'wind.', '', 'only', 'another', 'breath', 'will', 'i', 'breathe', 'in', 'this', 'still', 'air,', 'only', 'another', 'loving', 'look', 'cast', 'backward,', '', 'then', 'i', 'shall', 'stand', 'among', 'you,', 'seafarer', 'among', 'seafarers.', 'you,', 'vast', 'sea,', 'sleepless', 'mother,', '', 'who', 'alone', 'peace', 'freedom', 'river', 'stream,', '', 'only', 'another', 'winding', 'will', 'stream', 'make,', 'only', 'another', 'murmur', 'glade,', '', 'then', 'shall', 'i', 'come', 'you,', 'boundless', 'drop', 'boundless', 'ocean.', '', '*****', '', 'as', 'walked', 'saw', 'afar', 'men', 'women', 'leaving', 'their', 'fields', 'their', 'vineyards', 'hastening', 'towards', 'city', 'gates.', '', 'heard', 'their', 'voices', 'calling', 'his', 'name,', 'shouting', 'field', 'field', 'telling', 'one', 'another', 'coming', 'his', 'ship.', '', 'said', 'himself:', '', 'shall', 'day', 'parting', 'be', 'day', 'of', 'gathering?', '', 'shall', 'be', 'said', 'that', 'my', 'eve', 'was', 'in', 'truth', 'my', 'dawn?', '', 'what', 'shall', 'i', 'unto', 'him', 'who', 'has', 'left', 'plough', 'midfurrow,', 'to', 'him', 'who', 'has', 'stopped', 'wheel', 'his', 'winepress?', 'shall', 'my', 'heart', 'become', 'tree', 'heavy-laden', 'fruit', 'that', 'i', 'may', 'gather', 'unto', 'them?', '', 'shall', 'my', 'desires', 'flow', 'like', 'fountain', 'that', 'i', 'fill', 'their', 'cups?', '', 'am', 'i', 'harp', 'that', 'hand', 'mig ...

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # Your code here:
    return a +''+ b

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# Your code here:
prophet_string=reduce(concat_space,prophet_filter)
print(prophet_string)
# Out:
# prophet|almustafa,chosenbeloved,whowasdawnuntoownday,hadwaitedtwelveyearscityoforphaleseshipthatwastoreturnbearhimbackisleofhisbirth.twelfthyear,onseventhdayielool,monthreaping,heclimbedhillwithoutcitywallslookedseaward;beheldhisshipcomingmist.thengatesheartflungopen,joyflewfaroversea.closedeyesprayedsilencessoul.*****butasdescendedhill,sadnesscameuponhim,thoughthisheart:howshalligopeacewithoutsorrow?nay,withoutwoundspiritshallileavecity.longweredayspainihavespentwithinitswalls,longnightsaloneness;whocandepartfrompainalonenesswithoutregret?toomanyfragmentsspirithaveiscatteredthesestreets,toomanyarechildrenmylongingthatwalknakedamongthesehills,icannotwithdrawthemwithoutburdenache.itgarmenticastoffthisday,skinthatitearmyownhands.northoughtileavebehindme,butheartmadesweethungerwiththirst.*****yeticannottarrylonger.seathatcallsthingsuntohercallsme,imustembark.forstay,thoughhoursburninnight,freezecrystallizebeboundmould.fainwoulditakemethatishere.buthowshalli?voicecannotcarrytonguelipsthatgavewings.alonemustseekether.alonewithoutnestshalleagleflyacrosssun.*****nowwhenreachedfoothill,turnedagaintowardssea,sawshipapproachingharbour,uponherprowmariners,menownland.soulcriedoutthem,hesaid:sonsmyancientmother,ridersoftides,howoftenhavesailedmydreams.nowcomemyawakening,whichismydeeperdream.readyamigo,myeagernesswithsailsfullawaitswind.onlyanotherbreathwillibreatheinthisstillair,onlyanotherlovinglookcastbackward,thenishallstandamongyou,seafareramongseafarers.you,vastsea,sleeplessmother,whoalonepeacefreedomriverstream,onlyanotherwindingwillstreammake,onlyanothermurmurglade,thenshallicomeyou,boundlessdropboundlessocean.*****aswalkedsawafarmenwomenleavingtheirfieldstheirvineyardshasteningtowardscitygates.heardtheirvoicescallinghisname,shoutingfieldfieldtellingoneanothercominghisship.saidhimself:shalldaypartingbedayofgathering?shallbesaidthatmyevewasintruthmydawn?whatshalliuntohimwhohasleftploughmidfurrow,tohimwhohasstoppedwheelhiswinepress?shallmyheartbecometreeheavy-ladenfruitthatimaygatheruntothem?shallmydesiresflowlikefountainthatifilltheircups?amiharpthathandmightymaytouchme,flutethatbreathmaypassthroughme?seekersilencesami,whattreasurehaveifoundsilencesthatimaydispenseconfidence?ifmydayharvest,whatfieldshaveisowedseed,inwhatunrememberedseasons?ifindeedbehourwhichiliftupmylantern,myflamethatshallburntherein.emptydarkshalliraisemylantern,guardiannightshallfillitoilshalllightalso.*****thesethingssaidwords.butmuchinheartremainedunsaid.hehimselfspeakdeepersecret.*****[illustration:0020]whenenteredintocityallpeoplemeethim,theywerecryingouthimasonevoice.elderscitystoodforthsaid:goyetus.noontidehavebeenourtwilight,youryouthhasgivenusdreamsdream.nostrangeramongus,norguest,oursonourdearlybeloved.sufferyetoureyeshungerforyourface.*****priestspriestessessaiduntohim:letwavesseaseparateusnow,yearshavespentourmidstbecomememory.youhavewalkedamongusspirit,yourshadowhasbeenlightuponourfaces.muchhavewelovedyou.butspeechlesswasourlove,veilshasbeenveiled.yetnowcriesalouduntoyou,wouldstandrevealedyou.everhasbeenthatloveknowsnotitsowndepthuntilhourofseparation.*****othersalsoentreatedhim.butansweredthemnot.heonlybenthishead;whostoodnearsawhistearsfallinguponbreast.peopleproceededtowardssquaretemple.thereoutsanctuarywomanwhosenamewasalmitra.shewasseeress.lookeduponherexceedingtenderness,wasshewhohadfirstsoughtbelievedhimwhenhadbeendaytheircity.shehailedhim,saying:prophetgod,questuttermost,longhavesearcheddistancesyourship.nowyourshiphascome,mustneedsgo.deepyourlonginglandofyourmemoriesdwellingplaceofyourgreaterdesires;ourlovewouldbindnorourneedsholdyou.yetweaskereleaveus,thatyouspeakususyourtruth.wewilluntoourchildren,theyuntotheirchildren,itshallperish.inyouralonenesshavewatchedwithourdays,yourwakefulnessyouhavelistenedweepinglaughteroursleep.nowthereforediscloseusourselves,tellusthathasbeenshownyouthatwhichbetweenbirthdeath.*****answered,peopleorphalese,whatcanispeaksavethatwhichevennowmovingwithinyoursouls?**********thensaidalmitra,speakusof_love_.raisedhead ...

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will load a dataset below and then write a function that will perform the transformation.

# %%
# Run this code:

# The dataset below contains information about pollution from PM2.5 particles in Beijing 

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00381/PRSA_data_2010.1.1-2014.12.31.csv"
pm25 = pd.read_csv(url)

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# Your code here:
pm25.head(20)
# Out:
#     No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0    1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1    2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2    3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3    4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4    5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0
# 5    6  2010      1    1     5    NaN   -19 -10.0  1017.0   NW  16.10   0   0
# 6    7  2010      1    1     6    NaN   -19  -9.0  1017.0   NW  19.23   0   0
# 7    8  2010      1    1     7    NaN   -19  -9.0  1017.0   NW  21.02   0   0
# 8    9  2010      1    1     8    NaN   -19  -9.0  1017.0   NW  24.15   0   0
# 9   10  2010      1    1     9    NaN   -20  -8.0  1017.0   NW  27.28   0   0
# 10  11  2010      1    1    10    NaN   -19  -7.0  1017.0   NW  31.30   0   0
# 11  12  2010      1    1    11    NaN   -18  -5.0  1017.0   NW  34.43   0   0
# 12  13  2010      1    1    12    NaN   -19  -5.0  1015.0   NW  37.56   0   0
# 13  14  2010      1    1    13    NaN   -18  -3.0  1015.0   NW  40.69   0   0
# 14  15  2010      1    1    14    NaN   -18  -2.0  1014.0   NW  43.82   0   0
# 15  16  2010      1    1    15    NaN   -18  -1.0  1014.0   cv   0.89   0   0
# 16  17  2010      1    1    16    NaN   -19  -2.0  1015.0   NW   1.79   0   0
# 17  18  2010      1    1    17    NaN   -18  -3.0  1015.0   NW   2.68   0   0
# 18  19  2010      1    1    18    NaN   -18  -5.0  1016.0   NE   1.79   0   0
# 19  20  2010      1    1    19    NaN   -17  -4.0  1017.0   NW   1.79   0   0

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    
    # Your code here:
    return x/2

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
# Your code here:
df1=pm25[['Iws','Is','Ir']].apply(lambda x: hourly(x))
df1.head(10)
# Out:
#       Iws   Is   Ir
# 0   0.895  0.0  0.0
# 1   2.460  0.0  0.0
# 2   3.355  0.0  0.0
# 3   4.920  0.0  0.0
# 4   6.485  0.0  0.0
# 5   8.050  0.0  0.0
# 6   9.615  0.0  0.0
# 7  10.510  0.0  0.0
# 8  12.075  0.0  0.0
# 9  13.640  0.0  0.0

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # Your code here:
    len=(pm25[x].count())
    stv= np.std(pm25[x])/2
    return stv-1
# Out:
# 5.099236805784235

# %%
sample_sd('TEMP')
# Out:
# 5.099236805784235
