# %%
import pymongo
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://Dtavo:314159265141074.mongos@cluster0.uhlrc.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client.test

# %%
client.list_database_names()
# Out:
# ['sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
sakila = client['sakila']
sakila
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.uhlrc.mongodb.net:27017', 'cluster0-shard-00-02.uhlrc.mongodb.net:27017', 'cluster0-shard-00-01.uhlrc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-12gjui-shard-0', tls=True), 'sakila')

# %%
actors = sakila['actors']
actors
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.uhlrc.mongodb.net:27017', 'cluster0-shard-00-02.uhlrc.mongodb.net:27017', 'cluster0-shard-00-01.uhlrc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-12gjui-shard-0', tls=True), 'sakila'), 'actors')

# %%
import pymysql
from sqlalchemy import create_engine,text
import pandas as pd

# %%
path_sakila = 'mysql+pymysql://root:314159265141074.mysql@localhost:3306/sakila'

# %%
engine = create_engine(path_sakila)

# %%
df_sakila = pd.read_sql_query('SELECT * FROM actor',engine)

# %%
info_actors = df_sakila.to_dict('records')
info_actors
# Out:
# [{'actor_id': 1,
#   'first_name': 'PENELOPE',
#   'last_name': 'GUINESS',
#   'last_update': Timestamp('2006-02-15 04:34:33')},
#  {'actor_id': 2,
#   'first_name': 'NICK',
#   'last_name': 'WAHLBERG',
#   'last_update': Timestamp('2006-02-15 04:34:33')},
#  {'actor_id': 3,
#   'first_name': 'ED',
#   'last_name': 'CHASE',
#   'last_update': Timestamp('2006-02-15 04:34:33')},
#  {'actor_id': 4,
#   'first_name': 'JENNIFER',
#   'last_name': 'DAVIS',
#   'last_update': Timestamp('2006-02-15 04:34:33')},
#  {'actor_id': 5,
#   'first_name': 'JOHNNY',
#   'last_name': 'LOLLOBRIGIDA',
#   'last_update': Timestamp('2006-02-15 04:34:33')},
#  {'actor_id': 6,
#   'first_name': 'BETTE',
#   'last_name': 'NICHOLSON',
#   'last_update': Timestamp('2006-02-15 04:34:33')},
#  {'actor_id': 7,
#   'first_name': 'GRACE',
#   'last_name': 'MOSTEL',
#   'last_update': Timestamp('2006-02-15 04:34:33')},
#  {'actor_id': 8,
#   'first_name': 'MATTHEW',
#   'last_name': 'JOHANSSON',
# ...

# %%
results = actors.insert_many(info_actors)
results
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17184/2713647949.py in <module>
# ----> 1 results = actors.insert_many(info_actors)
#       2 results
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     689         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     690         blk.ops = [doc for doc in gen()]
# --> 691         blk.execute(write_concern, session=session)
#     692         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     693
#
# ~\anaconda3\lib\site-packages\pymongo\bulk.py in execute(self, write_concern, session)
#     510                 self.execute_no_results(sock_info, generator, write_concern)
#     511         else:
# ...
