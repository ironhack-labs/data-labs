# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **pokemons**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# ### Import all required libraries

# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ### Import data set
#
# Import data set `Pokemon.csv` from the `your-code` directory of this lab. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set
df = pd.read_csv('Pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### Print first 10 rows of `pokemon`

# %%
# enter your code here
df[0:11]
# Out:
#     #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                    Ivysaur  Grass  Poison    405  60      62       63
# 2   3                   Venusaur  Grass  Poison    525  80      82       83
# 3   3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4   4                 Charmander   Fire     NaN    309  39      52       43
# 5   5                 Charmeleon   Fire     NaN    405  58      64       58
# 6   6                  Charizard   Fire  Flying    534  78      84       78
# 7   6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8   6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9   7                   Squirtle  Water     NaN    314  44      48       65
# 10  8                  Wartortle  Water     NaN    405  59      63       80
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# 6       109       85    100           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 9        50       64     43           1      False
# 10       65       80     58           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# ### Obtain the distinct values across `Type 1` and `Type 2`
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# enter your code here
np.concatenate((
    df['Type 1'] , 
     df['Type 2']
))
# Out:
# array(['Grass', 'Grass', 'Grass', ..., 'Ghost', 'Dark', 'Water'],
#       dtype=object)

# %% [markdown]
# ### Cleanup `Name` that contain "Mega"
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# enter your code here

df['Name'] = np.where(
    df['Name'].str.contains('Mega'), 
    df['Name'].apply(lambda x: 'Mega ' + ' '.join(x.split(' ')[1:])), 
    df['Name']
)

# test transformed data

df.head(10)

# df['Name'].str.contains('Mega')
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %% [markdown]
# ### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# enter your code here
df['A/D Ratio'] = df['Attack'] / df['Defense']

df.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       65     45           1      False   1.000000
# 1       80     60           1      False   0.984127
# 2      100     80           1      False   0.987952
# 3      120     80           1      False   0.813008
# 4       50     65           1      False   1.209302
# 5       65     80           1      False   1.103448
# 6       85    100           1      False   1.076923
# 7       85    100           1      False   1.171171
# 8      115    100           1      False   1.333333
# 9       64     43           1      False   0.738462

# %% [markdown]
# ### Identify the pokemon with the highest `A/D Ratio`

# %%
# enter your code here

df.loc[df['A/D Ratio'] == df['A/D Ratio'].max()]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 429      180       20    150           3       True        9.0

# %% [markdown]
# ### Identify the pokemon with the lowest A/D Ratio

# %%
# enter your code here
# df[df['A/D Ratio'] == df['A/D Ratio'].min()]
df.loc[df['A/D Ratio'] == df['A/D Ratio'].min()]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  A/D Ratio
# 230      5           2      False   0.043478

# %% [markdown]
# ### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
# enter your code here

df['Combo Type'] = np.where(
    df['Type 1'].str.contains('NaN'), 
    df['Type 2'],
    np.where(
        df['Type 2'].str.contains('NaN'), 
        df['Type 1'],
        df['Type 1'] + "-" + df['Type 2']
    )
)

df.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio    Combo Type
# 0       65     45           1      False   1.000000  Grass-Poison
# 1       80     60           1      False   0.984127  Grass-Poison
# 2      100     80           1      False   0.987952  Grass-Poison
# 3      120     80           1      False   0.813008  Grass-Poison
# 4       50     65           1      False   1.209302          Fire

# %% [markdown]
# ### Identify the pokemons whose `A/D Ratio` are among the top 5

# %%
# enter your code here
top_5_AD = df.sort_values(by = 'A/D Ratio', ascending=False)[:6]
top_5_AD
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock     NaN    350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
# 428  386  DeoxysNormal Forme  Psychic     NaN    600  50     150       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000     Psychic
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125        Rock
# 348       95       40     95           3      False      3.000  Water-Dark
# 428      150       50    150           3       True      3.000     Psychic

# %% [markdown]
# ### For the 5 pokemons printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemons with the highest `A/D Ratio`.

# %%
# enter your code here
list(top_5_AD['Combo Type'].unique())
# Out:
# ['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock']

# %% [markdown]
# ### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemons.
#
# Your output should look like below:
#
# ![Aggregate](aggregated-mean.png)

# %%
# enter your code here
df.groupby('Combo Type').agg('mean')
# Out:
#                           #       Total          HP      Attack     Defense  \
# Combo Type
# Bug              361.352941  289.705882   53.058824   50.352941   55.411765
# Bug-Electric     595.500000  395.500000   60.000000   62.000000   55.000000
# Bug-Fighting     214.000000  550.000000   80.000000  155.000000   95.000000
# Bug-Fire         636.500000  455.000000   70.000000   72.500000   60.000000
# Bug-Flying       286.285714  419.500000   63.000000   70.142857   61.571429
# Bug-Ghost        292.000000  236.000000    1.000000   90.000000   45.000000
# Bug-Grass        354.833333  384.000000   55.000000   73.833333   76.666667
# Bug-Ground       351.500000  345.000000   45.500000   62.000000   97.500000
# Bug-Poison       199.166667  347.916667   53.750000   68.333333   58.083333
# Bug-Rock         442.666667  435.000000   46.666667   56.666667  146.666667
# Bug-Steel        416.000000  509.714286   67.714286  114.714286  112.428571
# Bug-Water        283.000000  269.000000   40.000000   30.000000   32.000000
# Dark             408.900000  436.200000   60.500000   88.800000   61.200000
# Dark-Dragon      634.000000  440.000000   72.000000   85.000000   70.000000
# Dark-Fighting    559.500000  418.000000   57.500000   82.500000   92.500000
# Dark-Fire        228.666667  476.666667   65.000000   80.000000   56.666667
# Dark-Flying      520.800000  494.000000   93.200000   92.200000   73.800000
# Dark-Ghost       302.000000  430.000000   50.000000   80.000000  100.000000
# Dark-Ice         338.000000  470.000000   62.500000  107.500000   60.000000
# Dark-Psychic     686.500000  385.000000   69.500000   73.000000   70.500000
# Dark-Steel       624.500000  415.000000   55.000000  105.000000   85.000000
# Dragon           509.727273  413.363636   61.818182   92.181818   67.090909
# Dragon-Electric  644.000000  680.000000  100.000000  150.000000  120.000000
# Dragon-Fairy     334.000000  590.000000   75.000000  110.000000  110.000000
# Dragon-Fire      643.000000  680.000000  100.000000  120.000000  100.000000
# Dragon-Flying    332.833333  641.666667   94.333333  135.666667   97.500000
# Dragon-Ground    499.000000  522.000000   90.000000  112.000000   88.200000
# Dragon-Ice       646.000000  686.666667  125.000000  140.000000   93.333333
# Dragon-Psychic   380.500000  650.000000   80.000000  100.000000   97.500000
# Electric         303.962963  413.555556   60.000000   69.222222   55.296296
# ...                     ...         ...         ...         ...         ...
# Rock-Grass       345.500000  425.000000   76.000000   61.000000   87.000000
# Rock-Ground      135.500000  380.000000   55.000000   81.333333  104.166667
# Rock-Ice         698.500000  441.500000  100.000000   68.000000   61.000000
# Rock-Psychic     337.500000  440.000000   70.000000   75.000000   75.000000
# Rock-Steel       432.333333  456.666667   50.000000   49.666667  143.666667
# Rock-Water       322.500000  417.666667   51.500000   75.333333  100.333333
# Steel            497.000000  494.000000   62.000000   90.000000  132.000000
# Steel-Dragon     483.000000  680.000000  100.000000  120.000000  120.000000
# Steel-Fairy      437.666667  443.333333   52.333333   90.000000  100.333333
# Steel-Fighting   638.000000  580.000000   91.000000   90.000000  129.000000
# Steel-Flying     227.000000  465.000000   65.000000   80.000000  140.000000
# Steel-Ghost      680.250000  453.250000   56.000000   97.500000  112.500000
# Steel-Ground     208.000000  560.000000   75.000000  105.000000  215.000000
# Steel-Psychic    394.142857  488.571429   69.142857   89.000000  108.857143
# Steel-Rock       305.000000  430.000000   60.000000   90.000000  140.000000
# Water            302.881356  413.745763   66.847458   71.830508   69.203390
# Water-Dark       347.666667  493.833333   69.166667  120.000000   65.166667
# Water-Dragon     357.000000  610.000000   82.500000  107.500000   97.500000
# Water-Electric   170.500000  395.000000  100.000000   48.000000   48.000000
# Water-Fairy      183.500000  335.000000   85.000000   35.000000   65.000000
# Water-Fighting   452.000000  556.666667   90.666667   79.666667   91.666667
# Water-Flying     361.714286  404.000000   63.142857   56.571429   63.142857
# Water-Ghost      592.500000  407.500000   77.500000   50.000000   60.000000
# Water-Grass      271.000000  346.666667   60.000000   50.000000   50.000000
# Water-Ground     334.300000  433.900000   87.100000   84.400000   71.400000
# Water-Ice        103.000000  511.666667   90.000000   83.333333  113.333333
# Water-Poison     118.666667  426.666667   61.666667   68.333333   58.333333
# Water-Psychic    111.800000  481.000000   87.000000   73.000000  104.000000
# Water-Rock       430.000000  428.750000   70.750000   82.750000  112.750000
# Water-Steel      395.000000  530.000000   84.000000   86.000000   88.000000
#
#                     Sp. Atk     Sp. Def       Speed  Generation  Legendary  \
# Combo Type
# Bug               39.294118   43.647059   47.941176    3.470588   0.000000
# Bug-Electric      77.000000   55.000000   86.500000    5.000000   0.000000
# Bug-Fighting      40.000000  100.000000   80.000000    2.000000   0.000000
# Bug-Fire          92.500000   80.000000   80.000000    5.000000   0.000000
# Bug-Flying        72.857143   69.071429   82.857143    2.857143   0.000000
# Bug-Ghost         30.000000   30.000000   40.000000    3.000000   0.000000
# Bug-Grass         57.333333   76.666667   44.500000    3.500000   0.000000
# Bug-Ground        44.500000   57.500000   38.000000    3.500000   0.000000
# Bug-Poison        42.500000   59.333333   65.916667    2.333333   0.000000
# Bug-Rock          36.666667  113.333333   35.000000    4.000000   0.000000
# Bug-Steel         68.142857   83.285714   63.428571    3.571429   0.000000
# Bug-Water         50.000000   52.000000   65.000000    3.000000   0.000000
# Dark              81.300000   61.700000   82.700000    3.800000   0.100000
# Dark-Dragon       78.333333   70.000000   64.666667    5.000000   0.000000
# Dark-Fighting     40.000000   92.500000   53.000000    5.000000   0.000000
# Dark-Fire        110.000000   73.333333   91.666667    2.000000   0.000000
# Dark-Flying       84.200000   70.400000   80.200000    4.400000   0.200000
# Dark-Ghost        75.000000   90.000000   35.000000    3.000000   0.000000
# Dark-Ice          40.000000   80.000000  120.000000    3.000000   0.000000
# Dark-Psychic      52.500000   60.500000   59.000000    6.000000   0.000000
# Dark-Steel        50.000000   55.000000   65.000000    5.000000   0.000000
# Dragon            59.818182   71.636364   60.818182    4.181818   0.000000
# Dragon-Electric  120.000000  100.000000   90.000000    5.000000   1.000000
# Dragon-Fairy     110.000000  105.000000   80.000000    3.000000   0.000000
# Dragon-Fire      150.000000  120.000000   90.000000    5.000000   1.000000
# Dragon-Flying    121.666667   94.166667   98.333333    2.666667   0.333333
# Dragon-Ground     74.200000   75.000000   82.600000    4.400000   0.200000
# Dragon-Ice       140.000000   93.333333   95.000000    5.000000   1.000000
# Dragon-Psychic   135.000000  127.500000  110.000000    3.000000   1.000000
# Electric          78.148148   66.370370   84.518519    2.888889   0.037037
# ...                     ...         ...         ...         ...        ...
# Rock-Grass        71.000000   97.000000   33.000000    3.000000   0.000000
# Rock-Ground       45.000000   50.833333   43.666667    1.333333   0.000000
# Rock-Ice          83.000000   77.500000   52.000000    6.000000   0.000000
# Rock-Psychic      75.000000   75.000000   70.000000    3.000000   0.000000
# Rock-Steel        54.666667  125.333333   33.333333    4.000000   0.000000
# Rock-Water        69.666667   63.666667   57.166667    2.666667   0.000000
# Steel             64.000000   92.000000   54.000000    4.200000   0.200000
# Steel-Dragon     150.000000  100.000000   90.000000    4.000000   1.000000
# Steel-Fairy       63.333333   79.000000   58.333333    4.000000   0.000000
# Steel-Fighting    90.000000   72.000000  108.000000    5.000000   1.000000
# Steel-Flying      40.000000   70.000000   70.000000    2.000000   0.000000
# Steel-Ghost       70.000000   71.500000   45.750000    6.000000   0.000000
# Steel-Ground      55.000000   80.000000   30.000000    2.000000   0.000000
# Steel-Psychic     70.428571   91.714286   59.428571    3.285714   0.142857
# Steel-Rock        50.000000   50.000000   40.000000    3.000000   0.000000
# Water             72.949153   65.033898   67.881356    2.864407   0.050847
# Water-Dark        88.833333   63.500000   87.166667    3.166667   0.000000
# Water-Dragon     122.500000  107.500000   92.500000    3.000000   0.500000
# Water-Electric    66.000000   66.000000   67.000000    2.000000   0.000000
# Water-Fairy       40.000000   65.000000   45.000000    2.000000   0.000000
# Water-Fighting   109.333333   90.000000   95.333333    3.666667   0.000000
# Water-Flying      67.285714   81.857143   72.000000    3.285714   0.000000
# Water-Ghost       75.000000   95.000000   50.000000    5.000000   0.000000
# Water-Grass       63.333333   73.333333   50.000000    3.000000   0.000000
# Water-Ground      69.400000   68.400000   53.200000    3.300000   0.000000
# Water-Ice         80.000000   78.333333   66.666667    1.000000   0.000000
# Water-Poison      61.666667   91.666667   85.000000    1.333333   0.000000
# Water-Psychic     94.000000   79.000000   44.000000    1.200000   0.000000
# Water-Rock        61.500000   65.000000   36.000000    3.750000   0.000000
# Water-Steel      111.000000  101.000000   60.000000    4.000000   0.000000
#
#                  A/D Ratio
# Combo Type
# Bug               0.940179
# Bug-Electric      1.111667
# Bug-Fighting      1.637681
# Bug-Fire          1.234266
# Bug-Flying        1.146274
# Bug-Ghost         2.000000
# Bug-Grass         0.983165
# Bug-Ground        0.626190
# Bug-Poison        1.315989
# Bug-Rock          0.522728
# Bug-Steel         1.037527
# Bug-Water         0.937500
# Dark              1.560107
# Dark-Dragon       1.226984
# Dark-Fighting     0.927019
# Dark-Fire         1.600000
# Dark-Flying       1.431797
# Dark-Ghost        0.840000
# Dark-Ice          1.786713
# Dark-Psychic      1.032161
# Dark-Steel        1.232143
# Dragon            1.388624
# Dragon-Electric   1.250000
# Dragon-Fairy      1.000000
# Dragon-Fire       1.200000
# Dragon-Flying     1.409643
# Dragon-Ground     1.322660
# Dragon-Ice        1.492593
# Dragon-Psychic    1.036806
# Electric          1.323922
# ...                    ...
# Rock-Grass        0.683760
# Rock-Ground       0.885069
# Rock-Ice          1.124722
# Rock-Psychic      0.981900
# Rock-Steel        0.348255
# Rock-Water        0.758882
# Steel             0.721216
# Steel-Dragon      1.000000
# Steel-Fairy       0.906374
# Steel-Fighting    0.697674
# Steel-Flying      0.571429
# Steel-Ghost       1.216667
# Steel-Ground      0.484239
# Steel-Psychic     0.784134
# Steel-Rock        0.651323
# Water             1.083157
# Water-Dark        2.291949
# Water-Dragon      1.100000
# Water-Electric    1.000000
# Water-Fairy       0.512500
# Water-Fighting    0.866667
# Water-Flying      0.902094
# Water-Ghost       0.828571
# Water-Grass       1.000000
# Water-Ground      1.165399
# Water-Ice         0.821759
# Water-Poison      1.162149
# Water-Psychic     0.783668
# Water-Rock        0.727170
# Water-Steel       0.977273
#
# [154 rows x 11 columns]
