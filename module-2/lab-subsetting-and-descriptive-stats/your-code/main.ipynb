# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.dtypes
# returns
# City            object
# State           object
# Temperature    float64
# dtype: object
# city column is a categorical, same as state
# temperature column if float data
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
temp[
    temp['State'] == 'New York' # subsetted via a Boolean to give all rows where the value in the State col = New York
]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
temp[
    temp['State'] == 'New York' # subset down to the New York State rows
]['Temperature'].mean() # subset to the Temperature column, and call the mean function on that column
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[
    temp['Temperature'] > 15 # subset down to rows where the temperature greater than 15,
][['City','State']] # then subset down with a list of column names
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp[
    temp['Temperature'] > 15
]['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[
    (temp['Temperature'] > 15) & (temp['Temperature'] < 20)
]['City']
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
NYmean = temp[
    temp['State'] == 'New York'
]['Temperature'].mean()

CTmean = temp[
    temp['State'] == 'Connecticut'
]['Temperature'].mean()

NJmean = temp[
    temp['State'] == 'New Jersey'
]['Temperature'].mean()

NYstd = temp[
    temp['State'] == 'New York'
]['Temperature'].std()

CTstd = temp[
    temp['State'] == 'Connecticut'
]['Temperature'].std()

NJstd = temp[
    temp['State'] == 'New Jersey'
]['Temperature'].std()

states = ['New York', 'Connecticut', 'New Jersey']
means = [NYmean, CTmean, NJmean]
stddevs = [NYstd, CTstd, NJstd]

for element in range(len(states)):
    print(f"{states[element]} has a mean of {round(means[element], 2)} degrees Celcius and a standard deviation of {round(stddevs[element], 2)} degrees Celsius")
# Out:
# New York has a mean of 10.74 degrees Celcius and a standard deviation of 8.13 degrees Celsius
# Connecticut has a mean of 15.83 degrees Celcius and a standard deviation of 1.96 degrees Celsius
# New Jersey has a mean of 21.11 degrees Celcius and a standard deviation of 1.57 degrees Celsius

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee = pd.read_csv('employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
print(employee.dtypes)
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# Years with the company and salary are integers, everything else is categorical data
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
print(employee.describe())
# looking at the integer data only, range of years with company is 1-8 years, and mean salary is 48.888889
# Out:
#           Years     Salary
# count  9.000000   9.000000
# mean   4.111111  48.888889
# std    2.803767  16.541194
# min    1.000000  30.000000
# 25%    2.000000  35.000000
# 50%    3.000000  55.000000
# 75%    7.000000  60.000000
# max    8.000000  70.000000

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
# %matplotlib inline 
# tells Jupyter Notebook to graph within the cell
employee.hist()
# neither Salary nor Years are normally distributed, gaps in the data. only two people making above 60.
# Years - most people have been with the company fewer than five years, with 2 tenured folks at 8 years
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11dd7e128>,
# ...
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee.Salary.mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee.Salary.min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee[
    employee.Salary == 30
]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[
    employee['Name'] == 'David'
]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[
    employee['Name'] == 'David'
]['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[
    employee['Title'] == 'associate'
]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3) # call the head function, and pass in the optional argument to limit to three rows (default five)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee[:3] # subset the dataframe by row index number, used 3 because the upper limit is not retrieved
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[
    (employee['Title'] == 'associate') & (employee['Salary'] ^ 55)
].Name # says Find the employee, so I grabbed just their names
# Out:
# 7    Pedro
# Name: Name, dtype: object

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby('Years').mean()
# first group the dataframe rows based on Years, and find the mean salary for each group
# Referenced used: https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html#grouping
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby('Title')['Salary'].mean()
# first group the dataframe rows by title, then subset to the Salary column, and call the .mean() function on it
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ## - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
# %matplotlib inline
employee.boxplot()

# %%
# print first quartile here
employee.quantile(.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
employee.quantile(.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby('Gender')['Salary'].mean()
# Yes, mean salary for F is 47.5, while mean salary for M is 50.0
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
# just df.min() df.mean() and df.max() would include the non-numeric columns
# we know from df.describe() and df.dtypes that the numeric columns are 'Years' and 'Salary'
# employee[
#     employee[['Years', 'Salary']]
# ].min()

# find the values, assign to variables to dynamically print them using f-string formatting
year_min = employee.Years.min()
year_mean = round(employee.Years.mean(), 2)
year_max = employee.Years.max()

salary_min = employee.Salary.min()
salary_mean = employee.Salary.mean()
salary_max = employee.Salary.max()


colname = ['Years', 'Salary']
statname = ['minimum', 'mean', 'maximum']
result = [year_min, year_mean, year_max, salary_min, salary_mean, salary_max]

for i in range(len(colname)):
    for el in range(len(statname)):
        print(f"For {colname[i]} the {statname[el]} is {result[el]}")
# Out:
# For Years the minimum is 1
# For Years the mean is 4.11
# For Years the maximum is 8
# For Salary the minimum is 1
# For Salary the mean is 4.11
# For Salary the maximum is 8

# %%
print([f"For {colname[i]} the {statname[el]} is {result[el]}" for i in range(len(colname)) for el in range(len(statname))])
# Out:
# ['For Years the minimum is 1', 'For Years the mean is 4.11', 'For Years the maximum is 8', 'For Salary the minimum is 1', 'For Salary the mean is 4.11', 'For Salary the maximum is 8']

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# group rows by Department, subset to Salary column, and use a lambda to calculate the Range
employee.groupby('Department')['Salary'].apply(lambda x: max(x) - min(x))
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# Name: Salary, dtype: int64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here

# had to unzip Orders.zip first
orders = pd.read_csv('Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object


# one unnamed column at column-index-zero
# time is split to year, month, day hour, as integers a mix is all datatypes except Boolean
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.describe()
# equal number of rows all the way across. can't tell if unnamed is something like amount_spent this year?
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders['amount_spent'].mean()
# Out:
# 22.39474850474768

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['amount_spent'].min()
# Out:
# 0.0

# %%
# your answer here
orders['amount_spent'].max()
# Out:
# 168469.6

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
orders[
    orders['Country'] == 'Spain'
]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 13974        21565     538095     22504  2010     12    4    14
# 13975        21566     538095     22212  2010     12    4    14
# 13976        21567     538095     22953  2010     12    4    14
# 13977        21568     538095     84818  2010     12    4    14
# 13978        21569     538095     21114  2010     12    4    14
# 13979        21570     538095     84692  2010     12    4    14
# 13980        21571     538095     22796  2010     12    4    14
# 13981        21572     538095     40001  2010     12    4    14
# 13982        21573     538095     22646  2010     12    4    14
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
# subset dataframe rows to Country Spain, look at Customer ID, count the number of rows and add them up
orders[orders['Country'] == 'Spain']['CustomerID'].value_counts().sum()
# Out:
# 2485

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders[
    orders['Quantity'] > 50
]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# 175            177     536386    85099B  2010     12    3     9
# 176            178     536387     79321  2010     12    3     9
# 177            179     536387     22780  2010     12    3     9
# 178            180     536387     22779  2010     12    3     9
# 179            181     536387     22466  2010     12    3     9
# 180            182     536387     21731  2010     12    3     9
# 215            217     536390    84970S  2010     12    3    10
# 217            219     536390     20668  2010     12    3    10
# 218            220     536390    85123A  2010     12    3    10
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders[
    (orders['Country'] == 'Spain') & (orders['Quantity'] > 50)
]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders[
    orders['amount_spent'] == 0
]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
# orders[
#     orders['Description'].contains('lunch bag')
# ]

# orders[
#     'lunch bag' in orders['Description']
# ]

# orders[
#     (orders['Description']startswith('lunch bag'))
# ]

# orders[
#     'lunch bag' in str(orders['Description'])
# ]

# Reference used: https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html#operations # the string methods heading


orders[
    orders['Description'].str.contains('lunch bag')
]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# 361            370     536401     20726  2010     12    3    11
# 362            371     536401     22384  2010     12    3    11
# 402            411     536404     22383  2010     12    3    11
# 403            412     536404     20728  2010     12    3    11
# 404            413     536404     20727  2010     12    3    11
# 532            541     536412     20728  2010     12    3    11
# 533            542     536412     22382  2010     12    3    11
# 535            544     536412     22662  2010     12    3    11
# 536            545     536412     22383  2010     12    3    11
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders[
    (orders['year'] == 2011) & orders['Description'].str.contains('lunch bag')
]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# 26861        43617     540098     22383  2011      1    2    15
# 26862        43618     540098     22382  2011      1    2    15
# 26863        43619     540098     20727  2011      1    2    15
# 26864        43620     540098     20727  2011      1    2    15
# 26902        43658     540099     20725  2011      1    2    16
# 26903        43659     540099     20726  2011      1    2    16
# 27118        44179     540157     22384  2011      1    3    11
# 27242        44329     540168     22383  2011      1    3    12
# 27360        44448     540176     22382  2011      1    3    12
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
orders.amount_spent.hist()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders[
    orders['month'] == 8
]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# 199480      285426     561905     84978  2011      8    1     9
# 199481      285427     561905     21754  2011      8    1     9
# 199482      285428     561905     23226  2011      8    1     9
# 199483      285429     561905     21715  2011      8    1     9
# 199484      285430     561905     21716  2011      8    1     9
# 199485      285431     561905     21746  2011      8    1     9
# 199486      285432     561905     21755  2011      8    1     9
# 199487      285433     561906     22367  2011      8    1    10
# 199488      285434     561906     20914  2011      8    1    10
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here

# group by Countries, subset to August, then value_counts()
# orders.groupby('Country')[
#     orders['month'] == 8
# ].value_counts()
# turns out value_counts() already does a groupby style count


orders[
    orders['month'] == 8
]['Country'].value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
# group by country, and get .mean() of amount_spent column

orders.groupby('Country')['amount_spent'].mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
# orders['UnitPrice'].max() # is just the price value, not the rest of the dataframe
# orders.max() # is just the highest value in each column, not the row data from the highest unitprice
# orders.loc[:,'UnitPrice'].max() # same as the first
# orders[
#     orders == orders.loc[:,'UnitPrice'].max()
# ]
# df.at[dates[0], 'A']
# orders.loc[str(orders['UnitPrice'].max())]


# idea - sort the data by UnitPrice descending, and then just view the top row?
orders.sort_values(by='UnitPrice', ascending = False)[:1]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour Description  \
# 118352      173382     551697      POST  2011      5    2    13     postage
#
#         Quantity          InvoiceDate  UnitPrice  CustomerID         Country  \
# 118352         1  2011-05-03 13:46:00    8142.75       16029  United Kingdom
#
#         amount_spent
# 118352       8142.75

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here

# group the rows by the year, look at the amount spent column and call .mean() on it
orders.groupby('year')['amount_spent'].mean()
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
