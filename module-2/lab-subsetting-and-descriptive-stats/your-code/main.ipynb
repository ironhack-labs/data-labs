# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp= pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp.head(100)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.dtypes
#City = object
#State = object
#Temperature = float64
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
temp[temp['State'] == 'New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
temp[temp['State'] == 'New York'].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp['Temperature'] > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here
temp[temp['Temperature']>15][['City']]
# Out:
#        City
# 0       NYC
# 3  Hartford
# 5    Treton
# 6    Newark

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[
    (temp['Temperature'] > 15) & (temp['Temperature']< 20)
]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
temp.rename(columns = {'Temperature':'AVG Temperature'}).groupby(['State']).mean()
# Out:
#              AVG Temperature
# State
# Connecticut        15.833333
# New Jersey         21.111111
# New York           10.740741

# %%
temp.rename(columns = {'Temperature':'STD Temperature'}).groupby(['State']).std()
# Out:
#              STD Temperature
# State
# Connecticut         1.964186
# New Jersey          1.571348
# New York            8.133404

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here
employee= pd.read_csv('employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.dtypes
#naame          object
#Department    object
#Education     object
#Gender        object
#Title         object
#Years          int64
#Salary         int64
employee.head(10)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee['Years'].plot(kind = 'hist')

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee['Salary'].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee['Salary'].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee[
    (employee['Salary'] <= 48.8) & (employee['Salary']>= 30)
]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30
# 3  Sonia         HR  Bachelor      F  analyst      4      35

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee['Name']
# Out:
# 0      Jose
# 1     Maria
# 2     David
# 3     Sonia
# 4    Samuel
# 5       Eva
# 6    Carlos
# 7     Pedro
# 8       Ana
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee['Name']== 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here
employee[employee['Title']== 'associate']
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[
    (employee['Title'] == 'associate') & (employee['Salary']> 55)
]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby(['Years']).mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here
employee.groupby(['Title']).mean()
# Out:
#            Years     Salary
# Title
# VP          8.00  70.000000
# analyst     2.25  32.500000
# associate   4.00  56.666667

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee['Salary'].plot(kind = 'box')

# %%
# print first quartile here
employee['Salary'].quantile(.25)
# Out:
# 35.0

# %%
# print third quartile here
employee['Salary'].quantile(.75)
# Out:
# 60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby(['Gender']).mean()
# Out:
#         Years  Salary
# Gender
# F         4.0    47.5
# M         4.2    50.0

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
df_stats=pd.DataFrame(employee.groupby('Department').agg(
    # Get max of the duration column for each group
max_salary=('Salary',max),
    # Get min of the duration column for each group
min_salary=('Salary', min),
    # Get mean of the duration column for each group
mean_salary=('Salary',"mean"),
max_year=('Years', max),
min_year=('Years', min),
mean_year=('Years', "mean")

))
df_stats.head()
# Out:
#             max_salary  min_salary  mean_salary  max_year  min_year  mean_year
# Department
# HR                  70          30        45.00         8         2   4.666667
# IT                  70          30        48.75         8         1   4.500000
# Sales               55          55        55.00         3         2   2.500000

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
df_stats['salary_diff']=df_stats['max_salary']-df_stats['min_salary']
df_stats.head()
# Out:
#             max_salary  min_salary  mean_salary  max_year  min_year  \
# Department
# HR                  70          30        45.00         8         2
# IT                  70          30        48.75         8         1
# Sales               55          55        55.00         3         2
#
#             mean_year  salary_diff
# Department
# HR           4.666667           40
# IT           4.500000           40
# Sales        2.500000            0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders= pd.read_csv('Orders.zip')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
orders.head(10)
# Out:
#    Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
# 5           5     536365     22752  2010     12    3     8
# 6           6     536365     21730  2010     12    3     8
# 7           7     536366     22633  2010     12    3     8
# 8           8     536366     22632  2010     12    3     8
# 9           9     536367     84879  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders['UnitPrice'].mean()
# Out:
# 3.1161744805540756

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders['UnitPrice'].max()
# Out:
# 8142.75

# %%
# your answer here
orders['UnitPrice'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
df3=orders[orders['Country']== 'Spain']
df3.head(10)
# Out:
#        Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250         6421     536944     22383  2010     12    5    12
# 4251         6422     536944     22384  2010     12    5    12
# 4252         6423     536944     20727  2010     12    5    12
# 4253         6424     536944     20725  2010     12    5    12
# 4254         6425     536944     20728  2010     12    5    12
# 13974       21565     538095     22504  2010     12    4    14
# 13975       21566     538095     22212  2010     12    4    14
# 13976       21567     538095     22953  2010     12    4    14
# 13977       21568     538095     84818  2010     12    4    14
# 13978       21569     538095     21114  2010     12    4    14
#
#                               Description  Quantity          InvoiceDate  \
# 4250              lunch bag suki  design         70  2010-12-03 12:20:00
# 4251              lunch bag pink polkadot       100  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here
spa_cus = pd.Series(list(df3['Country']))
spa_cus.value_counts()
# Out:
# Spain    2485
# dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders[orders['Quantity']>= 50]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 146            147     536382     22381  2010     12    3     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 397720      541702     581566     23404  2011     12    5    11
# 397721      541703     581567     21417  2011     12    5    11
# 397729      541711     581567     21326  2011     12    5    11
# 397761      541746     581571     23167  2011     12    5    12
# 397882      541867     581584     20832  2011     12    5    12
#
#                                Description  Quantity          InvoiceDate  \
# 46         paper chain kit 50's christmas         80  2010-12-01 09:00:00
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders[(orders['Country']=='Spain') & (orders['Quantity'] > 50)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders[orders['UnitPrice']==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders[orders['Description'].str.startswith('lunch bag')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders[(orders['Description'].str.startswith('lunch bag')) & (orders['year'] == 2011)]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 26340        42678     540015     20725  2011      1    2    11
# 26341        42679     540015     20726  2011      1    2    11
# 26512        42851     540023     22382  2011      1    2    12
# 26513        42852     540023     20726  2011      1    2    12
# 26860        43616     540098     22384  2011      1    2    15
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
elements = orders[orders['Country']=='Spain']
series = pd.Series(list(elements['amount_spent']))
series.value_counts()
# Out:
# 15.00     186
# 17.70     122
# 19.80      99
# 17.40      86
# 10.20      76
#          ...
# 29.85       1
# 7.56        1
# 280.00      1
# 360.00      1
# 4.74        1
# Length: 316, dtype: int64

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
orders[orders['month']== 8]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
elements = orders[orders['month']== 8]
count = elements['Country'].value_counts() 
print(count)
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
elements = orders[orders['month']== 8]
count = elements.groupby(['Country']).mean()
amt_spent=count['amount_spent']
print(amt_spent)
# Out:
# Country
# Australia          210.179439
# Austria             17.228182
# Belgium             18.319691
# Canada              10.312000
# Channel Islands     34.977000
# Denmark             13.321875
# EIRE                28.612782
# Finland             22.565574
# France              24.272337
# Germany             24.177069
# Iceland             26.586818
# Israel              28.501813
# Italy               20.957368
# Malta               20.345455
# Netherlands        144.027893
# Norway              26.309221
# Poland              23.635294
# Portugal            29.790244
# Spain               13.281389
# Sweden              35.021500
# Switzerland         18.613820
# United Kingdom      21.573396
# Unspecified         23.088261
# Name: amount_spent, dtype: float64

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
#df=elements.groupby(['Description'])
#series = pd.Series(list(df['UnitPrice']))
#series.sort_values()
#df.sort_values(by=['2'], ascending=False)
elements.sort_values(by=['UnitPrice'], ascending=False)
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 208732      297438     562946         M  2011      8    4     9
# 199712      285658     561916         M  2011      8    1    11
# 207566      295407     562787         M  2011      8    2    13
# 221995      312579     564357     22827  2011      8    3    15
# 225873      319701     564862      POST  2011      8    3    10
# ...            ...        ...       ...   ...    ...  ...   ...
# 199711      285657     561916         M  2011      8    1    11
# 223934      314748     564651     21786  2011      8    5    14
# 223933      314747     564651     22955  2011      8    5    14
# 223932      314746     564651     23268  2011      8    5    14
# 208950      298054     562973     23157  2011      8    4    11
#
#                                 Description  Quantity          InvoiceDate  \
# 208732                               manual         1  2011-08-11 09:38:00
# ...

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders['amount_spent'].mean()
# Out:
# 22.394748504739596
