# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here

import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
temp
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your findings
#
# ### ::TODO:: Specify what is the student expected to comment about?

# %%
# your answer here

temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here

temp.loc[temp["State"] == "New York"]
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here

temp.loc[temp["State"] == "New York"].mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here

temp.loc[temp["Temperature"] > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here

temp.loc[temp["Temperature"] > 15]["City"]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here

temp_df = temp["Temperature"]

Temp.loc[ (temp_df > 15) & (temp_df < 20)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here

#print(temp.describe())

print(temp.mean())

print(temp.std())
# Out:
# Temperature    15.15873
# dtype: float64
# Temperature    6.695265
# dtype: float64

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here

employee = pd.read_csv("employee.csv")

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here

employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. Comment your result.
#
# ### ::TODO:: Specify what is the student expected to comment about?

# %%
# your answer here

print(employee.hist(bins=20))
# Out:
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x11860bc50>
# ...

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here

employee["Salary"].mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here

employee["Salary"].max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here

employee["Salary"].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here

employee.loc[employee["Salary"]==30]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here

employee.loc[employee["Name"]=="David"]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here

employee.loc[employee["Name"]=="David"]["Salary"]
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here

associates = employee.loc[employee['Title']=='associate']

print(associates)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method

associates[0:3]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %%
# your answer here- 2nd method

associates.head(3)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here

employee.loc[(employee['Title']=='associate') & (employee['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### What's the average Salary per year?
#
# ## :FIX: To me it's kind of confusing to say "salary per year". It can be vague to the students and some of them may devide salary by years. I'd rather elaborate the question despite it's longer:
#
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here

employee.groupby('Years')['Salary'].mean()
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?
#
# ## :COMMENT: "salary per title" sounds fine because you cannot devide salary by title

# %%
# your answer here

employee.groupby('Title')['Salary'].mean()
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
#
# ## :FIX: The lesson only covered "quantile" not "quartile". I'm not sure if Marc will explain what is "quartile" in the class. So perhaps you need to explain quartile here?

# %%
# draw boxplot here

employee.boxplot()

# %%
# print first quartile here

employee.quantile([.25])
# Out:
#       Years  Salary
# 0.25    2.0    35.0

# %%
# print third quartile here

employee.quantile([.75])
# Out:
#       Years  Salary
# 0.75    7.0    60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here

employee.loc[employee["Gender"] == "M"]["Salary"].mean() == employee.loc[employee["Gender"] == "F"]["Salary"].mean()
# Out:
# False

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here

#print(employee.dtypes)

def get_numeric_cols(df):
    return df.select_dtypes(include=[np.number])

mins = employee.groupby('Department').apply(lambda a : get_numeric_cols(a)).min()

means = employee.groupby('Department').apply(lambda a : get_numeric_cols(a)).mean()

maxes = employee.groupby('Department').apply(lambda a : get_numeric_cols(a)).max()

print(mins)
print(means)
print(maxes)
# Out:
# Years      1
# Salary    30
# dtype: int64
# Years      4.111111
# Salary    48.888889
# dtype: float64
# Years      8
# Salary    70
# dtype: int64

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### Hint: try using `apply` and `lambda`

# %%
# your answer here

employee.groupby('Department').apply(lambda a : a["Salary"].max() - a["Salary"].min())
# Out:
# Department
# HR       40
# IT       40
# Sales     0
# dtype: int64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here

# %%
# your answer here

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here

# %%
# your answer here

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here

# %% [markdown]
# #### Select all free orders

# %%
# your answer here

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
