# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("z_train.csv")
test = pd.read_csv("z_test.csv")
sample = pd.read_csv("sample_submission.csv")

# %%
train.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours'],
#       dtype='object')

# %%
train_helper = train[['enrollee_id','relevent_experience','experience','training_hours','target']]
train_helper
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 0             8949  Has relevent experience        >20              36     1.0
# 1            29725   No relevent experience         15              47     0.0
# 2            11561   No relevent experience          5              83     0.0
# 3            33241   No relevent experience         <1              52     1.0
# 4            21651  Has relevent experience         11              24     1.0
# ...            ...                      ...        ...             ...     ...
# 15321         7386   No relevent experience         14              42     1.0
# 15322        31398  Has relevent experience         14              52     1.0
# 15323        24576  Has relevent experience        >20              44     0.0
# 15324         5756  Has relevent experience         <1              97     0.0
# 15325        23834   No relevent experience          2             127     0.0
#
# ...

# %%
train_helper.describe()
# Out:
#         enrollee_id  training_hours        target
# count  15326.000000    15326.000000  15326.000000
# mean   16838.278807       65.279068      0.249511
# std     9625.018286       60.079482      0.432744
# min        1.000000        1.000000      0.000000
# 25%     8482.250000       23.000000      0.000000
# 50%    16977.000000       47.000000      0.000000
# 75%    25144.000000       89.000000      0.000000
# max    33380.000000      336.000000      1.000000

# %%
t2 = train_helper.drop((train_helper[train_helper['target']== 0]).index)
t2
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 0             8949  Has relevent experience        >20              36     1.0
# 3            33241   No relevent experience         <1              52     1.0
# 4            21651  Has relevent experience         11              24     1.0
# 6              402  Has relevent experience         13              18     1.0
# 7            27107  Has relevent experience          7              46     1.0
# ...            ...                      ...        ...             ...     ...
# 15300         9651   No relevent experience          3              30     1.0
# 15314        17191   No relevent experience          4              48     1.0
# 15317          251  Has relevent experience          9              36     1.0
# 15321         7386   No relevent experience         14              42     1.0
# 15322        31398  Has relevent experience         14              52     1.0
#
# [3824 rows x 5 columns]

# %%
t3 = train_helper.drop((train_helper[train_helper['target']==1]).index)
t3
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 1            29725   No relevent experience         15              47     0.0
# 2            11561   No relevent experience          5              83     0.0
# 5            28806  Has relevent experience          5              24     0.0
# 8              699  Has relevent experience         17             123     0.0
# 10           23853  Has relevent experience          5             108     0.0
# ...            ...                      ...        ...             ...     ...
# 15319        11385   No relevent experience          2              60     0.0
# 15320        29754  Has relevent experience          7              25     0.0
# 15323        24576  Has relevent experience        >20              44     0.0
# 15324         5756  Has relevent experience         <1              97     0.0
# 15325        23834   No relevent experience          2             127     0.0
#
# ...

# %%
t4 = t3.drop((t3[t3['relevent_experience']== "No relevent experience"]).index)
t4
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 5            28806  Has relevent experience          5              24     0.0
# 8              699  Has relevent experience         17             123     0.0
# 10           23853  Has relevent experience          5             108     0.0
# 11           25619  Has relevent experience        >20              23     0.0
# 14            6588  Has relevent experience         16              18     0.0
# ...            ...                      ...        ...             ...     ...
# 15316        13167  Has relevent experience          5              51     0.0
# 15318        32313  Has relevent experience         10              23     0.0
# 15320        29754  Has relevent experience          7              25     0.0
# 15323        24576  Has relevent experience        >20              44     0.0
# 15324         5756  Has relevent experience         <1              97     0.0
#
# [8684 rows x 5 columns]

# %%
t4 = t4.sort_values(by = ["training_hours"], ascending= False)
t5 = t4[:8]

# %%
data = t2.append(t5)
d2 = data.sort_values(by = ["training_hours"], ascending= False)
d2
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 5668         10041   No relevent experience         <1             336     1.0
# 13421        26858  Has relevent experience         16             336     0.0
# 14770        32716  Has relevent experience         17             336     0.0
# 11144         4983  Has relevent experience          5             336     0.0
# 11004        23680   No relevent experience          3             336     1.0
# ...            ...                      ...        ...             ...     ...
# 5355         18749   No relevent experience          9               2     1.0
# 86           10473  Has relevent experience          2               2     1.0
# 3598         20934   No relevent experience          6               2     1.0
# 5801         18655  Has relevent experience          6               2     1.0
# 7059         26150   No relevent experience          6               1     1.0
#
# [3832 rows x 5 columns]

# %%
d3 = d2[["enrollee_id","target"]]
d3 = d3.set_index("enrollee_id")
d3
# Out:
#              target
# enrollee_id
# 10041           1.0
# 26858           0.0
# 32716           0.0
# 4983            0.0
# 23680           1.0
# ...             ...
# 18749           1.0
# 10473           1.0
# 20934           1.0
# 18655           1.0
# 26150           1.0
#
# [3832 rows x 1 columns]

# %%
d3.to_csv("sub3.csv")

# %%
train_helper.dtypes
# Out:
# enrollee_id              int64
# relevent_experience     object
# experience              object
# training_hours           int64
# target                 float64
# dtype: object

# %%
train_helper.describe()
# Out:
#         enrollee_id  training_hours        target
# count  15326.000000    15326.000000  15326.000000
# mean   16838.278807       65.279068      0.249511
# std     9625.018286       60.079482      0.432744
# min        1.000000        1.000000      0.000000
# 25%     8482.250000       23.000000      0.000000
# 50%    16977.000000       47.000000      0.000000
# 75%    25144.000000       89.000000      0.000000
# max    33380.000000      336.000000      1.000000

# %%
train_helper[train_helper["training_hours"]> 65]
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 2            11561   No relevent experience          5              83     0.0
# 8              699  Has relevent experience         17             123     0.0
# 10           23853  Has relevent experience          5             108     0.0
# 15            4167  Has relevent experience          1             106     0.0
# 18           31972  Has relevent experience         11              68     0.0
# ...            ...                      ...        ...             ...     ...
# 15306        20520  Has relevent experience          8             136     0.0
# 15307        22620  Has relevent experience          8              80     0.0
# 15315          155   No relevent experience          5             190     0.0
# 15324         5756  Has relevent experience         <1              97     0.0
# 15325        23834   No relevent experience          2             127     0.0
#
# [5539 rows x 5 columns]

# %%
train_helper[(train_helper["relevent_experience"] == "Has relevent experience") & (train_helper["training_hours"]> 65)]
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 8              699  Has relevent experience         17             123     0.0
# 10           23853  Has relevent experience          5             108     0.0
# 15            4167  Has relevent experience          1             106     0.0
# 18           31972  Has relevent experience         11              68     0.0
# 24           17139  Has relevent experience         14             148     1.0
# ...            ...                      ...        ...             ...     ...
# 15297        18750  Has relevent experience         12             119     0.0
# 15303        15549  Has relevent experience         10              67     0.0
# 15306        20520  Has relevent experience          8             136     0.0
# 15307        22620  Has relevent experience          8              80     0.0
# 15324         5756  Has relevent experience         <1              97     0.0
#
# [4077 rows x 5 columns]

# %%
d4 = train_helper[(train_helper["relevent_experience"] == "Has relevent experience") & (train_helper["training_hours"]> 65)]
d5 = d4.sort_values(by= "training_hours", ascending = False)
d5
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 11144         4983  Has relevent experience          5             336     0.0
# 13421        26858  Has relevent experience         16             336     0.0
# 14770        32716  Has relevent experience         17             336     0.0
# 11191        13744  Has relevent experience          6             334     0.0
# 4391         15053  Has relevent experience         20             334     0.0
# ...            ...                      ...        ...             ...     ...
# 8569         32700  Has relevent experience          3              66     1.0
# 3210         18869  Has relevent experience          4              66     0.0
# 7655         27845  Has relevent experience        >20              66     0.0
# 2079         13377  Has relevent experience          3              66     1.0
# 10982        15292  Has relevent experience        >20              66     0.0
#
# [4077 rows x 5 columns]

# %%
d5[d5["target"] == 1]
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 12304         6564  Has relevent experience          4             334     1.0
# 5346         15740  Has relevent experience          3             332     1.0
# 4414         32999  Has relevent experience          3             328     1.0
# 10623        21348  Has relevent experience         <1             324     1.0
# 14161        14612  Has relevent experience          4             320     1.0
# ...            ...                      ...        ...             ...     ...
# 10825        19358  Has relevent experience         <1              66     1.0
# 2640         31289  Has relevent experience         14              66     1.0
# 11488        15208  Has relevent experience         15              66     1.0
# 8569         32700  Has relevent experience          3              66     1.0
# 2079         13377  Has relevent experience          3              66     1.0
#
# [851 rows x 5 columns]

# %%
d5
# Out:
#        enrollee_id      relevent_experience experience  training_hours  target
# 11144         4983  Has relevent experience          5             336     0.0
# 13421        26858  Has relevent experience         16             336     0.0
# 14770        32716  Has relevent experience         17             336     0.0
# 11191        13744  Has relevent experience          6             334     0.0
# 4391         15053  Has relevent experience         20             334     0.0
# ...            ...                      ...        ...             ...     ...
# 8569         32700  Has relevent experience          3              66     1.0
# 3210         18869  Has relevent experience          4              66     0.0
# 7655         27845  Has relevent experience        >20              66     0.0
# 2079         13377  Has relevent experience          3              66     1.0
# 10982        15292  Has relevent experience        >20              66     0.0
#
# [4077 rows x 5 columns]

# %%
d6 = d5
d6["target"]= d6["target"].replace(0.0,1.0)

# %%
d7 = d6[:3832]
d8 = d7[["enrollee_id","target"]]
d8 = d8.set_index("enrollee_id")

# %%
d8.to_csv("sub4.csv")

# %%
t_cheat = sample

# %%
t_cheat = t_cheat.set_index("enrollee_id")
t_cheat
# Out:
#              target
# enrollee_id
# 23603             1
# 22499             1
# 10465             1
# 8293              1
# 4246              1
# ...             ...
# 8880              1
# 7886              1
# 12279             1
# 5326              1
# 4017              1
#
# [3832 rows x 1 columns]

# %%
t_cheat.to_csv("cheat.csv")

# %%
s1 = sample.set_index("enrollee_id")
s1
# Out:
#              target
# enrollee_id
# 23603             1
# 22499             1
# 10465             1
# 8293              1
# 4246              1
# ...             ...
# 8880              1
# 7886              1
# 12279             1
# 5326              1
# 4017              1
#
# [3832 rows x 1 columns]

# %%
t1 = train.set_index("enrollee_id")
t1
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 21651        city_176                   0.764    NaN  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %%
train
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4            21651  city_176                   0.764    NaN
# ...            ...       ...                     ...    ...
# 15321         7386  city_173                   0.878   Male
# 15322        31398  city_103                   0.920   Male
# 15323        24576  city_103                   0.920   Male
# 15324         5756   city_65                   0.802   Male
# 15325        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
sample
# Out:
#       enrollee_id  target
# 0           23603       1
# 1           22499       1
# 2           10465       1
# 3            8293       1
# 4            4246       1
# ...           ...     ...
# 3827         8880       1
# 3828         7886       1
# 3829        12279       1
# 3830         5326       1
# 3831         4017       1
#
# [3832 rows x 2 columns]

# %%
data = sample.merge(test, on = "enrollee_id", how = "left")

# %%
data
# Out:
#       enrollee_id  target      city  city_development_index  gender  \
# 0           23603       1  city_160                   0.920    Male
# 1           22499       1   city_45                   0.890     NaN
# 2           10465       1  city_149                   0.689    Male
# 3            8293       1   city_67                   0.855  Female
# 4            4246       1  city_103                   0.920    Male
# ...           ...     ...       ...                     ...     ...
# 3827         8880       1   city_41                   0.827     NaN
# 3828         7886       1   city_71                   0.884    Male
# 3829        12279       1  city_160                   0.920    Male
# 3830         5326       1   city_23                   0.899    Male
# 3831         4017       1  city_103                   0.920    Male
#
#           relevent_experience enrolled_university education_level  \
# 0      No relevent experience    Full time course        Graduate
# ...

# %%
data.describe()
# Out:
#         enrollee_id  target  city_development_index  training_hours
# count   3832.000000  3832.0             3832.000000     3832.000000
# mean   17023.656315     1.0                0.824523       65.718163
# std     9581.132710     0.0                0.126021       59.980867
# min       10.000000     1.0                0.448000        1.000000
# 25%     8791.250000     1.0                0.698000       23.000000
# 50%    17043.000000     1.0                0.899000       48.000000
# 75%    25285.750000     1.0                0.920000       88.000000
# max    33362.000000     1.0                0.949000      336.000000

# %%
data1 = data.sort_values(by = ["training_hours"], ascending= False)

# %%
data1
# Out:
#       enrollee_id  target      city  city_development_index gender  \
# 1446        31454       1   city_27                   0.848   Male
# 678         32554       1  city_103                   0.920   Male
# 1561         1919       1   city_90                   0.698    NaN
# 3092        12559       1  city_114                   0.926    NaN
# 217          8866       1   city_19                   0.682    NaN
# ...           ...     ...       ...                     ...    ...
# 1882        28714       1  city_114                   0.926   Male
# 2261        17156       1  city_115                   0.789   Male
# 3694        31811       1   city_77                   0.830   Male
# 3652         9969       1  city_103                   0.920   Male
# 1604         4168       1   city_16                   0.910    NaN
#
#           relevent_experience enrolled_university education_level  \
# 1446  Has relevent experience       no_enrollment        Graduate
# ...

# %%
d1 = data1
d1 = d1.set_index("enrollee_id")
d1 = d1[["target"]]
d1
# Out:
#              target
# enrollee_id
# 31454             1
# 32554             1
# 1919              1
# 12559             1
# 8866              1
# ...             ...
# 28714             1
# 17156             1
# 31811             1
# 9969              1
# 4168              1
#
# [3832 rows x 1 columns]

# %%
d1.to_csv("subm2.csv")
