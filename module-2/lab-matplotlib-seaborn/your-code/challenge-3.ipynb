# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.tail(50)
# Out:
#       PassengerId  Survived  Pclass  \
# 1259         1260       NaN       1
# 1260         1261       NaN       2
# 1261         1262       NaN       2
# 1262         1263       NaN       1
# 1263         1264       NaN       1
# 1264         1265       NaN       2
# 1265         1266       NaN       1
# 1266         1267       NaN       1
# 1267         1268       NaN       3
# 1268         1269       NaN       2
# 1269         1270       NaN       1
# 1270         1271       NaN       3
# 1271         1272       NaN       3
# 1272         1273       NaN       3
# 1273         1274       NaN       3
# 1274         1275       NaN       3
# 1275         1276       NaN       2
# 1276         1277       NaN       2
# 1277         1278       NaN       3
# 1278         1279       NaN       2
# 1279         1280       NaN       3
# 1280         1281       NaN       3
# 1281         1282       NaN       1
# 1282         1283       NaN       1
# 1283         1284       NaN       3
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include =['float64','int64']).head(10)
# Out:
#    PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.000000      1      0   7.2500
# 1            2       1.0       1  38.000000      1      0  71.2833
# 2            3       1.0       3  26.000000      0      0   7.9250
# 3            4       1.0       1  35.000000      1      0  53.1000
# 4            5       0.0       3  35.000000      0      0   8.0500
# 5            6       0.0       3  23.926502      0      0   8.4583
# 6            7       0.0       1  54.000000      0      0  51.8625
# 7            8       0.0       3   2.000000      3      1  21.0750
# 8            9       1.0       3  27.000000      0      2  11.1333
# 9           10       1.0       2  14.000000      1      0  30.0708

# %%
#your code here- categorical variable
titanic.select_dtypes(include ='object').head(10)
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male
# 6                            McCarthy, Mr. Timothy J    male
# 7                     Palsson, Master. Gosta Leonard    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S
# 5            330877    U0        Q
# 6             17463   E46        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic['Age'].plot(
    kind='hist')

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
fig, axs =plt.subplots(
    1,
    3)

axs[0].hist(titanic['Age'], bins = 10)
axs[1].hist(titanic['Age'], bins = 20)
axs[2].hist(titanic['Age'], bins = 50)
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#          75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#          35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#          14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
ax = titanic['Gender'].value_counts(ascending = True).plot(
    kind = 'bar',
    color = 'green',
    width = 0.5
)

# %%
# your code here- 2nd way
x=titanic['Gender'].value_counts()
sns.barplot(x.index,x)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
x=titanic['Pclass'].value_counts()
sns.barplot(x.index,x)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
titanic['Age'].plot(kind = 'box')

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
#The graphs tells us that the distrubution of our data is mainly shifted to the left with
#the mean age is between 20 and 30 years old

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
titanic['Age'].plot(
    kind='hist')

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
#The frequency of an age value in or data set

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
plt.title("Fare vs. Age")
plt.plot(
   titanic['Age'],
    titanic['Fare'],
    color = 'green'
)

# %%
# your code-2nd way
sns.lineplot(titanic['Age'],titanic['Fare'])

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
new_tit=titanic.dropna()
sns.heatmap(titanic.corr())

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
#SibSp and Parch have the strongest correlation according to the graph.
#Second, surivived and rate shows a moderate correlation

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(titanic['Pclass'],titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(titanic, col="Gender",legend_out=True)
g.map(plt.hist, "Age",bins=8, color="green")
