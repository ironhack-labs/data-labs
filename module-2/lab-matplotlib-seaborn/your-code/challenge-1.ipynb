# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way 
# plt.subplots(1, 2)
plt.plot(
    x, #x axis
    y,
    lw = 0.8,
    ls = '-',
    color = 'blue'#y axis
)

# plt.subplots(1, 2)
plt.plot(
    x, #x axis
    z,
    lw = 0.8,
    ls = '-',
    color = 'red'#y axis
)

#why when i do x and y alone the line is different than when i combine it with x and z

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
# plt.subplots(1, 2)
fig, ax = plt.subplots()
ax.plot(x, y)

fig, ax = plt.subplots()
ax.plot(x, z)

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, axs = plt.subplots(
    1, # ncols
    2, # nrows
    figsize = (12, 4)
)

fig.sca(axs[0]) # Call .sca() on the Figure object to set
plt.plot(
    x,
    y
)

fig.sca(axs[1])
plt.plot(
    x,
    z,
    ls = '--',
    lw = 2, 
    color = 'red'
)

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, axs = plt.subplots(
    1, # ncols
    2, # nrows
    figsize = (12, 4)
)

fig.sca(axs[0]) # Call .sca() on the Figure object to set
plt.plot(
    x,
    y
)
plt.xlabel('x') 
plt.ylabel('y')

fig.sca(axs[1])
plt.plot(
    x,
    z,
    ls = '--',
    lw = 2, 
    color = 'red'
)
plt.xlabel('x') 
plt.ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
from math import exp

fig, axs = plt.subplots(
    1, # ncols
    2, # nrows
    figsize = (12, 4)
)

fig.sca(axs[0]) # Call .sca() on the Figure object to set
plt.plot(
    x,
    x^2
)
plt.xlabel('x') 
plt.ylabel('y')

axs[0].set_xscale('log') 
axs[0].set_yscale('log')

fig.sca(axs[1])
z = [exp(el) for i, e in enumerate(x)]
plt.plot(
    x,
    z,
    ls = '--',
    lw = 2, 
    color = 'red'
)
plt.xlabel('x') 
plt.ylabel('z')

axs[0].set_xscale('log') 
axs[0].set_yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-77da336e6f4c> in <module>
#      20
#      21 fig.sca(axs[1])
# ---> 22 z = [exp(el) for i, e in enumerate(x)]
#      23 plt.plot(
#      24     x,
#
# <ipython-input-52-77da336e6f4c> in <listcomp>(.0)
#      20
#      21 fig.sca(axs[1])
# ---> 22 z = [exp(el) for i, e in enumerate(x)]
#      23 plt.plot(
#      24     x,
#
# NameError: name 'el' is not defined

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df = pd.read_csv('/Users/anielkaaslan/Documents/data-labs/module-2/lab-matplotlib-seaborn/your-code/vehicles.csv')

mpg = df.groupby('Year')['Combined MPG', 'Highway MPG'].mean().reset_index()
mpg.head()
# Out:
#    Year  Combined MPG  Highway MPG
# 0  1984     16.844961    19.075969
# 1  1985     19.805187    23.045541
# 2  1986     19.562290    22.717172
# 3  1987     19.349750    22.601836
# 4  1988     19.315460    22.686327

# %%
plt.scatter(mpg['Combined MPG'], mpg['Highway MPG'])

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here

plt.boxplot(df['CO2 Emission Grams/Mile'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a237ee518>,
#   <matplotlib.lines.Line2D at 0x1a237ee8d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a237eef28>,
#   <matplotlib.lines.Line2D at 0x1a236ee860>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a237eeb00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a236ee2e8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a236ee630>],
#  'means': []}

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
plt.hist(df['Fuel Barrels/Year'])
# Out:
# (array([8.1000e+01, 3.7400e+02, 6.7650e+03, 1.7039e+04, 8.9660e+03,
#         2.0960e+03, 5.6900e+02, 3.6000e+01, 2.1000e+01, 5.0000e+00]),
#  array([ 0.06      ,  4.76271429,  9.46542857, 14.16814286, 18.87085714,
#         23.57357143, 28.27628571, 32.979     , 37.68171429, 42.38442857,
#         47.08714286]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
plt.bar(df['Fuel Type'], df['City MPG'])
# Out:
# <BarContainer object of 35952 artists>
