# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:
admissions.notna().sum()
# df.eval(admissions == is
# Out:
# Serial No.           385
# GRE Score            385
# TOEFL Score          385
# University Rating    385
# SOP                  385
# LOR                  385
# CGPA                 385
# Research             385
# Chance of Admit      385
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:

admissions.set_index('Serial No.', inplace = True)
# admissions.head()

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:
admissions = pd.read_csv('../Admission_Predict.csv')
combination = zip(admissions['GRE Score'], admissions['CGPA'])
list(combination)
# Out:
# [(337, 9.65),
#  (316, 8.0),
#  (322, 8.67),
#  (314, 8.21),
#  (330, 9.34),
#  (321, 8.2),
#  (308, 7.9),
#  (302, 8.0),
#  (323, 8.6),
#  (327, 9.0),
#  (328, 9.1),
#  (307, 8.0),
#  (311, 8.2),
#  (314, 8.3),
#  (317, 8.7),
#  (319, 8.0),
#  (318, 8.8),
#  (303, 8.5),
#  (325, 8.4),
#  (328, 9.5),
#  (334, 9.7),
#  (336, 9.8),
#  (322, 8.8),
#  (298, 7.5),
#  (295, 7.2),
#  (310, 7.3),
#  (300, 8.1),
#  (327, 8.3),
#  (338, 9.4),
#  (340, 9.6),
#  (331, 9.8),
#  (320, 9.2),
#  (299, 8.4),
#  (300, 7.8),
#  (304, 7.5),
#  (307, 7.7),
#  (308, 8.0),
#  (316, 8.2),
#  (313, 8.5),
#  (332, 9.1),
#  (326, 9.4),
#  (322, 9.1),
#  (329, 9.3),
#  (339, 9.7),
#  (321, 8.85),
#  (327, 8.4),
#  (313, 8.3),
#  (312, 7.9),
#  (334, 8.0),
#  (324, 8.1),
#  (322, 8.0),
#  (320, 7.7),
#  (316, 7.4),
#  (298, 7.6),
#  (300, 6.8),
#  (311, 8.3),
#  (309, 8.1),
#  (307, 8.2),
#  (304, 8.2),
#  (315, 8.5),
#  (325, 8.7),
#  (325, 8.92),
#  (327, 9.02),
#  (316, 8.64),
#  (318, 9.22),
#  (328, 9.16),
#  (332, 9.64),
#  (336, 9.76),
#  (321, 9.45),
#  (314, 9.04),
#  (314, 8.9),
#  (329, 8.56),
#  (327, 8.72),
#  (301, 8.22),
#  (296, 7.54),
#  (294, 7.36),
#  (312, 8.02),
#  (340, 9.5),
#  (320, 9.22),
#  (322, 9.36),
#  (340, 9.45),
#  (319, 8.66),
#  (315, 8.42),
#  (317, 8.28),
#  (314, 8.14),
#  (318, 7.92),
#  (299, 7.66),
#  (298, 8.03),
#  (301, 7.88),
#  (303, 7.66),
#  (304, 7.84),
#  (306, 8.0),
#  (331, 8.96),
#  (332, 9.24),
#  (323, 8.88),
#  (322, 8.46),
#  (312, 8.12),
#  (314, 8.25),
#  (317, 8.47),
#  (326, 9.05),
#  (316, 8.78),
#  (329, 9.18),
#  (338, 9.46),
#  (331, 9.38),
#  (304, 8.64),
#  (305, 8.48),
#  (321, 8.68),
#  (301, 8.34),
#  (320, 8.56),
#  (311, 8.45),
#  (310, 9.04),
#  (299, 8.62),
#  (290, 7.46),
#  (296, 7.28),
#  (327, 8.84),
#  (335, 9.56),
#  (334, 9.48),
#  (310, 8.36),
#  (308, 8.22),
#  (301, 8.47),
#  (300, 8.66),
#  (323, 9.32),
#  (319, 8.71),
#  (326, 9.1),
#  (333, 9.35),
#  (339, 9.76),
#  (303, 8.65),
#  (323, 8.78),
#  (333, 9.28),
#  (314, 8.77),
#  (316, 8.16),
#  (326, 9.08),
#  (318, 9.12),
#  (329, 9.15),
#  (332, 9.36),
#  (331, 9.44),
#  (340, 9.92),
#  (325, 8.96),
#  (320, 8.64),
#  (315, 8.48),
#  (326, 9.11),
#  (339, 9.8),
#  (311, 8.26),
#  (334, 9.43),
#  (332, 9.28),
#  (321, 9.06),
#  (324, 8.75),
#  (326, 8.89),
#  (312, 8.69),
#  (315, 8.34),
#  (309, 8.26),
#  (306, 8.14),
#  (297, 7.9),
#  (315, 7.86),
#  (298, 7.46),
#  (318, 8.5),
#  (317, 8.56),
#  (329, 9.01),
#  (322, 8.97),
#  (302, 8.33),
#  (313, 8.27),
#  (293, 7.8),
#  (311, 7.98),
#  (312, 8.04),
#  (334, 9.07),
#  (322, 9.13),
#  (323, 9.23),
#  (321, 8.97),
#  (320, 8.87),
#  (329, 9.16),
#  (319, 9.04),
#  (309, 8.12),
#  (307, 8.27),
#  (300, 8.16),
#  (305, 8.42),
#  (299, 7.88),
#  (314, 8.8),
#  (327, 9.11),
#  (317, 8.68),
#  (335, 9.44),
#  (331, 9.36),
#  (324, 9.16),
#  (323, 8.98),
#  (322, 8.94),
#  (336, 9.53),
#  (316, 8.76),
#  (307, 8.52),
#  (306, 8.26),
#  (310, 8.33),
#  (313, 8.69),
#  (317, 8.54),
#  (315, 8.46),
#  (340, 9.91),
#  (334, 9.87),
#  (298, 8.54),
#  (295, 7.65),
#  (315, 7.89),
#  (310, 8.02),
#  (305, 8.16),
#  (301, 8.12),
#  (325, 9.06),
#  (328, 9.14),
#  (338, 9.66),
#  (333, 9.78),
#  (331, 9.42),
#  (330, 9.36),
#  (322, 9.26),
#  (321, 9.13),
#  (324, 8.97),
#  (312, 8.42),
#  (313, 8.75),
#  (316, 8.56),
#  (308, 8.45),
#  (305, 8.23),
#  (296, 8.03),
#  (306, 8.45),
#  (318, 8.67),
#  (324, 9.01),
#  (313, 8.65),
#  (319, 8.33),
#  (312, 8.27),
#  (304, 8.07),
#  (330, 9.31),
#  (326, 9.23),
#  (325, 9.17),
#  (329, 9.19),
#  (310, 8.37),
#  (299, 7.89),
#  (296, 7.68),
#  (317, 8.15),
#  (324, 8.76),
#  (325, 9.04),
#  (314, 8.56),
#  (328, 9.02),
#  (316, 8.73),
#  (311, 8.48),
#  (324, 8.87),
#  (321, 8.83),
#  (320, 8.57),
#  (316, 9.0),
#  (318, 8.54),
#  (335, 9.68),
#  (321, 9.12),
#  (307, 8.37),
#  (309, 8.56),
#  (324, 8.64),
#  (331, 9.34),
#  (327, 9.13),
#  (312, 8.09),
#  (308, 8.36),
#  (324, 8.79),
#  (325, 8.76),
#  (313, 8.68),
#  (312, 8.45),
#  (314, 8.17),
#  (327, 9.14),
#  (308, 8.34),
#  (306, 8.22),
#  (299, 7.86),
#  (294, 7.64),
#  (312, 8.01),
#  (315, 7.95),
#  (322, 8.96),
#  (329, 9.45),
#  (320, 8.62),
#  (308, 8.49),
#  (304, 8.73),
#  (311, 8.64),
#  (317, 9.11),
#  (312, 8.79),
#  (321, 8.9),
#  (340, 9.66),
#  (331, 9.26),
#  (336, 9.19),
#  (324, 9.08),
#  (314, 9.02),
#  (313, 9.0),
#  (307, 7.65),
#  (300, 7.87),
#  (302, 7.97),
#  (312, 8.18),
#  (316, 8.32),
#  (317, 8.57),
#  (310, 8.67),
#  (320, 9.11),
#  (330, 9.24),
#  (305, 8.65),
#  (309, 8.0),
#  (319, 8.76),
#  (322, 8.45),
#  (323, 8.55),
#  (313, 8.43),
#  (321, 8.8),
#  (323, 9.1),
#  (325, 9.0),
#  (312, 8.53),
#  (308, 8.6),
#  (320, 8.74),
#  (328, 9.18),
#  (311, 9.0),
#  (301, 8.04),
#  (308, 8.07),
#  (298, 7.86),
#  (300, 8.01),
#  (324, 8.8),
#  (327, 8.69),
#  (317, 8.5),
#  (323, 8.44),
#  (314, 8.27),
#  (305, 8.18),
#  (315, 8.33),
#  (326, 9.14),
#  (299, 8.02),
#  (295, 7.86),
#  (324, 8.77),
#  (297, 7.89),
#  (327, 8.66),
#  (311, 8.12),
#  (308, 8.21),
#  (319, 8.54),
#  (312, 8.65),
#  (319, 8.79),
#  (332, 9.47),
#  (323, 8.74),
#  (324, 8.66),
#  (312, 8.46),
#  (326, 8.76),
#  (308, 8.24),
#  (305, 8.13),
#  (295, 7.34),
#  (316, 7.43),
#  (304, 7.64),
#  (299, 7.34),
#  (302, 7.25),
#  (313, 8.04),
#  (318, 8.27),
#  (325, 8.67),
#  (303, 8.06),
#  (300, 8.17),
#  (297, 7.67),
#  (317, 8.12),
#  (327, 8.77),
#  (301, 7.89),
#  (314, 7.64),
#  (321, 8.44),
#  (322, 8.64),
#  (334, 9.54),
#  (338, 9.23),
#  (306, 8.36),
#  (313, 8.9),
#  (330, 9.17),
#  (320, 8.34),
#  (311, 7.46),
#  (298, 7.88),
#  (301, 8.03),
#  (310, 8.24),
#  (324, 9.22),
#  (336, 9.62),
#  (321, 8.54),
#  (315, 7.65),
#  (304, 7.66),
#  (297, 7.43),
#  (290, 7.56),
#  (303, 7.65),
#  (311, 8.43),
#  (322, 8.84),
#  (319, 8.67),
#  (324, 9.15),
#  (300, 8.26),
#  (340, 9.74),
#  (335, 9.82),
#  (302, 7.96),
#  (307, 8.1),
#  (296, 7.8),
#  (320, 8.44),
#  (314, 8.24),
#  (318, 8.65),
#  (326, 9.12),
#  (317, 8.76),
#  (329, 9.23),
#  (324, 9.04),
#  (325, 9.11),
#  (330, 9.45),
#  (312, 8.78),
#  (333, 9.66)]

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:
admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

admissions.set_index(['CGPA', 'GRE Score'], inplace = True, drop = True)
admissions
admissions.reset_index(inplace = True)
admissions
# Out:
#      CGPA  GRE Score  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0    9.65        337           1          118                  4  4.5  4.5
# 1    8.00        316           2          104                  3  3.0  3.5
# 2    8.67        322           3          110                  3  3.5  2.5
# 3    8.21        314           4          103                  2  2.0  3.0
# 4    9.34        330           5          115                  5  4.5  3.0
# 5    8.20        321           6          109                  3  3.0  4.0
# 6    7.90        308           7          101                  2  3.0  4.0
# 7    8.00        302           8          102                  1  2.0  1.5
# 8    8.60        323           9          108                  3  3.5  3.0
# 9    9.00        327          10          111                  4  4.0  4.5
# 10   9.10        328          11          112                  4  4.0  4.5
# 11   8.00        307          12          109                  3  4.0  3.0
# 12   8.20        311          13          104                  3  3.5  2.0
# 13   8.30        314          14          105                  3  3.5  2.5
# 14   8.70        317          15          107                  3  4.0  3.0
# 15   8.00        319          16          106                  3  4.0  3.0
# 16   8.80        318          17          110                  3  4.0  3.0
# 17   8.50        303          18          102                  3  3.5  3.0
# 18   8.40        325          19          114                  4  3.0  2.0
# 19   9.50        328          20          116                  5  5.0  5.0
# 20   9.70        334          21          119                  5  5.0  4.5
# 21   9.80        336          22          119                  5  4.0  3.5
# 22   8.80        322          23          109                  5  4.5  3.5
# 23   7.50        298          24           98                  2  1.5  2.5
# 24   7.20        295          25           93                  1  2.0  2.0
# 25   7.30        310          26           99                  2  1.5  2.0
# 26   8.10        300          27           97                  2  3.0  3.0
# 27   8.30        327          28          103                  3  4.0  4.0
# 28   9.40        338          29          118                  4  3.0  4.5
# 29   9.60        340          30          114                  5  4.0  4.0
# ..    ...        ...         ...          ...                ...  ...  ...
# 355  8.24        310         356          103                  2  2.5  2.5
# 356  9.22        324         357          110                  3  3.5  3.0
# 357  9.62        336         358          119                  4  4.5  4.0
# 358  8.54        321         359          109                  3  3.0  3.0
# 359  7.65        315         360          105                  2  2.0  2.5
# 360  7.66        304         361          101                  2  2.0  2.5
# 361  7.43        297         362           96                  2  2.5  2.0
# 362  7.56        290         363          100                  1  1.5  2.0
# 363  7.65        303         364           98                  1  2.0  2.5
# 364  8.43        311         365           99                  1  2.5  3.0
# 365  8.84        322         366          104                  3  3.5  4.0
# 366  8.67        319         367          105                  3  3.0  3.5
# 367  9.15        324         368          110                  4  4.5  4.0
# 368  8.26        300         369          100                  3  3.0  3.5
# 369  9.74        340         370          113                  4  5.0  5.0
# 370  9.82        335         371          117                  5  5.0  5.0
# 371  7.96        302         372          101                  2  2.5  3.5
# 372  8.10        307         373          105                  2  2.0  3.5
# 373  7.80        296         374           97                  2  1.5  2.0
# 374  8.44        320         375          108                  3  3.5  4.0
# 375  8.24        314         376          102                  2  2.0  2.5
# 376  8.65        318         377          106                  3  2.0  3.0
# 377  9.12        326         378          112                  4  4.0  3.5
# 378  8.76        317         379          104                  2  3.0  3.0
# 379  9.23        329         380          111                  4  4.5  4.0
# 380  9.04        324         381          110                  3  3.5  3.5
# 381  9.11        325         382          107                  3  3.0  3.5
# 382  9.45        330         383          116                  4  5.0  4.5
# 383  8.78        312         384          103                  3  3.5  4.0
# 384  9.66        333         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.72
# 2           1             0.80
# 3           0             0.65
# 4           1             0.90
# 5           1             0.75
# 6           0             0.68
# 7           0             0.50
# 8           0             0.45
# 9           1             0.84
# 10          1             0.78
# 11          1             0.62
# 12          1             0.61
# 13          0             0.54
# 14          0             0.66
# 15          1             0.65
# 16          0             0.63
# 17          0             0.62
# 18          0             0.70
# 19          1             0.94
# 20          1             0.95
# 21          1             0.97
# 22          0             0.76
# 23          1             0.44
# 24          0             0.46
# 25          0             0.54
# 26          1             0.65
# 27          1             0.74
# 28          1             0.91
# 29          1             0.90
# ..        ...              ...
# 355         0             0.72
# 356         1             0.89
# 357         1             0.95
# 358         1             0.79
# 359         0             0.39
# 360         0             0.38
# 361         0             0.34
# 362         0             0.47
# 363         0             0.56
# 364         1             0.71
# 365         1             0.78
# 366         1             0.73
# 367         1             0.82
# 368         0             0.62
# 369         1             0.96
# 370         1             0.96
# 371         0             0.46
# 372         0             0.53
# 373         0             0.49
# 374         1             0.76
# 375         0             0.64
# 376         0             0.71
# 377         1             0.84
# 378         0             0.77
# 379         1             0.89
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 383         0             0.67
# 384         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:
admissions[(admissions.CGPA > 9) * admissions.Research == 1]
# Out:
#      CGPA  GRE Score  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0    9.65        337           1          118                  4  4.5  4.5
# 4    9.34        330           5          115                  5  4.5  3.0
# 10   9.10        328          11          112                  4  4.0  4.5
# 19   9.50        328          20          116                  5  5.0  5.0
# 20   9.70        334          21          119                  5  5.0  4.5
# 21   9.80        336          22          119                  5  4.0  3.5
# 28   9.40        338          29          118                  4  3.0  4.5
# 29   9.60        340          30          114                  5  4.0  4.0
# 30   9.80        331          31          112                  5  4.0  5.0
# 31   9.20        320          32          110                  5  5.0  5.0
# 40   9.40        326          41          113                  5  4.5  4.0
# 41   9.10        322          42          110                  5  5.0  4.0
# 42   9.30        329          43          114                  5  4.0  5.0
# 64   9.22        318          65          109                  3  3.5  4.0
# 65   9.16        328          66          115                  4  4.5  4.0
# 66   9.64        332          67          118                  5  5.0  5.0
# 67   9.76        336          68          112                  5  5.0  5.0
# 68   9.45        321          69          111                  5  5.0  5.0
# 69   9.04        314          70          108                  4  4.5  4.0
# 77   9.50        340          78          120                  4  5.0  5.0
# 78   9.22        320          79          110                  5  5.0  4.5
# 79   9.36        322          80          115                  5  4.0  4.5
# 80   9.45        340          81          115                  5  4.5  4.5
# 93   9.24        332          94          119                  4  5.0  4.5
# 99   9.05        326         100          112                  3  3.5  3.0
# 101  9.18        329         102          111                  4  4.5  4.5
# 102  9.46        338         103          117                  4  3.5  4.5
# 103  9.38        331         104          116                  5  5.0  5.0
# 110  9.04        310         111          106                  4  4.5  4.5
# 115  9.56        335         116          117                  5  5.0  5.0
# ..    ...        ...         ...          ...                ...  ...  ...
# 231  9.04        325         232          114                  3  3.5  3.0
# 233  9.02        328         234          110                  4  4.0  2.5
# 241  9.68        335         242          115                  4  4.5  4.5
# 246  9.34        331         247          119                  4  5.0  4.5
# 247  9.13        327         248          108                  5  5.0  3.5
# 263  9.45        329         264          113                  5  5.0  4.5
# 268  9.11        317         269          110                  3  4.0  4.5
# 271  9.66        340         272          112                  4  5.0  4.5
# 272  9.26        331         273          116                  5  4.0  4.0
# 273  9.19        336         274          118                  5  4.5  4.0
# 274  9.08        324         275          114                  5  5.0  4.5
# 285  9.24        330         286          114                  3  4.5  4.5
# 293  9.10        323         294          110                  3  4.0  3.5
# 298  9.18        328         299          108                  4  4.5  4.0
# 311  9.14        326         312          116                  3  3.5  4.0
# 322  9.47        332         323          118                  5  5.0  5.0
# 346  9.54        334         347          116                  4  4.0  3.5
# 347  9.23        338         348          115                  5  4.5  5.0
# 350  9.17        330         351          114                  4  4.5  3.0
# 356  9.22        324         357          110                  3  3.5  3.0
# 357  9.62        336         358          119                  4  4.5  4.0
# 367  9.15        324         368          110                  4  4.5  4.0
# 369  9.74        340         370          113                  4  5.0  5.0
# 370  9.82        335         371          117                  5  5.0  5.0
# 377  9.12        326         378          112                  4  4.0  3.5
# 379  9.23        329         380          111                  4  4.5  4.0
# 380  9.04        324         381          110                  3  3.5  3.5
# 381  9.11        325         382          107                  3  3.0  3.5
# 382  9.45        330         383          116                  4  5.0  4.5
# 384  9.66        333         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit
# 0           1             0.92
# 4           1             0.90
# 10          1             0.78
# 19          1             0.94
# 20          1             0.95
# 21          1             0.97
# 28          1             0.91
# 29          1             0.90
# 30          1             0.94
# 31          1             0.88
# 40          1             0.91
# 41          1             0.88
# 42          1             0.86
# 64          1             0.68
# 65          1             0.78
# 66          1             0.94
# 67          1             0.96
# 68          1             0.93
# 69          1             0.84
# 77          1             0.96
# 78          1             0.92
# 79          1             0.92
# 80          1             0.94
# 93          1             0.90
# 99          1             0.74
# 101         1             0.87
# 102         1             0.91
# 103         1             0.93
# 110         1             0.66
# 115         1             0.94
# ..        ...              ...
# 231         1             0.76
# 233         1             0.81
# 241         1             0.93
# 246         1             0.90
# 247         1             0.87
# 263         1             0.89
# 268         1             0.80
# 271         1             0.94
# 272         1             0.93
# 273         1             0.92
# 274         1             0.89
# 285         1             0.90
# 293         1             0.79
# 298         1             0.84
# 311         1             0.81
# 322         1             0.94
# 346         1             0.93
# 347         1             0.91
# 350         1             0.86
# 356         1             0.89
# 357         1             0.95
# 367         1             0.82
# 369         1             0.96
# 370         1             0.96
# 377         1             0.84
# 379         1             0.89
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 384         1             0.95
#
# [101 rows x 9 columns]

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:

chance_of_admit = admissions[(admissions.CGPA > 9) * admissions.SOP < 3.5]
chance_of_admit['Chance of Admit'].mean()
# Out:
# 0.6631428571428568

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    avg = col.mean()
    stdv = col.std()
    series_standardized = (col - avg)/ stdv
    return series_standardized

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
admissions['CGPA_std'] = standardize(admissions['CGPA'])
admissions['GRE_std'] = standardize(admissions['GRE Score'])
admissions['LOR_std'] = standardize(admissions['LOR'])

admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0         1             0.92  1.747900  1.753381  1.191647
# 1         1             0.72 -0.991211 -0.063367  0.076740
# 2         1             0.80  0.121034  0.455704 -1.038166
# 3         0             0.65 -0.642597 -0.236391 -0.480713
# 4         1             0.90  1.233279  1.147798 -0.480713

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])
decision_choice
# Out:
# ['CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std']

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:
admissions['deciding_column'] = admissions.lookup(admissions.index,decision_choice)

# admissions['deciding_column'] = admissions.lookup([decision_choice])
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# 5             6        321          109                  3  3.0  4.0  8.20
# 6             7        308          101                  2  3.0  4.0  7.90
# 7             8        302          102                  1  2.0  1.5  8.00
# 8             9        323          108                  3  3.5  3.0  8.60
# 9            10        327          111                  4  4.0  4.5  9.00
# 10           11        328          112                  4  4.0  4.5  9.10
# 11           12        307          109                  3  4.0  3.0  8.00
# 12           13        311          104                  3  3.5  2.0  8.20
# 13           14        314          105                  3  3.5  2.5  8.30
# 14           15        317          107                  3  4.0  3.0  8.70
# 15           16        319          106                  3  4.0  3.0  8.00
# 16           17        318          110                  3  4.0  3.0  8.80
# 17           18        303          102                  3  3.5  3.0  8.50
# 18           19        325          114                  4  3.0  2.0  8.40
# 19           20        328          116                  5  5.0  5.0  9.50
# 20           21        334          119                  5  5.0  4.5  9.70
# 21           22        336          119                  5  4.0  3.5  9.80
# 22           23        322          109                  5  4.5  3.5  8.80
# 23           24        298           98                  2  1.5  2.5  7.50
# 24           25        295           93                  1  2.0  2.0  7.20
# 25           26        310           99                  2  1.5  2.0  7.30
# 26           27        300           97                  2  3.0  3.0  8.10
# 27           28        327          103                  3  4.0  4.0  8.30
# 28           29        338          118                  4  3.0  4.5  9.40
# 29           30        340          114                  5  4.0  4.0  9.60
# ..          ...        ...          ...                ...  ...  ...   ...
# 355         356        310          103                  2  2.5  2.5  8.24
# 356         357        324          110                  3  3.5  3.0  9.22
# 357         358        336          119                  4  4.5  4.0  9.62
# 358         359        321          109                  3  3.0  3.0  8.54
# 359         360        315          105                  2  2.0  2.5  7.65
# 360         361        304          101                  2  2.0  2.5  7.66
# 361         362        297           96                  2  2.5  2.0  7.43
# 362         363        290          100                  1  1.5  2.0  7.56
# 363         364        303           98                  1  2.0  2.5  7.65
# 364         365        311           99                  1  2.5  3.0  8.43
# 365         366        322          104                  3  3.5  4.0  8.84
# 366         367        319          105                  3  3.0  3.5  8.67
# 367         368        324          110                  4  4.5  4.0  9.15
# 368         369        300          100                  3  3.0  3.5  8.26
# 369         370        340          113                  4  5.0  5.0  9.74
# 370         371        335          117                  5  5.0  5.0  9.82
# 371         372        302          101                  2  2.5  3.5  7.96
# 372         373        307          105                  2  2.0  3.5  8.10
# 373         374        296           97                  2  1.5  2.0  7.80
# 374         375        320          108                  3  3.5  4.0  8.44
# 375         376        314          102                  2  2.0  2.5  8.24
# 376         377        318          106                  3  2.0  3.0  8.65
# 377         378        326          112                  4  4.0  3.5  9.12
# 378         379        317          104                  2  3.0  3.0  8.76
# 379         380        329          111                  4  4.5  4.0  9.23
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column
# 0           1             0.92  1.747900  1.753381  1.191647         1.747900
# 1           1             0.72 -0.991211 -0.063367  0.076740        -0.991211
# 2           1             0.80  0.121034  0.455704 -1.038166         0.455704
# 3           0             0.65 -0.642597 -0.236391 -0.480713        -0.480713
# 4           1             0.90  1.233279  1.147798 -0.480713        -0.480713
# 5           1             0.75 -0.659198  0.369192  0.634193        -0.659198
# 6           0             0.68 -1.157218 -0.755462  0.634193         0.634193
# 7           0             0.50 -0.991211 -1.274533 -2.153072        -0.991211
# 8           0             0.45  0.004829  0.542216 -0.480713         0.542216
# 9           1             0.84  0.668856  0.888263  1.191647         0.888263
# 10          1             0.78  0.834863  0.974775  1.191647         1.191647
# 11          1             0.62 -0.991211 -0.841973 -0.480713        -0.991211
# 12          1             0.61 -0.659198 -0.495926 -1.595619        -0.495926
# 13          0             0.54 -0.493191 -0.236391 -1.038166        -0.236391
# 14          0             0.66  0.170836  0.023145 -0.480713        -0.480713
# 15          1             0.65 -0.991211  0.196168 -0.480713        -0.991211
# 16          0             0.63  0.336843  0.109657 -0.480713         0.109657
# 17          0             0.62 -0.161177 -1.188021 -0.480713        -1.188021
# 18          0             0.70 -0.327184  0.715239 -1.595619        -0.327184
# 19          1             0.94  1.498890  0.974775  1.749100         0.974775
# 20          1             0.95  1.830903  1.493846  1.191647         1.191647
# 21          1             0.97  1.996910  1.666869  0.076740         1.666869
# 22          0             0.76  0.336843  0.455704  0.076740         0.455704
# 23          1             0.44 -1.821244 -1.620580 -1.038166        -1.038166
# 24          0             0.46 -2.319265 -1.880115 -1.595619        -2.319265
# 25          0             0.54 -2.153258 -0.582438 -1.595619        -0.582438
# 26          1             0.65 -0.825204 -1.447556 -0.480713        -0.825204
# 27          1             0.74 -0.493191  0.888263  0.634193         0.888263
# 28          1             0.91  1.332883  1.839893  1.191647         1.839893
# 29          1             0.90  1.664896  2.012916  0.634193         1.664896
# ..        ...              ...       ...       ...       ...              ...
# 355         0             0.72 -0.592795 -0.582438 -1.038166        -0.582438
# 356         1             0.89  1.034071  0.628727 -0.480713         0.628727
# 357         1             0.95  1.698098  1.666869  0.634193         1.666869
# 358         1             0.79 -0.094775  0.369192 -0.480713         0.369192
# 359         0             0.39 -1.572234 -0.149879 -1.038166        -0.149879
# 360         0             0.38 -1.555634 -1.101509 -1.038166        -1.101509
# 361         0             0.34 -1.937449 -1.707092 -1.595619        -1.707092
# 362         0             0.47 -1.721640 -2.312674 -1.595619        -1.595619
# 363         0             0.56 -1.572234 -1.188021 -1.038166        -1.572234
# 364         1             0.71 -0.277382 -0.495926 -0.480713        -0.277382
# 365         1             0.78  0.403245  0.455704  0.634193         0.455704
# 366         1             0.73  0.121034  0.196168  0.076740         0.196168
# 367         1             0.82  0.917866  0.628727  0.634193         0.628727
# 368         0             0.62 -0.559593 -1.447556  0.076740         0.076740
# 369         1             0.96  1.897306  2.012916  1.749100         1.749100
# 370         1             0.96  2.030111  1.580357  1.749100         1.580357
# 371         0             0.46 -1.057614 -1.274533  0.076740        -1.274533
# 372         0             0.53 -0.825204 -0.841973  0.076740         0.076740
# 373         0             0.49 -1.323224 -1.793603 -1.595619        -1.595619
# 374         1             0.76 -0.260781  0.282680  0.634193        -0.260781
# 375         0             0.64 -0.592795 -0.236391 -1.038166        -1.038166
# 376         0             0.71  0.087833  0.109657 -0.480713        -0.480713
# 377         1             0.84  0.868064  0.801751  0.076740         0.801751
# 378         0             0.77  0.270440  0.023145 -0.480713        -0.480713
# 379         1             0.89  1.050671  1.061286  0.634193         0.634193
# 380         1             0.82  0.735259  0.628727  0.076740         0.628727
# 381         1             0.84  0.851463  0.715239  0.076740         0.076740
# 382         1             0.91  1.415886  1.147798  1.191647         1.191647
# 383         0             0.67  0.303641 -0.409414  0.634193         0.303641
# 384         1             0.95  1.764500  1.407334  0.634193         0.634193
#
# [385 rows x 13 columns]

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:

admissions['decision'] = np.where(
admissions['deciding_column'] > 0.8,
1,
    0
)
admissions.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column  \
# 0         1             0.92  1.747900  1.753381  1.191647         1.747900
# 1         1             0.72 -0.991211 -0.063367  0.076740        -0.991211
# 2         1             0.80  0.121034  0.455704 -1.038166         0.455704
# 3         0             0.65 -0.642597 -0.236391 -0.480713        -0.480713
# 4         1             0.90  1.233279  1.147798 -0.480713        -0.480713
#
#    decision
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:
admissions.query('decision == 1').count()
# Out:
# Serial No.           83
# GRE Score            83
# TOEFL Score          83
# University Rating    83
# SOP                  83
# LOR                  83
# CGPA                 83
# Research             83
# Chance of Admit      83
# CGPA_std             83
# GRE_std              83
# LOR_std              83
# deciding_column      83
# decision             83
# dtype: int64

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# admissions.rename(str.lower, axis='columns')#works, missing replace non character symbols and spaces to underscore
# # # # admissions.columns.str.replace(' ','-').rename(str.lower)
# # zz# admissions.columns = (admissions.columns.str.replace('.','') and admissions.columns.str.lower())
# # admissions.head(5)
# admissions.columns
admissions['deciding_column'] = admissions.lookup(admissions.index,decision_choice)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GRE_std'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-5371053fb817> in <module>
#       4 # # admissions.head(5)
#       5 # admissions.columns
# ----> 6 admissions['deciding_column'] = admissions.lookup(admissions.index,decision_choice)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in lookup(self, row_labels, col_labels)
#    3717             result = np.empty(n, dtype='O')
#    3718             for i, (r, c) in enumerate(zip(row_labels, col_labels)):
# -> 3719                 result[i] = self._get_value(r, c)
#    3720
#    3721         if is_object_dtype(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    2765             return com.maybe_box_datetimelike(series._values[index])
#    2766
# -> 2767         series = self._get_item_cache(col)
#    2768         engine = self.index._engine
#    2769
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3059         res = cache.get(item)
#    3060         if res is None:
# -> 3061             values = self._data.get(item)
#    3062             res = self._box_item_values(item, values)
#    3063             cache[item] = res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in get(self, item, fastpath)
#     939
#     940             if not isna(item):
# --> 941                 loc = self.items.get_loc(item)
#     942             else:
#     943                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GRE_std'

# %% [markdown]
# zzzzIn the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:z
# adjusted_gre = admissions[(admissions['University Rating'] > 4) * admiszsions['GRE Score'] > 10] 
admissions['adjusted_gre'] = pd.cut(
    (admissions['University Rating'] > 4 & admissions['GRE Score'] > 10),
    4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-92b00d20430f> in <module>
#       2 # adjusted_gre = admissions[(admissions['University Rating'] > 4) * admiszsions['GRE Score'] > 10]
#       3 admissions['adjusted_gre'] = pd.cut(
# ----> 4     (admissions['University Rating'] > 4 & admissions['GRE Score'] > 10),
#       5     4)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
