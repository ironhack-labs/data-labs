# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Once we've loaded our baseline dependencies, we'll load the training data.

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    -47  0  -5  -27  -11  -19  -2  -33  37  0.1  ...  0.3  2.1  -4.3  -3.2   4  \
# 0    1  1  -2   -3   -1   -3  39   10   0   -1  ...   -7   -2     1     6  -2
# 1    1 -4  -2   -6  -20   20  -1   -3  20    3  ...   14    2    -2     0  23
# 2   10  2   1   -7   -8   12  41   21 -14    3  ...    2    1     2    -2  -8
# 3    1 -3  -2   -6    1    0  10   -6   4    0  ...    5    0    -3    -8 -11
# 4    3  0   4   11   11    9 -21  -17 -20   -7  ...   -5   -4    -5   -14 -25
#
#    -23.1  -68  15  C  0.4
# 0      4   22   2  C    0
# 1     21   -3  22  A    1
# 2    -29   29   7  C    0
# 3     -2   19   4  C    0
# 4     -3  -34  -2  C    0
#
# [5 rows x 66 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8677 entries, 0 to 8676
# Data columns (total 66 columns):
# -47      8677 non-null int64
# 0        8677 non-null int64
# -5       8677 non-null int64
# -27      8677 non-null int64
# -11      8677 non-null int64
# -19      8677 non-null int64
# -2       8677 non-null int64
# -33      8677 non-null int64
# 37       8677 non-null int64
# 0.1      8677 non-null int64
# -4       8677 non-null int64
# -4.1     8677 non-null int64
# 5        8677 non-null int64
# 12       8677 non-null int64
# -28      8677 non-null int64
# 16       8677 non-null int64
# -19.1    8677 non-null int64
# -5.1     8677 non-null int64
# -3       8677 non-null int64
# -10      8677 non-null int64
# -12      8677 non-null int64
# 5.1      8677 non-null int64
# 41       8677 non-null int64
# 0.2      8677 non-null int64
# 12.1     8677 non-null int64
# -9       8677 non-null int64
# -2.1     8677 non-null int64
# 16.1     8677 non-null int64
# -11.1    8677 non-null int64
# -36      8677 non-null int64
# 14       8677 non-null int64
# -10.1    8677 non-null int64
# 9        8677 non-null int64
# 7        8677 non-null int64
# 2        8677 non-null int64
# -4.2     8677 non-null int64
# 29       8677 non-null int64
# 60       8677 non-null int64
# 19       8677 non-null int64
# 11       8677 non-null int64
# -14      8677 non-null int64
# -7       8677 non-null int64
# -2.2     8677 non-null int64
# 5.2      8677 non-null int64
# -14.1    8677 non-null int64
# -27.1    8677 non-null int64
# -59      8677 non-null int64
# -13      8677 non-null int64
# -6       8677 non-null int64
# 1        8677 non-null int64
# -3.1     8677 non-null int64
# -1       8677 non-null int64
# -10.2    8677 non-null int64
# 3        8677 non-null int64
# 20       8677 non-null int64
# -23      8677 non-null int64
# 0.3      8677 non-null int64
# 2.1      8677 non-null int64
# -4.3     8677 non-null int64
# -3.2     8677 non-null int64
# 4        8677 non-null int64
# -23.1    8677 non-null int64
# -68      8677 non-null int64
# 15       8677 non-null int64
# C        8677 non-null object
# 0.4      8677 non-null int64
# dtypes: int64(65), object(1)
# memory usage: 4.4+ MB

# %%
df['C'].value_counts()
# Out:
# D    2202
# C    2176
# A    2152
# B    2147
# Name: C, dtype: int64

# %%
df['0.4'].value_counts()
# Out:
# 2    2202
# 0    2176
# 1    2152
# 3    2147
# Name: 0.4, dtype: int64

# %%
#Demostrating C column is the same as 0.4 column

# %%
df['numerical_C'] = df['C'].apply(lambda x:1 if 'A' in x else (2 if 'D' in x else (3 if 'B' in x else 0)))
df['numerical_C'].equals(df['0.4'])
# Out:
# True

# %%
df.drop(columns = 'C', inplace = True)

# %% [markdown]
# ## Correlated Features

# %%
df.corr()
# Out:
#                   -47         0        -5       -27       -11       -19  \
# -47          1.000000  0.244662  0.046450 -0.000303 -0.020278  0.014931
# 0            0.244662  1.000000  0.333370  0.081316 -0.062082 -0.021186
# -5           0.046450  0.333370  1.000000  0.509942 -0.059332  0.017919
# -27         -0.000303  0.081316  0.509942  1.000000  0.046765  0.051033
# -11         -0.020278 -0.062082 -0.059332  0.046765  1.000000  0.502534
# -19          0.014931 -0.021186  0.017919  0.051033  0.502534  1.000000
# -2           0.130753  0.076302  0.094762  0.025919  0.089337  0.245414
# -33          0.237063  0.080824  0.111097  0.041150  0.026372  0.115886
# 37          -0.358387 -0.068678 -0.028504 -0.009320 -0.000580 -0.024352
# 0.1         -0.071917 -0.273657 -0.128111 -0.051865  0.005375 -0.013933
# -4          -0.014145 -0.085050 -0.285045 -0.104012 -0.001153  0.000494
# -4.1        -0.012084 -0.031011 -0.123272 -0.295715 -0.011553  0.012226
# 5            0.028901  0.017614  0.035673  0.023913 -0.376787 -0.179185
# 12           0.026574 -0.011590 -0.049259 -0.074088 -0.110099 -0.298505
# -28         -0.008078 -0.032977 -0.061203 -0.064622 -0.036273 -0.117916
# 16          -0.050862 -0.022284 -0.033468 -0.038012 -0.003006 -0.048115
# -19.1       -0.034616 -0.015849  0.012548  0.021259 -0.006122 -0.034117
# -5.1        -0.023748 -0.056481 -0.010402  0.013260 -0.000466  0.001848
# -3          -0.004282 -0.005915 -0.064787 -0.070098  0.014261  0.007367
# -10          0.019884  0.002451 -0.059365 -0.090023  0.012052  0.011139
# -12          0.013619 -0.001801  0.007241 -0.024162 -0.052024 -0.060234
# 5.1          0.009756  0.020704  0.016970 -0.001396 -0.049081 -0.069992
# 41          -0.011905 -0.004631  0.010552  0.021923 -0.017478 -0.044146
# 0.2         -0.007574 -0.007504 -0.007882  0.009080 -0.009360 -0.031533
# 12.1        -0.016801 -0.003602 -0.010572 -0.000934 -0.019072 -0.010310
# -9          -0.002295 -0.036882  0.001750 -0.003040 -0.015377  0.000775
# -2.1         0.002837 -0.002995 -0.065279 -0.052864  0.006696  0.006363
# 16.1         0.011383  0.020696 -0.045690 -0.089032  0.006987  0.016068
# -11.1       -0.008132  0.008113  0.003686  0.011092 -0.015891 -0.025761
# -36         -0.012659 -0.008809 -0.024298 -0.003267 -0.035714 -0.042784
# ...               ...       ...       ...       ...       ...       ...
# 29          -0.015022  0.006801  0.003484 -0.014514 -0.112164 -0.050543
# 60          -0.012544 -0.003149  0.007536  0.010293 -0.081267 -0.127500
# 19          -0.031057 -0.005536  0.003812  0.010770  0.002915 -0.021386
# 11          -0.039016 -0.015187 -0.009418 -0.006428 -0.009792 -0.017954
# -14          0.095240  0.031170  0.005237 -0.004308  0.016971  0.035129
# -7           0.030409  0.069692  0.027300 -0.000818  0.000031  0.002005
# -11.1       -0.013921    -0.013921
# -36         -0.016227    -0.016227
# ...               ...          ...
# 29          -0.000900    -0.000900
# 60           0.002115     0.002115
# 19           0.048930     0.048930
# 11           0.008102     0.008102
# -14          0.004427     0.004427
# -7          -0.008031    -0.008031
# -2.2        -0.007360    -0.007360
# 5.2         -0.006471    -0.006471
# -14.1       -0.008478    -0.008478
# -27.1       -0.011083    -0.011083
# -59          0.034175     0.034175
# -13          0.006882     0.006882
# -6           0.012687     0.012687
# 1            0.013675     0.013675
# -3.1         0.007650     0.007650
# -1           0.005625     0.005625
# -10.2       -0.014589    -0.014589
# 3           -0.008769    -0.008769
# 20           0.064209     0.064209
# -23          0.009788     0.009788
# 0.3          0.001201     0.001201
# 2.1         -0.000582    -0.000582
# -4.3         0.023222     0.023222
# -3.2         0.003176     0.003176
# 4           -0.000117    -0.000117
# -23.1       -0.003925    -0.003925
# -68          0.025736     0.025736
# 15           0.020699     0.020699
# 0.4          1.000000     1.000000
# numerical_C  1.000000     1.000000
#
# [66 rows x 66 columns]

# %%
# We can see that numerical_C and 0.4 have a correlation of 1. Therefore, we should drop one of the two to avoid redundant information. Also we have to check if there are other features with hard correlation and drop them too:

# %%
corr_matrix = df.corr()
tri = np.triu(np.ones(corr_matrix.shape), k = 1).astype(np.bool)
#Select upper triangle of correlation matrix
upper = corr_matrix.where(tri)
# Find index of feature columns with correlation greater than 90%
to_drop = [col for col in upper.columns if any(upper[col] > 0.9)]
# Drop highly colinear features
df.drop(df[to_drop], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (8677, 65)

# %%
df.isnull().sum()
# Out:
# -47      0
# 0        0
# -5       0
# -27      0
# -11      0
# -19      0
# -2       0
# -33      0
# 37       0
# 0.1      0
# -4       0
# -4.1     0
# 5        0
# 12       0
# -28      0
# 16       0
# -19.1    0
# -5.1     0
# -3       0
# -10      0
# -12      0
# 5.1      0
# 41       0
# 0.2      0
# 12.1     0
# -9       0
# -2.1     0
# 16.1     0
# -11.1    0
# -36      0
#         ..
# -4.2     0
# 29       0
# 60       0
# 19       0
# 11       0
# -14      0
# -7       0
# -2.2     0
# 5.2      0
# -14.1    0
# -27.1    0
# -59      0
# -13      0
# -6       0
# 1        0
# -3.1     0
# -1       0
# -10.2    0
# 3        0
# 20       0
# -23      0
# 0.3      0
# 2.1      0
# -4.3     0
# -3.2     0
# 4        0
# -23.1    0
# -68      0
# 15       0
# 0.4      0
# Length: 65, dtype: int64

# %%
features = df[[col for col in df if col != '0.4']]
features.head()
# Out:
#    -47  0  -5  -27  -11  -19  -2  -33  37  0.1  ...  20  -23  0.3  2.1  -4.3  \
# 0    1  1  -2   -3   -1   -3  39   10   0   -1  ...  54   17   -7   -2     1
# 1    1 -4  -2   -6  -20   20  -1   -3  20    3  ...  -6   -7   14    2    -2
# 2   10  2   1   -7   -8   12  41   21 -14    3  ... -22    3    2    1     2
# 3    1 -3  -2   -6    1    0  10   -6   4    0  ...  -9   -7    5    0    -3
# 4    3  0   4   11   11    9 -21  -17 -20   -7  ... -64  -11   -5   -4    -5
#
#    -3.2   4  -23.1  -68  15
# 0     6  -2      4   22   2
# 1     0  23     21   -3  22
# 2    -2  -8    -29   29   7
# 3    -8 -11     -2   19   4
# 4   -14 -25     -3  -34  -2
#
# [5 rows x 64 columns]

# %%
target = df['0.4']

# %% [markdown]
# ## Modeling and Evaluation with all features of the data

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_y, test_y = train_test_split(
    features,
    target,
    test_size = .2,
    random_state = 42
)

# %% [markdown]
# #### Bernoulli

# %%
from sklearn.naive_bayes import BernoulliNB

bernoulli = BernoulliNB().fit(train_X, train_y)
bernoulli.score(test_X, test_y)
# Out:
# 0.4619815668202765

# %% [markdown]
# #### GaussianNB

# %%
from sklearn.naive_bayes import GaussianNB

gaussian = GaussianNB().fit(train_X, train_y)
gaussian.score(test_X, test_y)
# Out:
# 0.875

# %% [markdown]
# ### LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

log_regr = LogisticRegression(max_iter = 1000)
log_regr.fit(train_X, train_y.values.ravel())
log_regr.score(test_X, test_y)
# Out:
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.33986175115207373

# %% [markdown]
# #### KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(train_X, train_y.values.ravel())
knn.score(test_X, test_y)
# Out:
# 0.6866359447004609

# %% [markdown]
# #### Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

scalar = RobustScaler().fit(train_X)
knn_robust = KNeighborsClassifier()
knn_robust.fit(scalar.transform(train_X), train_y.values.ravel())
knn_robust.score(scalar.transform(test_X), test_y)
# Out:
# 0.7753456221198156

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

ks_rf = RandomForestClassifier().fit(train_X, train_y)
ks_rf.score(test_X, test_y)
# Out:
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8773041474654378

# %% [markdown]
# ## Select Features

# %% [markdown]
# Feature selection is a process where you automatically select those features in your data that contribute most to the prediction variable or output in which you are interested.
#
# Having too many irrelevant features in your data can decrease the accuracy of the models. Three benefits of performing feature selection before modeling your data are:
#
# * Reduces Overfitting: Less redundant data means less opportunity to make decisions based on noise.
# * Improves Accuracy: Less misleading data means modeling accuracy improves.
# * Reduces Training Time: Less data means that algorithms train faster.
#
# Two different feature selection methods provided by the scikit-learn Python library are Recursive Feature Elimination and feature importance ranking.

# %% [markdown]
# ### RFE & RandomForestClassifier
#
# RandomForestClassifier: A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.
#
# Recursive Feature Elimination (RFE): Feature ranking with recursive feature elimination.
#
# Given an external estimator that assigns weights to features (e.g., the coefficients of a linear model), the goal of recursive feature elimination (RFE) is to select features by recursively considering smaller and smaller sets of features. First, the estimator is trained on the initial set of features and the importance of each feature is obtained either through a coef_ attribute or through a feature_importances_ attribute. Then, the least important features are pruned from current set of features. That procedure is recursively repeated on the pruned set until the desired number of features to select is eventually reached.

# %%
from sklearn.feature_selection import RFE

log_regr = RandomForestClassifier()

# create the RFE model and select 30 attributes
rfe = RFE(log_regr, 30)

rfe.fit(train_X, train_y.values.ravel())
rfe.score(test_X, test_y)
# Out:
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8882488479262672

# %% [markdown]
# ### SelectFromModel & LogisticRegression
#
# Logistic Regression (aka logit, MaxEnt) classifier.
#
# In the multiclass case, the training algorithm uses the one-vs-rest (OvR) scheme if the ‘multi_class’ option is set to ‘ovr’, and uses the cross-entropy loss if the ‘multi_class’ option is set to ‘multinomial’. (Currently the ‘multinomial’ option is supported only by the ‘lbfgs’, ‘sag’, ‘saga’ and ‘newton-cg’ solvers.)
#
# SelectFromModel: Meta-transformer for selecting features based on importance weights.

# %%
from sklearn.feature_selection import SelectFromModel

model = SelectFromModel(estimator=LogisticRegression(max_iter = 1000)).fit(train_X, train_y)
new_test_X = model.transform(train_X)
new_test_X.shape
# Out:
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# (6941, 23)

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
  ('feature_selection', SelectFromModel(estimator=LogisticRegression(max_iter = 1000))),
  ('classification', RandomForestClassifier())
])
pipe = clf.fit(train_X, train_y)
pipe.score(test_X, test_y)
# Out:
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.761520737327189

# %% [markdown]
# ### SelectFromModel & LinearSVC
#
# Linear Support Vector Classification: Similar to SVC with parameter kernel=’linear’, but implemented in terms of liblinear rather than libsvm, so it has more flexibility in the choice of penalties and loss functions and should scale better to large numbers of samples.
#
# This class supports both dense and sparse input and the multiclass support is handled according to a one-vs-the-rest scheme.
#
# SelectFromModel: Meta-transformer for selecting features based on importance weights.

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel

model = SelectFromModel(estimator=LinearSVC(C=0.01, penalty="l1", dual=False)).fit(train_X, train_y)
new_test_X = model.transform(train_X)
new_test_X.shape
# Out:
# (6941, 64)

# %%
clf = Pipeline([
  ('feature_selection', SelectFromModel(LinearSVC(C=0.01, penalty="l1", dual=False))),
  ('classification', RandomForestClassifier())
])
pipe = clf.fit(train_X, train_y)
pipe.score(test_X, test_y)
# Out:
# /Users/anielkaaslan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8807603686635944

# %%
test = pd.read_csv('test.csv')
num_columns = len(test.columns)
print(test.shape)
# Out:
# (2999, 66)

# %%
test.drop(columns = 'A', inplace = True)

# %%
test.dropna(axis=0, how='any', inplace = True)

# %%
test.shape
# Out:
# (2988, 65)

# %%
features = test[[col for col in test if col != '0.4']]

# %%
target = test['0.4']

# %%
from sklearn.model_selection import train_test_split

train_X, test_X, train_y, test_y = train_test_split(
    features,
    target, 
    test_size = .2,
    random_state = 42
)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 100).fit(train_X, train_y)

predicition = rf.predict(test_X)
predicition

# %%
predictions = pipe.predict(test_X)
predictions
# Out:
# array([1, 1, 3, 2, 0, 2, 0, 3, 1, 1, 3, 0, 3, 0, 0, 1, 0, 3, 1, 2, 0, 2,
#        0, 1, 2, 0, 1, 1, 3, 2, 1, 3, 2, 2, 1, 1, 3, 1, 2, 3, 3, 2, 3, 0,
#        2, 2, 1, 2, 0, 3, 2, 1, 3, 3, 2, 2, 1, 0, 2, 0, 3, 1, 0, 0, 3, 2,
#        1, 2, 2, 3, 0, 1, 1, 3, 2, 3, 0, 1, 3, 2, 0, 2, 2, 3, 1, 3, 2, 2,
#        0, 0, 3, 1, 1, 3, 1, 0, 1, 2, 3, 2, 0, 1, 3, 1, 3, 2, 0, 1, 1, 3,
#        1, 2, 2, 3, 3, 3, 0, 0, 0, 0, 0, 2, 1, 3, 0, 2, 3, 0, 1, 0, 1, 1,
#        2, 0, 1, 1, 1, 1, 0, 2, 1, 2, 0, 2, 1, 3, 2, 3, 1, 1, 0, 1, 3, 2,
#        3, 1, 1, 3, 3, 2, 0, 3, 3, 0, 0, 2, 3, 3, 1, 0, 2, 3, 3, 3, 2, 2,
#        1, 2, 2, 3, 0, 3, 1, 1, 1, 3, 3, 1, 2, 1, 2, 3, 2, 2, 0, 0, 2, 2,
#        1, 1, 1, 0, 0, 0, 2, 0, 0, 0, 1, 2, 0, 3, 3, 3, 3, 0, 0, 0, 0, 0,
#        0, 1, 0, 3, 0, 2, 2, 2, 0, 2, 1, 0, 2, 1, 3, 1, 1, 0, 1, 1, 1, 2,
#        3, 2, 3, 0, 2, 1, 2, 0, 2, 2, 2, 1, 1, 2, 1, 2, 1, 2, 1, 2, 0, 0,
#        1, 1, 3, 1, 2, 2, 3, 0, 3, 1, 0, 1, 3, 2, 3, 2, 3, 2, 2, 2, 0, 3,
#        1, 3, 2, 1, 1, 1, 1, 1, 1, 2, 2, 2, 0, 1, 2, 2, 2, 3, 3, 2, 3, 1,
#        2, 3, 3, 3, 2, 2, 0, 3, 2, 2, 0, 3, 0, 3, 0, 2, 3, 2, 1, 0, 2, 2,
#        3, 0, 2, 0, 3, 0, 3, 3, 1, 3, 2, 3, 2, 0, 2, 0, 2, 0, 0, 2, 3, 2,
#        2, 1, 0, 3, 3, 0, 2, 2, 3, 2, 2, 1, 3, 3, 3, 3, 1, 0, 3, 1, 0, 2,
#        0, 3, 1, 3, 0, 1, 1, 2, 3, 1, 1, 1, 2, 0, 3, 1, 3, 2, 2, 3, 1, 3,
#        0, 0, 0, 2, 2, 2, 1, 1, 1, 1, 3, 1, 1, 1, 0, 0, 0, 2, 1, 1, 2, 2,
#        1, 0, 1, 1, 1, 2, 3, 2, 2, 0, 2, 3, 2, 1, 2, 2, 1, 0, 3, 3, 3, 0,
#        0, 3, 0, 3, 1, 2, 3, 2, 1, 3, 1, 3, 0, 2, 3, 1, 1, 1, 1, 3, 2, 3,
#        0, 0, 0, 1, 0, 3, 1, 3, 1, 1, 1, 2, 3, 0, 1, 0, 1, 3, 2, 3, 2, 0,
#        0, 3, 3, 2, 0, 2, 1, 1, 2, 2, 0, 0, 2, 3, 2, 1, 0, 1, 2, 3, 0, 0,
#        0, 0, 2, 0, 1, 2, 0, 1, 3, 1, 1, 0, 2, 0, 2, 2, 0, 0, 2, 0, 1, 2,
#        2, 3, 1, 1, 0, 0, 3, 0, 2, 3, 3, 2, 0, 0, 0, 2, 3, 2, 2, 0, 2, 0,
#        3, 3, 1, 1, 2, 1, 0, 0, 2, 3, 2, 1, 1, 1, 0, 3, 2, 0, 1, 0, 3, 0,
#        0, 3, 1, 0, 2, 3, 0, 0, 2, 2, 2, 3, 1, 0, 3, 1, 3, 0, 3, 0, 3, 1,
#        1, 2, 1, 2])

# %%
from sklearn import metrics
metrics.r2_score(predictions, test_y)
# Out:
# 0.9121949173083735
