# %% [markdown]
# # Challenge 3 - Sentiment Analysis
#
# data: https://www.kaggle.com/kazanova/sentiment140
#
# example: https://www.kaggle.com/ngyptr/python-nltk-sentiment-analysis
#
# https://zablo.net/blog/post/twitter-sentiment-analysis-python-scikit-word2vec-nltk-xgboost
#
# https://www.laurentluce.com/posts/twitter-sentiment-analysis-using-python-and-nltk/

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

import nltk
from nltk.corpus import stopwords

from nltk.sentiment import SentimentAnalyzer

NUM_FEATURES = 5000
TEST_SET_SIZE = 20000

# %% [markdown]
# ## Load Data & Data Exploration

# %%
raw_data = pd.read_csv('Sentiment140.csv', encoding="ISO-8859-1")

# data = raw_data.head(10000).append(raw_data.tail(10000))

data = raw_data.sample(TEST_SET_SIZE)

# %%
data.target.value_counts()
# Out:
# 0    10044
# 4     9956
# Name: target, dtype: int64

# %%
data.isna().sum()
# Out:
# target    0
# id        0
# date      0
# flag      0
# user      0
# text      0
# dtype: int64

# %% [markdown]
# ## Cleaning
#
# * Generic text
#     * Missing values
#     * Special characters
#     * Numbers
# * Web text
#     * URLs
#     * HTML tags
# * Twitter-specific
#     * Twitter usernames with handler (optional)
#     * Hashtags (optional)
#
#
# ### References
#
# * Replace regex in substring: https://stackoverflow.com/questions/5658369/how-to-input-a-regex-in-string-replace

# %%
import re

def remove_by_regex(tweet, regexp):
        return re.sub(regexp, '', tweet)

def remove_url(tweet):
    return remove_by_regex(tweet, re.compile(r"http.?://[^\s]+[\s]?"))

def remove_special_char(tweet):
    return re.sub(r"[^a-zA-Z0-9 ]", " ", tweet)#add space placeholder

def remove_numbers(tweet):
    return remove_by_regex(tweet, re.compile(r"[1234567890]"))

def clean_up(tweet):
    tweet = remove_numbers(tweet)
    tweet = remove_url(tweet)
    tweet = remove_special_char(tweet)
    return tweet.lower().strip()

clean_up("@Ironhack's-#Q website 776-is http://ironhack.com [(2018)]")
# Out:
# 'ironhack s  q website  is'

# %%
data.text = data.text.apply(lambda tweet: clean_up(tweet))

data.head()
# Out:
#          target          id                          date      flag  \
# 747160        0  2283470553  Mon Jun 22 12:40:08 PDT 2009  NO_QUERY
# 905846        4  1695220322  Mon May 04 05:33:32 PDT 2009  NO_QUERY
# 131359        0  1835516465  Mon May 18 06:10:11 PDT 2009  NO_QUERY
# 1444993       4  2062327669  Sat Jun 06 22:55:34 PDT 2009  NO_QUERY
# 127208        0  1834675017  Mon May 18 03:49:21 PDT 2009  NO_QUERY
#
#                 user                                               text
# 747160     Gibbo2910               timelord uke awww  why not  its cool
# 905846   nadiaishere  finally  im back online  i miss my lappy  so m...
# 131359       eleni__  one more hour of being  yrs old  ur only  once...
# 1444993      natwebb  mmmmmm i had one chicken rissole with  little ...
# 127208        bartTC  wants that clevercss is supported native by ev...

# %% [markdown]
# ## Tokenization

# %%
from nltk.tokenize import word_tokenize

# https://www.nltk.org/api/nltk.tokenize.html
# tknzr = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True) 

data['text_processed'] = data.text.apply(lambda x: word_tokenize(x))

data.head()
# Out:
#          target          id                          date      flag  \
# 747160        0  2283470553  Mon Jun 22 12:40:08 PDT 2009  NO_QUERY
# 905846        4  1695220322  Mon May 04 05:33:32 PDT 2009  NO_QUERY
# 131359        0  1835516465  Mon May 18 06:10:11 PDT 2009  NO_QUERY
# 1444993       4  2062327669  Sat Jun 06 22:55:34 PDT 2009  NO_QUERY
# 127208        0  1834675017  Mon May 18 03:49:21 PDT 2009  NO_QUERY
#
#                 user                                               text  \
# 747160     Gibbo2910               timelord uke awww  why not  its cool
# 905846   nadiaishere  finally  im back online  i miss my lappy  so m...
# 131359       eleni__  one more hour of being  yrs old  ur only  once...
# 1444993      natwebb  mmmmmm i had one chicken rissole with  little ...
# 127208        bartTC  wants that clevercss is supported native by ev...
#
#                                             text_processed
# 747160          [timelord, uke, awww, why, not, its, cool]
# 905846   [finally, im, back, online, i, miss, my, lappy...
# 131359   [one, more, hour, of, being, yrs, old, ur, onl...
# 1444993  [mmmmmm, i, had, one, chicken, rissole, with, ...
# 127208   [wants, that, clevercss, is, supported, native...

# %% [markdown]
# ## Stemming & Lemmatization

# %%
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer

# Porter vs Snowball vs Lancaster
#https://stackoverflow.com/questions/10554052/what-are-the-major-differences-and-benefits-of-porter-and-lancaster-stemming-alg
stemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(tweet):
    return list(map(lambda s: lemmatizer.lemmatize(stemmer.stem(s)), tweet))

stem_and_lemmatize(['students', 'loves', 'tokenization', 'new york', 'ourselves', 'tuberculosis', 'was', 'liked'])
# Out:
# ['student',
#  'love',
#  'token',
#  'new york',
#  'ourselv',
#  'tuberculosi',
#  'wa',
#  'like']

# %%
data.text_processed = data.text_processed.apply(lambda s: stem_and_lemmatize(s))

data.head()
# Out:
#          target          id                          date      flag  \
# 747160        0  2283470553  Mon Jun 22 12:40:08 PDT 2009  NO_QUERY
# 905846        4  1695220322  Mon May 04 05:33:32 PDT 2009  NO_QUERY
# 131359        0  1835516465  Mon May 18 06:10:11 PDT 2009  NO_QUERY
# 1444993       4  2062327669  Sat Jun 06 22:55:34 PDT 2009  NO_QUERY
# 127208        0  1834675017  Mon May 18 03:49:21 PDT 2009  NO_QUERY
#
#                 user                                               text  \
# 747160     Gibbo2910               timelord uke awww  why not  its cool
# 905846   nadiaishere  finally  im back online  i miss my lappy  so m...
# 131359       eleni__  one more hour of being  yrs old  ur only  once...
# 1444993      natwebb  mmmmmm i had one chicken rissole with  little ...
# 127208        bartTC  wants that clevercss is supported native by ev...
#
#                                             text_processed
# 747160           [timelord, uke, awww, whi, not, it, cool]
# 905846   [final, im, back, onlin, i, miss, my, lappi, s...
# 131359   [one, more, hour, of, be, yr, old, ur, onli, o...
# 1444993  [mmmmmm, i, had, one, chicken, rissol, with, l...
# 127208   [want, that, clevercss, is, support, nativ, by...

# %% [markdown]
# ## Removing Stopwords

# %%
stopwords_list = stopwords.words("english")

# stopwords_list

# %%
def remove_stopwords(tweet):
    return [x for x in tweet if x not in stopwords_list]

data.text_processed = data.text_processed.apply(lambda s: remove_stopwords(s))

data.head()
# Out:
#          target          id                          date      flag  \
# 747160        0  2283470553  Mon Jun 22 12:40:08 PDT 2009  NO_QUERY
# 905846        4  1695220322  Mon May 04 05:33:32 PDT 2009  NO_QUERY
# 131359        0  1835516465  Mon May 18 06:10:11 PDT 2009  NO_QUERY
# 1444993       4  2062327669  Sat Jun 06 22:55:34 PDT 2009  NO_QUERY
# 127208        0  1834675017  Mon May 18 03:49:21 PDT 2009  NO_QUERY
#
#                 user                                               text  \
# 747160     Gibbo2910               timelord uke awww  why not  its cool
# 905846   nadiaishere  finally  im back online  i miss my lappy  so m...
# 131359       eleni__  one more hour of being  yrs old  ur only  once...
# 1444993      natwebb  mmmmmm i had one chicken rissole with  little ...
# 127208        bartTC  wants that clevercss is supported native by ev...
#
#                                             text_processed
# 747160                    [timelord, uke, awww, whi, cool]
# 905846   [final, im, back, onlin, miss, lappi, mani, th...
# 131359    [one, hour, yr, old, ur, onli, onc, went, quick]
# 1444993  [mmmmmm, one, chicken, rissol, littl, babi, po...
# 127208   [want, clevercss, support, nativ, everi, webbr...

# %%
all_words = []

for index, value in data.text_processed.iteritems():
    if value not in all_words:
        all_words += value

top_features = [x[0] for x in nltk.FreqDist(all_words).most_common(NUM_FEATURES)]

# top_features = list(nltk.FreqDist(all_words).keys())[:NUM_FEATURES]

# %%
top_features
# Out:
# ['go',
#  'get',
#  'wa',
#  'day',
#  'good',
#  'work',
#  'like',
#  'love',
#  'got',
#  'quot',
#  'today',
#  'time',
#  'u',
#  'thank',
#  'back',
#  'miss',
#  'want',
#  'know',
#  'lol',
#  'one',
#  'realli',
#  'see',
#  'feel',
#  'think',
#  'im',
#  'amp',
#  'still',
#  'night',
#  'hope',
#  'well',
#  'watch',
#  'need',
#  'new',
#  'make',
#  'home',
#  'na',
#  'oh',
#  'ha',
#  'twitter',
#  'come',
#  'last',
#  'look',
#  'much',
#  'wish',
#  'great',
#  'tomorrow',
#  'sad',
#  'morn',
#  'sleep',
#  'wait',
#  'tri',
#  'haha',
#  'veri',
#  'fun',
#  'whi',
#  'follow',
#  'sorri',
#  'bad',
#  'right',
#  'happi',
#  'friend',
#  'would',
#  'onli',
#  'tonight',
#  'week',
#  'way',
#  'say',
#  'though',
#  'nice',
#  'hate',
#  'gon',
#  'bed',
#  'yeah',
#  'guy',
#  'take',
#  'better',
#  'school',
#  'could',
#  'thing',
#  'hour',
#  'even',
#  'start',
#  'show',
#  'tweet',
#  'use',
#  'awesom',
#  'lt',
#  'peopl',
#  'weekend',
#  'hey',
#  'ok',
#  'play',
#  'x',
#  'next',
#  'yes',
#  'final',
#  'everyon',
#  'plea',
#  'let',
#  'first',
#  'long',
#  'best',
#  'tire',
#  'help',
#  'movi',
#  'never',
#  'cant',
#  'year',
#  'sure',
#  'soon',
#  'call',
#  'cool',
#  'dont',
#  'rain',
#  'littl',
#  'keep',
#  'alreadi',
#  'life',
#  'girl',
#  'sick',
#  'bore',
#  'wan',
#  'find',
#  'ani',
#  'lot',
#  'read',
#  'suck',
#  'man',
#  'anoth',
#  'hurt',
#  'done',
#  'made',
#  'head',
#  'talk',
#  'yay',
#  'summer',
#  'went',
#  'someth',
#  'eat',
#  'live',
#  'enjoy',
#  'readi',
#  'befor',
#  'finish',
#  'alway',
#  'yet',
#  'excit',
#  'leav',
#  'amaz',
#  'end',
#  'someon',
#  'song',
#  'mayb',
#  'damn',
#  'babi',
#  'left',
#  'sound',
#  'game',
#  'ever',
#  'ur',
#  'pretti',
#  'omg',
#  'phone',
#  'stuff',
#  'away',
#  'noth',
#  'doe',
#  'lost',
#  'listen',
#  'old',
#  'hear',
#  'hous',
#  'hard',
#  'thought',
#  'big',
#  'two',
#  'hot',
#  'tell',
#  'bit',
#  'earli',
#  'birthday',
#  'sun',
#  'becaus',
#  'wow',
#  'late',
#  'guess',
#  'b',
#  'weather',
#  'mean',
#  'parti',
#  'also',
#  'glad',
#  'n',
#  'pic',
#  'later',
#  'said',
#  'give',
#  'god',
#  'happen',
#  'put',
#  'th',
#  'run',
#  'fuck',
#  'friday',
#  'world',
#  'stop',
#  'mom',
#  'might',
#  'ya',
#  'wonder',
#  'win',
#  'exam',
#  'w',
#  'actual',
#  'famili',
#  'ugh',
#  'cold',
#  'may',
#  'stay',
#  'kid',
#  'r',
#  'music',
#  'saw',
#  'car',
#  'hi',
#  'check',
#  'stupid',
#  'sunday',
#  'monday',
#  'woke',
#  'updat',
#  'book',
#  'p',
#  'ta',
#  'job',
#  'com',
#  'luck',
#  'beauti',
#  'boy',
#  'plan',
#  'sinc',
#  'mani',
#  'sweet',
#  'seem',
#  'free',
#  'yesterday',
#  'shop',
#  'drive',
#  'found',
#  'must',
#  'hair',
#  'around',
#  'everyth',
#  'total',
#  'meet',
#  'post',
#  'tho',
#  'pictur',
#  'chang',
#  'move',
#  'drink',
#  'write',
#  'iphon',
#  'dinner',
#  'turn',
#  'welcom',
#  'break',
#  'almost',
#  'cute',
#  'studi',
#  'shit',
#  'busi',
#  'aww',
#  'lunch',
#  'till',
#  'c',
#  'anyth',
#  'video',
#  'dad',
#  'fan',
#  'funni',
#  'okay',
#  'food',
#  'forward',
#  'name',
#  'enough',
#  'dream',
#  'didnt',
#  'brother',
#  'month',
#  'ill',
#  'gone',
#  'coffe',
#  'room',
#  'super',
#  'least',
#  'person',
#  'believ',
#  'hello',
#  'hang',
#  'without',
#  'die',
#  'el',
#  'outsid',
#  'buy',
#  'walk',
#  'far',
#  'everi',
#  'anyon',
#  'wake',
#  'poor',
#  'bring',
#  'rememb',
#  'money',
#  'wrong',
#  'class',
#  'hit',
#  'ask',
#  'word',
#  'close',
#  'mine',
#  'caus',
#  'tv',
#  'kinda',
#  'cri',
#  'place',
#  'onc',
#  'sooo',
#  'xx',
#  'beach',
#  'fail',
#  'headach',
#  'half',
#  'saturday',
#  'hahaha',
#  'dog',
#  'either',
#  'train',
#  'cours',
#  'eye',
#  'gt',
#  'trip',
#  'whole',
#  'link',
#  'fall',
#  'pm',
#  'sit',
#  'comput',
#  'goodnight',
#  'repli',
#  'minut',
#  'blog',
#  'serious',
#  'clean',
#  'photo',
#  'took',
#  'rock',
#  'onlin',
#  'nite',
#  'mother',
#  'ago',
#  'idea',
#  'offic',
#  'email',
#  'anymor',
#  'real',
#  'open',
#  'seen',
#  'kill',
#  'boo',
#  'news',
#  'abl',
#  'wont',
#  'sunni',
#  'heart',
#  'cuz',
#  'came',
#  'ah',
#  'probabl',
#  'soo',
#  'awww',
#  'problem',
#  'send',
#  'hungri',
#  'xd',
#  'aw',
#  'face',
#  'concert',
#  'shower',
#  'kind',
#  'hehe',
#  'forgot',
#  'true',
#  'pay',
#  'sister',
#  'high',
#  'pain',
#  'test',
#  'e',
#  'www',
#  'definit',
#  'site',
#  'goe',
#  'v',
#  'k',
#  'danc',
#  'heard',
#  'til',
#  'ticket',
#  'homework',
#  'pack',
#  'laugh',
#  'part',
#  'fix',
#  'instead',
#  'wear',
#  'rest',
#  'st',
#  'internet',
#  'june',
#  'tea',
#  'awak',
#  'cat',
#  'crazi',
#  'g',
#  'sometim',
#  'alon',
#  'mr',
#  'care',
#  'learn',
#  'stuck',
#  'visit',
#  'add',
#  'asleep',
#  'dude',
#  'store',
#  'pick',
#  'set',
#  'ladi',
#  'smile',
#  'fine',
#  'reason',
#  'quit',
#  'dear',
#  'hell',
#  'cut',
#  'graduat',
#  'full',
#  'la',
#  'vote',
#  'suppos',
#  'worri',
#  'broke',
#  'mileycyrus',
#  'crap',
#  'interest',
#  'offici',
#  'btw',
#  'sore',
#  'afternoon',
#  'youtub',
#  'star',
#  'account',
#  'lucki',
#  'lmao',
#  'tommcfli',
#  'side',
#  'depress',
#  'line',
#  'catch',
#  'breakfast',
#  'told',
#  'pas',
#  'revis',
#  'hug',
#  'hand',
#  'download',
#  'min',
#  'via',
#  'coupl',
#  'favorit',
#  'facebook',
#  'ice',
#  'holiday',
#  'season',
#  'tour',
#  'realiz',
#  'anyway',
#  'sign',
#  'jealous',
#  'spend',
#  'text',
#  'question',
#  'nd',
#  'short',
#  'bout',
#  'congrat',
#  'l',
#  'nap',
#  'websit',
#  'lil',
#  'myspac',
#  'ddlovato',
#  'agre',
#  'hr',
#  'mind',
#  'ipod',
#  'messag',
#  'complet',
#  'order',
#  'album',
#  'figur',
#  'near',
#  'le',
#  'foot',
#  'cheer',
#  'relax',
#  'forget',
#  'dead',
#  'save',
#  'bye',
#  'three',
#  'stori',
#  'comment',
#  'cook',
#  'soooo',
#  'togeth',
#  'paper',
#  'mad',
#  'second',
#  'sing',
#  'juli',
#  'perfect',
#  'burn',
#  'ad',
#  'water',
#  'team',
#  'page',
#  'weird',
#  'sim',
#  'beer',
#  'past',
#  'upset',
#  'bought',
#  'list',
#  'answer',
#  'load',
#  'worth',
#  'plane',
#  'shirt',
#  'sleepi',
#  'drop',
#  'googl',
#  'bless',
#  'math',
#  'pool',
#  'differ',
#  'broken',
#  'decid',
#  'yea',
#  'top',
#  'goin',
#  'understand',
#  'sat',
#  'share',
#  'upload',
#  'unfortun',
#  'ride',
#  'jona',
#  'idk',
#  'garden',
#  'usual',
#  'sent',
#  'club',
#  'road',
#  'fell',
#  'mood',
#  'church',
#  'lay',
#  'blue',
#  'air',
#  'due',
#  'town',
#  'chat',
#  'colleg',
#  'moon',
#  'sigh',
#  'thx',
#  'followfriday',
#  'safe',
#  'stomach',
#  'green',
#  'citi',
#  'uk',
#  'kick',
#  'ahh',
#  'mac',
#  'park',
#  'worst',
#  'throat',
#  'scare',
#  'type',
#  'gorgeous',
#  'yummi',
#  'chanc',
#  'laptop',
#  'fast',
#  'drunk',
#  'cough',
#  'red',
#  'doesnt',
#  'angel',
#  'si',
#  'window',
#  'random',
#  'co',
#  'bbq',
#  'xxx',
#  'bro',
#  'met',
#  'support',
#  'easi',
#  'band',
#  'possibl',
#  'insid',
#  'tan',
#  'david',
#  'especi',
#  'em',
#  'moment',
#  'h',
#  'bet',
#  'block',
#  'small',
#  'parent',
#  'annoy',
#  'begin',
#  'dress',
#  'fb',
#  'laker',
#  'warm',
#  'english',
#  'expect',
#  'gym',
#  'wors',
#  'special',
#  'mess',
#  'havent',
#  'episod',
#  'wed',
#  'beat',
#  'lose',
#  'pizza',
#  'ppl',
#  'box',
#  'award',
#  'buddi',
#  'ach',
#  'except',
#  'touch',
#  'hill',
#  'date',
#  'lazi',
#  'surpris',
#  'wednesday',
#  'disappoint',
#  'cake',
#  'cup',
#  'gettin',
#  'join',
#  'magic',
#  'cd',
#  'celebr',
#  'power',
#  'chocol',
#  'f',
#  'round',
#  'leg',
#  'yr',
#  'piss',
#  'lie',
#  'shall',
#  'swim',
#  'chill',
#  'front',
#  'airport',
#  'project',
#  'shoe',
#  'dm',
#  'cream',
#  'son',
#  'woo',
#  'age',
#  'luv',
#  'plus',
#  'mtv',
#  'chicken',
#  'goodby',
#  'alright',
#  'point',
#  'ive',
#  'addict',
#  'light',
#  'black',
#  'card',
#  'bday',
#  'huge',
#  'histori',
#  'flight',
#  'camp',
#  'ahhh',
#  'babe',
#  'case',
#  'rd',
#  'hmm',
#  'promis',
#  'app',
#  'yep',
#  'present',
#  'dvd',
#  'voic',
#  'number',
#  'shame',
#  'confus',
#  'record',
#  'jonasbroth',
#  'issu',
#  'bike',
#  'woman',
#  'bird',
#  'longer',
#  'interview',
#  'fire',
#  'fantast',
#  'wash',
#  'finger',
#  'spent',
#  'j',
#  'tast',
#  'count',
#  'mum',
#  'speak',
#  'ruin',
#  'flu',
#  'appreci',
#  'cooki',
#  'quick',
#  'raini',
#  'bb',
#  'nope',
#  'sunshin',
#  'cover',
#  'film',
#  'thursday',
#  'knew',
#  'gave',
#  'felt',
#  'arriv',
#  'notic',
#  'watchin',
#  'terribl',
#  'bloodi',
#  'hilari',
#  'fact',
#  'deal',
#  'wast',
#  'hold',
#  'rather',
#  'tuesday',
#  'miley',
#  'stress',
#  'cancel',
#  'coz',
#  'note',
#  'gay',
#  'kitti',
#  'nose',
#  'shut',
#  'connect',
#  'exact',
#  'fli',
#  'remind',
#  'xoxo',
#  'matter',
#  'bum',
#  'view',
#  'extrem',
#  'storm',
#  'tip',
#  'scari',
#  'current',
#  'london',
#  'earlier',
#  'french',
#  'proud',
#  'vacat',
#  'ate',
#  'step',
#  'yup',
#  'fair',
#  'ahead',
#  'isnt',
#  'burnt',
#  'da',
#  'memori',
#  'twilight',
#  'white',
#  'screen',
#  'boyfriend',
#  'roll',
#  'smell',
#  'inspir',
#  'cousin',
#  'yum',
#  'bodi',
#  'slept',
#  'match',
#  'stand',
#  'vega',
#  'tom',
#  'gosh',
#  'uh',
#  'crash',
#  'shot',
#  'offer',
#  'pray',
#  'perhap',
#  'brain',
#  'slow',
#  'tummi',
#  'plz',
#  'death',
#  'sort',
#  'countri',
#  'nick',
#  'ear',
#  'mate',
#  'level',
#  'fight',
#  'freak',
#  'bus',
#  'ouch',
#  'hun',
#  'bar',
#  'meant',
#  'mail',
#  'fav',
#  'joe',
#  'mile',
#  'becom',
#  'state',
#  'event',
#  'delet',
#  'pink',
#  'itun',
#  'art',
#  'fam',
#  'sooooo',
#  'twit',
#  'direct',
#  'fit',
#  'hubbi',
#  'invit',
#  'guitar',
#  'mommi',
#  'chillin',
#  'blood',
#  'sale',
#  'tear',
#  'certain',
#  'daughter',
#  'fat',
#  'releas',
#  'everybodi',
#  'doin',
#  'wine',
#  'fake',
#  'hospit',
#  'design',
#  'ran',
#  'absolut',
#  'hmmm',
#  'product',
#  'shout',
#  'screw',
#  'fish',
#  'tweep',
#  'war',
#  'camera',
#  'exhaust',
#  'taken',
#  'search',
#  'manag',
#  'lame',
#  'shoot',
#  'lone',
#  'servic',
#  'bitch',
#  'australia',
#  'doctor',
#  'traffic',
#  'radio',
#  'wtf',
#  'assign',
#  'joke',
#  'practic',
#  'somewher',
#  'father',
#  'troubl',
#  'inde',
#  'bother',
#  'four',
#  'allow',
#  'shine',
#  'daddi',
#  'ball',
#  'vip',
#  'doubl',
#  'jus',
#  'nyc',
#  'ohh',
#  'bag',
#  'wife',
#  'child',
#  'aint',
#  'behind',
#  'fever',
#  'normal',
#  'mention',
#  'chick',
#  'control',
#  'act',
#  'south',
#  'sever',
#  'king',
#  'alot',
#  'low',
#  'experi',
#  'five',
#  'taylor',
#  'forev',
#  'cloth',
#  'laundri',
#  'brought',
#  'clear',
#  'copi',
#  'perform',
#  'chine',
#  'iran',
#  'creat',
#  'return',
#  'congratul',
#  'impress',
#  'build',
#  'whatev',
#  'posit',
#  'rip',
#  'somebodi',
#  'land',
#  'dure',
#  'kiss',
#  'hangov',
#  'compani',
#  'soup',
#  'blast',
#  'version',
#  'instal',
#  'web',
#  'futur',
#  'schedul',
#  'anim',
#  'peac',
#  'sell',
#  'men',
#  'sold',
#  'dunno',
#  'tweetdeck',
#  'young',
#  'profil',
#  'bath',
#  'wat',
#  'none',
#  'jon',
#  'huh',
#  'chicago',
#  'horribl',
#  'paint',
#  'avail',
#  'appl',
#  'sport',
#  'travel',
#  'main',
#  'pop',
#  'board',
#  'hahah',
#  'smoke',
#  'spam',
#  'sweeti',
#  'diet',
#  'entertain',
#  ...]

# %% [markdown]
# ## Building Features
#
# https://pythonprogramming.net/words-as-features-nltk-tutorial/
#
# https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/

# %%
def build_features(words):
    features = {}
    for w in top_features:
        features[w] = (w in words)
    return features

# %%
featuresets = []

for index, row in data.iterrows():
    featuresets.append((build_features(row['text_processed']), row['target']==4))

# %%
featuresets[:10]
# Out:
# [({'go': False,
#    'get': False,
#    'wa': False,
#    'day': False,
#    'good': False,
#    'work': False,
#    'like': False,
#    'love': False,
#    'got': False,
#    'quot': False,
#    'today': False,
#    'time': False,
#    'u': False,
#    'thank': False,
#    'back': False,
#    'miss': False,
#    'want': False,
#    'know': False,
#    'lol': False,
#    'one': False,
#    'realli': False,
#    'see': False,
#    'feel': False,
#    'think': False,
#    'im': False,
#    'amp': False,
#    'still': False,
#    'night': False,
#    'hope': False,
#    'well': False,
#    'watch': False,
#    'need': False,
#    'new': False,
#    'make': False,
#    'home': False,
#    'na': False,
#    'oh': False,
#    'ha': False,
#    'twitter': False,
#    'come': False,
#    'last': False,
#    'look': False,
#    'much': False,
#    'wish': False,
#    'great': False,
#    'tomorrow': False,
#    'sad': False,
#    'morn': False,
#    'sleep': False,
#    'wait': False,
#    'tri': False,
#    'haha': False,
#    'veri': False,
#    'fun': False,
#    'whi': True,
#    'follow': False,
#    'sorri': False,
#    'bad': False,
#    'right': False,
#    'happi': False,
#    'friend': False,
#    'would': False,
#    'onli': False,
#    'tonight': False,
#    'week': False,
#    'way': False,
#    'say': False,
#    'though': False,
#    'nice': False,
#    'hate': False,
#    'gon': False,
#    'bed': False,
#    'yeah': False,
#    'guy': False,
#    'take': False,
#    'better': False,
#    'school': False,
#    'could': False,
#    'thing': False,
#    'hour': False,
#    'even': False,
#    'start': False,
#    'show': False,
#    'tweet': False,
#    'use': False,
#    'awesom': False,
#    'lt': False,
#    'peopl': False,
#    'weekend': False,
#    'hey': False,
#    'ok': False,
#    'play': False,
#    'x': False,
#    'next': False,
#    'yes': False,
#    'final': False,
#    'everyon': False,
#    'plea': False,
#    'let': False,
#    'first': False,
#    'long': False,
#    'best': False,
#    'tire': False,
#    'help': False,
#    'movi': False,
#    'never': False,
#    'cant': False,
#    'year': False,
#    'sure': False,
#    'soon': False,
#    'call': False,
#    'cool': True,
#    'dont': False,
#    'rain': False,
#    'littl': False,
#    'keep': False,
#    'alreadi': False,
#    'life': False,
#    'girl': False,
#    'sick': False,
#    'bore': False,
#    'wan': False,
#    'find': False,
#    'ani': False,
#    'lot': False,
#    'read': False,
#    'suck': False,
#    'man': False,
#    'anoth': False,
#    'hurt': False,
#    'done': False,
#    'made': False,
#    'head': False,
#    'talk': False,
#    'yay': False,
#    'summer': False,
#    'went': False,
#    'someth': False,
#    'eat': False,
#    'live': False,
#    'enjoy': False,
#    'readi': False,
#    'befor': False,
#    'finish': False,
#    'alway': False,
#    'yet': False,
#    'excit': False,
#    'leav': False,
#    'amaz': False,
#    'end': False,
#    'someon': False,
#    'song': False,
#    'mayb': False,
#    'damn': False,
#    'babi': False,
#    'left': False,
#    'sound': False,
#    'game': False,
#    'ever': False,
#    'ur': False,
#    'pretti': False,
#    'omg': False,
#    'phone': False,
#    'stuff': False,
#    'away': False,
#    'noth': False,
#    'doe': False,
#    'lost': False,
#    'listen': False,
#    'old': False,
#    'hear': False,
#    'hous': False,
#    'hard': False,
#    'thought': False,
#    'big': False,
#    'two': False,
#    'hot': False,
#    'tell': False,
#    'bit': False,
#    'earli': False,
#    'birthday': False,
#    'sun': False,
#    'becaus': False,
#    'wow': False,
#    'late': False,
#    'guess': False,
#    'b': False,
#    'weather': False,
#    'mean': False,
#    'parti': False,
#    'also': False,
#    'glad': False,
#    'n': False,
#    'pic': False,
#    'later': False,
#    'said': False,
#    'give': False,
#    'god': False,
#    'happen': False,
#    'put': False,
#    'th': False,
#    'run': False,
#    'fuck': False,
#    'friday': False,
#    'world': False,
#    'stop': False,
#    'mom': False,
#    'might': False,
#    'ya': False,
#    'wonder': False,
#    'win': False,
#    'exam': False,
#    'w': False,
#    'actual': False,
#    'famili': False,
#    'ugh': False,
#    'cold': False,
#    'may': False,
#    'stay': False,
#    'kid': False,
#    'r': False,
#    'music': False,
#    'saw': False,
#    'car': False,
#    'hi': False,
#    'check': False,
#    'stupid': False,
#    'sunday': False,
#    'monday': False,
#    'woke': False,
#    'updat': False,
#    'book': False,
#    'p': False,
#    'ta': False,
#    'job': False,
#    'com': False,
#    'luck': False,
#    'beauti': False,
#    'boy': False,
#    'plan': False,
#    'sinc': False,
#    'mani': False,
#    'sweet': False,
#    'seem': False,
#    'free': False,
#    'yesterday': False,
#    'shop': False,
#    'drive': False,
#    'found': False,
#    'must': False,
#    'hair': False,
#    'around': False,
#    'everyth': False,
#    'total': False,
#    'meet': False,
#    'post': False,
#    'tho': False,
#    'pictur': False,
#    'chang': False,
#    'move': False,
#    'drink': False,
#    'write': False,
#    'iphon': False,
#    'dinner': False,
#    'turn': False,
#    'welcom': False,
#    'break': False,
#    'almost': False,
#    'cute': False,
#    'studi': False,
#    'shit': False,
#    'busi': False,
#    'aww': False,
#    'lunch': False,
#    'till': False,
#    'c': False,
#    'anyth': False,
#    'video': False,
#    'dad': False,
#    'fan': False,
#    'funni': False,
#    'okay': False,
#    'food': False,
#    'forward': False,
#    'name': False,
#    'enough': False,
#    'dream': False,
#    'didnt': False,
#    'brother': False,
#    'month': False,
#    'ill': False,
#    'gone': False,
#    'coffe': False,
#    'room': False,
#    'super': False,
#    'least': False,
#    'person': False,
#    'believ': False,
#    'hello': False,
#    'hang': False,
#    'without': False,
#    'die': False,
#    'el': False,
#    'outsid': False,
#    'buy': False,
#    'walk': False,
#    'far': False,
#    'everi': False,
#    'anyon': False,
#    'wake': False,
#    'poor': False,
#    'bring': False,
#    'rememb': False,
#    'money': False,
#    'wrong': False,
#    'class': False,
#    'hit': False,
#    'ask': False,
#    'word': False,
#    'close': False,
#    'mine': False,
#    'caus': False,
#    'tv': False,
#    'kinda': False,
#    'cri': False,
#    'place': False,
#    'onc': False,
#    'sooo': False,
#    'xx': False,
#    'beach': False,
#    'fail': False,
#    'headach': False,
#    'half': False,
#    'saturday': False,
#    'hahaha': False,
#    'dog': False,
#    'either': False,
#    'train': False,
#    'cours': False,
#    'eye': False,
#    'gt': False,
#    'trip': False,
#    'whole': False,
#    'link': False,
#    'fall': False,
#    'pm': False,
#    'sit': False,
#    'comput': False,
#    'goodnight': False,
#    'repli': False,
#    'minut': False,
#    'blog': False,
#    'serious': False,
#    'clean': False,
#    'photo': False,
#    'took': False,
#    'rock': False,
#    'onlin': False,
#    'nite': False,
#    'mother': False,
#    'ago': False,
#    'idea': False,
#    'offic': False,
#    'email': False,
#    'anymor': False,
#    'real': False,
#    'open': False,
#    'seen': False,
#    'kill': False,
#    'boo': False,
#    'news': False,
#    'abl': False,
#    'wont': False,
#    'sunni': False,
#    'heart': False,
#    'cuz': False,
#    'came': False,
#    'ah': False,
#    'probabl': False,
#    'soo': False,
#    'awww': True,
#    'problem': False,
#    'send': False,
#    'hungri': False,
#    'xd': False,
#    'aw': False,
#    'face': False,
#    'concert': False,
#    'shower': False,
#    'kind': False,
#    'hehe': False,
#    'forgot': False,
#    'true': False,
#    'pay': False,
#    'sister': False,
#    'high': False,
#    'pain': False,
#    'test': False,
#    'e': False,
#    'www': False,
#    'definit': False,
#    'site': False,
#    'goe': False,
#    'v': False,
#    'k': False,
#    'danc': False,
#    'heard': False,
#    'til': False,
#    'ticket': False,
#    'homework': False,
#    'pack': False,
#    'laugh': False,
#    'part': False,
#    'fix': False,
#    'instead': False,
#    'wear': False,
#    'rest': False,
#    'st': False,
#    'internet': False,
#    'june': False,
#    'tea': False,
#    'awak': False,
#    'cat': False,
#    'crazi': False,
#    'g': False,
#    'sometim': False,
#    'alon': False,
#    'mr': False,
#    'care': False,
#    'learn': False,
#    'stuck': False,
#    'visit': False,
#    'add': False,
#    'asleep': False,
#    'dude': False,
#    'store': False,
#    'pick': False,
#    'set': False,
#    'ladi': False,
#    'smile': False,
#    'fine': False,
#    'reason': False,
#    'quit': False,
#    'dear': False,
#    'hell': False,
#    'cut': False,
#    'graduat': False,
#    'full': False,
#    'la': False,
#    'vote': False,
#    'suppos': False,
#    'worri': False,
#    'broke': False,
#    'mileycyrus': False,
#    'crap': False,
#    'interest': False,
#    'offici': False,
#    'btw': False,
#    'sore': False,
#    'afternoon': False,
#    'youtub': False,
#    'star': False,
#    'account': False,
#    'lucki': False,
#    'lmao': False,
#    'tommcfli': False,
#    'side': False,
#    'depress': False,
#    'line': False,
#    'catch': False,
#    'breakfast': False,
#    'told': False,
#    'pas': False,
#    'revis': False,
#    'hug': False,
#    'hand': False,
#    'download': False,
#    'min': False,
#    'via': False,
#    'coupl': False,
#    'favorit': False,
#    'facebook': False,
#    'ice': False,
#    'holiday': False,
#    'season': False,
#    'tour': False,
#    'realiz': False,
#    'anyway': False,
#    'sign': False,
#    'jealous': False,
#    'spend': False,
#    'text': False,
#    'question': False,
#    'nd': False,
#    'short': False,
#    'bout': False,
#    'congrat': False,
#    'l': False,
#    'nap': False,
#    'websit': False,
#    'lil': False,
#    'myspac': False,
#    'ddlovato': False,
#    'agre': False,
#    'hr': False,
#    'mind': False,
#    'ipod': False,
#    'messag': False,
#    'complet': False,
#    'order': False,
#    'album': False,
#    'figur': False,
#    'near': False,
#    'le': False,
#    'foot': False,
#    'cheer': False,
#    'relax': False,
#    'forget': False,
#    'dead': False,
#    'save': False,
#    'bye': False,
#    'three': False,
#    'stori': False,
#    'comment': False,
#    'cook': False,
#    'soooo': False,
#    'togeth': False,
#    'paper': False,
#    'mad': False,
#    'second': False,
#    'sing': False,
#    'juli': False,
#    'perfect': False,
#    'burn': False,
#    'ad': False,
#    'water': False,
#    'team': False,
#    'page': False,
#    'weird': False,
#    'sim': False,
#    'beer': False,
#    'past': False,
#    'upset': False,
#    'bought': False,
#    'list': False,
#    'answer': False,
#    'load': False,
#    'worth': False,
#    'plane': False,
#    'shirt': False,
#    'sleepi': False,
#    'drop': False,
#    'googl': False,
#    'bless': False,
#    'math': False,
#    'pool': False,
#    'differ': False,
#    'broken': False,
#    'decid': False,
#    'yea': False,
#    'top': False,
#    'goin': False,
#    'understand': False,
#    'sat': False,
#    'share': False,
#    'upload': False,
#    'unfortun': False,
#    'ride': False,
#    'jona': False,
#    'idk': False,
#    'garden': False,
#    'usual': False,
#    'sent': False,
#    'club': False,
#    'road': False,
#    'fell': False,
#    'mood': False,
#    'church': False,
#    'lay': False,
#    'blue': False,
#    'air': False,
#    'due': False,
#    'town': False,
#    'chat': False,
#    'colleg': False,
#    'moon': False,
#    'sigh': False,
#    'thx': False,
#    'followfriday': False,
#    'safe': False,
#    'stomach': False,
#    'green': False,
#    'citi': False,
#    'uk': False,
#    'kick': False,
#    'ahh': False,
#    'mac': False,
#    'park': False,
#    'worst': False,
#    'throat': False,
#    'scare': False,
#    'type': False,
#    'gorgeous': False,
#    'yummi': False,
#    'chanc': False,
#    'laptop': False,
#    'fast': False,
#    'drunk': False,
#    'cough': False,
#    'red': False,
#    'doesnt': False,
#    'angel': False,
#    'si': False,
#    'window': False,
#    'random': False,
#    'co': False,
#    'bbq': False,
#    'xxx': False,
#    'bro': False,
#    'met': False,
#    'support': False,
#    'easi': False,
#    'band': False,
#    'possibl': False,
#    'insid': False,
#    'tan': False,
#    'david': False,
#    'especi': False,
#    'em': False,
#    'moment': False,
#    'h': False,
#    'bet': False,
#    'block': False,
#    'small': False,
#    'parent': False,
#    'annoy': False,
#    'begin': False,
#    'dress': False,
#    'fb': False,
#    'laker': False,
#    'warm': False,
#    'english': False,
#    'expect': False,
#    'gym': False,
#    'wors': False,
#    'special': False,
#    'mess': False,
#    'havent': False,
#    'episod': False,
#    'wed': False,
#    'beat': False,
#    'lose': False,
#    'pizza': False,
#    'ppl': False,
#    'box': False,
#    'award': False,
#    'buddi': False,
#    'ach': False,
#    'except': False,
#    'touch': False,
#    'hill': False,
#    'date': False,
#    'lazi': False,
#    'surpris': False,
#    'wednesday': False,
#    'disappoint': False,
#    'cake': False,
#    'cup': False,
#    'gettin': False,
#    'join': False,
#    'magic': False,
#    'cd': False,
#    'celebr': False,
#    'power': False,
#    'chocol': False,
#    'f': False,
#    'round': False,
#    'leg': False,
#    'yr': False,
#    'piss': False,
#    'lie': False,
#    'shall': False,
#    'swim': False,
#    'chill': False,
#    'front': False,
#    'airport': False,
#    'project': False,
#    'shoe': False,
#    'dm': False,
#    'cream': False,
#    'son': False,
#    'woo': False,
#    'age': False,
#    'luv': False,
#    'plus': False,
#    'mtv': False,
#    'chicken': False,
#    'goodby': False,
#    'alright': False,
#    'point': False,
#    'ive': False,
#    'addict': False,
#    'light': False,
#    'black': False,
#    'card': False,
#    'bday': False,
#    'huge': False,
#    'histori': False,
#    'flight': False,
#    'camp': False,
#    'ahhh': False,
#    'babe': False,
#    'case': False,
#    'rd': False,
#    'hmm': False,
#    'promis': False,
#    'app': False,
#    'yep': False,
#    'present': False,
#    'dvd': False,
#    'voic': False,
#    'number': False,
#    'shame': False,
#    'confus': False,
#    'record': False,
#    'jonasbroth': False,
#    'issu': False,
#    'bike': False,
#    'woman': False,
#    'bird': False,
#    'longer': False,
#    'interview': False,
#    'fire': False,
#    'fantast': False,
#    'wash': False,
#    'finger': False,
#    'spent': False,
#    'j': False,
#    'tast': False,
#    'count': False,
#    'mum': False,
#    'speak': False,
#    'ruin': False,
#    'flu': False,
#    'appreci': False,
#    'cooki': False,
#    'quick': False,
#    'raini': False,
#    'bb': False,
#    'nope': False,
#    'sunshin': False,
#    'cover': False,
#    'film': False,
#    'thursday': False,
#    'knew': False,
#    'gave': False,
#    'felt': False,
#    'arriv': False,
#    'notic': False,
#    'watchin': False,
#    'terribl': False,
#    'bloodi': False,
#    'hilari': False,
#    'fact': False,
#    'deal': False,
#    'wast': False,
#    'hold': False,
#    'rather': False,
#    'tuesday': False,
#    'miley': False,
#    'stress': False,
#    'cancel': False,
#    'coz': False,
#    'note': False,
#    'gay': False,
#    'kitti': False,
#    'nose': False,
#    'shut': False,
#    'connect': False,
#    'exact': False,
#    'fli': False,
#    'remind': False,
#    'xoxo': False,
#    'matter': False,
#    'bum': False,
#    'view': False,
#    'extrem': False,
#    'storm': False,
#    'tip': False,
#    'scari': False,
#    'current': False,
#    'london': False,
#    'earlier': False,
#    'french': False,
#    'proud': False,
#    'vacat': False,
#    'ate': False,
#    'step': False,
#    'yup': False,
#    'fair': False,
#    'ahead': False,
#    'isnt': False,
#    'burnt': False,
#    'da': False,
#    'memori': False,
#    'twilight': False,
#    'white': False,
#    'screen': False,
#    'boyfriend': False,
#    'roll': False,
#    'smell': False,
#    'inspir': False,
#    'cousin': False,
#    'yum': False,
#    'bodi': False,
#    'slept': False,
#    'match': False,
#    'stand': False,
#    'vega': False,
#    'tom': False,
#    'gosh': False,
#    'uh': False,
#    'crash': False,
#    'shot': False,
#    'offer': False,
#    'pray': False,
#    'perhap': False,
#    'brain': False,
#    'slow': False,
#    'tummi': False,
#    'plz': False,
#    'death': False,
#    'sort': False,
#    'countri': False,
#    'nick': False,
#    'ear': False,
#    'mate': False,
#    'level': False,
#    'fight': False,
#    'freak': False,
#    'bus': False,
#    'ouch': False,
#    'hun': False,
#    'bar': False,
#    'meant': False,
#    'mail': False,
#    'fav': False,
#    'joe': False,
#    'mile': False,
#    'becom': False,
#    'state': False,
#    'event': False,
#    'delet': False,
#    'pink': False,
#    'itun': False,
#    'art': False,
#    'fam': False,
#    'sooooo': False,
#    'twit': False,
#    'direct': False,
#    'fit': False,
#    'hubbi': False,
#    'invit': False,
#    'guitar': False,
#    'mommi': False,
#    'chillin': False,
#    'blood': False,
#    'sale': False,
#    'tear': False,
#    'certain': False,
#    'daughter': False,
#    'fat': False,
#    'releas': False,
#    'everybodi': False,
#    'doin': False,
#    'wine': False,
#    'fake': False,
#    'hospit': False,
#    'design': False,
#    'ran': False,
#    'absolut': False,
#    'hmmm': False,
#    'product': False,
#    'shout': False,
#    'screw': False,
#    'fish': False,
#    'tweep': False,
#    'war': False,
#    'camera': False,
#    'exhaust': False,
#    'taken': False,
#    'search': False,
#    'manag': False,
#    'lame': False,
#    'shoot': False,
#    'lone': False,
#    'servic': False,
#    'bitch': False,
#    'australia': False,
#    'doctor': False,
#    'traffic': False,
#    'radio': False,
#    'wtf': False,
#    'assign': False,
#    'joke': False,
#    'practic': False,
#    'somewher': False,
#    'father': False,
#    'troubl': False,
#    'inde': False,
#    'bother': False,
#    'four': False,
#    'allow': False,
#    'shine': False,
#    'daddi': False,
#    'ball': False,
#    'vip': False,
#    'doubl': False,
#    'jus': False,
#    'nyc': False,
#    'ohh': False,
#    'bag': False,
#    'wife': False,
#    'child': False,
#    'aint': False,
#    'behind': False,
#    'fever': False,
#    'normal': False,
#    'mention': False,
#    'chick': False,
#    'control': False,
#    'act': False,
#    'south': False,
#    'sever': False,
#    'king': False,
#    'alot': False,
#    'low': False,
#    'experi': False,
#    'five': False,
#    'taylor': False,
#    'forev': False,
#    'cloth': False,
#    'laundri': False,
#    'brought': False,
#    'clear': False,
#    'copi': False,
#    'perform': False,
#    'chine': False,
#    'iran': False,
#    'creat': False,
#    'return': False,
#    'congratul': False,
#    'impress': False,
#    'build': False,
#    'whatev': False,
#    'posit': False,
#    'rip': False,
#    'somebodi': False,
#    'land': False,
#    'dure': False,
#    'kiss': False,
#    'hangov': False,
#    'compani': False,
#    'soup': False,
#    'blast': False,
#    'version': False,
#    'instal': False,
#    'web': False,
#    'futur': False,
#    'schedul': False,
#    'anim': False,
#    'peac': False,
#    'sell': False,
#    'men': False,
#    'sold': False,
#    'dunno': False,
#    'tweetdeck': False,
#    'young': False,
#    'profil': False,
#    'bath': False,
#    'wat': False,
#    'none': False,
#    'jon': False,
#    'huh': False,
#    'chicago': False,
#    'horribl': False,
#    'paint': False,
#    'avail': False,
#    'appl': False,
#    'sport': False,
#    'travel': False,
#    'main': False,
#    'pop': False,
#    'board': False,
#    'hahah': False,
#    'smoke': False,
#    'spam': False,
#    'sweeti': False,
#    'diet': False,
#    'entertain': False,
#    ...},
#   False),
#  ({'go': False,
#    'get': False,
#    'wa': False,
#    'day': False,
#    'good': False,
#    'work': False,
#    'like': False,
#    'love': False,
#    'got': False,
#    'quot': False,
#    'today': False,
#    'time': False,
#    'u': False,
#    'thank': False,
#    'back': True,
#    'miss': True,
#    'want': False,
#    'know': False,
#    'lol': False,
#    'one': False,
#    'realli': False,
#    'see': False,
#    'feel': False,
#    'think': False,
#    'im': True,
#    'amp': False,
#    'still': False,
#    'night': False,
#    'hope': False,
#    'well': False,
#    'watch': False,
#    'need': False,
#    'new': False,
#    'make': False,
#    'home': False,
#    'na': False,
#    'oh': False,
#    'ha': False,
#    'twitter': False,
#    'come': False,
#    'last': False,
#    'look': False,
#    'much': False,
#    'wish': False,
#    'great': False,
#    'tomorrow': False,
#    'sad': False,
#    'morn': False,
#    'sleep': False,
#    'wait': False,
#    'tri': False,
#    'haha': True,
#    'veri': False,
#    'fun': False,
#    'whi': False,
#    'follow': True,
#    'sorri': False,
#    'bad': False,
#    'right': False,
#    'happi': False,
#    'friend': False,
#    'would': False,
#    'onli': False,
#    'tonight': False,
#    'week': False,
#    'way': False,
#    'say': False,
#    'though': False,
#    'nice': False,
#    'hate': False,
#    'gon': False,
#    'bed': False,
#    'yeah': False,
#    'guy': False,
#    'take': False,
#    'better': False,
#    'school': False,
#    'could': False,
#    'thing': True,
#    'hour': False,
#    'even': False,
#    'start': True,
#    'show': False,
#    'tweet': False,
#    'use': False,
#    'awesom': False,
#    'lt': False,
#    'peopl': False,
#    'weekend': False,
#    'hey': False,
#    'ok': False,
#    'play': False,
#    'x': False,
#    'next': False,
#    'yes': False,
#    'final': True,
#    'everyon': False,
#    'plea': False,
#    'let': False,
#    'first': False,
#    'long': False,
#    'best': False,
#    'tire': False,
#    'help': False,
#    'movi': False,
#    'never': False,
#    'cant': False,
#    'year': False,
#    'sure': False,
#    'soon': False,
#    'call': False,
#    'cool': False,
#    'dont': False,
#    'rain': False,
#    'littl': False,
#    'keep': False,
#    'alreadi': False,
#    'life': False,
#    'girl': False,
#    'sick': False,
#    'bore': False,
#    'wan': False,
#    'find': False,
#    'ani': False,
#    'lot': False,
#    'read': False,
#    'suck': False,
#    'man': False,
#    'anoth': False,
#    'hurt': False,
#    'done': False,
#    'made': False,
#    'head': False,
#    'talk': False,
#    'yay': False,
#    'summer': False,
#    'went': False,
#    'someth': False,
#    'eat': False,
#    'live': False,
#    'enjoy': False,
#    'readi': False,
#    'befor': False,
#    'finish': False,
#    'alway': False,
#    'yet': False,
#    'excit': False,
#    'leav': False,
#    'amaz': False,
#    'end': False,
#    'someon': False,
#    'song': False,
#    'mayb': False,
#    'damn': False,
#    'babi': False,
#    'left': False,
#    'sound': False,
#    'game': False,
#    'ever': False,
#    'ur': False,
#    'pretti': False,
#    'omg': False,
#    'phone': False,
#    'stuff': False,
#    'away': False,
#    'noth': False,
#    'doe': False,
#    'lost': False,
#    'listen': False,
#    'old': False,
#    'hear': False,
#    'hous': False,
#    'hard': False,
#    'thought': False,
#    'big': False,
#    'two': False,
#    'hot': False,
#    'tell': False,
#    'bit': False,
#    'earli': False,
#    'birthday': False,
#    'sun': False,
#    'becaus': False,
#    'wow': False,
#    'late': False,
#    'guess': False,
#    'b': False,
#    'weather': False,
#    'mean': False,
#    'parti': False,
#    'also': False,
#    'glad': False,
#    'n': False,
#    'pic': False,
#    'later': False,
#    'said': False,
#    'give': False,
#    'god': False,
#    'happen': False,
#    'put': False,
#    'th': False,
#    'run': False,
#    'fuck': False,
#    'friday': False,
#    'world': False,
#    'stop': False,
#    'mom': False,
#    'might': False,
#    'ya': False,
#    'wonder': False,
#    'win': False,
#    'exam': False,
#    'w': False,
#    'actual': False,
#    'famili': False,
#    'ugh': False,
#    'cold': False,
#    'may': False,
#    'stay': False,
#    'kid': False,
#    'r': False,
#    'music': False,
#    'saw': False,
#    'car': False,
#    'hi': False,
#    'check': False,
#    'stupid': False,
#    'sunday': False,
#    'monday': False,
#    'woke': False,
#    'updat': False,
#    'book': False,
#    'p': False,
#    'ta': False,
#    'job': False,
#    'com': False,
#    'luck': False,
#    'beauti': False,
#    'boy': False,
#    'plan': False,
#    'sinc': False,
#    'mani': True,
#    'sweet': False,
#    'seem': False,
#    'free': False,
#    'yesterday': False,
#    'shop': False,
#    'drive': False,
#    'found': False,
#    'must': False,
#    'hair': False,
#    'around': False,
#    'everyth': False,
#    'total': False,
#    'meet': False,
#    'post': False,
#    'tho': False,
#    'pictur': False,
#    'chang': False,
#    'move': False,
#    'drink': False,
#    'write': False,
#    'iphon': False,
#    'dinner': False,
#    'turn': False,
#    'welcom': False,
#    'break': False,
#    'almost': False,
#    'cute': False,
#    'studi': False,
#    'shit': False,
#    'busi': False,
#    'aww': False,
#    'lunch': False,
#    'till': False,
#    'c': False,
#    'anyth': False,
#    'video': False,
#    'dad': False,
#    'fan': False,
#    'funni': False,
#    'okay': False,
#    'food': False,
#    'forward': False,
#    'name': False,
#    'enough': False,
#    'dream': False,
#    'didnt': False,
#    'brother': False,
#    'month': False,
#    'ill': False,
#    'gone': False,
#    'coffe': False,
#    'room': False,
#    'super': False,
#    'least': False,
#    'person': False,
#    'believ': False,
#    'hello': False,
#    'hang': False,
#    'without': False,
#    'die': False,
#    'el': False,
#    'outsid': False,
#    'buy': False,
#    'walk': False,
#    'far': False,
#    'everi': False,
#    'anyon': False,
#    'wake': False,
#    'poor': False,
#    'bring': False,
#    'rememb': False,
#    'money': False,
#    'wrong': False,
#    'class': False,
#    'hit': False,
#    'ask': False,
#    'word': False,
#    'close': False,
#    'mine': False,
#    'caus': False,
#    'tv': False,
#    'kinda': False,
#    'cri': False,
#    'place': False,
#    'onc': False,
#    'sooo': False,
#    'xx': False,
#    'beach': False,
#    'fail': False,
#    'headach': False,
#    'half': False,
#    'saturday': False,
#    'hahaha': False,
#    'dog': False,
#    'either': False,
#    'train': False,
#    'cours': False,
#    'eye': False,
#    'gt': False,
#    'trip': False,
#    'whole': False,
#    'link': False,
#    'fall': False,
#    'pm': False,
#    'sit': False,
#    'comput': False,
#    'goodnight': False,
#    'repli': False,
#    'minut': False,
#    'blog': False,
#    'serious': False,
#    'clean': False,
#    'photo': False,
#    'took': False,
#    'rock': False,
#    'onlin': True,
#    'nite': False,
#    'mother': False,
#    'ago': False,
#    'idea': False,
#    'offic': False,
#    'email': False,
#    'anymor': False,
#    'real': False,
#    'open': False,
#    'seen': False,
#    'kill': False,
#    'boo': False,
#    'news': False,
#    'abl': False,
#    'wont': False,
#    'sunni': False,
#    'heart': False,
#    'cuz': False,
#    'came': False,
#    'ah': False,
#    'probabl': False,
#    'soo': False,
#    'awww': False,
#    'problem': False,
#    'send': False,
#    'hungri': False,
#    'xd': False,
#    'aw': False,
#    'face': False,
#    'concert': False,
#    'shower': False,
#    'kind': False,
#    'hehe': False,
#    'forgot': False,
#    'true': False,
#    'pay': False,
#    'sister': False,
#    'high': False,
#    'pain': False,
#    'test': False,
#    'e': False,
#    'www': False,
#    'definit': False,
#    'site': False,
#    'goe': False,
#    'v': False,
#    'k': False,
#    'danc': False,
#    'heard': False,
#    'til': False,
#    'ticket': False,
#    'homework': False,
#    'pack': False,
#    'laugh': False,
#    'part': False,
#    'fix': False,
#    'instead': False,
#    'wear': False,
#    'rest': False,
#    'st': False,
#    'internet': False,
#    'june': False,
#    'tea': False,
#    'awak': False,
#    'cat': False,
#    'crazi': False,
#    'g': False,
#    'sometim': False,
#    'alon': False,
#    'mr': False,
#    'care': False,
#    'learn': False,
#    'stuck': False,
#    'visit': False,
#    'add': False,
#    'asleep': False,
#    'dude': False,
#    'store': False,
#    'pick': False,
#    'set': False,
#    'ladi': False,
#    'smile': False,
#    'fine': False,
#    'reason': False,
#    'quit': False,
#    'dear': False,
#    'hell': False,
#    'cut': False,
#    'graduat': False,
#    'full': False,
#    'la': False,
#    'vote': False,
#    'suppos': False,
#    'worri': False,
#    'broke': False,
#    'mileycyrus': False,
#    'crap': False,
#    'interest': False,
#    'offici': False,
#    'btw': False,
#    'sore': False,
#    'afternoon': False,
#    'youtub': False,
#    'star': False,
#    'account': False,
#    'lucki': False,
#    'lmao': False,
#    'tommcfli': False,
#    'side': False,
#    'depress': False,
#    'line': False,
#    'catch': False,
#    'breakfast': False,
#    'told': False,
#    'pas': False,
#    'revis': False,
#    'hug': False,
#    'hand': False,
#    'download': False,
#    'min': False,
#    'via': False,
#    'coupl': False,
#    'favorit': False,
#    'facebook': False,
#    'ice': False,
#    'holiday': False,
#    'season': False,
#    'tour': False,
#    'realiz': False,
#    'anyway': False,
#    'sign': False,
#    'jealous': False,
#    'spend': False,
#    'text': False,
#    'question': False,
#    'nd': False,
#    'short': False,
#    'bout': False,
#    'congrat': False,
#    'l': False,
#    'nap': False,
#    'websit': False,
#    'lil': False,
#    'myspac': False,
#    'ddlovato': False,
#    'agre': False,
#    'hr': False,
#    'mind': False,
#    'ipod': False,
#    'messag': False,
#    'complet': False,
#    'order': False,
#    'album': False,
#    'figur': False,
#    'near': False,
#    'le': False,
#    'foot': False,
#    'cheer': False,
#    'relax': False,
#    'forget': False,
#    'dead': False,
#    'save': False,
#    'bye': False,
#    'three': False,
#    'stori': False,
#    'comment': False,
#    'cook': False,
#    'soooo': False,
#    'togeth': False,
#    'paper': False,
#    'mad': False,
#    'second': False,
#    'sing': False,
#    'juli': False,
#    'perfect': False,
#    'burn': False,
#    'ad': False,
#    'water': False,
#    'team': False,
#    'page': False,
#    'weird': False,
#    'sim': False,
#    'beer': False,
#    'past': False,
#    'upset': False,
#    'bought': False,
#    'list': False,
#    'answer': False,
#    'load': False,
#    'worth': False,
#    'plane': False,
#    'shirt': False,
#    'sleepi': False,
#    'drop': False,
#    'googl': False,
#    'bless': False,
#    'math': False,
#    'pool': False,
#    'differ': False,
#    'broken': False,
#    'decid': False,
#    'yea': False,
#    'top': False,
#    'goin': False,
#    'understand': False,
#    'sat': False,
#    'share': False,
#    'upload': False,
#    'unfortun': False,
#    'ride': False,
#    'jona': False,
#    'idk': False,
#    'garden': False,
#    'usual': False,
#    'sent': False,
#    'club': False,
#    'road': False,
#    'fell': False,
#    'mood': False,
#    'church': False,
#    'lay': False,
#    'blue': False,
#    'air': False,
#    'due': False,
#    'town': False,
#    'chat': False,
#    'colleg': False,
#    'moon': False,
#    'sigh': False,
#    'thx': False,
#    'followfriday': False,
#    'safe': False,
#    'stomach': False,
#    'green': False,
#    'citi': False,
#    'uk': False,
#    'kick': False,
#    'ahh': False,
#    'mac': False,
#    'park': False,
#    'worst': False,
#    'throat': False,
#    'scare': False,
#    'type': False,
#    'gorgeous': False,
#    'yummi': False,
#    'chanc': False,
#    'laptop': False,
#    'fast': False,
#    'drunk': False,
#    'cough': False,
#    'red': False,
#    'doesnt': False,
#    'angel': False,
#    'si': False,
#    'window': False,
#    'random': False,
#    'co': False,
#    'bbq': False,
#    'xxx': False,
#    'bro': False,
#    'met': False,
#    'support': False,
#    'easi': False,
#    'band': False,
#    'possibl': False,
#    'insid': False,
#    'tan': False,
#    'david': False,
#    'especi': False,
#    'em': False,
#    'moment': False,
#    'h': False,
#    'bet': False,
#    'block': False,
#    'small': False,
#    'parent': False,
#    'annoy': False,
#    'begin': False,
#    'dress': False,
#    'fb': False,
#    'laker': False,
#    'warm': False,
#    'english': False,
#    'expect': False,
#    'gym': False,
#    'wors': False,
#    'special': False,
#    'mess': False,
#    'havent': False,
#    'episod': False,
#    'wed': False,
#    'beat': False,
#    'lose': False,
#    'pizza': False,
#    'ppl': False,
#    'box': False,
#    'award': False,
#    'buddi': False,
#    'ach': False,
#    'except': False,
#    'touch': False,
#    'hill': False,
#    'date': False,
#    'lazi': False,
#    'surpris': False,
#    'wednesday': False,
#    'disappoint': False,
#    'cake': False,
#    'cup': False,
#    'gettin': False,
#    'join': False,
#    'magic': False,
#    'cd': False,
#    'celebr': False,
#    'power': False,
#    'chocol': False,
#    'f': False,
#    'round': False,
#    'leg': False,
#    'yr': False,
#    'piss': False,
#    'lie': False,
#    'shall': False,
#    'swim': False,
#    'chill': False,
#    'front': False,
#    'airport': False,
#    'project': False,
#    'shoe': False,
#    'dm': False,
#    'cream': False,
#    'son': False,
#    'woo': False,
#    'age': False,
#    'luv': False,
#    'plus': False,
#    'mtv': False,
#    'chicken': False,
#    'goodby': False,
#    'alright': False,
#    'point': False,
#    'ive': False,
#    'addict': False,
#    'light': False,
#    'black': False,
#    'card': False,
#    'bday': False,
#    'huge': False,
#    'histori': False,
#    'flight': False,
#    'camp': False,
#    'ahhh': False,
#    'babe': False,
#    'case': False,
#    'rd': False,
#    'hmm': False,
#    'promis': False,
#    'app': False,
#    'yep': False,
#    'present': False,
#    'dvd': False,
#    'voic': False,
#    'number': False,
#    'shame': False,
#    'confus': False,
#    'record': False,
#    'jonasbroth': False,
#    'issu': False,
#    'bike': False,
#    'woman': False,
#    'bird': False,
#    'longer': False,
#    'interview': False,
#    'fire': False,
#    'fantast': False,
#    'wash': False,
#    'finger': False,
#    'spent': False,
#    'j': False,
#    'tast': False,
#    'count': False,
#    'mum': False,
#    'speak': False,
#    'ruin': False,
#    'flu': False,
#    'appreci': False,
#    'cooki': False,
#    'quick': False,
#    'raini': False,
#    'bb': False,
#    'nope': False,
#    'sunshin': False,
#    'cover': False,
#    'film': False,
#    'thursday': False,
#    'knew': False,
#    'gave': False,
#    'felt': False,
#    'arriv': False,
#    'notic': False,
#    'watchin': False,
#    'terribl': False,
#    'bloodi': False,
#    'hilari': False,
#    'fact': False,
#    'deal': False,
#    'wast': False,
#    'hold': False,
#    'rather': False,
#    'tuesday': False,
#    'miley': False,
#    'stress': False,
#    'cancel': False,
#    'coz': False,
#    'note': False,
#    'gay': False,
#    'kitti': False,
#    'nose': False,
#    'shut': False,
#    'connect': False,
#    'exact': False,
#    'fli': False,
#    'remind': False,
#    'xoxo': False,
#    'matter': False,
#    'bum': False,
#    'view': False,
#    'extrem': False,
#    'storm': False,
#    'tip': False,
#    'scari': False,
#    'current': False,
#    'london': False,
#    'earlier': False,
#    'french': False,
#    'proud': False,
#    'vacat': False,
#    'ate': False,
#    'step': False,
#    'yup': False,
#    'fair': False,
#    'ahead': False,
#    'isnt': False,
#    'burnt': False,
#    'da': False,
#    'memori': False,
#    'twilight': False,
#    'white': False,
#    'screen': False,
#    'boyfriend': False,
#    'roll': False,
#    'smell': False,
#    'inspir': False,
#    'cousin': False,
#    'yum': False,
#    'bodi': False,
#    'slept': False,
#    'match': False,
#    'stand': False,
#    'vega': False,
#    'tom': False,
#    'gosh': False,
#    'uh': False,
#    'crash': False,
#    'shot': False,
#    'offer': False,
#    'pray': False,
#    'perhap': False,
#    'brain': False,
#    'slow': False,
#    'tummi': False,
#    'plz': False,
#    'death': False,
#    'sort': False,
#    'countri': False,
#    'nick': False,
#    'ear': False,
#    'mate': False,
#    'level': False,
#    'fight': False,
#    'freak': False,
#    'bus': False,
#    'ouch': False,
#    'hun': False,
#    'bar': False,
#    'meant': False,
#    'mail': False,
#    'fav': False,
#    'joe': False,
#    'mile': False,
#    'becom': False,
#    'state': False,
#    'event': False,
#    'delet': False,
#    'pink': False,
#    'itun': False,
#    'art': False,
#    'fam': False,
#    'sooooo': False,
#    'twit': False,
#    'direct': False,
#    'fit': False,
#    'hubbi': False,
#    'invit': False,
#    'guitar': False,
#    'mommi': False,
#    'chillin': False,
#    'blood': False,
#    'sale': False,
#    'tear': False,
#    'certain': False,
#    'daughter': False,
#    'fat': False,
#    'releas': False,
#    'everybodi': False,
#    'doin': False,
#    'wine': False,
#    'fake': False,
#    'hospit': False,
#    'design': False,
#    'ran': False,
#    'absolut': False,
#    'hmmm': False,
#    'product': False,
#    'shout': False,
#    'screw': False,
#    'fish': False,
#    'tweep': False,
#    'war': False,
#    'camera': False,
#    'exhaust': False,
#    'taken': False,
#    'search': False,
#    'manag': False,
#    'lame': False,
#    'shoot': False,
#    'lone': False,
#    'servic': False,
#    'bitch': False,
#    'australia': False,
#    'doctor': False,
#    'traffic': False,
#    'radio': False,
#    'wtf': False,
#    'assign': False,
#    'joke': False,
#    'practic': False,
#    'somewher': False,
#    'father': False,
#    'troubl': False,
#    'inde': False,
#    'bother': False,
#    'four': False,
#    'allow': False,
#    'shine': False,
#    'daddi': False,
#    'ball': False,
#    'vip': False,
#    'doubl': False,
#    'jus': False,
#    'nyc': False,
#    'ohh': False,
#    'bag': False,
#    'wife': False,
#    'child': False,
#    'aint': False,
#    'behind': False,
#    'fever': False,
#    'normal': False,
#    'mention': False,
#    'chick': False,
#    'control': False,
#    'act': False,
#    'south': False,
#    'sever': False,
#    'king': False,
#    'alot': False,
#    'low': False,
#    'experi': False,
#    'five': False,
#    'taylor': False,
#    'forev': False,
#    'cloth': False,
#    'laundri': False,
#    'brought': False,
#    'clear': False,
#    'copi': False,
#    'perform': False,
#    'chine': False,
#    'iran': False,
#    'creat': False,
#    'return': False,
#    'congratul': False,
#    'impress': False,
#    'build': False,
#    'whatev': False,
#    'posit': False,
#    'rip': False,
#    'somebodi': False,
#    'land': False,
#    'dure': False,
#    'kiss': False,
#    'hangov': False,
#    'compani': False,
#    'soup': False,
#    'blast': False,
#    'version': False,
#    'instal': False,
#    'web': False,
#    'futur': False,
#    'schedul': False,
#    'anim': False,
#    'peac': False,
#    'sell': False,
#    'men': False,
#    'sold': False,
#    'dunno': False,
#    'tweetdeck': False,
#    'young': False,
#    'profil': False,
#    'bath': False,
#    'wat': False,
#    'none': False,
#    'jon': False,
#    'huh': False,
#    'chicago': False,
#    'horribl': False,
#    'paint': False,
#    'avail': False,
#    'appl': False,
#    'sport': False,
#    'travel': False,
#    'main': False,
#    'pop': False,
#    'board': False,
#    'hahah': False,
#    'smoke': False,
#    'spam': False,
#    'sweeti': False,
#    'diet': False,
#    'entertain': False,
#    ...},
#   True),
#  ({'go': False,
#    'get': False,
#    'wa': False,
#    'day': False,
#    'good': False,
#    'work': False,
#    'like': False,
#    'love': False,
#    'got': False,
#    'quot': False,
#    'today': False,
#    'time': False,
#    'u': False,
#    'thank': False,
#    'back': False,
#    'miss': False,
#    'want': False,
#    'know': False,
#    'lol': False,
#    'one': True,
#    'realli': False,
#    'see': False,
#    'feel': False,
#    'think': False,
#    'im': False,
#    'amp': False,
#    'still': False,
#    'night': False,
#    'hope': False,
#    'well': False,
#    'watch': False,
#    'need': False,
#    'new': False,
#    'make': False,
#    'home': False,
#    'na': False,
#    'oh': False,
#    'ha': False,
#    'twitter': False,
#    'come': False,
#    'last': False,
#    'look': False,
#    'much': False,
#    'wish': False,
#    'great': False,
#    'tomorrow': False,
#    'sad': False,
#    'morn': False,
#    'sleep': False,
#    'wait': False,
#    'tri': False,
#    'haha': False,
#    'veri': False,
#    'fun': False,
#    'whi': False,
#    'follow': False,
#    'sorri': False,
#    'bad': False,
#    'right': False,
#    'happi': False,
#    'friend': False,
#    'would': False,
#    'onli': True,
#    'tonight': False,
#    'week': False,
#    'way': False,
#    'say': False,
#    'though': False,
#    'nice': False,
#    'hate': False,
#    'gon': False,
#    'bed': False,
#    'yeah': False,
#    'guy': False,
#    'take': False,
#    'better': False,
#    'school': False,
#    'could': False,
#    'thing': False,
#    'hour': True,
#    'even': False,
#    'start': False,
#    'show': False,
#    'tweet': False,
#    'use': False,
#    'awesom': False,
#    'lt': False,
#    'peopl': False,
#    'weekend': False,
#    'hey': False,
#    'ok': False,
#    'play': False,
#    'x': False,
#    'next': False,
#    'yes': False,
#    'final': False,
#    'everyon': False,
#    'plea': False,
#    'let': False,
#    'first': False,
#    'long': False,
#    'best': False,
#    'tire': False,
#    'help': False,
#    'movi': False,
#    'never': False,
#    'cant': False,
#    'year': False,
#    'sure': False,
#    'soon': False,
#    'call': False,
#    'cool': False,
#    'dont': False,
#    'rain': False,
#    'littl': False,
#    'keep': False,
#    'alreadi': False,
#    'life': False,
#    'girl': False,
#    'sick': False,
#    'bore': False,
#    'wan': False,
#    'find': False,
#    'ani': False,
#    'lot': False,
#    'read': False,
#    'suck': False,
#    'man': False,
#    'anoth': False,
#    'hurt': False,
#    'done': False,
#    'made': False,
#    'head': False,
#    'talk': False,
#    'yay': False,
#    'summer': False,
#    'went': True,
#    'someth': False,
#    'eat': False,
#    'live': False,
#    'enjoy': False,
#    'readi': False,
#    'befor': False,
#    'finish': False,
#    'alway': False,
#    'yet': False,
#    'excit': False,
#    'leav': False,
#    'amaz': False,
#    'end': False,
#    'someon': False,
#    'song': False,
#    'mayb': False,
#    'damn': False,
#    'babi': False,
#    'left': False,
#    'sound': False,
#    'game': False,
#    'ever': False,
#    'ur': True,
#    'pretti': False,
#    'omg': False,
#    'phone': False,
#    'stuff': False,
#    'away': False,
#    'noth': False,
#    'doe': False,
#    'lost': False,
#    'listen': False,
#    'old': True,
#    'hear': False,
#    'hous': False,
#    'hard': False,
#    'thought': False,
#    'big': False,
#    'two': False,
#    'hot': False,
#    'tell': False,
#    'bit': False,
#    'earli': False,
#    'birthday': False,
#    'sun': False,
#    'becaus': False,
#    'wow': False,
#    'late': False,
#    'guess': False,
#    'b': False,
#    'weather': False,
#    'mean': False,
#    'parti': False,
#    'also': False,
#    'glad': False,
#    'n': False,
#    'pic': False,
#    'later': False,
#    'said': False,
#    'give': False,
#    'god': False,
#    'happen': False,
#    'put': False,
#    'th': False,
#    'run': False,
#    'fuck': False,
#    'friday': False,
#    'world': False,
#    'stop': False,
#    'mom': False,
#    'might': False,
#    'ya': False,
#    'wonder': False,
#    'win': False,
#    'exam': False,
#    'w': False,
#    'actual': False,
#    'famili': False,
#    'ugh': False,
#    'cold': False,
#    'may': False,
#    'stay': False,
#    'kid': False,
#    'r': False,
#    'music': False,
#    'saw': False,
#    'car': False,
#    'hi': False,
#    'check': False,
#    'stupid': False,
#    'sunday': False,
#    'monday': False,
#    'woke': False,
#    'updat': False,
#    'book': False,
#    'p': False,
#    'ta': False,
#    'job': False,
#    'com': False,
#    'luck': False,
#    'beauti': False,
#    'boy': False,
#    'plan': False,
#    'sinc': False,
#    'mani': False,
#    'sweet': False,
#    'seem': False,
#    'free': False,
#    'yesterday': False,
#    'shop': False,
#    'drive': False,
#    'found': False,
#    'must': False,
#    'hair': False,
#    'around': False,
#    'everyth': False,
#    'total': False,
#    'meet': False,
#    'post': False,
#    'tho': False,
#    'pictur': False,
#    'chang': False,
#    'move': False,
#    'drink': False,
#    'write': False,
#    'iphon': False,
#    'dinner': False,
#    'turn': False,
#    'welcom': False,
#    'break': False,
#    'almost': False,
#    'cute': False,
#    'studi': False,
#    'shit': False,
#    'busi': False,
#    'aww': False,
#    'lunch': False,
#    'till': False,
#    'c': False,
#    'anyth': False,
#    'video': False,
#    'dad': False,
#    'fan': False,
#    'funni': False,
#    'okay': False,
#    'food': False,
#    'forward': False,
#    'name': False,
#    'enough': False,
#    'dream': False,
#    'didnt': False,
#    'brother': False,
#    'month': False,
#    'ill': False,
#    'gone': False,
#    'coffe': False,
#    'room': False,
#    'super': False,
#    'least': False,
#    'person': False,
#    'believ': False,
#    'hello': False,
#    'hang': False,
#    'without': False,
#    'die': False,
#    'el': False,
#    'outsid': False,
#    'buy': False,
#    'walk': False,
#    'far': False,
#    'everi': False,
#    'anyon': False,
#    'wake': False,
#    'poor': False,
#    'bring': False,
#    'rememb': False,
#    'money': False,
#    'wrong': False,
#    'class': False,
#    'hit': False,
#    'ask': False,
#    'word': False,
#    'close': False,
#    'mine': False,
#    'caus': False,
#    'tv': False,
#    'kinda': False,
#    'cri': False,
#    'place': False,
#    'onc': True,
#    'sooo': False,
#    'xx': False,
#    'beach': False,
#    'fail': False,
#    'headach': False,
#    'half': False,
#    'saturday': False,
#    'hahaha': False,
#    'dog': False,
#    'either': False,
#    'train': False,
#    'cours': False,
#    'eye': False,
#    'gt': False,
#    'trip': False,
#    'whole': False,
#    'link': False,
#    'fall': False,
#    'pm': False,
#    'sit': False,
#    'comput': False,
#    'goodnight': False,
#    'repli': False,
#    'minut': False,
#    'blog': False,
#    'serious': False,
#    'clean': False,
#    'photo': False,
#    'took': False,
#    'rock': False,
#    'onlin': False,
#    'nite': False,
#    'mother': False,
#    'ago': False,
#    'idea': False,
#    'offic': False,
#    'email': False,
#    'anymor': False,
#    'real': False,
#    'open': False,
#    'seen': False,
#    'kill': False,
#    'boo': False,
#    'news': False,
#    'abl': False,
#    'wont': False,
#    'sunni': False,
#    'heart': False,
#    'cuz': False,
#    'came': False,
#    'ah': False,
#    'probabl': False,
#    'soo': False,
#    'awww': False,
#    'problem': False,
#    'send': False,
#    'hungri': False,
#    'xd': False,
#    'aw': False,
#    'face': False,
#    'concert': False,
#    'shower': False,
#    'kind': False,
#    'hehe': False,
#    'forgot': False,
#    'true': False,
#    'pay': False,
#    'sister': False,
#    'high': False,
#    'pain': False,
#    'test': False,
#    'e': False,
#    'www': False,
#    'definit': False,
#    'site': False,
#    'goe': False,
#    'v': False,
#    'k': False,
#    'danc': False,
#    'heard': False,
#    'til': False,
#    'ticket': False,
#    'homework': False,
#    'pack': False,
#    'laugh': False,
#    'part': False,
#    'fix': False,
#    'instead': False,
#    'wear': False,
#    'rest': False,
#    'st': False,
#    'internet': False,
#    'june': False,
#    'tea': False,
#    'awak': False,
#    'cat': False,
#    'crazi': False,
#    'g': False,
#    'sometim': False,
#    'alon': False,
#    'mr': False,
#    'care': False,
#    'learn': False,
#    'stuck': False,
#    'visit': False,
#    'add': False,
#    'asleep': False,
#    'dude': False,
#    'store': False,
#    'pick': False,
#    'set': False,
#    'ladi': False,
#    'smile': False,
#    'fine': False,
#    'reason': False,
#    'quit': False,
#    'dear': False,
#    'hell': False,
#    'cut': False,
#    'graduat': False,
#    'full': False,
#    'la': False,
#    'vote': False,
#    'suppos': False,
#    'worri': False,
#    'broke': False,
#    'mileycyrus': False,
#    'crap': False,
#    'interest': False,
#    'offici': False,
#    'btw': False,
#    'sore': False,
#    'afternoon': False,
#    'youtub': False,
#    'star': False,
#    'account': False,
#    'lucki': False,
#    'lmao': False,
#    'tommcfli': False,
#    'side': False,
#    'depress': False,
#    'line': False,
#    'catch': False,
#    'breakfast': False,
#    'told': False,
#    'pas': False,
#    'revis': False,
#    'hug': False,
#    'hand': False,
#    'download': False,
#    'min': False,
#    'via': False,
#    'coupl': False,
#    'favorit': False,
#    'facebook': False,
#    'ice': False,
#    'holiday': False,
#    'season': False,
#    'tour': False,
#    'realiz': False,
#    'anyway': False,
#    'sign': False,
#    'jealous': False,
#    'spend': False,
#    'text': False,
#    'question': False,
#    'nd': False,
#    'short': False,
#    'bout': False,
#    'congrat': False,
#    'l': False,
#    'nap': False,
#    'websit': False,
#    'lil': False,
#    'myspac': False,
#    'ddlovato': False,
#    'agre': False,
#    'hr': False,
#    'mind': False,
#    'ipod': False,
#    'messag': False,
#    'complet': False,
#    'order': False,
#    'album': False,
#    'figur': False,
#    'near': False,
#    'le': False,
#    'foot': False,
#    'cheer': False,
#    'relax': False,
#    'forget': False,
#    'dead': False,
#    'save': False,
#    'bye': False,
#    'three': False,
#    'stori': False,
#    'comment': False,
#    'cook': False,
#    'soooo': False,
#    'togeth': False,
#    'paper': False,
#    'mad': False,
#    'second': False,
#    'sing': False,
#    'juli': False,
#    'perfect': False,
#    'burn': False,
#    'ad': False,
#    'water': False,
#    'team': False,
#    'page': False,
#    'weird': False,
#    'sim': False,
#    'beer': False,
#    'past': False,
#    'upset': False,
#    'bought': False,
#    'list': False,
#    'answer': False,
#    'load': False,
#    'worth': False,
#    'plane': False,
#    'shirt': False,
#    'sleepi': False,
#    'drop': False,
#    'googl': False,
#    'bless': False,
#    'math': False,
#    'pool': False,
#    'differ': False,
#    'broken': False,
#    'decid': False,
#    'yea': False,
#    'top': False,
#    'goin': False,
#    'understand': False,
#    'sat': False,
#    'share': False,
#    'upload': False,
#    'unfortun': False,
#    'ride': False,
#    'jona': False,
#    'idk': False,
#    'garden': False,
#    'usual': False,
#    'sent': False,
#    'club': False,
#    'road': False,
#    'fell': False,
#    'mood': False,
#    'church': False,
#    'lay': False,
#    'blue': False,
#    'air': False,
#    'due': False,
#    'town': False,
#    'chat': False,
#    'colleg': False,
#    'moon': False,
#    'sigh': False,
#    'thx': False,
#    'followfriday': False,
#    'safe': False,
# ...
#    'finish': False,
#    'alway': True,
#    'yet': False,
#    'excit': False,
#    'leav': False,
#    'amaz': False,
#    'end': False,
#    'someon': False,
#    'song': False,
#    'mayb': False,
#    'damn': False,
#    'babi': False,
#    'left': False,
#    'sound': False,
#    'game': False,
#    'ever': False,
#    'ur': False,
#    'pretti': False,
#    'omg': False,
#    'phone': False,
#    'stuff': False,
#    'away': False,
#    'noth': False,
#    'doe': False,
#    'lost': False,
#    'listen': False,
#    'old': False,
#    'hear': False,
#    'hous': False,
#    'hard': False,
#    'thought': False,
#    'big': False,
#    'two': False,
#    'hot': False,
#    'tell': False,
#    'bit': False,
#    'earli': False,
#    'birthday': False,
#    'sun': False,
#    'becaus': False,
#    'wow': False,
#    'late': False,
#    'guess': True,
#    'b': False,
#    'weather': False,
#    'mean': False,
#    'parti': False,
#    'also': False,
#    'glad': False,
#    'n': False,
#    'pic': False,
#    'later': False,
#    'said': False,
#    'give': False,
#    'god': False,
#    'happen': False,
#    'put': False,
#    'th': False,
#    'run': False,
#    'fuck': False,
#    'friday': False,
#    'world': False,
#    'stop': False,
#    'mom': False,
#    'might': False,
#    'ya': False,
#    'wonder': False,
#    'win': False,
#    'exam': False,
#    'w': False,
#    'actual': False,
#    'famili': False,
#    'ugh': False,
#    'cold': False,
#    'may': False,
#    'stay': False,
#    'kid': False,
#    'r': False,
#    'music': False,
#    'saw': False,
#    'car': False,
#    'hi': False,
#    'check': False,
#    'stupid': False,
#    'sunday': False,
#    'monday': False,
#    'woke': False,
#    'updat': False,
#    'book': False,
#    'p': False,
#    'ta': False,
#    'job': False,
#    'com': False,
#    'luck': False,
#    'beauti': False,
#    'boy': False,
#    'plan': False,
#    'sinc': False,
#    'mani': False,
#    'sweet': False,
#    'seem': False,
#    'free': False,
#    'yesterday': False,
#    'shop': False,
#    'drive': False,
#    'found': False,
#    'must': False,
#    'hair': False,
#    'around': False,
#    'everyth': False,
#    'total': False,
#    'meet': False,
#    'post': False,
#    'tho': False,
#    'pictur': False,
#    'chang': False,
#    'move': False,
#    'drink': False,
#    'write': False,
#    'iphon': False,
#    'dinner': False,
#    'turn': False,
#    'welcom': False,
#    'break': False,
#    'almost': False,
#    'cute': False,
#    'studi': False,
#    'shit': False,
#    'busi': False,
#    'aww': False,
#    'lunch': False,
#    'till': False,
#    'c': False,
#    'anyth': False,
#    'video': False,
#    'dad': False,
#    'fan': False,
#    'funni': False,
#    'okay': False,
#    'food': False,
#    'forward': False,
#    'name': False,
#    'enough': False,
#    'dream': False,
#    'didnt': False,
#    'brother': False,
#    'month': False,
#    'ill': False,
#    'gone': False,
#    'coffe': False,
#    'room': False,
#    'super': False,
#    'least': False,
#    'person': False,
#    'believ': False,
#    'hello': False,
#    'hang': False,
#    'without': False,
#    'die': False,
#    'el': False,
#    'outsid': False,
#    'buy': False,
#    'walk': False,
#    'far': False,
#    'everi': False,
#    'anyon': False,
#    'wake': False,
#    'poor': False,
#    'bring': False,
#    'rememb': False,
#    'money': False,
#    'wrong': False,
#    'class': False,
#    'hit': False,
#    'ask': False,
#    'word': False,
#    'close': False,
#    'mine': False,
#    'caus': False,
#    'tv': False,
#    'kinda': False,
#    'cri': False,
#    'place': False,
#    'onc': False,
#    'sooo': False,
#    'xx': False,
#    'beach': False,
#    'fail': False,
#    'headach': False,
#    'half': False,
#    'saturday': False,
#    'hahaha': False,
#    'dog': False,
#    'either': False,
#    'train': False,
#    'cours': False,
#    'eye': False,
#    'gt': False,
#    'trip': False,
#    'whole': False,
#    'link': False,
#    'fall': False,
#    'pm': False,
#    'sit': False,
#    'comput': False,
#    'goodnight': False,
#    'repli': False,
#    'minut': False,
#    'blog': False,
#    'serious': False,
#    'clean': False,
#    'photo': False,
#    'took': False,
#    'rock': False,
#    'onlin': False,
#    'nite': False,
#    'mother': False,
#    'ago': False,
#    'idea': False,
#    'offic': False,
#    'email': False,
#    'anymor': False,
#    'real': False,
#    'open': False,
#    'seen': False,
#    'kill': False,
#    'boo': False,
#    'news': False,
#    'abl': False,
#    'wont': False,
#    'sunni': False,
#    'heart': False,
#    'cuz': False,
#    'came': False,
#    'ah': False,
#    'probabl': False,
#    'soo': False,
#    'awww': False,
#    'problem': False,
#    'send': False,
#    'hungri': False,
#    'xd': False,
#    'aw': False,
#    'face': False,
#    'concert': False,
#    'shower': False,
#    'kind': False,
#    'hehe': False,
#    'forgot': False,
#    'true': False,
#    'pay': False,
#    'sister': False,
#    'high': False,
#    'pain': False,
#    'test': False,
#    'e': False,
#    'www': False,
#    'definit': False,
#    'site': False,
#    'goe': False,
#    'v': False,
#    'k': False,
#    'danc': False,
#    'heard': False,
#    'til': False,
#    'ticket': False,
#    'homework': False,
#    'pack': False,
#    'laugh': False,
#    'part': False,
#    'fix': False,
#    'instead': False,
#    'wear': False,
#    'rest': False,
#    'st': False,
#    'internet': False,
#    'june': False,
#    'tea': False,
#    'awak': False,
#    'cat': False,
#    'crazi': False,
#    'g': False,
#    'sometim': False,
#    'alon': False,
#    'mr': False,
#    'care': False,
#    'learn': False,
#    'stuck': False,
#    'visit': False,
#    'add': False,
#    'asleep': False,
#    'dude': False,
#    'store': False,
#    'pick': False,
#    'set': False,
#    'ladi': False,
#    'smile': False,
#    'fine': False,
#    'reason': False,
#    'quit': False,
#    'dear': False,
#    'hell': False,
#    'cut': False,
#    'graduat': False,
#    'full': False,
#    'la': False,
#    'vote': False,
#    'suppos': False,
#    'worri': False,
#    'broke': False,
#    'mileycyrus': False,
#    'crap': False,
#    'interest': False,
#    'offici': False,
#    'btw': False,
#    'sore': False,
#    'afternoon': False,
#    'youtub': False,
#    'star': False,
#    'account': False,
#    'lucki': False,
#    'lmao': False,
#    'tommcfli': False,
#    'side': False,
#    'depress': False,
#    'line': False,
#    'catch': False,
#    'breakfast': False,
#    'told': False,
#    'pas': False,
#    'revis': False,
#    'hug': False,
#    'hand': False,
#    'download': False,
#    'min': False,
#    'via': False,
#    'coupl': False,
#    'favorit': False,
#    'facebook': False,
#    'ice': False,
#    'holiday': False,
#    'season': False,
#    'tour': False,
#    'realiz': False,
#    'anyway': False,
#    'sign': False,
#    'jealous': False,
#    'spend': False,
#    'text': False,
#    'question': False,
#    'nd': False,
#    'short': False,
#    'bout': False,
#    'congrat': False,
#    'l': False,
#    'nap': False,
#    'websit': False,
#    'lil': False,
#    'myspac': False,
#    'ddlovato': False,
#    'agre': False,
#    'hr': False,
#    'mind': False,
#    'ipod': False,
#    'messag': False,
#    'complet': False,
#    'order': False,
#    'album': False,
#    'figur': False,
#    'near': False,
#    'le': False,
#    'foot': False,
#    'cheer': False,
#    'relax': False,
#    'forget': False,
#    'dead': False,
#    'save': False,
#    'bye': False,
#    'three': False,
#    'stori': False,
#    'comment': False,
#    'cook': False,
#    'soooo': False,
#    'togeth': False,
#    'paper': False,
#    'mad': False,
#    'second': False,
#    'sing': False,
#    'juli': False,
#    'perfect': False,
#    'burn': False,
#    'ad': False,
#    'water': False,
#    'team': False,
#    'page': False,
#    'weird': False,
#    'sim': False,
#    'beer': False,
#    'past': False,
#    'upset': False,
#    'bought': False,
#    'list': False,
#    'answer': False,
#    'load': False,
#    'worth': False,
#    'plane': False,
#    'shirt': False,
#    'sleepi': False,
#    'drop': False,
#    'googl': False,
#    'bless': False,
#    'math': False,
#    'pool': False,
#    'differ': False,
#    'broken': False,
#    'decid': False,
#    'yea': False,
#    'top': False,
#    'goin': False,
#    'understand': False,
#    'sat': False,
#    'share': False,
#    'upload': False,
#    'unfortun': False,
#    'ride': False,
#    'jona': False,
#    'idk': False,
#    'garden': False,
#    'usual': False,
#    'sent': False,
#    'club': False,
#    'road': False,
#    'fell': False,
#    'mood': False,
#    'church': False,
#    'lay': False,
#    'blue': False,
#    'air': False,
#    'due': False,
#    'town': False,
#    'chat': False,
#    'colleg': False,
#    'moon': False,
#    'sigh': False,
#    'thx': False,
#    'followfriday': False,
#    'safe': False,
#    'stomach': False,
#    'green': False,
#    'citi': False,
#    'uk': False,
#    'kick': False,
#    'ahh': False,
#    'mac': False,
#    'park': False,
#    'worst': False,
#    'throat': False,
#    'scare': False,
#    'type': False,
#    'gorgeous': False,
#    'yummi': False,
#    'chanc': False,
#    'laptop': False,
#    'fast': False,
#    'drunk': False,
#    'cough': False,
#    'red': False,
#    'doesnt': False,
#    'angel': False,
#    'si': False,
#    'window': False,
#    'random': False,
#    'co': False,
#    'bbq': False,
#    'xxx': False,
#    'bro': False,
#    'met': False,
#    'support': False,
#    'easi': False,
#    'band': False,
#    'possibl': False,
#    'insid': False,
#    'tan': False,
#    'david': False,
#    'especi': False,
#    'em': False,
#    'moment': False,
#    'h': False,
#    'bet': False,
#    'block': False,
#    'small': False,
#    'parent': False,
#    'annoy': False,
#    'begin': False,
#    'dress': False,
#    'fb': False,
#    'laker': False,
#    'warm': False,
#    'english': False,
#    'expect': False,
#    'gym': False,
#    'wors': False,
#    'special': False,
#    'mess': False,
#    'havent': False,
#    'episod': False,
#    'wed': False,
#    'beat': False,
#    'lose': False,
#    'pizza': False,
#    'ppl': False,
#    'box': False,
#    'award': False,
#    'buddi': False,
#    'ach': False,
#    'except': False,
#    'touch': False,
#    'hill': False,
#    'date': False,
#    'lazi': False,
#    'surpris': False,
#    'wednesday': False,
#    'disappoint': False,
#    'cake': False,
#    'cup': False,
#    'gettin': False,
#    'join': False,
#    'magic': False,
#    'cd': False,
#    'celebr': False,
#    'power': False,
#    'chocol': False,
#    'f': False,
#    'round': False,
#    'leg': False,
#    'yr': False,
#    'piss': False,
#    'lie': False,
#    'shall': False,
#    'swim': False,
#    'chill': False,
#    'front': False,
#    'airport': False,
#    'project': False,
#    'shoe': False,
#    'dm': False,
#    'cream': False,
#    'son': False,
#    'woo': False,
#    'age': False,
#    'luv': False,
#    'plus': False,
#    'mtv': False,
#    'chicken': False,
#    'goodby': False,
#    'alright': False,
#    'point': False,
#    'ive': False,
#    'addict': False,
#    'light': False,
#    'black': False,
#    'card': False,
#    'bday': False,
#    'huge': False,
#    'histori': False,
#    'flight': False,
#    'camp': False,
#    'ahhh': False,
#    'babe': False,
#    'case': False,
#    'rd': False,
#    'hmm': False,
#    'promis': False,
#    'app': False,
#    'yep': False,
#    'present': False,
#    'dvd': False,
#    'voic': False,
#    'number': False,
#    'shame': False,
#    'confus': False,
#    'record': False,
#    'jonasbroth': False,
#    'issu': False,
#    'bike': False,
#    'woman': False,
#    'bird': False,
#    'longer': False,
#    'interview': False,
#    'fire': False,
#    'fantast': False,
#    'wash': False,
#    'finger': False,
#    'spent': False,
#    'j': False,
#    'tast': False,
#    'count': False,
#    'mum': False,
#    'speak': False,
#    'ruin': False,
#    'flu': False,
#    'appreci': False,
#    'cooki': False,
#    'quick': False,
#    'raini': False,
#    'bb': False,
#    'nope': False,
#    'sunshin': False,
#    'cover': False,
#    'film': False,
#    'thursday': False,
#    'knew': False,
#    'gave': False,
#    'felt': False,
#    'arriv': False,
#    'notic': False,
#    'watchin': False,
#    'terribl': False,
#    'bloodi': False,
#    'hilari': False,
#    'fact': False,
#    'deal': False,
#    'wast': False,
#    'hold': False,
#    'rather': False,
#    'tuesday': False,
#    'miley': False,
#    'stress': False,
#    'cancel': False,
#    'coz': False,
#    'note': False,
#    'gay': False,
#    'kitti': False,
#    'nose': False,
#    'shut': False,
#    'connect': False,
#    'exact': False,
#    'fli': False,
#    'remind': False,
#    'xoxo': False,
#    'matter': False,
#    'bum': False,
#    'view': False,
#    'extrem': False,
#    'storm': False,
#    'tip': False,
#    'scari': False,
#    'current': False,
#    'london': False,
#    'earlier': False,
#    'french': False,
#    'proud': False,
#    'vacat': False,
#    'ate': False,
#    'step': False,
#    'yup': False,
#    'fair': False,
#    'ahead': False,
#    'isnt': False,
#    'burnt': False,
#    'da': False,
#    'memori': False,
#    'twilight': False,
#    'white': False,
#    'screen': False,
#    'boyfriend': False,
#    'roll': False,
#    'smell': False,
#    'inspir': False,
#    'cousin': False,
#    'yum': False,
#    'bodi': False,
#    'slept': False,
#    'match': False,
#    'stand': False,
#    'vega': False,
#    'tom': False,
#    'gosh': False,
#    'uh': False,
#    'crash': False,
#    'shot': False,
#    'offer': False,
#    'pray': False,
#    'perhap': False,
#    'brain': False,
#    'slow': False,
#    'tummi': False,
#    'plz': False,
#    'death': False,
#    'sort': False,
#    'countri': False,
#    'nick': False,
#    'ear': False,
#    'mate': False,
#    'level': False,
#    'fight': False,
#    'freak': False,
#    'bus': False,
#    'ouch': False,
#    'hun': False,
#    'bar': False,
#    'meant': False,
#    'mail': False,
#    'fav': False,
#    'joe': False,
#    'mile': False,
#    'becom': False,
#    'state': False,
#    'event': False,
#    'delet': False,
#    'pink': False,
#    'itun': False,
#    'art': False,
#    'fam': False,
#    'sooooo': False,
#    'twit': False,
#    'direct': False,
#    'fit': False,
#    'hubbi': False,
#    'invit': False,
#    'guitar': False,
#    'mommi': False,
#    'chillin': False,
#    'blood': False,
#    'sale': False,
#    'tear': False,
#    'certain': False,
#    'daughter': False,
#    'fat': False,
#    'releas': False,
#    'everybodi': False,
#    'doin': False,
#    'wine': False,
#    'fake': False,
#    'hospit': False,
#    'design': False,
#    'ran': False,
#    'absolut': False,
#    'hmmm': False,
#    'product': False,
#    'shout': False,
#    'screw': False,
#    'fish': False,
#    'tweep': False,
#    'war': False,
#    'camera': False,
#    'exhaust': False,
#    'taken': False,
#    'search': False,
#    'manag': False,
#    'lame': False,
#    'shoot': False,
#    'lone': False,
#    'servic': False,
#    'bitch': False,
#    'australia': False,
#    'doctor': False,
#    'traffic': False,
#    'radio': False,
#    'wtf': False,
#    'assign': False,
#    'joke': False,
#    'practic': False,
#    'somewher': False,
#    'father': False,
#    'troubl': False,
#    'inde': False,
#    'bother': False,
#    'four': False,
#    'allow': False,
#    'shine': False,
#    'daddi': False,
#    'ball': False,
#    'vip': False,
#    'doubl': False,
#    'jus': False,
#    'nyc': False,
#    'ohh': False,
#    'bag': False,
#    'wife': False,
#    'child': False,
#    'aint': False,
#    'behind': False,
#    'fever': False,
#    'normal': False,
#    'mention': False,
#    'chick': False,
#    'control': False,
#    'act': False,
#    'south': False,
#    'sever': False,
#    'king': False,
#    'alot': False,
#    'low': False,
#    'experi': False,
#    'five': False,
#    'taylor': False,
#    'forev': False,
#    'cloth': False,
#    'laundri': False,
#    'brought': False,
#    'clear': False,
#    'copi': False,
#    'perform': False,
#    'chine': False,
#    'iran': False,
#    'creat': False,
#    'return': False,
#    'congratul': False,
#    'impress': False,
#    'build': False,
#    'whatev': False,
#    'posit': False,
#    'rip': False,
#    'somebodi': False,
#    'land': False,
#    'dure': False,
#    'kiss': False,
#    'hangov': False,
#    'compani': False,
#    'soup': False,
#    'blast': False,
#    'version': False,
#    'instal': False,
#    'web': False,
#    'futur': False,
#    'schedul': False,
#    'anim': False,
#    'peac': False,
#    'sell': False,
#    'men': False,
#    'sold': False,
#    'dunno': False,
#    'tweetdeck': False,
#    'young': False,
#    'profil': False,
#    'bath': False,
#    'wat': False,
#    'none': False,
#    'jon': False,
#    'huh': False,
#    'chicago': False,
#    'horribl': False,
#    'paint': False,
#    'avail': False,
#    'appl': False,
#    'sport': False,
#    'travel': False,
#    'main': False,
#    'pop': False,
#    'board': False,
#    'hahah': False,
#    'smoke': False,
#    'spam': False,
#    'sweeti': False,
#    'diet': False,
#    'entertain': False,
#    ...},
#   True)]

# %%
data['target'].value_counts()
# Out:
# 0    10044
# 4     9956
# Name: target, dtype: int64

# %% [markdown]
# ## Model Training

# %%
training, test = train_test_split(featuresets, test_size=0.2)

# %%
classifier = nltk.NaiveBayesClassifier.train(training)

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#                    upset = True            False : True   =     24.1 : 1.0
#                   throat = True            False : True   =     20.8 : 1.0
#                      ugh = True            False : True   =     19.5 : 1.0
#                   cancel = True            False : True   =     16.8 : 1.0
#                  terribl = True            False : True   =     14.8 : 1.0
#                   welcom = True             True : False  =     14.4 : 1.0
#                      www = True             True : False  =     14.3 : 1.0
#                 unfortun = True            False : True   =     13.6 : 1.0
#                    stuck = True            False : True   =     13.4 : 1.0
#                      sad = True            False : True   =     13.3 : 1.0

# %% [markdown]
# ## Model Evaluation

# %%
print("Classifier accuracy percent:",(nltk.classify.accuracy(classifier, test))*100.00)
# Out:
# Classifier accuracy percent: 72.39999999999999

# %% [markdown]
# ## Prediction
