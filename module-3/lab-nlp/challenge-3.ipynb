# %% [markdown]
# # Challenge 3 - Sentiment Analysis
#
# data: https://www.kaggle.com/kazanova/sentiment140
#
# example: https://www.kaggle.com/ngyptr/python-nltk-sentiment-analysis
#
# https://zablo.net/blog/post/twitter-sentiment-analysis-python-scikit-word2vec-nltk-xgboost
#
# https://www.laurentluce.com/posts/twitter-sentiment-analysis-using-python-and-nltk/

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

import nltk
from nltk.corpus import stopwords

from nltk.sentiment import SentimentAnalyzer

NUM_FEATURES = 5000
TEST_SET_SIZE = 20000

# %% [markdown]
# ## Load Data & Data Exploration

# %%
raw_data = pd.read_csv('Sentiment140.csv', encoding="ISO-8859-1")

# data = raw_data.head(10000).append(raw_data.tail(10000))

data = raw_data.sample(TEST_SET_SIZE)

# %%
data.target.value_counts()
# Out:
# 4    10008
# 0     9992
# Name: target, dtype: int64

# %%
data.isna().sum()
# Out:
# target    0
# id        0
# date      0
# flag      0
# user      0
# text      0
# dtype: int64

# %% [markdown]
# ## Cleaning
#
# * Generic text
#     * Missing values
#     * Special characters
#     * Numbers
# * Web text
#     * URLs
#     * HTML tags
# * Twitter-specific
#     * Twitter usernames with handler (optional)
#     * Hashtags (optional)
#
#
# ### References
#
# * Replace regex in substring: https://stackoverflow.com/questions/5658369/how-to-input-a-regex-in-string-replace

# %%
import re

def remove_by_regex(tweet, regexp):
        return re.sub(regexp, '', tweet)

def remove_url(tweet):
    return remove_by_regex(tweet, re.compile(r"http.?://[^\s]+[\s]?"))

def remove_special_char(tweet):
    return re.sub(r"[^a-zA-Z0-9 ]", " ", tweet)#add space placeholder

def remove_numbers(tweet):
    return remove_by_regex(tweet, re.compile(r"[1234567890]"))

def clean_up(tweet):
    tweet = remove_numbers(tweet)
    tweet = remove_url(tweet)
    tweet = remove_special_char(tweet)
    return tweet.lower().strip()

clean_up("@Ironhack's-#Q website 776-is http://ironhack.com [(2018)]")
# Out:
# 'ironhack s  q website  is'

# %%
data.text = data.text.apply(lambda tweet: clean_up(tweet))

data.head()
# Out:
#          target          id                          date      flag  \
# 268623        0  1989444030  Mon Jun 01 01:33:48 PDT 2009  NO_QUERY
# 279503        0  1991806787  Mon Jun 01 07:41:52 PDT 2009  NO_QUERY
# 730925        0  2263695952  Sun Jun 21 01:32:37 PDT 2009  NO_QUERY
# 1493559       4  2069529931  Sun Jun 07 16:02:47 PDT 2009  NO_QUERY
# 162603        0  1957583820  Fri May 29 00:57:36 PDT 2009  NO_QUERY
#
#                    user                                               text
# 268623     csummers1610  is hacked off that he s just found the perfect...
# 279503   enviromaverick                              overslept again today
# 730925       ginnielizz          a garbage truck just tried to run me over
# 1493559    PrincessofNY  if u can tell me what i m doin right no ill fo...
# 162603        shriggles  can t believe he has to wait till october to s...

# %% [markdown]
# ## Tokenization

# %%
from nltk.tokenize import word_tokenize

# https://www.nltk.org/api/nltk.tokenize.html
# tknzr = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True) 

data['text_processed'] = data.text.apply(lambda x: word_tokenize(x))

data.head()
# Out:
#          target          id                          date      flag  \
# 268623        0  1989444030  Mon Jun 01 01:33:48 PDT 2009  NO_QUERY
# 279503        0  1991806787  Mon Jun 01 07:41:52 PDT 2009  NO_QUERY
# 730925        0  2263695952  Sun Jun 21 01:32:37 PDT 2009  NO_QUERY
# 1493559       4  2069529931  Sun Jun 07 16:02:47 PDT 2009  NO_QUERY
# 162603        0  1957583820  Fri May 29 00:57:36 PDT 2009  NO_QUERY
#
#                    user                                               text  \
# 268623     csummers1610  is hacked off that he s just found the perfect...
# 279503   enviromaverick                              overslept again today
# 730925       ginnielizz          a garbage truck just tried to run me over
# 1493559    PrincessofNY  if u can tell me what i m doin right no ill fo...
# 162603        shriggles  can t believe he has to wait till october to s...
#
#                                             text_processed
# 268623   [is, hacked, off, that, he, s, just, found, th...
# 279503                           [overslept, again, today]
# 730925   [a, garbage, truck, just, tried, to, run, me, ...
# 1493559  [if, u, can, tell, me, what, i, m, doin, right...
# 162603   [can, t, believe, he, has, to, wait, till, oct...

# %% [markdown]
# ## Stemming & Lemmatization

# %%
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer

# Porter vs Snowball vs Lancaster
#https://stackoverflow.com/questions/10554052/what-are-the-major-differences-and-benefits-of-porter-and-lancaster-stemming-alg
stemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(tweet):
    return list(map(lambda s: lemmatizer.lemmatize(stemmer.stem(s)), tweet))

stem_and_lemmatize(['students', 'loves', 'tokenization', 'new york', 'ourselves', 'tuberculosis', 'was', 'liked'])
# Out:
# ['student',
#  'love',
#  'token',
#  'new york',
#  'ourselv',
#  'tuberculosi',
#  'wa',
#  'like']

# %%
data.text_processed = data.text_processed.apply(lambda s: stem_and_lemmatize(s))

data.head()
# Out:
#          target          id                          date      flag  \
# 268623        0  1989444030  Mon Jun 01 01:33:48 PDT 2009  NO_QUERY
# 279503        0  1991806787  Mon Jun 01 07:41:52 PDT 2009  NO_QUERY
# 730925        0  2263695952  Sun Jun 21 01:32:37 PDT 2009  NO_QUERY
# 1493559       4  2069529931  Sun Jun 07 16:02:47 PDT 2009  NO_QUERY
# 162603        0  1957583820  Fri May 29 00:57:36 PDT 2009  NO_QUERY
#
#                    user                                               text  \
# 268623     csummers1610  is hacked off that he s just found the perfect...
# 279503   enviromaverick                              overslept again today
# 730925       ginnielizz          a garbage truck just tried to run me over
# 1493559    PrincessofNY  if u can tell me what i m doin right no ill fo...
# 162603        shriggles  can t believe he has to wait till october to s...
#
#                                             text_processed
# 268623   [is, hack, off, that, he, s, just, found, the,...
# 279503                           [overslept, again, today]
# 730925    [a, garbag, truck, just, tri, to, run, me, over]
# 1493559  [if, u, can, tell, me, what, i, m, doin, right...
# 162603   [can, t, believ, he, ha, to, wait, till, octob...

# %% [markdown]
# ## Removing Stopwords

# %%
stopwords_list = stopwords.words("english")

# stopwords_list

# %%
def remove_stopwords(tweet):
    return [x for x in tweet if x not in stopwords_list]

data.text_processed = data.text_processed.apply(lambda s: remove_stopwords(s))

data.head()
# Out:
#          target          id                          date      flag  \
# 268623        0  1989444030  Mon Jun 01 01:33:48 PDT 2009  NO_QUERY
# 279503        0  1991806787  Mon Jun 01 07:41:52 PDT 2009  NO_QUERY
# 730925        0  2263695952  Sun Jun 21 01:32:37 PDT 2009  NO_QUERY
# 1493559       4  2069529931  Sun Jun 07 16:02:47 PDT 2009  NO_QUERY
# 162603        0  1957583820  Fri May 29 00:57:36 PDT 2009  NO_QUERY
#
#                    user                                               text  \
# 268623     csummers1610  is hacked off that he s just found the perfect...
# 279503   enviromaverick                              overslept again today
# 730925       ginnielizz          a garbage truck just tried to run me over
# 1493559    PrincessofNY  if u can tell me what i m doin right no ill fo...
# 162603        shriggles  can t believe he has to wait till october to s...
#
#                                             text_processed
# 268623   [hack, found, perfect, job, relev, degre, dead...
# 279503                                  [overslept, today]
# 730925                           [garbag, truck, tri, run]
# 1493559             [u, tell, doin, right, ill, follow, u]
# 162603   [believ, ha, wait, till, octob, see, quot, quo...

# %%
all_words = []

for index, value in data.text_processed.iteritems():
    if value not in all_words:
        all_words += value

top_features = list(nltk.FreqDist(all_words).keys())[:NUM_FEATURES]

# %%
top_features
# Out:
# ['hack',
#  'found',
#  'perfect',
#  'job',
#  'relev',
#  'degre',
#  'deadlin',
#  'wa',
#  'week',
#  'ago',
#  'overslept',
#  'today',
#  'garbag',
#  'truck',
#  'tri',
#  'run',
#  'u',
#  'tell',
#  'doin',
#  'right',
#  'ill',
#  'follow',
#  'believ',
#  'ha',
#  'wait',
#  'till',
#  'octob',
#  'see',
#  'quot',
#  'american',
#  'get',
#  'weekend',
#  'wish',
#  'new',
#  'sim',
#  'wasnt',
#  'expens',
#  'realli',
#  'need',
#  'play',
#  'prep',
#  'audit',
#  'time',
#  'go',
#  'home',
#  'dinner',
#  'someon',
#  'veri',
#  'special',
#  'bonddiiiieee',
#  'gooooo',
#  'stephda',
#  'bonestodust',
#  'yo',
#  'dude',
#  'feel',
#  'lone',
#  'hous',
#  'leav',
#  'group',
#  'love',
#  'fellowship',
#  'laptop',
#  'yahoooo',
#  'handshak',
#  'know',
#  'cassandra',
#  'physic',
#  'comput',
#  'hang',
#  'girl',
#  'guy',
#  'jessicahaley',
#  'trey',
#  'cinespac',
#  'rt',
#  'bbgirl',
#  'whi',
#  'tomorrrrrrooww',
#  'caus',
#  'like',
#  'dryforkpastor',
#  'hope',
#  'everyth',
#  'okay',
#  'oh',
#  'got',
#  'bye',
#  'twitter',
#  'tom',
#  'behind',
#  'mishab',
#  'heh',
#  'grab',
#  'could',
#  'probabl',
#  'becaus',
#  'fit',
#  'manschutz',
#  'yes',
#  'daniel',
#  'full',
#  'dual',
#  'refer',
#  'doubl',
#  'fulfil',
#  'post',
#  'note',
#  'backstreet',
#  'team',
#  'thank',
#  'blackbirdcorn',
#  'typewrit',
#  'action',
#  'limit',
#  'front',
#  'find',
#  'sew',
#  'machin',
#  'hard',
#  'rubbish',
#  'collect',
#  'tho',
#  'call',
#  'night',
#  'much',
#  'followfirday',
#  'best',
#  'tcot',
#  'unit',
#  'good',
#  'exhaust',
#  'though',
#  'ttunnel',
#  'thought',
#  'onli',
#  'two',
#  'charter',
#  'member',
#  'exclud',
#  'sad',
#  'absolut',
#  'hate',
#  'die',
#  'thirst',
#  'noooooo',
#  'juic',
#  'fridg',
#  'zeta',
#  'updat',
#  'hot',
#  'missyward',
#  'easi',
#  'cleveland',
#  'sport',
#  'fan',
#  'actual',
#  'piti',
#  'act',
#  'win',
#  'never',
#  'life',
#  'alway',
#  'biggest',
#  'mess',
#  'imagin',
#  'usual',
#  'doe',
#  'bad',
#  'shane',
#  'except',
#  'sorri',
#  'better',
#  'live',
#  'traffic',
#  'vacat',
#  'car',
#  'drive',
#  'crazi',
#  'german',
#  'agress',
#  'driver',
#  'miss',
#  'canada',
#  'kirstystil',
#  'come',
#  'lilgari',
#  'take',
#  'back',
#  'im',
#  'lost',
#  'lol',
#  'iphon',
#  'cool',
#  'app',
#  'expans',
#  'paid',
#  'euro',
#  'almost',
#  'canadian',
#  'shoulda',
#  'befor',
#  'still',
#  'give',
#  'away',
#  'ticket',
#  'foto',
#  'na',
#  'dan',
#  'sleeper',
#  'zula',
#  'friday',
#  'www',
#  'onesmallse',
#  'net',
#  'fall',
#  'eddi',
#  'pearl',
#  'jam',
#  'lt',
#  'old',
#  'myspac',
#  'com',
#  'zoe',
#  'suicid',
#  'wooooooo',
#  'looooov',
#  'concert',
#  'holi',
#  'shit',
#  'hour',
#  'ohar',
#  'shitti',
#  'internet',
#  'connect',
#  'world',
#  'didlik',
#  'monday',
#  'vibe',
#  'sexyjoy',
#  'hmm',
#  'gon',
#  'store',
#  'opend',
#  'bed',
#  'earli',
#  'prepar',
#  'day',
#  'write',
#  'paper',
#  'tomorrow',
#  'notoriousmsg',
#  'make',
#  'sure',
#  'shout',
#  'one',
#  'song',
#  'four',
#  'cinci',
#  'text',
#  'word',
#  'yay',
#  'sun',
#  'rehers',
#  'littl',
#  'sundayi',
#  'imageisfound',
#  'comment',
#  'dumbest',
#  'copi',
#  'ever',
#  'morn',
#  'laugh',
#  'close',
#  'truth',
#  'man',
#  'legend',
#  'druri',
#  'hotel',
#  'atlanta',
#  'head',
#  'va',
#  'last',
#  'via',
#  'addthi',
#  'spill',
#  'water',
#  'bottl',
#  'bookshelf',
#  'design',
#  'amp',
#  'italia',
#  'book',
#  'dri',
#  'jeswearsp',
#  'supercooltnicki',
#  'nope',
#  'piss',
#  'pant',
#  'lmao',
#  'suck',
#  'horribl',
#  'ugh',
#  'sick',
#  'wit',
#  'fever',
#  'check',
#  'blak',
#  'track',
#  'oramarecord',
#  'mortgag',
#  'yayyyyyi',
#  'dysarra',
#  'bitch',
#  'weight',
#  'surgeri',
#  'ear',
#  'disappoint',
#  'sleep',
#  'dgirlholland',
#  'first',
#  'year',
#  'line',
#  'stuff',
#  'might',
#  'well',
#  'tidi',
#  'room',
#  'sinc',
#  'alot',
#  'peep',
#  'bordersmedia',
#  'finish',
#  'read',
#  'chipkidd',
#  'chees',
#  'monkey',
#  'ellenlupton',
#  'think',
#  'type',
#  'ahaha',
#  'exam',
#  'left',
#  'bludgi',
#  'ipod',
#  'le',
#  'commut',
#  'interest',
#  'cristiano',
#  'deathdud',
#  'killingd',
#  'sara',
#  'sound',
#  'chillin',
#  'mommi',
#  'spring',
#  'terribl',
#  'jealous',
#  'besti',
#  'move',
#  'cali',
#  'boyfriend',
#  'sunshin',
#  'kathryn',
#  'mcfli',
#  'yeah',
#  'addict',
#  'relationship',
#  'yellow',
#  'colour',
#  'support',
#  'demil',
#  'hey',
#  'officialnjona',
#  'ihat',
#  'jalapeno',
#  'green',
#  'chicken',
#  'soup',
#  'mmmm',
#  'crawl',
#  'billion',
#  'carlsalazar',
#  'neither',
#  'way',
#  'start',
#  'mine',
#  'simplowdfan',
#  'sam',
#  'jon',
#  'prescott',
#  'ex',
#  'mike',
#  'want',
#  'ignor',
#  'studio',
#  'cours',
#  'rappin',
#  'present',
#  'gnuchri',
#  'damondcclark',
#  'eww',
#  'grit',
#  'eat',
#  'lot',
#  'frijol',
#  'jessidavi',
#  'work',
#  'mr',
#  'hows',
#  'ya',
#  'land',
#  'nellagirl',
#  'great',
#  'mind',
#  'alik',
#  'eh',
#  'cheth',
#  'problem',
#  'cant',
#  'pic',
#  'upload',
#  'downtown',
#  'mpls',
#  'chang',
#  'dushbag',
#  'total',
#  'orlando',
#  'long',
#  'forget',
#  'buzzedit',
#  'made',
#  'taylor',
#  'fansit',
#  'sort',
#  'lame',
#  'taylovelov',
#  'wont',
#  'let',
#  'profil',
#  'awak',
#  'restless',
#  'grayson',
#  'mariahmancha',
#  'say',
#  'groceri',
#  'mom',
#  'irl',
#  'school',
#  'kraftykoala',
#  'cut',
#  'bit',
#  'thin',
#  'xx',
#  'meerasapra',
#  'even',
#  'nice',
#  'dp',
#  'delta',
#  'angel',
#  'noe',
#  'next',
#  'shall',
#  'awesom',
#  'movi',
#  'bord',
#  'lovejamieo',
#  'haha',
#  'celebr',
#  'besid',
#  'jona',
#  'bros',
#  'ick',
#  'l',
#  'babi',
#  'lay',
#  'cuddl',
#  'watch',
#  'selena',
#  'shot',
#  'part',
#  'understand',
#  'account',
#  'financi',
#  'askelf',
#  'order',
#  'readi',
#  'coupon',
#  'code',
#  'expir',
#  'unicorn',
#  'bebo',
#  'awpoordidi',
#  'true',
#  'hahh',
#  'eager',
#  'happili',
#  'keep',
#  'held',
#  'enjoy',
#  'moment',
#  'rockshow',
#  'angi',
#  'pangiee',
#  'x',
#  'swear',
#  'bos',
#  'breath',
#  'secret',
#  'hear',
#  'todisappear',
#  'allow',
#  'twitterfail',
#  'beauti',
#  'bride',
#  'st',
#  'wed',
#  'dress',
#  'levywed',
#  'slambooutchea',
#  'gokeyisadouch',
#  'trench',
#  'douch',
#  'w',
#  'e',
#  'crazeegeekchick',
#  'knew',
#  'reason',
#  'def',
#  'guess',
#  'lie',
#  'hospit',
#  'smoke',
#  'neighbour',
#  'happi',
#  'mother',
#  'mistagrimm',
#  'wow',
#  'look',
#  'final',
#  'surfac',
#  'evonlegend',
#  'omg',
#  'plea',
#  'jonaslov',
#  'nawww',
#  'aiight',
#  'tomoro',
#  'anyway',
#  'xoxo',
#  'goodnight',
#  'inhabit',
#  'mikasound',
#  'frog',
#  'madwif',
#  'awww',
#  'soon',
#  'daughter',
#  'luck',
#  'prayer',
#  'answer',
#  'ask',
#  'friend',
#  'overwhelm',
#  'bless',
#  'happen',
#  'er',
#  'heidi',
#  'major',
#  'road',
#  'rash',
#  'possibl',
#  'shoulder',
#  'injuri',
#  'poor',
#  'mdlstudio',
#  'wordspray',
#  'aloha',
#  'alohahard',
#  'neilhimself',
#  'ani',
#  'burn',
#  'must',
#  'replac',
#  'sale',
#  'elecgeek',
#  'cherinj',
#  'hi',
#  'fun',
#  'jb',
#  'show',
#  'knight',
#  'thing',
#  'men',
#  'gene',
#  'simmon',
#  'urin',
#  'cake',
#  'talk',
#  'wet',
#  'melomayn',
#  'mannnnnn',
#  'steal',
#  'nadi',
#  'noflea',
#  'mention',
#  'srestal',
#  'thepet',
#  'fuckit',
#  'outsid',
#  'saragthatsm',
#  'trend',
#  'setter',
#  'registr',
#  'quiet',
#  'organ',
#  'backpack',
#  'shirt',
#  'badg',
#  'ngc',
#  'end',
#  'continu',
#  'idea',
#  'cancel',
#  'success',
#  'shcow',
#  'accid',
#  'era',
#  'jemappellebrttl',
#  'bruce',
#  'youuuu',
#  'thecashman',
#  'ah',
#  'meant',
#  'social',
#  'sunday',
#  'stay',
#  'radio',
#  'amaz',
#  'yesterday',
#  'purs',
#  'ahhhhh',
#  'erica',
#  'pegasusangel',
#  'courteen',
#  'noww',
#  'dockland',
#  'darllin',
#  'gatorad',
#  'g',
#  'commerci',
#  'simpl',
#  'energet',
#  'agenc',
#  'cater',
#  'client',
#  'medgirl',
#  'stephlovee',
#  'grate',
#  'hiccuupppss',
#  'missmari',
#  'jonasfanjad',
#  'cheer',
#  'paig',
#  'stickam',
#  'would',
#  'danielcaguin',
#  'asian',
#  'tiuri',
#  'repli',
#  'gott',
#  'sei',
#  'dank',
#  'aber',
#  'premuto',
#  'ist',
#  'gut',
#  'und',
#  'dawn',
#  'dead',
#  'ultim',
#  'aaand',
#  'folk',
#  'put',
#  'person',
#  'tv',
#  'gosselin',
#  'kid',
#  'credit',
#  'card',
#  'mean',
#  'saturday',
#  'due',
#  'cash',
#  'moneyyy',
#  'crash',
#  'afford',
#  'may',
#  'turn',
#  'hook',
#  'flow',
#  'anyth',
#  'worth',
#  'share',
#  'use',
#  'cpl',
#  'white',
#  'castl',
#  'burger',
#  'depress',
#  'celtic',
#  'whatttt',
#  'careeeeeee',
#  'ur',
#  'god',
#  'judg',
#  'pa',
#  'extremist',
#  'fang',
#  'pas',
#  'resolut',
#  'ban',
#  'sister',
#  'islam',
#  'humblemonst',
#  'ow',
#  'saad',
#  'caseyb',
#  'aw',
#  'wan',
#  'hooom',
#  'rain',
#  'nonsens',
#  'mood',
#  'shift',
#  'hole',
#  'fuck',
#  'lucki',
#  'hed',
#  'stuck',
#  'ugli',
#  'kill',
#  'suffer',
#  'regent',
#  'test',
#  'thursday',
#  'dont',
#  'amen',
#  'lolz',
#  'bbrathwait',
#  'season',
#  'offlin',
#  'five',
#  'episod',
#  'stop',
#  'complet',
#  'jonesin',
#  'sugarhustl',
#  'hehe',
#  'funni',
#  'epic',
#  'discoveri',
#  'channel',
#  'hella',
#  'record',
#  'lifeinthegalaxi',
#  'smile',
#  'face',
#  'send',
#  'light',
#  'wrong',
#  'quit',
#  'short',
#  'kosherwineguy',
#  'stupid',
#  'took',
#  'month',
#  'figur',
#  'without',
#  'intellig',
#  'sometim',
#  'judgment',
#  'isla',
#  'potipot',
#  'stylist',
#  'rememb',
#  'nick',
#  'name',
#  'sing',
#  'cold',
#  'outsiddeee',
#  'shell',
#  'shock',
#  'news',
#  'prof',
#  'rajeev',
#  'motwani',
#  'demis',
#  'mentor',
#  'pdwhite',
#  'alright',
#  'tire',
#  'voic',
#  'boy',
#  'hardcor',
#  'shoot',
#  'lidiaanain',
#  'visit',
#  'whynava',
#  'definit',
#  'eatslow',
#  'convo',
#  'privat',
#  'download',
#  'serious',
#  'summer',
#  'pool',
#  'listen',
#  'sip',
#  'cocktail',
#  'jordanknight',
#  'done',
#  'b',
#  'dancin',
#  'esp',
#  'nkotb',
#  'danc',
#  'hit',
#  'juli',
#  'recommend',
#  'hollywood',
#  'tweep',
#  'ticklemejoey',
#  'paul',
#  'paint',
#  'kitankhamun',
#  'unfortun',
#  'bookmarklet',
#  'anyon',
#  'trick',
#  'asleep',
#  'goddamnit',
#  'jack',
#  'bauer',
#  'photograph',
#  'famili',
#  'photo',
#  'clean',
#  'pretti',
#  'unusu',
#  'pressur',
#  'jesus',
#  'moon',
#  'goldieaz',
#  'chilli',
#  'ginthegin',
#  'past',
#  'minut',
#  'suppos',
#  'french',
#  'ballet',
#  'ieatx',
#  'repeat',
#  'garden',
#  'later',
#  'afternoon',
#  'paintboy',
#  'carwash',
#  'oil',
#  'kinda',
#  'ta',
#  'mariahjb',
#  'drink',
#  'drunk',
#  'cell',
#  'somet',
#  'el',
#  'stomach',
#  'sweetkellen',
#  'someth',
#  'research',
#  'dissert',
#  'least',
#  'disappear',
#  'shop',
#  'fakenico',
#  'samesi',
#  'fake',
#  'celeb',
#  'ftl',
#  'especi',
#  'seth',
#  'rogen',
#  'grr',
#  'everyon',
#  'lazi',
#  'asrisjon',
#  'tweeti',
#  'daivrawk',
#  'ubertwitt',
#  'rawk',
#  'companywoman',
#  'wooo',
#  'despit',
#  'frustrat',
#  'charger',
#  'ebay',
#  'charg',
#  'network',
#  'site',
#  'pay',
#  'dcpincus',
#  'laker',
#  'vacuum',
#  'ellen',
#  'rebeccaclair',
#  'alreadi',
#  'sell',
#  'mad',
#  'door',
#  'kiss',
#  'death',
#  'marissa',
#  'gtdk',
#  'nurs',
#  'class',
#  'practic',
#  'arm',
#  'bruis',
#  'bought',
#  'bunch',
#  'mandi',
#  'moor',
#  'forgot',
#  'product',
#  'descript',
#  'per',
#  'kestx',
#  'hip',
#  'hooray',
#  'begin',
#  'wonder',
#  'rosiege',
#  'lovee',
#  'heard',
#  'temptalia',
#  'nevermind',
#  'valid',
#  'thru',
#  'mistak',
#  'anxious',
#  'buy',
#  'artemi',
#  'neith',
#  'hon',
#  'muse',
#  'taunt',
#  'orbitaldiamond',
#  'count',
#  'bc',
#  'money',
#  'hollyhatesyou',
#  'asin',
#  'np',
#  'thanx',
#  'elisamarie',
#  'switchfoot',
#  'perform',
#  'cursedbyevil',
#  'hello',
#  'danger',
#  'stranger',
#  'went',
#  'acousticor',
#  'race',
#  'nd',
#  'birthday',
#  'parti',
#  'music',
#  'gallon',
#  'challeng',
#  'video',
#  'along',
#  'peopl',
#  'hurl',
#  'chibialfa',
#  'impress',
#  'slide',
#  'deck',
#  'nileylov',
#  'shes',
#  'hhahha',
#  'cri',
#  'emot',
#  'ayo',
#  'three',
#  'mafia',
#  'keri',
#  'hilson',
#  'gucci',
#  ...]

# %% [markdown]
# ## Building Features
#
# https://pythonprogramming.net/words-as-features-nltk-tutorial/
#
# https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/

# %%
def build_features(words):
    features = {}
    for w in top_features:
        features[w] = (w in words)
    return features

# %%
featuresets = []

for index, row in data.iterrows():
    featuresets.append((build_features(row['text_processed']), row['target']==4))

# %%
featuresets[:10]
# Out:
# [({'hack': True,
#    'found': True,
#    'perfect': True,
#    'job': True,
#    'relev': True,
#    'degre': True,
#    'deadlin': True,
#    'wa': True,
#    'week': True,
#    'ago': True,
#    'overslept': False,
#    'today': False,
#    'garbag': False,
#    'truck': False,
#    'tri': False,
#    'run': False,
#    'u': False,
#    'tell': False,
#    'doin': False,
#    'right': False,
#    'ill': False,
#    'follow': False,
#    'believ': False,
#    'ha': False,
#    'wait': False,
#    'till': False,
#    'octob': False,
#    'see': False,
#    'quot': False,
#    'american': False,
#    'get': False,
#    'weekend': False,
#    'wish': False,
#    'new': False,
#    'sim': False,
#    'wasnt': False,
#    'expens': False,
#    'realli': False,
#    'need': False,
#    'play': False,
#    'prep': False,
#    'audit': False,
#    'time': False,
#    'go': False,
#    'home': False,
#    'dinner': False,
#    'someon': False,
#    'veri': False,
#    'special': False,
#    'bonddiiiieee': False,
#    'gooooo': False,
#    'stephda': False,
#    'bonestodust': False,
#    'yo': False,
#    'dude': False,
#    'feel': False,
#    'lone': False,
#    'hous': False,
#    'leav': False,
#    'group': False,
#    'love': False,
#    'fellowship': False,
#    'laptop': False,
#    'yahoooo': False,
#    'handshak': False,
#    'know': False,
#    'cassandra': False,
#    'physic': False,
#    'comput': False,
#    'hang': False,
#    'girl': False,
#    'guy': False,
#    'jessicahaley': False,
#    'trey': False,
#    'cinespac': False,
#    'rt': False,
#    'bbgirl': False,
#    'whi': False,
#    'tomorrrrrrooww': False,
#    'caus': False,
#    'like': False,
#    'dryforkpastor': False,
#    'hope': False,
#    'everyth': False,
#    'okay': False,
#    'oh': False,
#    'got': False,
#    'bye': False,
#    'twitter': False,
#    'tom': False,
#    'behind': False,
#    'mishab': False,
#    'heh': False,
#    'grab': False,
#    'could': False,
#    'probabl': False,
#    'becaus': False,
#    'fit': False,
#    'manschutz': False,
#    'yes': False,
#    'daniel': False,
#    'full': False,
#    'dual': False,
#    'refer': False,
#    'doubl': False,
#    'fulfil': False,
#    'post': False,
#    'note': False,
#    'backstreet': False,
#    'team': False,
#    'thank': False,
#    'blackbirdcorn': False,
#    'typewrit': False,
#    'action': False,
#    'limit': False,
#    'front': False,
#    'find': False,
#    'sew': False,
#    'machin': False,
#    'hard': False,
#    'rubbish': False,
#    'collect': False,
#    'tho': False,
#    'call': False,
#    'night': False,
#    'much': False,
#    'followfirday': False,
#    'best': False,
#    'tcot': False,
#    'unit': False,
#    'good': False,
#    'exhaust': False,
#    'though': False,
#    'ttunnel': False,
#    'thought': False,
#    'onli': False,
#    'two': False,
#    'charter': False,
#    'member': False,
#    'exclud': False,
#    'sad': False,
#    'absolut': False,
#    'hate': False,
#    'die': False,
#    'thirst': False,
#    'noooooo': False,
#    'juic': False,
#    'fridg': False,
#    'zeta': False,
#    'updat': False,
#    'hot': False,
#    'missyward': False,
#    'easi': False,
#    'cleveland': False,
#    'sport': False,
#    'fan': False,
#    'actual': False,
#    'piti': False,
#    'act': False,
#    'win': False,
#    'never': False,
#    'life': False,
#    'alway': False,
#    'biggest': False,
#    'mess': False,
#    'imagin': False,
#    'usual': False,
#    'doe': False,
#    'bad': False,
#    'shane': False,
#    'except': False,
#    'sorri': False,
#    'better': False,
#    'live': False,
#    'traffic': False,
#    'vacat': False,
#    'car': False,
#    'drive': False,
#    'crazi': False,
#    'german': False,
#    'agress': False,
#    'driver': False,
#    'miss': False,
#    'canada': False,
#    'kirstystil': False,
#    'come': False,
#    'lilgari': False,
#    'take': False,
#    'back': False,
#    'im': False,
#    'lost': False,
#    'lol': False,
#    'iphon': False,
#    'cool': False,
#    'app': False,
#    'expans': False,
#    'paid': False,
#    'euro': False,
#    'almost': False,
#    'canadian': False,
#    'shoulda': False,
#    'befor': False,
#    'still': False,
#    'give': False,
#    'away': False,
#    'ticket': False,
#    'foto': False,
#    'na': False,
#    'dan': False,
#    'sleeper': False,
#    'zula': False,
#    'friday': False,
#    'www': False,
#    'onesmallse': False,
#    'net': False,
#    'fall': False,
#    'eddi': False,
#    'pearl': False,
#    'jam': False,
#    'lt': False,
#    'old': False,
#    'myspac': False,
#    'com': False,
#    'zoe': False,
#    'suicid': False,
#    'wooooooo': False,
#    'looooov': False,
#    'concert': False,
#    'holi': False,
#    'shit': False,
#    'hour': False,
#    'ohar': False,
#    'shitti': False,
#    'internet': False,
#    'connect': False,
#    'world': False,
#    'didlik': False,
#    'monday': False,
#    'vibe': False,
#    'sexyjoy': False,
#    'hmm': False,
#    'gon': False,
#    'store': False,
#    'opend': False,
#    'bed': False,
#    'earli': False,
#    'prepar': False,
#    'day': False,
#    'write': False,
#    'paper': False,
#    'tomorrow': False,
#    'notoriousmsg': False,
#    'make': False,
#    'sure': False,
#    'shout': False,
#    'one': False,
#    'song': False,
#    'four': False,
#    'cinci': False,
#    'text': False,
#    'word': False,
#    'yay': False,
#    'sun': False,
#    'rehers': False,
#    'littl': False,
#    'sundayi': False,
#    'imageisfound': False,
#    'comment': False,
#    'dumbest': False,
#    'copi': False,
#    'ever': False,
#    'morn': False,
#    'laugh': False,
#    'close': False,
#    'truth': False,
#    'man': False,
#    'legend': False,
#    'druri': False,
#    'hotel': False,
#    'atlanta': False,
#    'head': False,
#    'va': False,
#    'last': False,
#    'via': False,
#    'addthi': False,
#    'spill': False,
#    'water': False,
#    'bottl': False,
#    'bookshelf': False,
#    'design': False,
#    'amp': False,
#    'italia': False,
#    'book': False,
#    'dri': False,
#    'jeswearsp': False,
#    'supercooltnicki': False,
#    'nope': False,
#    'piss': False,
#    'pant': False,
#    'lmao': False,
#    'suck': False,
#    'horribl': False,
#    'ugh': False,
#    'sick': False,
#    'wit': False,
#    'fever': False,
#    'check': False,
#    'blak': False,
#    'track': False,
#    'oramarecord': False,
#    'mortgag': False,
#    'yayyyyyi': False,
#    'dysarra': False,
#    'bitch': False,
#    'weight': False,
#    'surgeri': False,
#    'ear': False,
#    'disappoint': False,
#    'sleep': False,
#    'dgirlholland': False,
#    'first': False,
#    'year': False,
#    'line': False,
#    'stuff': False,
#    'might': False,
#    'well': False,
#    'tidi': False,
#    'room': False,
#    'sinc': False,
#    'alot': False,
#    'peep': False,
#    'bordersmedia': False,
#    'finish': False,
#    'read': False,
#    'chipkidd': False,
#    'chees': False,
#    'monkey': False,
#    'ellenlupton': False,
#    'think': False,
#    'type': False,
#    'ahaha': False,
#    'exam': False,
#    'left': False,
#    'bludgi': False,
#    'ipod': False,
#    'le': False,
#    'commut': False,
#    'interest': False,
#    'cristiano': False,
#    'deathdud': False,
#    'killingd': False,
#    'sara': False,
#    'sound': False,
#    'chillin': False,
#    'mommi': False,
#    'spring': False,
#    'terribl': False,
#    'jealous': False,
#    'besti': False,
#    'move': False,
#    'cali': False,
#    'boyfriend': False,
#    'sunshin': False,
#    'kathryn': False,
#    'mcfli': False,
#    'yeah': False,
#    'addict': False,
#    'relationship': False,
#    'yellow': False,
#    'colour': False,
#    'support': False,
#    'demil': False,
#    'hey': False,
#    'officialnjona': False,
#    'ihat': False,
#    'jalapeno': False,
#    'green': False,
#    'chicken': False,
#    'soup': False,
#    'mmmm': False,
#    'crawl': False,
#    'billion': False,
#    'carlsalazar': False,
#    'neither': False,
#    'way': False,
#    'start': False,
#    'mine': False,
#    'simplowdfan': False,
#    'sam': False,
#    'jon': False,
#    'prescott': False,
#    'ex': False,
#    'mike': False,
#    'want': False,
#    'ignor': False,
#    'studio': False,
#    'cours': False,
#    'rappin': False,
#    'present': False,
#    'gnuchri': False,
#    'damondcclark': False,
#    'eww': False,
#    'grit': False,
#    'eat': False,
#    'lot': False,
#    'frijol': False,
#    'jessidavi': False,
#    'work': False,
#    'mr': False,
#    'hows': False,
#    'ya': False,
#    'land': False,
#    'nellagirl': False,
#    'great': False,
#    'mind': False,
#    'alik': False,
#    'eh': False,
#    'cheth': False,
#    'problem': False,
#    'cant': False,
#    'pic': False,
#    'upload': False,
#    'downtown': False,
#    'mpls': False,
#    'chang': False,
#    'dushbag': False,
#    'total': False,
#    'orlando': False,
#    'long': False,
#    'forget': False,
#    'buzzedit': False,
#    'made': False,
#    'taylor': False,
#    'fansit': False,
#    'sort': False,
#    'lame': False,
#    'taylovelov': False,
#    'wont': False,
#    'let': False,
#    'profil': False,
#    'awak': False,
#    'restless': False,
#    'grayson': False,
#    'mariahmancha': False,
#    'say': False,
#    'groceri': False,
#    'mom': False,
#    'irl': False,
#    'school': False,
#    'kraftykoala': False,
#    'cut': False,
#    'bit': False,
#    'thin': False,
#    'xx': False,
#    'meerasapra': False,
#    'even': False,
#    'nice': False,
#    'dp': False,
#    'delta': False,
#    'angel': False,
#    'noe': False,
#    'next': False,
#    'shall': False,
#    'awesom': False,
#    'movi': False,
#    'bord': False,
#    'lovejamieo': False,
#    'haha': False,
#    'celebr': False,
#    'besid': False,
#    'jona': False,
#    'bros': False,
#    'ick': False,
#    'l': False,
#    'babi': False,
#    'lay': False,
#    'cuddl': False,
#    'watch': False,
#    'selena': False,
#    'shot': False,
#    'part': False,
#    'understand': False,
#    'account': False,
#    'financi': False,
#    'askelf': False,
#    'order': False,
#    'readi': False,
#    'coupon': False,
#    'code': False,
#    'expir': False,
#    'unicorn': False,
#    'bebo': False,
#    'awpoordidi': False,
#    'true': False,
#    'hahh': False,
#    'eager': False,
#    'happili': False,
#    'keep': False,
#    'held': False,
#    'enjoy': False,
#    'moment': False,
#    'rockshow': False,
#    'angi': False,
#    'pangiee': False,
#    'x': False,
#    'swear': False,
#    'bos': False,
#    'breath': False,
#    'secret': False,
#    'hear': False,
#    'todisappear': False,
#    'allow': False,
#    'twitterfail': False,
#    'beauti': False,
#    'bride': False,
#    'st': False,
#    'wed': False,
#    'dress': False,
#    'levywed': False,
#    'slambooutchea': False,
#    'gokeyisadouch': False,
#    'trench': False,
#    'douch': False,
#    'w': False,
#    'e': False,
#    'crazeegeekchick': False,
#    'knew': False,
#    'reason': False,
#    'def': False,
#    'guess': False,
#    'lie': False,
#    'hospit': False,
#    'smoke': False,
#    'neighbour': False,
#    'happi': False,
#    'mother': False,
#    'mistagrimm': False,
#    'wow': False,
#    'look': False,
#    'final': False,
#    'surfac': False,
#    'evonlegend': False,
#    'omg': False,
#    'plea': False,
#    'jonaslov': False,
#    'nawww': False,
#    'aiight': False,
#    'tomoro': False,
#    'anyway': False,
#    'xoxo': False,
#    'goodnight': False,
#    'inhabit': False,
#    'mikasound': False,
#    'frog': False,
#    'madwif': False,
#    'awww': False,
#    'soon': False,
#    'daughter': False,
#    'luck': False,
#    'prayer': False,
#    'answer': False,
#    'ask': False,
#    'friend': False,
#    'overwhelm': False,
#    'bless': False,
#    'happen': False,
#    'er': False,
#    'heidi': False,
#    'major': False,
#    'road': False,
#    'rash': False,
#    'possibl': False,
#    'shoulder': False,
#    'injuri': False,
#    'poor': False,
#    'mdlstudio': False,
#    'wordspray': False,
#    'aloha': False,
#    'alohahard': False,
#    'neilhimself': False,
#    'ani': False,
#    'burn': False,
#    'must': False,
#    'replac': False,
#    'sale': False,
#    'elecgeek': False,
#    'cherinj': False,
#    'hi': False,
#    'fun': False,
#    'jb': False,
#    'show': False,
#    'knight': False,
#    'thing': False,
#    'men': False,
#    'gene': False,
#    'simmon': False,
#    'urin': False,
#    'cake': False,
#    'talk': False,
#    'wet': False,
#    'melomayn': False,
#    'mannnnnn': False,
#    'steal': False,
#    'nadi': False,
#    'noflea': False,
#    'mention': False,
#    'srestal': False,
#    'thepet': False,
#    'fuckit': False,
#    'outsid': False,
#    'saragthatsm': False,
#    'trend': False,
#    'setter': False,
#    'registr': False,
#    'quiet': False,
#    'organ': False,
#    'backpack': False,
#    'shirt': False,
#    'badg': False,
#    'ngc': False,
#    'end': False,
#    'continu': False,
#    'idea': False,
#    'cancel': False,
#    'success': False,
#    'shcow': False,
#    'accid': False,
#    'era': False,
#    'jemappellebrttl': False,
#    'bruce': False,
#    'youuuu': False,
#    'thecashman': False,
#    'ah': False,
#    'meant': False,
#    'social': False,
#    'sunday': False,
#    'stay': False,
#    'radio': False,
#    'amaz': False,
#    'yesterday': False,
#    'purs': False,
#    'ahhhhh': False,
#    'erica': False,
#    'pegasusangel': False,
#    'courteen': False,
#    'noww': False,
#    'dockland': False,
#    'darllin': False,
#    'gatorad': False,
#    'g': False,
#    'commerci': False,
#    'simpl': False,
#    'energet': False,
#    'agenc': False,
#    'cater': False,
#    'client': False,
#    'medgirl': False,
#    'stephlovee': False,
#    'grate': False,
#    'hiccuupppss': False,
#    'missmari': False,
#    'jonasfanjad': False,
#    'cheer': False,
#    'paig': False,
#    'stickam': False,
#    'would': False,
#    'danielcaguin': False,
#    'asian': False,
#    'tiuri': False,
#    'repli': False,
#    'gott': False,
#    'sei': False,
#    'dank': False,
#    'aber': False,
#    'premuto': False,
#    'ist': False,
#    'gut': False,
#    'und': False,
#    'dawn': False,
#    'dead': False,
#    'ultim': False,
#    'aaand': False,
#    'folk': False,
#    'put': False,
#    'person': False,
#    'tv': False,
#    'gosselin': False,
#    'kid': False,
#    'credit': False,
#    'card': False,
#    'mean': False,
#    'saturday': False,
#    'due': False,
#    'cash': False,
#    'moneyyy': False,
#    'crash': False,
#    'afford': False,
#    'may': False,
#    'turn': False,
#    'hook': False,
#    'flow': False,
#    'anyth': False,
#    'worth': False,
#    'share': False,
#    'use': False,
#    'cpl': False,
#    'white': False,
#    'castl': False,
#    'burger': False,
#    'depress': False,
#    'celtic': False,
#    'whatttt': False,
#    'careeeeeee': False,
#    'ur': False,
#    'god': False,
#    'judg': False,
#    'pa': False,
#    'extremist': False,
#    'fang': False,
#    'pas': False,
#    'resolut': False,
#    'ban': False,
#    'sister': False,
#    'islam': False,
#    'humblemonst': False,
#    'ow': False,
#    'saad': False,
#    'caseyb': False,
#    'aw': False,
#    'wan': False,
#    'hooom': False,
#    'rain': False,
#    'nonsens': False,
#    'mood': False,
#    'shift': False,
#    'hole': False,
#    'fuck': False,
#    'lucki': False,
#    'hed': False,
#    'stuck': False,
#    'ugli': False,
#    'kill': False,
#    'suffer': False,
#    'regent': False,
#    'test': False,
#    'thursday': False,
#    'dont': False,
#    'amen': False,
#    'lolz': False,
#    'bbrathwait': False,
#    'season': False,
#    'offlin': False,
#    'five': False,
#    'episod': False,
#    'stop': False,
#    'complet': False,
#    'jonesin': False,
#    'sugarhustl': False,
#    'hehe': False,
#    'funni': False,
#    'epic': False,
#    'discoveri': False,
#    'channel': False,
#    'hella': False,
#    'record': False,
#    'lifeinthegalaxi': False,
#    'smile': False,
#    'face': False,
#    'send': False,
#    'light': False,
#    'wrong': False,
#    'quit': False,
#    'short': False,
#    'kosherwineguy': False,
#    'stupid': False,
#    'took': False,
#    'month': False,
#    'figur': False,
#    'without': False,
#    'intellig': False,
#    'sometim': False,
#    'judgment': False,
#    'isla': False,
#    'potipot': False,
#    'stylist': False,
#    'rememb': False,
#    'nick': False,
#    'name': False,
#    'sing': False,
#    'cold': False,
#    'outsiddeee': False,
#    'shell': False,
#    'shock': False,
#    'news': False,
#    'prof': False,
#    'rajeev': False,
#    'motwani': False,
#    'demis': False,
#    'mentor': False,
#    'pdwhite': False,
#    'alright': False,
#    'tire': False,
#    'voic': False,
#    'boy': False,
#    'hardcor': False,
#    'shoot': False,
#    'lidiaanain': False,
#    'visit': False,
#    'whynava': False,
#    'definit': False,
#    'eatslow': False,
#    'convo': False,
#    'privat': False,
#    'download': False,
#    'serious': False,
#    'summer': False,
#    'pool': False,
#    'listen': False,
#    'sip': False,
#    'cocktail': False,
#    'jordanknight': False,
#    'done': False,
#    'b': False,
#    'dancin': False,
#    'esp': False,
#    'nkotb': False,
#    'danc': False,
#    'hit': False,
#    'juli': False,
#    'recommend': False,
#    'hollywood': False,
#    'tweep': False,
#    'ticklemejoey': False,
#    'paul': False,
#    'paint': False,
#    'kitankhamun': False,
#    'unfortun': False,
#    'bookmarklet': False,
#    'anyon': False,
#    'trick': False,
#    'asleep': False,
#    'goddamnit': False,
#    'jack': False,
#    'bauer': False,
#    'photograph': False,
#    'famili': False,
#    'photo': False,
#    'clean': False,
#    'pretti': False,
#    'unusu': False,
#    'pressur': False,
#    'jesus': False,
#    'moon': False,
#    'goldieaz': False,
#    'chilli': False,
#    'ginthegin': False,
#    'past': False,
#    'minut': False,
#    'suppos': False,
#    'french': False,
#    'ballet': False,
#    'ieatx': False,
#    'repeat': False,
#    'garden': False,
#    'later': False,
#    'afternoon': False,
#    'paintboy': False,
#    'carwash': False,
#    'oil': False,
#    'kinda': False,
#    'ta': False,
#    'mariahjb': False,
#    'drink': False,
#    'drunk': False,
#    'cell': False,
#    'somet': False,
#    'el': False,
#    'stomach': False,
#    'sweetkellen': False,
#    'someth': False,
#    'research': False,
#    'dissert': False,
#    'least': False,
#    'disappear': False,
#    'shop': False,
#    'fakenico': False,
#    'samesi': False,
#    'fake': False,
#    'celeb': False,
#    'ftl': False,
#    'especi': False,
#    'seth': False,
#    'rogen': False,
#    'grr': False,
#    'everyon': False,
#    'lazi': False,
#    'asrisjon': False,
#    'tweeti': False,
#    'daivrawk': False,
#    'ubertwitt': False,
#    'rawk': False,
#    'companywoman': False,
#    'wooo': False,
#    'despit': False,
#    'frustrat': False,
#    'charger': False,
#    'ebay': False,
#    'charg': False,
#    'network': False,
#    'site': False,
#    'pay': False,
#    'dcpincus': False,
#    'laker': False,
#    'vacuum': False,
#    'ellen': False,
#    'rebeccaclair': False,
#    'alreadi': False,
#    'sell': False,
#    'mad': False,
#    'door': False,
#    'kiss': False,
#    'death': False,
#    'marissa': False,
#    'gtdk': False,
#    'nurs': False,
#    'class': False,
#    'practic': False,
#    'arm': False,
#    'bruis': False,
#    'bought': False,
#    'bunch': False,
#    'mandi': False,
#    'moor': False,
#    'forgot': False,
#    'product': False,
#    'descript': False,
#    'per': False,
#    'kestx': False,
#    'hip': False,
#    'hooray': False,
#    'begin': False,
#    'wonder': False,
#    'rosiege': False,
#    'lovee': False,
#    'heard': False,
#    'temptalia': False,
#    'nevermind': False,
#    'valid': False,
#    'thru': False,
#    'mistak': False,
#    'anxious': False,
#    'buy': False,
#    'artemi': False,
#    'neith': False,
#    'hon': False,
#    'muse': False,
#    'taunt': False,
#    'orbitaldiamond': False,
#    'count': False,
#    'bc': False,
#    'money': False,
#    'hollyhatesyou': False,
#    'asin': False,
#    'np': False,
#    'thanx': False,
#    'elisamarie': False,
#    'switchfoot': False,
#    'perform': False,
#    'cursedbyevil': False,
#    'hello': False,
#    'danger': False,
#    'stranger': False,
#    'went': False,
#    'acousticor': False,
#    'race': False,
#    'nd': False,
#    'birthday': False,
#    'parti': False,
#    'music': False,
#    'gallon': False,
#    'challeng': False,
#    'video': False,
#    'along': False,
#    'peopl': False,
#    'hurl': False,
#    'chibialfa': False,
#    'impress': False,
#    'slide': False,
#    'deck': False,
#    'nileylov': False,
#    'shes': False,
#    'hhahha': False,
#    'cri': False,
#    'emot': False,
#    'ayo': False,
#    'three': False,
#    'mafia': False,
#    'keri': False,
#    'hilson': False,
#    'gucci': False,
#    ...},
#   False),
#  ({'hack': False,
#    'found': False,
#    'perfect': False,
#    'job': False,
#    'relev': False,
#    'degre': False,
#    'deadlin': False,
#    'wa': False,
#    'week': False,
#    'ago': False,
#    'overslept': True,
#    'today': True,
#    'garbag': False,
#    'truck': False,
#    'tri': False,
#    'run': False,
#    'u': False,
#    'tell': False,
#    'doin': False,
#    'right': False,
#    'ill': False,
#    'follow': False,
#    'believ': False,
#    'ha': False,
#    'wait': False,
#    'till': False,
#    'octob': False,
#    'see': False,
#    'quot': False,
#    'american': False,
#    'get': False,
#    'weekend': False,
#    'wish': False,
#    'new': False,
#    'sim': False,
#    'wasnt': False,
#    'expens': False,
#    'realli': False,
#    'need': False,
#    'play': False,
#    'prep': False,
#    'audit': False,
#    'time': False,
#    'go': False,
#    'home': False,
#    'dinner': False,
#    'someon': False,
#    'veri': False,
#    'special': False,
#    'bonddiiiieee': False,
#    'gooooo': False,
#    'stephda': False,
#    'bonestodust': False,
#    'yo': False,
#    'dude': False,
#    'feel': False,
#    'lone': False,
#    'hous': False,
#    'leav': False,
#    'group': False,
#    'love': False,
#    'fellowship': False,
#    'laptop': False,
#    'yahoooo': False,
#    'handshak': False,
#    'know': False,
#    'cassandra': False,
#    'physic': False,
#    'comput': False,
#    'hang': False,
#    'girl': False,
#    'guy': False,
#    'jessicahaley': False,
#    'trey': False,
#    'cinespac': False,
#    'rt': False,
#    'bbgirl': False,
#    'whi': False,
#    'tomorrrrrrooww': False,
#    'caus': False,
#    'like': False,
#    'dryforkpastor': False,
#    'hope': False,
#    'everyth': False,
#    'okay': False,
#    'oh': False,
#    'got': False,
#    'bye': False,
#    'twitter': False,
#    'tom': False,
#    'behind': False,
#    'mishab': False,
#    'heh': False,
#    'grab': False,
#    'could': False,
#    'probabl': False,
#    'becaus': False,
#    'fit': False,
#    'manschutz': False,
#    'yes': False,
#    'daniel': False,
#    'full': False,
#    'dual': False,
#    'refer': False,
#    'doubl': False,
#    'fulfil': False,
#    'post': False,
#    'note': False,
#    'backstreet': False,
#    'team': False,
#    'thank': False,
#    'blackbirdcorn': False,
#    'typewrit': False,
#    'action': False,
#    'limit': False,
#    'front': False,
#    'find': False,
#    'sew': False,
#    'machin': False,
#    'hard': False,
#    'rubbish': False,
#    'collect': False,
#    'tho': False,
#    'call': False,
#    'night': False,
#    'much': False,
#    'followfirday': False,
#    'best': False,
#    'tcot': False,
#    'unit': False,
#    'good': False,
#    'exhaust': False,
#    'though': False,
#    'ttunnel': False,
#    'thought': False,
#    'onli': False,
#    'two': False,
#    'charter': False,
#    'member': False,
#    'exclud': False,
#    'sad': False,
#    'absolut': False,
#    'hate': False,
#    'die': False,
#    'thirst': False,
#    'noooooo': False,
#    'juic': False,
#    'fridg': False,
#    'zeta': False,
#    'updat': False,
#    'hot': False,
#    'missyward': False,
#    'easi': False,
#    'cleveland': False,
#    'sport': False,
#    'fan': False,
#    'actual': False,
#    'piti': False,
#    'act': False,
#    'win': False,
#    'never': False,
#    'life': False,
#    'alway': False,
#    'biggest': False,
#    'mess': False,
#    'imagin': False,
#    'usual': False,
#    'doe': False,
#    'bad': False,
#    'shane': False,
#    'except': False,
#    'sorri': False,
#    'better': False,
#    'live': False,
#    'traffic': False,
#    'vacat': False,
#    'car': False,
#    'drive': False,
#    'crazi': False,
#    'german': False,
#    'agress': False,
#    'driver': False,
#    'miss': False,
#    'canada': False,
#    'kirstystil': False,
#    'come': False,
#    'lilgari': False,
#    'take': False,
#    'back': False,
#    'im': False,
#    'lost': False,
#    'lol': False,
#    'iphon': False,
#    'cool': False,
#    'app': False,
#    'expans': False,
#    'paid': False,
#    'euro': False,
#    'almost': False,
#    'canadian': False,
#    'shoulda': False,
#    'befor': False,
#    'still': False,
#    'give': False,
#    'away': False,
#    'ticket': False,
#    'foto': False,
#    'na': False,
#    'dan': False,
#    'sleeper': False,
#    'zula': False,
#    'friday': False,
#    'www': False,
#    'onesmallse': False,
#    'net': False,
#    'fall': False,
#    'eddi': False,
#    'pearl': False,
#    'jam': False,
#    'lt': False,
#    'old': False,
#    'myspac': False,
#    'com': False,
#    'zoe': False,
#    'suicid': False,
#    'wooooooo': False,
#    'looooov': False,
#    'concert': False,
#    'holi': False,
#    'shit': False,
#    'hour': False,
#    'ohar': False,
#    'shitti': False,
#    'internet': False,
#    'connect': False,
#    'world': False,
#    'didlik': False,
#    'monday': False,
#    'vibe': False,
#    'sexyjoy': False,
#    'hmm': False,
#    'gon': False,
#    'store': False,
#    'opend': False,
#    'bed': False,
#    'earli': False,
#    'prepar': False,
#    'day': False,
#    'write': False,
#    'paper': False,
#    'tomorrow': False,
#    'notoriousmsg': False,
#    'make': False,
#    'sure': False,
#    'shout': False,
#    'one': False,
#    'song': False,
#    'four': False,
#    'cinci': False,
#    'text': False,
#    'word': False,
#    'yay': False,
#    'sun': False,
#    'rehers': False,
#    'littl': False,
#    'sundayi': False,
#    'imageisfound': False,
#    'comment': False,
#    'dumbest': False,
#    'copi': False,
#    'ever': False,
#    'morn': False,
#    'laugh': False,
#    'close': False,
#    'truth': False,
#    'man': False,
#    'legend': False,
#    'druri': False,
#    'hotel': False,
#    'atlanta': False,
#    'head': False,
#    'va': False,
#    'last': False,
#    'via': False,
#    'addthi': False,
#    'spill': False,
#    'water': False,
#    'bottl': False,
#    'bookshelf': False,
#    'design': False,
#    'amp': False,
#    'italia': False,
#    'book': False,
#    'dri': False,
#    'jeswearsp': False,
#    'supercooltnicki': False,
#    'nope': False,
#    'piss': False,
#    'pant': False,
#    'lmao': False,
#    'suck': False,
#    'horribl': False,
#    'ugh': False,
#    'sick': False,
#    'wit': False,
#    'fever': False,
#    'check': False,
#    'blak': False,
#    'track': False,
#    'oramarecord': False,
#    'mortgag': False,
#    'yayyyyyi': False,
#    'dysarra': False,
#    'bitch': False,
#    'weight': False,
#    'surgeri': False,
#    'ear': False,
#    'disappoint': False,
#    'sleep': False,
#    'dgirlholland': False,
#    'first': False,
#    'year': False,
#    'line': False,
#    'stuff': False,
#    'might': False,
#    'well': False,
#    'tidi': False,
#    'room': False,
#    'sinc': False,
#    'alot': False,
#    'peep': False,
#    'bordersmedia': False,
#    'finish': False,
#    'read': False,
#    'chipkidd': False,
#    'chees': False,
#    'monkey': False,
#    'ellenlupton': False,
#    'think': False,
#    'type': False,
#    'ahaha': False,
#    'exam': False,
#    'left': False,
#    'bludgi': False,
#    'ipod': False,
#    'le': False,
#    'commut': False,
#    'interest': False,
#    'cristiano': False,
#    'deathdud': False,
#    'killingd': False,
#    'sara': False,
#    'sound': False,
#    'chillin': False,
#    'mommi': False,
#    'spring': False,
#    'terribl': False,
#    'jealous': False,
#    'besti': False,
#    'move': False,
#    'cali': False,
#    'boyfriend': False,
#    'sunshin': False,
#    'kathryn': False,
#    'mcfli': False,
#    'yeah': False,
#    'addict': False,
#    'relationship': False,
#    'yellow': False,
#    'colour': False,
#    'support': False,
#    'demil': False,
#    'hey': False,
#    'officialnjona': False,
#    'ihat': False,
#    'jalapeno': False,
#    'green': False,
#    'chicken': False,
#    'soup': False,
#    'mmmm': False,
#    'crawl': False,
#    'billion': False,
#    'carlsalazar': False,
#    'neither': False,
#    'way': False,
#    'start': False,
#    'mine': False,
#    'simplowdfan': False,
#    'sam': False,
#    'jon': False,
#    'prescott': False,
#    'ex': False,
#    'mike': False,
#    'want': False,
#    'ignor': False,
#    'studio': False,
#    'cours': False,
#    'rappin': False,
#    'present': False,
#    'gnuchri': False,
#    'damondcclark': False,
#    'eww': False,
#    'grit': False,
#    'eat': False,
#    'lot': False,
#    'frijol': False,
#    'jessidavi': False,
#    'work': False,
#    'mr': False,
#    'hows': False,
#    'ya': False,
#    'land': False,
#    'nellagirl': False,
#    'great': False,
#    'mind': False,
#    'alik': False,
#    'eh': False,
#    'cheth': False,
#    'problem': False,
#    'cant': False,
#    'pic': False,
#    'upload': False,
#    'downtown': False,
#    'mpls': False,
#    'chang': False,
#    'dushbag': False,
#    'total': False,
#    'orlando': False,
#    'long': False,
#    'forget': False,
#    'buzzedit': False,
#    'made': False,
#    'taylor': False,
#    'fansit': False,
#    'sort': False,
#    'lame': False,
#    'taylovelov': False,
#    'wont': False,
#    'let': False,
#    'profil': False,
#    'awak': False,
#    'restless': False,
#    'grayson': False,
#    'mariahmancha': False,
#    'say': False,
#    'groceri': False,
#    'mom': False,
#    'irl': False,
#    'school': False,
#    'kraftykoala': False,
#    'cut': False,
#    'bit': False,
#    'thin': False,
#    'xx': False,
#    'meerasapra': False,
#    'even': False,
#    'nice': False,
#    'dp': False,
#    'delta': False,
#    'angel': False,
#    'noe': False,
#    'next': False,
#    'shall': False,
#    'awesom': False,
#    'movi': False,
#    'bord': False,
#    'lovejamieo': False,
#    'haha': False,
#    'celebr': False,
#    'besid': False,
#    'jona': False,
#    'bros': False,
#    'ick': False,
#    'l': False,
#    'babi': False,
#    'lay': False,
#    'cuddl': False,
#    'watch': False,
#    'selena': False,
#    'shot': False,
#    'part': False,
#    'understand': False,
#    'account': False,
#    'financi': False,
#    'askelf': False,
#    'order': False,
#    'readi': False,
#    'coupon': False,
#    'code': False,
#    'expir': False,
#    'unicorn': False,
#    'bebo': False,
#    'awpoordidi': False,
#    'true': False,
#    'hahh': False,
#    'eager': False,
#    'happili': False,
#    'keep': False,
#    'held': False,
#    'enjoy': False,
#    'moment': False,
#    'rockshow': False,
#    'angi': False,
#    'pangiee': False,
#    'x': False,
#    'swear': False,
#    'bos': False,
#    'breath': False,
#    'secret': False,
#    'hear': False,
#    'todisappear': False,
#    'allow': False,
#    'twitterfail': False,
#    'beauti': False,
#    'bride': False,
#    'st': False,
#    'wed': False,
#    'dress': False,
#    'levywed': False,
#    'slambooutchea': False,
#    'gokeyisadouch': False,
#    'trench': False,
#    'douch': False,
#    'w': False,
#    'e': False,
#    'crazeegeekchick': False,
#    'knew': False,
#    'reason': False,
#    'def': False,
#    'guess': False,
#    'lie': False,
#    'hospit': False,
#    'smoke': False,
#    'neighbour': False,
#    'happi': False,
#    'mother': False,
#    'mistagrimm': False,
#    'wow': False,
#    'look': False,
#    'final': False,
#    'surfac': False,
#    'evonlegend': False,
#    'omg': False,
#    'plea': False,
#    'jonaslov': False,
#    'nawww': False,
#    'aiight': False,
#    'tomoro': False,
#    'anyway': False,
#    'xoxo': False,
#    'goodnight': False,
#    'inhabit': False,
#    'mikasound': False,
#    'frog': False,
#    'madwif': False,
#    'awww': False,
#    'soon': False,
#    'daughter': False,
#    'luck': False,
#    'prayer': False,
#    'answer': False,
#    'ask': False,
#    'friend': False,
#    'overwhelm': False,
#    'bless': False,
#    'happen': False,
#    'er': False,
#    'heidi': False,
#    'major': False,
#    'road': False,
#    'rash': False,
#    'possibl': False,
#    'shoulder': False,
#    'injuri': False,
#    'poor': False,
#    'mdlstudio': False,
#    'wordspray': False,
#    'aloha': False,
#    'alohahard': False,
#    'neilhimself': False,
#    'ani': False,
#    'burn': False,
#    'must': False,
#    'replac': False,
#    'sale': False,
#    'elecgeek': False,
#    'cherinj': False,
#    'hi': False,
#    'fun': False,
#    'jb': False,
#    'show': False,
#    'knight': False,
#    'thing': False,
#    'men': False,
#    'gene': False,
#    'simmon': False,
#    'urin': False,
#    'cake': False,
#    'talk': False,
#    'wet': False,
#    'melomayn': False,
#    'mannnnnn': False,
#    'steal': False,
#    'nadi': False,
#    'noflea': False,
#    'mention': False,
#    'srestal': False,
#    'thepet': False,
#    'fuckit': False,
#    'outsid': False,
#    'saragthatsm': False,
#    'trend': False,
#    'setter': False,
#    'registr': False,
#    'quiet': False,
#    'organ': False,
#    'backpack': False,
#    'shirt': False,
#    'badg': False,
#    'ngc': False,
#    'end': False,
#    'continu': False,
#    'idea': False,
#    'cancel': False,
#    'success': False,
#    'shcow': False,
#    'accid': False,
#    'era': False,
#    'jemappellebrttl': False,
#    'bruce': False,
#    'youuuu': False,
#    'thecashman': False,
#    'ah': False,
#    'meant': False,
#    'social': False,
#    'sunday': False,
#    'stay': False,
#    'radio': False,
#    'amaz': False,
#    'yesterday': False,
#    'purs': False,
#    'ahhhhh': False,
#    'erica': False,
#    'pegasusangel': False,
#    'courteen': False,
#    'noww': False,
#    'dockland': False,
#    'darllin': False,
#    'gatorad': False,
#    'g': False,
#    'commerci': False,
#    'simpl': False,
#    'energet': False,
#    'agenc': False,
#    'cater': False,
#    'client': False,
#    'medgirl': False,
#    'stephlovee': False,
#    'grate': False,
#    'hiccuupppss': False,
#    'missmari': False,
#    'jonasfanjad': False,
#    'cheer': False,
#    'paig': False,
#    'stickam': False,
#    'would': False,
#    'danielcaguin': False,
#    'asian': False,
#    'tiuri': False,
#    'repli': False,
#    'gott': False,
#    'sei': False,
#    'dank': False,
#    'aber': False,
#    'premuto': False,
#    'ist': False,
#    'gut': False,
#    'und': False,
#    'dawn': False,
#    'dead': False,
#    'ultim': False,
#    'aaand': False,
#    'folk': False,
#    'put': False,
#    'person': False,
#    'tv': False,
#    'gosselin': False,
#    'kid': False,
#    'credit': False,
#    'card': False,
#    'mean': False,
#    'saturday': False,
#    'due': False,
#    'cash': False,
#    'moneyyy': False,
#    'crash': False,
#    'afford': False,
#    'may': False,
#    'turn': False,
#    'hook': False,
#    'flow': False,
#    'anyth': False,
#    'worth': False,
#    'share': False,
#    'use': False,
#    'cpl': False,
#    'white': False,
#    'castl': False,
#    'burger': False,
#    'depress': False,
#    'celtic': False,
#    'whatttt': False,
#    'careeeeeee': False,
#    'ur': False,
#    'god': False,
#    'judg': False,
#    'pa': False,
#    'extremist': False,
#    'fang': False,
#    'pas': False,
#    'resolut': False,
#    'ban': False,
#    'sister': False,
#    'islam': False,
#    'humblemonst': False,
#    'ow': False,
#    'saad': False,
#    'caseyb': False,
#    'aw': False,
#    'wan': False,
#    'hooom': False,
#    'rain': False,
#    'nonsens': False,
#    'mood': False,
#    'shift': False,
#    'hole': False,
#    'fuck': False,
#    'lucki': False,
#    'hed': False,
#    'stuck': False,
#    'ugli': False,
#    'kill': False,
#    'suffer': False,
#    'regent': False,
#    'test': False,
#    'thursday': False,
#    'dont': False,
#    'amen': False,
#    'lolz': False,
#    'bbrathwait': False,
#    'season': False,
#    'offlin': False,
#    'five': False,
#    'episod': False,
#    'stop': False,
#    'complet': False,
#    'jonesin': False,
#    'sugarhustl': False,
#    'hehe': False,
#    'funni': False,
#    'epic': False,
#    'discoveri': False,
#    'channel': False,
#    'hella': False,
#    'record': False,
#    'lifeinthegalaxi': False,
#    'smile': False,
#    'face': False,
#    'send': False,
#    'light': False,
#    'wrong': False,
#    'quit': False,
#    'short': False,
#    'kosherwineguy': False,
#    'stupid': False,
#    'took': False,
#    'month': False,
#    'figur': False,
#    'without': False,
#    'intellig': False,
#    'sometim': False,
#    'judgment': False,
#    'isla': False,
#    'potipot': False,
#    'stylist': False,
#    'rememb': False,
#    'nick': False,
#    'name': False,
#    'sing': False,
#    'cold': False,
#    'outsiddeee': False,
#    'shell': False,
#    'shock': False,
#    'news': False,
#    'prof': False,
#    'rajeev': False,
#    'motwani': False,
#    'demis': False,
#    'mentor': False,
#    'pdwhite': False,
#    'alright': False,
#    'tire': False,
#    'voic': False,
#    'boy': False,
#    'hardcor': False,
#    'shoot': False,
#    'lidiaanain': False,
#    'visit': False,
#    'whynava': False,
#    'definit': False,
#    'eatslow': False,
#    'convo': False,
#    'privat': False,
#    'download': False,
#    'serious': False,
#    'summer': False,
#    'pool': False,
#    'listen': False,
#    'sip': False,
#    'cocktail': False,
#    'jordanknight': False,
#    'done': False,
#    'b': False,
#    'dancin': False,
#    'esp': False,
#    'nkotb': False,
#    'danc': False,
#    'hit': False,
#    'juli': False,
#    'recommend': False,
#    'hollywood': False,
#    'tweep': False,
#    'ticklemejoey': False,
#    'paul': False,
#    'paint': False,
#    'kitankhamun': False,
#    'unfortun': False,
#    'bookmarklet': False,
#    'anyon': False,
#    'trick': False,
#    'asleep': False,
#    'goddamnit': False,
#    'jack': False,
#    'bauer': False,
#    'photograph': False,
#    'famili': False,
#    'photo': False,
#    'clean': False,
#    'pretti': False,
#    'unusu': False,
#    'pressur': False,
#    'jesus': False,
#    'moon': False,
#    'goldieaz': False,
#    'chilli': False,
#    'ginthegin': False,
#    'past': False,
#    'minut': False,
#    'suppos': False,
#    'french': False,
#    'ballet': False,
#    'ieatx': False,
#    'repeat': False,
#    'garden': False,
#    'later': False,
#    'afternoon': False,
#    'paintboy': False,
#    'carwash': False,
#    'oil': False,
#    'kinda': False,
#    'ta': False,
#    'mariahjb': False,
#    'drink': False,
#    'drunk': False,
#    'cell': False,
#    'somet': False,
#    'el': False,
#    'stomach': False,
#    'sweetkellen': False,
#    'someth': False,
#    'research': False,
#    'dissert': False,
#    'least': False,
#    'disappear': False,
#    'shop': False,
#    'fakenico': False,
#    'samesi': False,
#    'fake': False,
#    'celeb': False,
#    'ftl': False,
#    'especi': False,
#    'seth': False,
#    'rogen': False,
#    'grr': False,
#    'everyon': False,
#    'lazi': False,
#    'asrisjon': False,
#    'tweeti': False,
#    'daivrawk': False,
#    'ubertwitt': False,
#    'rawk': False,
#    'companywoman': False,
#    'wooo': False,
#    'despit': False,
#    'frustrat': False,
#    'charger': False,
#    'ebay': False,
#    'charg': False,
#    'network': False,
#    'site': False,
#    'pay': False,
#    'dcpincus': False,
#    'laker': False,
#    'vacuum': False,
#    'ellen': False,
#    'rebeccaclair': False,
#    'alreadi': False,
#    'sell': False,
#    'mad': False,
#    'door': False,
#    'kiss': False,
#    'death': False,
#    'marissa': False,
#    'gtdk': False,
#    'nurs': False,
#    'class': False,
#    'practic': False,
#    'arm': False,
#    'bruis': False,
#    'bought': False,
#    'bunch': False,
#    'mandi': False,
#    'moor': False,
#    'forgot': False,
#    'product': False,
#    'descript': False,
#    'per': False,
#    'kestx': False,
#    'hip': False,
#    'hooray': False,
#    'begin': False,
#    'wonder': False,
#    'rosiege': False,
#    'lovee': False,
#    'heard': False,
#    'temptalia': False,
#    'nevermind': False,
#    'valid': False,
#    'thru': False,
#    'mistak': False,
#    'anxious': False,
#    'buy': False,
#    'artemi': False,
#    'neith': False,
#    'hon': False,
#    'muse': False,
#    'taunt': False,
#    'orbitaldiamond': False,
#    'count': False,
#    'bc': False,
#    'money': False,
#    'hollyhatesyou': False,
#    'asin': False,
#    'np': False,
#    'thanx': False,
#    'elisamarie': False,
#    'switchfoot': False,
#    'perform': False,
#    'cursedbyevil': False,
#    'hello': False,
#    'danger': False,
#    'stranger': False,
#    'went': False,
#    'acousticor': False,
#    'race': False,
#    'nd': False,
#    'birthday': False,
#    'parti': False,
#    'music': False,
#    'gallon': False,
#    'challeng': False,
#    'video': False,
#    'along': False,
#    'peopl': False,
#    'hurl': False,
#    'chibialfa': False,
#    'impress': False,
#    'slide': False,
#    'deck': False,
#    'nileylov': False,
#    'shes': False,
#    'hhahha': False,
#    'cri': False,
#    'emot': False,
#    'ayo': False,
#    'three': False,
#    'mafia': False,
#    'keri': False,
#    'hilson': False,
#    'gucci': False,
#    ...},
#   False),
#  ({'hack': False,
#    'found': False,
#    'perfect': False,
#    'job': False,
#    'relev': False,
#    'degre': False,
#    'deadlin': False,
#    'wa': False,
#    'week': False,
#    'ago': False,
#    'overslept': False,
#    'today': False,
#    'garbag': True,
#    'truck': True,
#    'tri': True,
#    'run': True,
#    'u': False,
#    'tell': False,
#    'doin': False,
#    'right': False,
#    'ill': False,
#    'follow': False,
#    'believ': False,
#    'ha': False,
#    'wait': False,
#    'till': False,
#    'octob': False,
#    'see': False,
#    'quot': False,
#    'american': False,
#    'get': False,
#    'weekend': False,
#    'wish': False,
#    'new': False,
#    'sim': False,
#    'wasnt': False,
#    'expens': False,
#    'realli': False,
#    'need': False,
#    'play': False,
#    'prep': False,
#    'audit': False,
#    'time': False,
#    'go': False,
#    'home': False,
#    'dinner': False,
#    'someon': False,
#    'veri': False,
#    'special': False,
#    'bonddiiiieee': False,
#    'gooooo': False,
#    'stephda': False,
#    'bonestodust': False,
#    'yo': False,
#    'dude': False,
#    'feel': False,
#    'lone': False,
#    'hous': False,
#    'leav': False,
#    'group': False,
#    'love': False,
#    'fellowship': False,
#    'laptop': False,
#    'yahoooo': False,
#    'handshak': False,
#    'know': False,
#    'cassandra': False,
#    'physic': False,
#    'comput': False,
#    'hang': False,
#    'girl': False,
#    'guy': False,
#    'jessicahaley': False,
#    'trey': False,
#    'cinespac': False,
#    'rt': False,
#    'bbgirl': False,
#    'whi': False,
#    'tomorrrrrrooww': False,
#    'caus': False,
#    'like': False,
#    'dryforkpastor': False,
#    'hope': False,
#    'everyth': False,
#    'okay': False,
#    'oh': False,
#    'got': False,
#    'bye': False,
#    'twitter': False,
#    'tom': False,
#    'behind': False,
#    'mishab': False,
#    'heh': False,
#    'grab': False,
#    'could': False,
#    'probabl': False,
#    'becaus': False,
#    'fit': False,
#    'manschutz': False,
#    'yes': False,
#    'daniel': False,
#    'full': False,
#    'dual': False,
#    'refer': False,
#    'doubl': False,
#    'fulfil': False,
#    'post': False,
#    'note': False,
#    'backstreet': False,
#    'team': False,
#    'thank': False,
#    'blackbirdcorn': False,
#    'typewrit': False,
#    'action': False,
#    'limit': False,
#    'front': False,
#    'find': False,
#    'sew': False,
#    'machin': False,
#    'hard': False,
#    'rubbish': False,
#    'collect': False,
#    'tho': False,
#    'call': False,
#    'night': False,
#    'much': False,
#    'followfirday': False,
#    'best': False,
#    'tcot': False,
#    'unit': False,
#    'good': False,
#    'exhaust': False,
#    'though': False,
#    'ttunnel': False,
#    'thought': False,
#    'onli': False,
#    'two': False,
#    'charter': False,
#    'member': False,
#    'exclud': False,
#    'sad': False,
#    'absolut': False,
#    'hate': False,
#    'die': False,
#    'thirst': False,
#    'noooooo': False,
#    'juic': False,
#    'fridg': False,
#    'zeta': False,
#    'updat': False,
#    'hot': False,
#    'missyward': False,
#    'easi': False,
#    'cleveland': False,
#    'sport': False,
#    'fan': False,
#    'actual': False,
#    'piti': False,
#    'act': False,
#    'win': False,
#    'never': False,
#    'life': False,
#    'alway': False,
#    'biggest': False,
#    'mess': False,
#    'imagin': False,
#    'usual': False,
#    'doe': False,
#    'bad': False,
#    'shane': False,
#    'except': False,
#    'sorri': False,
#    'better': False,
#    'live': False,
#    'traffic': False,
#    'vacat': False,
#    'car': False,
#    'drive': False,
#    'crazi': False,
#    'german': False,
#    'agress': False,
#    'driver': False,
#    'miss': False,
#    'canada': False,
#    'kirstystil': False,
#    'come': False,
#    'lilgari': False,
#    'take': False,
#    'back': False,
#    'im': False,
#    'lost': False,
#    'lol': False,
#    'iphon': False,
#    'cool': False,
#    'app': False,
#    'expans': False,
#    'paid': False,
#    'euro': False,
#    'almost': False,
#    'canadian': False,
#    'shoulda': False,
#    'befor': False,
#    'still': False,
#    'give': False,
#    'away': False,
#    'ticket': False,
#    'foto': False,
#    'na': False,
#    'dan': False,
#    'sleeper': False,
#    'zula': False,
#    'friday': False,
#    'www': False,
#    'onesmallse': False,
#    'net': False,
#    'fall': False,
#    'eddi': False,
#    'pearl': False,
#    'jam': False,
#    'lt': False,
#    'old': False,
#    'myspac': False,
#    'com': False,
#    'zoe': False,
#    'suicid': False,
#    'wooooooo': False,
#    'looooov': False,
#    'concert': False,
#    'holi': False,
#    'shit': False,
#    'hour': False,
#    'ohar': False,
#    'shitti': False,
#    'internet': False,
#    'connect': False,
#    'world': False,
#    'didlik': False,
#    'monday': False,
#    'vibe': False,
#    'sexyjoy': False,
#    'hmm': False,
#    'gon': False,
#    'store': False,
#    'opend': False,
#    'bed': False,
#    'earli': False,
#    'prepar': False,
#    'day': False,
#    'write': False,
#    'paper': False,
#    'tomorrow': False,
#    'notoriousmsg': False,
#    'make': False,
#    'sure': False,
#    'shout': False,
#    'one': False,
#    'song': False,
#    'four': False,
#    'cinci': False,
#    'text': False,
#    'word': False,
#    'yay': False,
#    'sun': False,
#    'rehers': False,
#    'littl': False,
#    'sundayi': False,
#    'imageisfound': False,
#    'comment': False,
#    'dumbest': False,
#    'copi': False,
#    'ever': False,
#    'morn': False,
#    'laugh': False,
#    'close': False,
#    'truth': False,
#    'man': False,
#    'legend': False,
#    'druri': False,
#    'hotel': False,
#    'atlanta': False,
#    'head': False,
#    'va': False,
#    'last': False,
#    'via': False,
#    'addthi': False,
#    'spill': False,
#    'water': False,
#    'bottl': False,
#    'bookshelf': False,
#    'design': False,
#    'amp': False,
#    'italia': False,
#    'book': False,
#    'dri': False,
#    'jeswearsp': False,
#    'supercooltnicki': False,
#    'nope': False,
#    'piss': False,
#    'pant': False,
#    'lmao': False,
#    'suck': False,
#    'horribl': False,
#    'ugh': False,
#    'sick': False,
#    'wit': False,
#    'fever': False,
#    'check': False,
#    'blak': False,
#    'track': False,
#    'oramarecord': False,
#    'mortgag': False,
#    'yayyyyyi': False,
#    'dysarra': False,
#    'bitch': False,
#    'weight': False,
#    'surgeri': False,
#    'ear': False,
#    'disappoint': False,
#    'sleep': False,
#    'dgirlholland': False,
#    'first': False,
#    'year': False,
#    'line': False,
#    'stuff': False,
#    'might': False,
#    'well': False,
#    'tidi': False,
#    'room': False,
#    'sinc': False,
#    'alot': False,
#    'peep': False,
#    'bordersmedia': False,
#    'finish': False,
#    'read': False,
#    'chipkidd': False,
#    'chees': False,
#    'monkey': False,
#    'ellenlupton': False,
#    'think': False,
#    'type': False,
#    'ahaha': False,
#    'exam': False,
#    'left': False,
#    'bludgi': False,
#    'ipod': False,
#    'le': False,
#    'commut': False,
#    'interest': False,
#    'cristiano': False,
#    'deathdud': False,
#    'killingd': False,
#    'sara': False,
#    'sound': False,
#    'chillin': False,
#    'mommi': False,
#    'spring': False,
#    'terribl': False,
#    'jealous': False,
#    'besti': False,
#    'move': False,
#    'cali': False,
#    'boyfriend': False,
#    'sunshin': False,
#    'kathryn': False,
#    'mcfli': False,
#    'yeah': False,
#    'addict': False,
#    'relationship': False,
#    'yellow': False,
#    'colour': False,
#    'support': False,
#    'demil': False,
#    'hey': False,
#    'officialnjona': False,
#    'ihat': False,
#    'jalapeno': False,
#    'green': False,
#    'chicken': False,
#    'soup': False,
#    'mmmm': False,
#    'crawl': False,
#    'billion': False,
#    'carlsalazar': False,
#    'neither': False,
#    'way': False,
#    'start': False,
#    'mine': False,
#    'simplowdfan': False,
#    'sam': False,
#    'jon': False,
#    'prescott': False,
#    'ex': False,
#    'mike': False,
#    'want': False,
#    'ignor': False,
#    'studio': False,
#    'cours': False,
#    'rappin': False,
#    'present': False,
#    'gnuchri': False,
#    'damondcclark': False,
#    'eww': False,
#    'grit': False,
#    'eat': False,
#    'lot': False,
#    'frijol': False,
#    'jessidavi': False,
#    'work': False,
#    'mr': False,
#    'hows': False,
#    'ya': False,
#    'land': False,
#    'nellagirl': False,
#    'great': False,
#    'mind': False,
#    'alik': False,
#    'eh': False,
#    'cheth': False,
#    'problem': False,
#    'cant': False,
#    'pic': False,
#    'upload': False,
#    'downtown': False,
#    'mpls': False,
#    'chang': False,
#    'dushbag': False,
#    'total': False,
#    'orlando': False,
#    'long': False,
#    'forget': False,
#    'buzzedit': False,
#    'made': False,
#    'taylor': False,
#    'fansit': False,
#    'sort': False,
#    'lame': False,
#    'taylovelov': False,
#    'wont': False,
#    'let': False,
#    'profil': False,
#    'awak': False,
#    'restless': False,
#    'grayson': False,
#    'mariahmancha': False,
#    'say': False,
#    'groceri': False,
#    'mom': False,
#    'irl': False,
#    'school': False,
#    'kraftykoala': False,
#    'cut': False,
#    'bit': False,
#    'thin': False,
#    'xx': False,
#    'meerasapra': False,
#    'even': False,
#    'nice': False,
#    'dp': False,
#    'delta': False,
#    'angel': False,
#    'noe': False,
#    'next': False,
#    'shall': False,
#    'awesom': False,
#    'movi': False,
#    'bord': False,
#    'lovejamieo': False,
# ...
#    'canada': False,
#    'kirstystil': False,
#    'come': False,
#    'lilgari': False,
#    'take': False,
#    'back': False,
#    'im': False,
#    'lost': False,
#    'lol': False,
#    'iphon': False,
#    'cool': False,
#    'app': False,
#    'expans': False,
#    'paid': False,
#    'euro': False,
#    'almost': False,
#    'canadian': False,
#    'shoulda': False,
#    'befor': False,
#    'still': False,
#    'give': False,
#    'away': False,
#    'ticket': False,
#    'foto': False,
#    'na': False,
#    'dan': False,
#    'sleeper': False,
#    'zula': False,
#    'friday': False,
#    'www': False,
#    'onesmallse': False,
#    'net': False,
#    'fall': False,
#    'eddi': False,
#    'pearl': False,
#    'jam': False,
#    'lt': False,
#    'old': False,
#    'myspac': False,
#    'com': False,
#    'zoe': False,
#    'suicid': False,
#    'wooooooo': False,
#    'looooov': False,
#    'concert': False,
#    'holi': False,
#    'shit': False,
#    'hour': False,
#    'ohar': False,
#    'shitti': False,
#    'internet': False,
#    'connect': False,
#    'world': False,
#    'didlik': False,
#    'monday': False,
#    'vibe': False,
#    'sexyjoy': False,
#    'hmm': False,
#    'gon': False,
#    'store': False,
#    'opend': False,
#    'bed': False,
#    'earli': False,
#    'prepar': False,
#    'day': False,
#    'write': False,
#    'paper': False,
#    'tomorrow': False,
#    'notoriousmsg': False,
#    'make': False,
#    'sure': False,
#    'shout': False,
#    'one': False,
#    'song': False,
#    'four': False,
#    'cinci': False,
#    'text': False,
#    'word': False,
#    'yay': False,
#    'sun': False,
#    'rehers': False,
#    'littl': False,
#    'sundayi': False,
#    'imageisfound': False,
#    'comment': False,
#    'dumbest': False,
#    'copi': False,
#    'ever': False,
#    'morn': False,
#    'laugh': False,
#    'close': False,
#    'truth': False,
#    'man': False,
#    'legend': False,
#    'druri': False,
#    'hotel': False,
#    'atlanta': False,
#    'head': False,
#    'va': False,
#    'last': False,
#    'via': False,
#    'addthi': False,
#    'spill': False,
#    'water': False,
#    'bottl': False,
#    'bookshelf': False,
#    'design': False,
#    'amp': False,
#    'italia': False,
#    'book': False,
#    'dri': False,
#    'jeswearsp': False,
#    'supercooltnicki': False,
#    'nope': False,
#    'piss': False,
#    'pant': False,
#    'lmao': False,
#    'suck': False,
#    'horribl': False,
#    'ugh': False,
#    'sick': False,
#    'wit': False,
#    'fever': False,
#    'check': False,
#    'blak': False,
#    'track': False,
#    'oramarecord': False,
#    'mortgag': False,
#    'yayyyyyi': False,
#    'dysarra': False,
#    'bitch': False,
#    'weight': False,
#    'surgeri': False,
#    'ear': False,
#    'disappoint': False,
#    'sleep': False,
#    'dgirlholland': False,
#    'first': False,
#    'year': False,
#    'line': False,
#    'stuff': False,
#    'might': False,
#    'well': False,
#    'tidi': False,
#    'room': False,
#    'sinc': False,
#    'alot': False,
#    'peep': False,
#    'bordersmedia': False,
#    'finish': False,
#    'read': False,
#    'chipkidd': False,
#    'chees': False,
#    'monkey': False,
#    'ellenlupton': False,
#    'think': False,
#    'type': False,
#    'ahaha': False,
#    'exam': False,
#    'left': False,
#    'bludgi': False,
#    'ipod': False,
#    'le': False,
#    'commut': False,
#    'interest': False,
#    'cristiano': False,
#    'deathdud': False,
#    'killingd': False,
#    'sara': False,
#    'sound': False,
#    'chillin': False,
#    'mommi': False,
#    'spring': False,
#    'terribl': False,
#    'jealous': False,
#    'besti': False,
#    'move': False,
#    'cali': False,
#    'boyfriend': False,
#    'sunshin': False,
#    'kathryn': False,
#    'mcfli': False,
#    'yeah': False,
#    'addict': False,
#    'relationship': False,
#    'yellow': False,
#    'colour': False,
#    'support': False,
#    'demil': False,
#    'hey': False,
#    'officialnjona': False,
#    'ihat': False,
#    'jalapeno': False,
#    'green': False,
#    'chicken': False,
#    'soup': False,
#    'mmmm': False,
#    'crawl': False,
#    'billion': False,
#    'carlsalazar': False,
#    'neither': False,
#    'way': False,
#    'start': False,
#    'mine': False,
#    'simplowdfan': False,
#    'sam': False,
#    'jon': False,
#    'prescott': False,
#    'ex': False,
#    'mike': False,
#    'want': False,
#    'ignor': False,
#    'studio': False,
#    'cours': False,
#    'rappin': False,
#    'present': False,
#    'gnuchri': False,
#    'damondcclark': False,
#    'eww': False,
#    'grit': False,
#    'eat': False,
#    'lot': False,
#    'frijol': False,
#    'jessidavi': False,
#    'work': False,
#    'mr': False,
#    'hows': False,
#    'ya': False,
#    'land': False,
#    'nellagirl': False,
#    'great': False,
#    'mind': False,
#    'alik': False,
#    'eh': False,
#    'cheth': False,
#    'problem': False,
#    'cant': False,
#    'pic': False,
#    'upload': False,
#    'downtown': False,
#    'mpls': False,
#    'chang': False,
#    'dushbag': False,
#    'total': False,
#    'orlando': False,
#    'long': False,
#    'forget': False,
#    'buzzedit': False,
#    'made': False,
#    'taylor': False,
#    'fansit': False,
#    'sort': False,
#    'lame': False,
#    'taylovelov': False,
#    'wont': False,
#    'let': False,
#    'profil': False,
#    'awak': False,
#    'restless': False,
#    'grayson': False,
#    'mariahmancha': False,
#    'say': False,
#    'groceri': False,
#    'mom': False,
#    'irl': False,
#    'school': False,
#    'kraftykoala': False,
#    'cut': False,
#    'bit': False,
#    'thin': False,
#    'xx': False,
#    'meerasapra': False,
#    'even': False,
#    'nice': False,
#    'dp': False,
#    'delta': False,
#    'angel': False,
#    'noe': False,
#    'next': False,
#    'shall': False,
#    'awesom': False,
#    'movi': False,
#    'bord': False,
#    'lovejamieo': False,
#    'haha': False,
#    'celebr': False,
#    'besid': False,
#    'jona': False,
#    'bros': False,
#    'ick': False,
#    'l': False,
#    'babi': False,
#    'lay': False,
#    'cuddl': False,
#    'watch': False,
#    'selena': False,
#    'shot': False,
#    'part': False,
#    'understand': False,
#    'account': False,
#    'financi': False,
#    'askelf': False,
#    'order': False,
#    'readi': False,
#    'coupon': False,
#    'code': False,
#    'expir': False,
#    'unicorn': False,
#    'bebo': False,
#    'awpoordidi': False,
#    'true': False,
#    'hahh': False,
#    'eager': False,
#    'happili': False,
#    'keep': False,
#    'held': False,
#    'enjoy': False,
#    'moment': False,
#    'rockshow': False,
#    'angi': False,
#    'pangiee': False,
#    'x': False,
#    'swear': False,
#    'bos': False,
#    'breath': False,
#    'secret': False,
#    'hear': False,
#    'todisappear': False,
#    'allow': False,
#    'twitterfail': False,
#    'beauti': False,
#    'bride': False,
#    'st': False,
#    'wed': False,
#    'dress': False,
#    'levywed': False,
#    'slambooutchea': False,
#    'gokeyisadouch': False,
#    'trench': False,
#    'douch': False,
#    'w': False,
#    'e': False,
#    'crazeegeekchick': False,
#    'knew': False,
#    'reason': False,
#    'def': False,
#    'guess': False,
#    'lie': False,
#    'hospit': False,
#    'smoke': False,
#    'neighbour': False,
#    'happi': False,
#    'mother': False,
#    'mistagrimm': False,
#    'wow': False,
#    'look': False,
#    'final': False,
#    'surfac': False,
#    'evonlegend': False,
#    'omg': False,
#    'plea': False,
#    'jonaslov': False,
#    'nawww': False,
#    'aiight': False,
#    'tomoro': False,
#    'anyway': False,
#    'xoxo': False,
#    'goodnight': False,
#    'inhabit': False,
#    'mikasound': False,
#    'frog': False,
#    'madwif': False,
#    'awww': False,
#    'soon': False,
#    'daughter': False,
#    'luck': False,
#    'prayer': False,
#    'answer': False,
#    'ask': False,
#    'friend': False,
#    'overwhelm': False,
#    'bless': False,
#    'happen': False,
#    'er': False,
#    'heidi': False,
#    'major': False,
#    'road': False,
#    'rash': False,
#    'possibl': False,
#    'shoulder': False,
#    'injuri': False,
#    'poor': False,
#    'mdlstudio': False,
#    'wordspray': False,
#    'aloha': False,
#    'alohahard': False,
#    'neilhimself': False,
#    'ani': False,
#    'burn': False,
#    'must': False,
#    'replac': False,
#    'sale': False,
#    'elecgeek': False,
#    'cherinj': False,
#    'hi': False,
#    'fun': False,
#    'jb': False,
#    'show': False,
#    'knight': False,
#    'thing': False,
#    'men': False,
#    'gene': False,
#    'simmon': False,
#    'urin': False,
#    'cake': False,
#    'talk': False,
#    'wet': False,
#    'melomayn': False,
#    'mannnnnn': False,
#    'steal': False,
#    'nadi': False,
#    'noflea': False,
#    'mention': False,
#    'srestal': False,
#    'thepet': False,
#    'fuckit': False,
#    'outsid': False,
#    'saragthatsm': False,
#    'trend': False,
#    'setter': False,
#    'registr': False,
#    'quiet': False,
#    'organ': False,
#    'backpack': False,
#    'shirt': False,
#    'badg': False,
#    'ngc': False,
#    'end': False,
#    'continu': False,
#    'idea': False,
#    'cancel': False,
#    'success': False,
#    'shcow': False,
#    'accid': False,
#    'era': False,
#    'jemappellebrttl': False,
#    'bruce': False,
#    'youuuu': False,
#    'thecashman': False,
#    'ah': False,
#    'meant': False,
#    'social': False,
#    'sunday': False,
#    'stay': False,
#    'radio': False,
#    'amaz': False,
#    'yesterday': False,
#    'purs': False,
#    'ahhhhh': False,
#    'erica': False,
#    'pegasusangel': False,
#    'courteen': False,
#    'noww': False,
#    'dockland': False,
#    'darllin': False,
#    'gatorad': False,
#    'g': False,
#    'commerci': False,
#    'simpl': False,
#    'energet': False,
#    'agenc': False,
#    'cater': False,
#    'client': False,
#    'medgirl': False,
#    'stephlovee': False,
#    'grate': False,
#    'hiccuupppss': False,
#    'missmari': False,
#    'jonasfanjad': False,
#    'cheer': False,
#    'paig': False,
#    'stickam': False,
#    'would': False,
#    'danielcaguin': False,
#    'asian': False,
#    'tiuri': False,
#    'repli': False,
#    'gott': False,
#    'sei': False,
#    'dank': False,
#    'aber': False,
#    'premuto': False,
#    'ist': False,
#    'gut': False,
#    'und': False,
#    'dawn': False,
#    'dead': False,
#    'ultim': False,
#    'aaand': False,
#    'folk': False,
#    'put': False,
#    'person': False,
#    'tv': False,
#    'gosselin': False,
#    'kid': False,
#    'credit': False,
#    'card': False,
#    'mean': False,
#    'saturday': False,
#    'due': False,
#    'cash': False,
#    'moneyyy': False,
#    'crash': False,
#    'afford': False,
#    'may': False,
#    'turn': False,
#    'hook': False,
#    'flow': False,
#    'anyth': False,
#    'worth': False,
#    'share': False,
#    'use': False,
#    'cpl': False,
#    'white': False,
#    'castl': False,
#    'burger': False,
#    'depress': False,
#    'celtic': False,
#    'whatttt': False,
#    'careeeeeee': False,
#    'ur': False,
#    'god': False,
#    'judg': False,
#    'pa': False,
#    'extremist': False,
#    'fang': False,
#    'pas': False,
#    'resolut': False,
#    'ban': False,
#    'sister': False,
#    'islam': False,
#    'humblemonst': False,
#    'ow': False,
#    'saad': False,
#    'caseyb': False,
#    'aw': False,
#    'wan': False,
#    'hooom': False,
#    'rain': False,
#    'nonsens': False,
#    'mood': False,
#    'shift': False,
#    'hole': False,
#    'fuck': False,
#    'lucki': False,
#    'hed': False,
#    'stuck': False,
#    'ugli': False,
#    'kill': False,
#    'suffer': False,
#    'regent': False,
#    'test': False,
#    'thursday': False,
#    'dont': False,
#    'amen': False,
#    'lolz': False,
#    'bbrathwait': False,
#    'season': False,
#    'offlin': False,
#    'five': False,
#    'episod': False,
#    'stop': False,
#    'complet': False,
#    'jonesin': False,
#    'sugarhustl': False,
#    'hehe': False,
#    'funni': False,
#    'epic': False,
#    'discoveri': False,
#    'channel': False,
#    'hella': False,
#    'record': False,
#    'lifeinthegalaxi': False,
#    'smile': False,
#    'face': False,
#    'send': False,
#    'light': False,
#    'wrong': False,
#    'quit': False,
#    'short': False,
#    'kosherwineguy': False,
#    'stupid': False,
#    'took': False,
#    'month': False,
#    'figur': False,
#    'without': False,
#    'intellig': False,
#    'sometim': False,
#    'judgment': False,
#    'isla': False,
#    'potipot': False,
#    'stylist': False,
#    'rememb': False,
#    'nick': False,
#    'name': False,
#    'sing': False,
#    'cold': False,
#    'outsiddeee': False,
#    'shell': False,
#    'shock': False,
#    'news': False,
#    'prof': False,
#    'rajeev': False,
#    'motwani': False,
#    'demis': False,
#    'mentor': False,
#    'pdwhite': False,
#    'alright': False,
#    'tire': False,
#    'voic': False,
#    'boy': False,
#    'hardcor': False,
#    'shoot': False,
#    'lidiaanain': False,
#    'visit': False,
#    'whynava': False,
#    'definit': False,
#    'eatslow': False,
#    'convo': False,
#    'privat': False,
#    'download': False,
#    'serious': False,
#    'summer': False,
#    'pool': False,
#    'listen': False,
#    'sip': False,
#    'cocktail': False,
#    'jordanknight': False,
#    'done': False,
#    'b': False,
#    'dancin': False,
#    'esp': False,
#    'nkotb': False,
#    'danc': False,
#    'hit': False,
#    'juli': False,
#    'recommend': False,
#    'hollywood': False,
#    'tweep': False,
#    'ticklemejoey': False,
#    'paul': False,
#    'paint': False,
#    'kitankhamun': False,
#    'unfortun': False,
#    'bookmarklet': False,
#    'anyon': False,
#    'trick': False,
#    'asleep': False,
#    'goddamnit': False,
#    'jack': False,
#    'bauer': False,
#    'photograph': False,
#    'famili': False,
#    'photo': False,
#    'clean': False,
#    'pretti': False,
#    'unusu': False,
#    'pressur': False,
#    'jesus': False,
#    'moon': False,
#    'goldieaz': False,
#    'chilli': False,
#    'ginthegin': False,
#    'past': False,
#    'minut': False,
#    'suppos': False,
#    'french': False,
#    'ballet': False,
#    'ieatx': False,
#    'repeat': False,
#    'garden': False,
#    'later': False,
#    'afternoon': False,
#    'paintboy': False,
#    'carwash': False,
#    'oil': False,
#    'kinda': False,
#    'ta': False,
#    'mariahjb': False,
#    'drink': False,
#    'drunk': False,
#    'cell': False,
#    'somet': False,
#    'el': False,
#    'stomach': False,
#    'sweetkellen': False,
#    'someth': False,
#    'research': False,
#    'dissert': False,
#    'least': False,
#    'disappear': False,
#    'shop': False,
#    'fakenico': False,
#    'samesi': False,
#    'fake': False,
#    'celeb': False,
#    'ftl': False,
#    'especi': False,
#    'seth': False,
#    'rogen': False,
#    'grr': False,
#    'everyon': False,
#    'lazi': False,
#    'asrisjon': False,
#    'tweeti': False,
#    'daivrawk': False,
#    'ubertwitt': False,
#    'rawk': False,
#    'companywoman': False,
#    'wooo': False,
#    'despit': False,
#    'frustrat': False,
#    'charger': False,
#    'ebay': False,
#    'charg': False,
#    'network': False,
#    'site': False,
#    'pay': False,
#    'dcpincus': False,
#    'laker': False,
#    'vacuum': False,
#    'ellen': False,
#    'rebeccaclair': False,
#    'alreadi': False,
#    'sell': False,
#    'mad': False,
#    'door': False,
#    'kiss': False,
#    'death': False,
#    'marissa': False,
#    'gtdk': False,
#    'nurs': False,
#    'class': False,
#    'practic': False,
#    'arm': False,
#    'bruis': False,
#    'bought': False,
#    'bunch': False,
#    'mandi': False,
#    'moor': False,
#    'forgot': False,
#    'product': False,
#    'descript': False,
#    'per': False,
#    'kestx': False,
#    'hip': False,
#    'hooray': False,
#    'begin': False,
#    'wonder': False,
#    'rosiege': False,
#    'lovee': False,
#    'heard': False,
#    'temptalia': False,
#    'nevermind': False,
#    'valid': False,
#    'thru': False,
#    'mistak': False,
#    'anxious': False,
#    'buy': False,
#    'artemi': False,
#    'neith': False,
#    'hon': False,
#    'muse': False,
#    'taunt': False,
#    'orbitaldiamond': False,
#    'count': False,
#    'bc': False,
#    'money': False,
#    'hollyhatesyou': False,
#    'asin': False,
#    'np': False,
#    'thanx': False,
#    'elisamarie': False,
#    'switchfoot': False,
#    'perform': False,
#    'cursedbyevil': False,
#    'hello': False,
#    'danger': False,
#    'stranger': False,
#    'went': False,
#    'acousticor': False,
#    'race': False,
#    'nd': False,
#    'birthday': False,
#    'parti': False,
#    'music': False,
#    'gallon': False,
#    'challeng': False,
#    'video': False,
#    'along': False,
#    'peopl': False,
#    'hurl': False,
#    'chibialfa': False,
#    'impress': False,
#    'slide': False,
#    'deck': False,
#    'nileylov': False,
#    'shes': False,
#    'hhahha': False,
#    'cri': False,
#    'emot': False,
#    'ayo': False,
#    'three': False,
#    'mafia': False,
#    'keri': False,
#    'hilson': False,
#    'gucci': False,
#    ...},
#   False)]

# %%
data['target'].value_counts()
# Out:
# 4    10008
# 0     9992
# Name: target, dtype: int64

# %% [markdown]
# ## Model Training

# %%
training, test = train_test_split(featuresets, test_size=0.2)

# %%
classifier = nltk.NaiveBayesClassifier.train(training)

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#             followfriday = True             True : False  =     16.7 : 1.0
#                  horribl = True            False : True   =     16.6 : 1.0
#                      sad = True            False : True   =     15.2 : 1.0
#                    fever = True            False : True   =     13.9 : 1.0
#                   welcom = True             True : False  =     13.4 : 1.0
#                   broken = True            False : True   =     12.8 : 1.0
#                     kill = True            False : True   =     11.6 : 1.0
#                  headach = True            False : True   =     10.8 : 1.0
#                recommend = True             True : False  =     10.2 : 1.0
#                    worst = True            False : True   =     10.0 : 1.0

# %% [markdown]
# ## Model Evaluation

# %%
print("Classifier accuracy percent:",(nltk.classify.accuracy(classifier, test))*100.00)
# Out:
# Classifier accuracy percent: 72.85000000000001

# %% [markdown]
# ## Prediction
